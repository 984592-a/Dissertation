# %% [markdown]
# ### To note: Running this on different systems (i.e. local, SCW, server) will result in slight changes needing to the code

# %%
# Load libraries
import os
import numpy as np
import torch
import sys
import torchvision
import torchvision.transforms as T
import torchvision.models as models
from PIL import Image
from PIL import ImageEnhance
import matplotlib.pyplot as plt
import imagesize
import subprocess
sys.path
from IPython.core.debugger import set_trace
import scipy.ndimage
import matplotlib.patches as patches
# plt.rcParams['figure.figsize'] = [12,12]
# sys.path.append('/workspace/myFile/Mask_RCNN_Tutorial/')
from tqdm import tqdm
from torch import nn as nn
from torch import optim as optim
from torch.optim import lr_scheduler
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
import re
import time
import copy
import pylab
from torch.utils.tensorboard import SummaryWriter
from tempfile import TemporaryDirectory
import torch.backends.cudnn as cudnn
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import seaborn as sn
import pandas as pd
import glob
# Rather than have a messy notebook with a load of functions we can store them in separate .py files and import them

cudnn.benchmark = True
plt.ion()   # interactive mode
# Out:
# /opt/conda/lib/python3.8/site-packages/scipy/__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
# %load_ext tensorboard
writer = SummaryWriter("Experiments/TENSORBOARD")    # This determines the tensorboard file name

# %%
class DNADataset(object):
    def __init__(self, root, transforms, labels, imDx = False):
        self.root, self.transforms, self.labels = root, transforms, labels
    
        # load all image files, sorting them to ensure they are aligned
        self.imgDir = glob.glob(root+"*/*.tiff")
        Damagednuclei= [x for x in self.imgDir if 'Damaged_nuclei_' in x]
        Undamagednuclei= [x for x in self.imgDir if "No_damage_nuclei" in x]
        #np.random.shuffle(Undamagednuclei)
        #Undamagednuclei=Undamagednuclei[:10000]
        self.imgDir= Damagednuclei+Undamagednuclei
        size80=[]
        for x in self.imgDir:
            img = Image.open(x) # Open image
            w,h=img.size
            if w<=80 and h<=80:
                size80.append(x)
        self.imgDir=size80              
        
        self.imgs = sorted(self.imgDir) # list of images

        

        
    def __getitem__(self, idx):
        img_path = self.imgs[idx]
       
        # Transform images into tensors
        img = Image.open(img_path) # Open image
        w,h=img.size
        img = np.array(img) # Convert image into an array
        img = np.float32(np.divide(img, 2**16)) # Ensure all values are floats
        
        result=np.zeros((80,80), dtype=np.float32)
        x_center = (80 - w) // 2
        y_center = (80 - h) // 2 # copy img image into center of result image
        result[y_center:y_center+h, x_center:x_center+w] = img
        img = result
        
        targetlab=""
        if img_path.find('No_damage_nuclei') != -1:
            targetlab= 'Undamaged'
        if img_path.find('Damaged_nuclei_') != -1:
            targetlab= 'Damaged'  # Find labels corresponding to image
        target = self.labels.index(targetlab) # Get the label and assign to a value
        
        # Convert label to tensor
        #torch.to
        
        if self.transforms is not None:
            img = self.transforms(img)
#             #print('In the transforms')
        imNo = idx
        return img, target, imNo
        
    def __len__(self):
        return len(self.imgs)

# %%
root="/workspace/myFile/Output/17052023/"
p= glob.glob(root+"*/*.tiff")
Damagednuclei= [x for x in p if 'Damaged_nuclei_' in x]
Undamagednuclei= [x for x in p if "No_damage_nuclei" in x]
#np.random.shuffle(Undamagednuclei)
#Undamagednuclei=Undamagednuclei[:10000]
#Undamagednuclei

# %%
imDr = "/workspace/myFile/Output/17052023/"  # Image patches directory

labels = ['Damaged', 'Undamaged']  # Your labels

# %%
# For data augmentation
def get_transform(train):
    transforms = []

    transforms.append(T.ToTensor())
    #transforms.append(T.Normalize([0.0019368887995516483], [0.00672996630111016]))
    #transforms.append(T.RandomHorizontalFlip(0.5))
    
    if train:
        transforms.append(T.RandomHorizontalFlip(p=1))
        transforms.append(T.RandomVerticalFlip(p=1))
    
    return T.Compose(transforms)

# %%
def train_model(model, criterion, optimizer, scheduler, train, test, num_epochs=25):
    since = time.time()
    # Create a temporary directory to save training checkpoints
    with TemporaryDirectory() as tempdir:
        best_model_params_path = os.path.join(tempdir, 'best_model_params.pt')

        torch.save(model.state_dict(), best_model_params_path)
        best_acc = 0.0
        
        for epoch in range(num_epochs):
            print(f'Epoch {epoch}/{num_epochs - 1}')
            print('-' * 10)
            dataset_train = torch.utils.data.Subset(dataSetTrain, train[epoch])
            dataset_test = torch.utils.data.Subset(dataSetTest, test[epoch])
            data_loader_train = torch.utils.data.DataLoader(
                dataset_train, batch_size=128, shuffle=True, num_workers=0)

            data_loader_test = torch.utils.data.DataLoader(
                dataset_test, batch_size=128, shuffle=False, num_workers=0)
            # Each epoch has a training and validation phase
            for phase in ['train', 'val']:
                if phase == 'train':
                    model.train()  # Set model to training mode
                    dataloaders = data_loader_train
                else:
                    model.eval()   # Set model to evaluate mode
                    dataloaders = data_loader_test

                running_loss = 0.0
                running_corrects = 0
                damaged_len=0
                damaged_corrects = 0
                undamaged_len=0
                undamaged_corrects = 0

                # Iterate over data.
                for inputs, labels, imNo in dataloaders:
                    inputs = inputs.to(device)
                    labels = labels.to(device)

                    # zero the parameter gradients
                    optimizer.zero_grad()

                    # forward
                    # track history if only in train
                    with torch.set_grad_enabled(phase == 'train'):
                        outputs = model(inputs)
                        _, preds = torch.max(outputs, 1)
                        loss = criterion(outputs, labels)
                        # backward + optimize only if in training phase
                        if phase == 'train':
                            loss.backward()
                            optimizer.step()

                    # statistics
                    running_loss += loss.item() * inputs.size(0)    # Loss
                    nada=torch.tensor(np.zeros(len(labels))).to(device)
                    uno=nada+1
                    falseneg=preds+1
                    falsepos=preds-1
                    FPplusTN=torch.sum(labels==nada)
                    TPplusFN=torch.sum(labels==uno)
                    FN=torch.sum(labels==falseneg)
                    FP=torch.sum(labels==falsepos)
                    TN=FPplusTN-FP
                    TP=TPplusFN-FN
                    running_corrects += torch.sum(preds == labels.data) # Accuracy
                    damaged_len+=TPplusFN
                    damaged_corrects += TP
                    undamaged_len+=FPplusTN
                    undamaged_corrects += TN
                damaged_acc = damaged_corrects / damaged_len
                undamaged_acc = undamaged_corrects/undamaged_len
                epoch_acc= (damaged_acc+undamaged_acc)/2
                
                if phase == 'train':
                    scheduler.step()

                epoch_loss = running_loss / dataset_sizes[phase]    # Loss metric per epoch
                #epoch_acc = running_corrects.double() / dataset_sizes[phase]    # Accuracy metric per epoch

                if phase == "train":    # This is the tensorboard code that writes accuracy and loss metrics
                    writer.add_scalar("Train/Accuracy", epoch_acc, epoch)
                    writer.add_scalar("Train/Loss", epoch_loss, epoch)
                else:
                    writer.add_scalar("Validation/Accuracy", epoch_acc, epoch)
                    writer.add_scalar("Validation/Loss", epoch_loss, epoch)

                print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

                # deep copy the model
                if phase == 'val' and epoch_acc >= best_acc: 
                    # This compares validation accuracy to previous bests and adjusts model weights accordingly
                    best_acc = epoch_acc
                    torch.save(model.state_dict(), best_model_params_path)
                    con_mat= torch.tensor([[damaged_corrects, damaged_len-damaged_corrects],[undamaged_len-undamaged_corrects,undamaged_corrects]])

            print()

        time_elapsed = time.time() - since  # Nice way to measure training time but info also stored (indirectly) by tensorboard
        print(
            f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
        print(f'Best val Acc: {best_acc:4f}')
        #labels= labels.cpu().numpy()
        #preds=preds.cpu().numpy()
        model.load_state_dict(torch.load(best_model_params_path))
    writer.close()
    return model, con_mat, best_acc   # We want to return the model because its the model, also confusion matrix for later analysis

# %%
# This is your RESNET
# Initialize CNN with kaiming
def init_cnn(m):
    # Set the weights of the RESNET
    if getattr(m, 'bias', None) is not None: nn.init.constant_(m.bias, 0)
    if isinstance(m, (nn.Conv2d,nn.Linear)): nn.init.kaiming_normal_(m.weight)
    for l in m.children(): init_cnn(l)


# noop function for returning nothing
def noop(x): return x
# activation function(RELU)
act_fn = nn.ReLU(inplace=True)

# Flatten
class Flatten(nn.Module):
    def forward(self, x): return x.view(x.size(0), -1)

# Make a convolution
def conv(ni, nf, ks=3, stride=1, bias=False):
    return nn.Conv2d(ni, nf, kernel_size=ks, stride=stride, padding=ks//2, bias=bias)

# Create a convuolutional layer with convolution and batch norm
def conv_layer(ni, nf, ks=3, stride=1, zero_bn=False, act=True):
    bn = nn.BatchNorm2d(nf) # get a 2d batch norm from Pytorhc
    nn.init.constant_(bn.weight, 0. if zero_bn else 1.)
    layers = [conv(ni, nf, ks, stride=stride), bn]
    if act: layers.append(act_fn) # add in the activation function if act is true
    return nn.Sequential(*layers)


# Resblock
class ResBlock(nn.Module):
    def __init__(self, expansion, ni, nh, stride = 1):
        super().__init__()
        # ni - number of inputs channels, nf - number of filters
        # nh - number of filters in first conv
        # expansion is 1 for resnet 18, 34 and 4 for larger networks
        nf, ni = nh*expansion, ni*expansion
        layers = [conv_layer(ni, nh, 3, stride = stride), # for resnet < 34 2 convs per resblock
                 conv_layer(nh, nf, 3, zero_bn = True, act = False)
                 ] if expansion == 1 else [ # for RESNET > 34 then 3 convs per block with bottleneck
                            conv_layer(ni, nh, 1),
                            conv_layer(nh, nh, 3, stride = stride),
                            conv_layer(nh, nf, 1, zero_bn = True, act = False)
        ]
        self.convs = nn.Sequential(*layers) # Creates the conv layers
        self.idconv = noop if ni==nf else conv_layer(ni, nf, 1, act = False) # id convolution ()
        self.pool = noop if stride== 1 else nn.AvgPool2d(2, ceil_mode = True) # average pool on 
        
    def forward(self, x): 
        # Forward function adds the convolution part to the id part 
        #return act_fn(self.convs(x)) + self.idconv(self.pool(x))
        return act_fn(self.convs(x) + self.idconv(self.pool(x)))

# XResnet
class XResNet(nn.Sequential):
    @classmethod
    def create(cls, expansion, layers, c_in=3, c_out=1000):
        nfs = [c_in, (c_in + 1)*8, 64, 64] # number of filters in stem layer (c_in is number of image channels)
        stem = [conv_layer(nfs[i], nfs[i+1], stride=2 if i==0 else 1)
            for i in range(3)]

        nfs = [64//expansion,64,128,256,512]
        res_layers = [cls._make_layer(expansion, nfs[i], nfs[i+1],
                                      n_blocks=l, stride=1 if i==0 else 2)
                  for i,l in enumerate(layers)]
        res = cls(
        *stem,
        nn.MaxPool2d(kernel_size=3, stride = 2, padding = 1), # then a max pooling layer
        *res_layers,
        nn.AdaptiveAvgPool2d(1), Flatten(), 
        nn.Linear(nfs[-1]*expansion, c_out)
        )
        init_cnn(res)
        return res
        
    @staticmethod
    def _make_layer(expansion, ni, nf, n_blocks, stride): # returns a resblock
        return nn.Sequential(
        *[ResBlock(expansion, ni if i==0 else nf, nf, stride if i==0 else 1)
         for i in range(n_blocks)])

# %%
def xresnet18 (**kwargs): return XResNet.create(1, [2, 2,  2, 2], **kwargs)
def xresnet34 (**kwargs): return XResNet.create(1, [3, 4,  6, 3], **kwargs)
def xresnet50 (**kwargs): return XResNet.create(4, [3, 4,  6, 3], **kwargs)
model18 = xresnet18(c_in = 1, c_out = 2)
model34 = xresnet34(c_in = 1, c_out = 2)
model50 = xresnet50(c_in = 1, c_out = 2)

# Label smoothing cross entropy
import torch.nn.functional as F


def reduce_loss(loss, reduction='mean'):
    return loss.mean() if reduction=='mean' else loss.sum() if reduction=='sum' else loss

class LabelSmoothingCrossEntropy(nn.Module):
    def __init__(self, ε:float=0.1, reduction='mean'):
        super().__init__()
        self.ε,self.reduction = ε,reduction
    
    def forward(self, output, target):
        c = output.size()[-1]
        log_preds = F.log_softmax(output, dim=-1)
        loss = reduce_loss(-log_preds.sum(dim=-1), self.reduction)
        nll = F.nll_loss(log_preds, target, reduction=self.reduction)
        return lin_comb(loss/c, nll, self.ε)

# %%
# Helper functions that shows the image, true class, predicted class and degree of prediction

def images_to_probs(net, images):
    '''
    Generates predictions and corresponding probabilities from a trained
    network and a list of images
    '''
    output = net(images)
    # convert output probabilities to predicted class
    _, preds_tensor = torch.max(output, 1)
    preds = np.squeeze(preds_tensor.numpy())
    return preds, [F.softmax(el, dim=0)[i].item() for i, el in zip(preds, output)]


def plot_classes_preds(net, images, labels):
    '''
    Generates matplotlib Figure using a trained network, along with images
    and labels from a batch, that shows the network's top prediction along
    with its probability, alongside the actual label, coloring this
    information based on whether the prediction was correct or not.
    Uses the "images_to_probs" function.
    '''
    preds, probs = images_to_probs(net, images)
    # plot the images in the batch, along with predicted and true labels
    fig = plt.figure(figsize=(12, 48))
    for idx in np.arange(4):
        ax = fig.add_subplot(1, 4, idx+1, xticks=[], yticks=[])
        matplotlib_imshow(images[idx], one_channel=True)
        ax.set_title("{0}, {1:.1f}%\n(label: {2})".format(
            labels[preds[idx]],
            probs[idx] * 100.0,
            labels[labels[idx]]),
                    color=("green" if preds[idx]==labels[idx].item() else "red"))
    return fig

def matplotlib_imshow(img, one_channel=True):
    if one_channel:
        img = img.mean(dim=0)
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    if one_channel:
        plt.imshow(npimg, cmap="Greys")
    else:
        plt.imshow(np.transpose(npimg, (1, 2, 0)))

# %%
def confusion_matrix_calc(data_loader_test, classes, model_ft):       
        y_pred = []
        y_true = []
        for inputs, labels, imNo in data_loader_test:
                inputs = inputs.to(device)
                labels = labels.to(device)
                output = model_ft(inputs) # Feed Network

                output = (torch.max(torch.exp(output), 1)[1]).data.cpu().numpy()
                y_pred.extend(output) # Save Prediction
                
                labels = labels.data.cpu().numpy()
                y_true.extend(labels) # Save Truth

        # constant for classes
        # classes = ('Alive', 'Dead')

        # Build confusion matrix
        cf_matrix = confusion_matrix(y_true, y_pred)
        return cf_matrix

# %%
k=5 #NUMBER OF K FOLDS
epoch=range(30) #NUMBER OF EPOCHS

torch.manual_seed(10)
imIdx = torch.randperm(1).tolist()

## Create dataset
dataSetTrain = DNADataset(imDr, get_transform(train = True), labels, imDx=imIdx)
dataSetTest = DNADataset(imDr, get_transform(train = False), labels, imDx=imIdx)

data_loader_train=[]
data_loader_test=[]

# ## Create dataloaders
# Get subset
torch.manual_seed(10)
TotalSetTrain=list(range(len(dataSetTrain)))
np.random.shuffle(TotalSetTrain)
TotalSetTest=list(range(len(dataSetTest)))
np.random.shuffle(TotalSetTest)

train=[]
test=[]
for epoch in epoch:
    
    Kfifth = len(dataSetTrain)//k
    split= epoch%k
    train.append(TotalSetTrain[(split+1)*Kfifth:]+TotalSetTrain[:Kfifth*split])
    test.append(TotalSetTest[split*Kfifth:(split+1)*Kfifth])

#dataset_train = torch.utils.data.Subset(dataSetTrain, indices[-noTrain:])

#dataset_test = torch.utils.data.Subset(dataSetTest, indices[:-noTrain])
#len(indices), len(indices[:-50]), len(indices[-50:]), 50/191, type(dataset_test)

dataset_sizes = {'train': len(train[0]), 'val': len(test[0])}

#dataset_train = torch.utils.data.Subset(dataSetTrain, train)
#data_loader_train.append(dataset_train)
#dataset_testo = torch.utils.data.Subset(dataSetTest, test)
#data_loader_test.append(dataset_testo)
# define training and validation data loaders


# Collate function (gathers together the outputs)
# def collate_fn(batch):
#     return tuple(zip(*batch))

#len(indices[-noTrain:]), dataset_sizes
#dataset_test[0][1], dataset_test[3][1], dataset_test[-1][1], dataSetTrain.imgs

# %%
class_weights= [0.924865,0.075135] #1-(#inclass/ #intotal )
class_weights = torch.Tensor(class_weights)
class_weights=class_weights.to(device)
criterion = nn.CrossEntropyLoss(weight = class_weights) 

# Observe that all parameters are being optimized
learning_rate=[0.05, 0.1,0.2]
Momentum=[0.5,0.9,0.99]
GAMMA=[0.05, 0.1, 0.5]
#Batch_size= [16,32]#,64,128]
models=[model18, model34, model50]
modelnames=["model18","model34","model50"]
#ADD IN A THING SO IT SAVES THE TENSORBOARD TO DIFFERENT BITS
best_params = None
best_score=0.00
Current_params=None
for lrnum in range(4):
    for gamnum in range(4):
        for Momnum in range(4):
            for modnum in range(3):
                model=models[modnum]
                model = model.to(device)
                optimizer_ft = optim.SGD(model.parameters(), lr=learning_rate[lrnum], momentum=Momentum[Momnum])
                exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=GAMMA[gamnum])
                writer = SummaryWriter("Experiments/TENSORBOARD/lr"+str(learning_rate[lrnum])+"momentum"+
                        str(Momentum[Momnum])+"gamma"+str(GAMMA[gamnum])+"model"+modelnames[modnum])  
                model_ft, con_mat, current_score = train_model(model, criterion, optimizer_ft, exp_lr_scheduler,
                   train,test,num_epochs=10)
                con_mat=con_mat.cpu().numpy()
                current_score=current_score.cpu().numpy()
                Current_params= {'learning rate': learning_rate[lrnum], 'gamma': GAMMA[gamnum], 
                                   'Momentum': Momentum[Momnum], 'Model': modelnames[modnum]}
                print(con_mat)
                print("Current hyperparameters:", Current_params)
                df_cm_ratio = pd.DataFrame(con_mat / np.sum(con_mat, axis=1)[:, None], index=[i for i in labels],
                                     columns=[i for i in labels])
                plt.figure(figsize=(12, 7))
                sn.heatmap(df_cm_ratio, annot=True)
                if current_score > best_score:
                    best_score = current_score
                    best_params = {'learning rate': learning_rate[lrnum], 'gamma': GAMMA[gamnum], 
                                   'Momentum': Momentum[Momnum], 'Model': modelnames[modnum]}
                            
print("Best hyperparameters:", best_params)
print("Best score:", best_score)
# Out:
# Epoch 0/9
# ----------
# train Loss: 0.5196 Acc: 0.7587
# val Loss: 0.7197 Acc: 0.6286
#
# Epoch 1/9
# ----------
# train Loss: 0.4475 Acc: 0.8047
# val Loss: 0.4741 Acc: 0.7772
#
# Epoch 2/9
# ----------
# train Loss: 0.4208 Acc: 0.8172
# val Loss: 0.4175 Acc: 0.8162
#
# Epoch 3/9
# ----------
# train Loss: 0.4053 Acc: 0.8234
# val Loss: 0.5375 Acc: 0.7615
#
# Epoch 4/9
# ----------
# train Loss: 0.3946 Acc: 0.8279
# val Loss: 0.7323 Acc: 0.6440
#
# Epoch 5/9
# ----------
# train Loss: 0.4054 Acc: 0.8205
# val Loss: 0.5026 Acc: 0.7864
#
# Epoch 6/9
# ----------
# train Loss: 0.3869 Acc: 0.8317
# val Loss: 0.9605 Acc: 0.6403
#
# Epoch 7/9
# ----------
# train Loss: 0.3526 Acc: 0.8504
# val Loss: 0.3521 Acc: 0.8499
#
# Epoch 8/9
# ----------
# train Loss: 0.3466 Acc: 0.8530
# val Loss: 0.4176 Acc: 0.8198
#
# Epoch 9/9
# ----------
# train Loss: 0.3407 Acc: 0.8548
# val Loss: 0.3755 Acc: 0.8381
#
# Training complete in 29m 20s
# Best val Acc: 0.849882
# [[20378  3930]
#  [  281  1747]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/9
# ----------
# train Loss: 0.5212 Acc: 0.7566
# val Loss: 0.6016 Acc: 0.7331
#
# Epoch 1/9
# ----------
# train Loss: 0.4489 Acc: 0.8002
# val Loss: 0.6077 Acc: 0.7328
#
# Epoch 2/9
# ----------
# train Loss: 0.4259 Acc: 0.8122
# val Loss: 0.5118 Acc: 0.7743
#
# Epoch 3/9
# ----------
# train Loss: 0.4079 Acc: 0.8191
# val Loss: 0.4289 Acc: 0.8074
#
# Epoch 4/9
# ----------
# train Loss: 0.3896 Acc: 0.8301
# val Loss: 1.4983 Acc: 0.5134
#
# Epoch 5/9
# ----------
# train Loss: 0.3973 Acc: 0.8261
# val Loss: 0.4044 Acc: 0.8265
#
# Epoch 6/9
# ----------
# train Loss: 0.3795 Acc: 0.8351
# val Loss: 0.6126 Acc: 0.7250
#
# Epoch 7/9
# ----------
# train Loss: 0.3473 Acc: 0.8506
# val Loss: 0.3561 Acc: 0.8496
#
# Epoch 8/9
# ----------
# train Loss: 0.3401 Acc: 0.8558
# val Loss: 0.3740 Acc: 0.8399
#
# Epoch 9/9
# ----------
# train Loss: 0.3364 Acc: 0.8570
# val Loss: 0.3550 Acc: 0.8460
#
# Training complete in 41m 30s
# Best val Acc: 0.849585
# [[19968  4340]
#  [  248  1780]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/9
# ----------
# train Loss: 0.6747 Acc: 0.7185
# val Loss: 0.9449 Acc: 0.6410
#
# Epoch 1/9
# ----------
# train Loss: 0.5027 Acc: 0.7902
# val Loss: 1.9708 Acc: 0.5324
#
# Epoch 2/9
# ----------
# train Loss: 0.4451 Acc: 0.8079
# val Loss: 0.5321 Acc: 0.7848
#
# Epoch 3/9
# ----------
# train Loss: 0.4167 Acc: 0.8192
# val Loss: 1.8445 Acc: 0.5164
#
# Epoch 4/9
# ----------
# train Loss: 0.4010 Acc: 0.8243
# val Loss: 0.4383 Acc: 0.8049
#
# Epoch 5/9
# ----------
# train Loss: 0.3947 Acc: 0.8318
# val Loss: 1.2052 Acc: 0.5039
#
# Epoch 6/9
# ----------
# train Loss: 0.3860 Acc: 0.8331
# val Loss: 0.5152 Acc: 0.7510
#
# Epoch 7/9
# ----------
# train Loss: 0.3538 Acc: 0.8488
# val Loss: 0.3586 Acc: 0.8478
#
# Epoch 8/9
# ----------
# train Loss: 0.3478 Acc: 0.8519
# val Loss: 0.3847 Acc: 0.8335
#
# Epoch 9/9
# ----------
# train Loss: 0.3447 Acc: 0.8529
# val Loss: 0.3815 Acc: 0.8422
#
# Training complete in 37m 1s
# Best val Acc: 0.847784
# [[21151  3157]
#  [  354  1674]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/9
# ----------
# train Loss: 0.4475 Acc: 0.8002
# val Loss: 1.2120 Acc: 0.6041
#
# Epoch 1/9
# ----------
# train Loss: 0.4079 Acc: 0.8199
# val Loss: 0.9905 Acc: 0.5582
#
# Epoch 2/9
# ----------
# train Loss: 0.4127 Acc: 0.8177
# val Loss: 0.3730 Acc: 0.8393
#
# Epoch 3/9
# ----------
# train Loss: 0.3844 Acc: 0.8316
# val Loss: 0.6973 Acc: 0.7037
#
# Epoch 4/9
# ----------
# train Loss: 0.3774 Acc: 0.8345
# val Loss: 0.6189 Acc: 0.6860
#
# Epoch 5/9
# ----------
# train Loss: 0.3901 Acc: 0.8306
# val Loss: 0.4304 Acc: 0.8059
#
# Epoch 6/9
# ----------
# train Loss: 0.3679 Acc: 0.8412
# val Loss: 0.3982 Acc: 0.8297
#
# Epoch 7/9
# ----------
# train Loss: 0.3362 Acc: 0.8567
# val Loss: 0.3440 Acc: 0.8557
#
# Epoch 8/9
# ----------
# train Loss: 0.3262 Acc: 0.8622
# val Loss: 0.3641 Acc: 0.8452
#
# Epoch 9/9
# ----------
# train Loss: 0.3212 Acc: 0.8639
# val Loss: 0.3465 Acc: 0.8505
#
# Training complete in 28m 38s
# Best val Acc: 0.855699
# [[20469  3839]
#  [  265  1763]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/9
# ----------
# train Loss: 0.4498 Acc: 0.7985
# val Loss: 0.7880 Acc: 0.6631
#
# Epoch 1/9
# ----------
# train Loss: 0.4050 Acc: 0.8241
# val Loss: 0.5730 Acc: 0.7234
#
# Epoch 2/9
# ----------
# train Loss: 0.3940 Acc: 0.8279
# val Loss: 0.6755 Acc: 0.7080
#
# Epoch 3/9
# ----------
# train Loss: 0.3805 Acc: 0.8332
# val Loss: 0.4134 Acc: 0.8112
#
# Epoch 4/9
# ----------
# train Loss: 0.3717 Acc: 0.8384
# val Loss: 0.3942 Acc: 0.8271
#
# Epoch 5/9
# ----------
# train Loss: 0.3676 Acc: 0.8422
# val Loss: 0.3927 Acc: 0.8202
#
# Epoch 6/9
# ----------
# train Loss: 0.3623 Acc: 0.8423
# val Loss: 0.4108 Acc: 0.8140
#
# Epoch 7/9
# ----------
# train Loss: 0.3308 Acc: 0.8590
# val Loss: 0.3429 Acc: 0.8569
#
# Epoch 8/9
# ----------
# train Loss: 0.3168 Acc: 0.8657
# val Loss: 0.3620 Acc: 0.8503
#
# Epoch 9/9
# ----------
# train Loss: 0.3117 Acc: 0.8682
# val Loss: 0.3565 Acc: 0.8478
#
# Training complete in 32m 2s
# Best val Acc: 0.856899
# [[20839  3469]
#  [  291  1737]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/9
# ----------
# train Loss: 0.4676 Acc: 0.7937
# val Loss: 1.7893 Acc: 0.5029
#
# Epoch 1/9
# ----------
# train Loss: 0.4181 Acc: 0.8127
# val Loss: 0.4392 Acc: 0.8115
#
# Epoch 2/9
# ----------
# train Loss: 0.3981 Acc: 0.8254
# val Loss: 0.3824 Acc: 0.8341
#
# Epoch 3/9
# ----------
# train Loss: 0.4058 Acc: 0.8206
# val Loss: 0.4173 Acc: 0.8196
#
# Epoch 4/9
# ----------
# train Loss: 0.3869 Acc: 0.8318
# val Loss: 1.0327 Acc: 0.5446
#
# Epoch 5/9
# ----------
# train Loss: 0.3781 Acc: 0.8359
# val Loss: 0.3852 Acc: 0.8264
#
# Epoch 6/9
# ----------
# train Loss: 0.3719 Acc: 0.8383
# val Loss: 0.3922 Acc: 0.8284
#
# Epoch 7/9
# ----------
# train Loss: 0.3403 Acc: 0.8542
# val Loss: 0.3570 Acc: 0.8485
#
# Epoch 8/9
# ----------
# train Loss: 0.3324 Acc: 0.8580
# val Loss: 0.3582 Acc: 0.8497
#
# Epoch 9/9
# ----------
# train Loss: 0.3252 Acc: 0.8626
# val Loss: 0.3547 Acc: 0.8510
#
# Training complete in 36m 54s
# Best val Acc: 0.850990
# [[19765  4642]
#  [  208  1721]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/9
# ----------
# train Loss: 0.4738 Acc: 0.7865
# val Loss: 0.4790 Acc: 0.7872
#
# Epoch 1/9
# ----------
# train Loss: 0.4485 Acc: 0.7996
# val Loss: 0.4414 Acc: 0.8000
#
# Epoch 2/9
# ----------
# train Loss: 0.4350 Acc: 0.8055
# val Loss: 0.4340 Acc: 0.7986
#
# Epoch 3/9
# ----------
# train Loss: 0.4160 Acc: 0.8157
# val Loss: 0.4260 Acc: 0.8115
#
# Epoch 4/9
# ----------
# train Loss: 0.4176 Acc: 0.8186
# val Loss: 0.4233 Acc: 0.8077
#
# Epoch 5/9
# ----------
# train Loss: 0.4142 Acc: 0.8167
# val Loss: 0.4564 Acc: 0.7894
#
# Epoch 6/9
# ----------
# train Loss: 0.4005 Acc: 0.8251
# val Loss: 0.3965 Acc: 0.8264
#
# Epoch 7/9
# ----------
# train Loss: 0.3720 Acc: 0.8388
# val Loss: 0.3886 Acc: 0.8296
#
# Epoch 8/9
# ----------
# train Loss: 0.3623 Acc: 0.8452
# val Loss: 0.3914 Acc: 0.8330
#
# Epoch 9/9
# ----------
# train Loss: 0.3571 Acc: 0.8453
# val Loss: 0.3633 Acc: 0.8504
#
# Training complete in 28m 43s
# Best val Acc: 0.850448
# [[20194  4213]
#  [  244  1685]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/9
# ----------
# train Loss: 0.4794 Acc: 0.7824
# val Loss: 0.8681 Acc: 0.6141
#
# Epoch 1/9
# ----------
# train Loss: 0.4489 Acc: 0.7997
# val Loss: 0.4320 Acc: 0.8025
#
# Epoch 2/9
# ----------
# train Loss: 0.4376 Acc: 0.8060
# val Loss: 0.4521 Acc: 0.7910
#
# Epoch 3/9
# ----------
# train Loss: 0.4220 Acc: 0.8130
# val Loss: 0.4445 Acc: 0.8098
#
# Epoch 4/9
# ----------
# train Loss: 0.4131 Acc: 0.8163
# val Loss: 0.4021 Acc: 0.8247
#
# Epoch 5/9
# ----------
# train Loss: 0.4118 Acc: 0.8187
# val Loss: 0.4264 Acc: 0.8089
#
# Epoch 6/9
# ----------
# train Loss: 0.4062 Acc: 0.8240
# val Loss: 0.5449 Acc: 0.7661
#
# Epoch 7/9
# ----------
# train Loss: 0.3750 Acc: 0.8361
# val Loss: 0.3992 Acc: 0.8261
#
# Epoch 8/9
# ----------
# train Loss: 0.3659 Acc: 0.8414
# val Loss: 0.3814 Acc: 0.8331
#
# Epoch 9/9
# ----------
# train Loss: 0.3602 Acc: 0.8444
# val Loss: 0.3621 Acc: 0.8445
#
# Training complete in 32m 5s
# Best val Acc: 0.844540
# [[21057  3350]
#  [  335  1594]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/9
# ----------
# train Loss: 0.4718 Acc: 0.7889
# val Loss: 0.4911 Acc: 0.7715
#
# Epoch 1/9
# ----------
# train Loss: 0.4467 Acc: 0.8013
# val Loss: 0.4655 Acc: 0.7788
#
# Epoch 2/9
# ----------
# train Loss: 0.4361 Acc: 0.8080
# val Loss: 0.4310 Acc: 0.8054
#
# Epoch 3/9
# ----------
# train Loss: 0.4141 Acc: 0.8173
# val Loss: 0.4247 Acc: 0.8091
#
# Epoch 4/9
# ----------
# train Loss: 0.4259 Acc: 0.8109
# val Loss: 0.4193 Acc: 0.7993
#
# Epoch 5/9
# ----------
# train Loss: 0.4204 Acc: 0.8159
# val Loss: 0.4334 Acc: 0.8065
#
# Epoch 6/9
# ----------
# train Loss: 0.4156 Acc: 0.8187
# val Loss: 0.4361 Acc: 0.7984
#
# Epoch 7/9
# ----------
# train Loss: 0.3822 Acc: 0.8310
# val Loss: 0.3853 Acc: 0.8360
#
# Epoch 8/9
# ----------
# train Loss: 0.3699 Acc: 0.8370
# val Loss: 0.4299 Acc: 0.8139
#
# Epoch 9/9
# ----------
# train Loss: 0.3667 Acc: 0.8395
# val Loss: 0.3783 Acc: 0.8385
#
# Training complete in 36m 43s
# Best val Acc: 0.838511
# [[19624  4783]
#  [  245  1684]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model50'}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_5115/3501996796.py in <module>
#      21                 model=models[modnum]
#      22                 model = model.to(device)
# ---> 23                 optimizer_ft = optim.SGD(model.parameters(), lr=learning_rate[lrnum], momentum=Momentum[Momnum])
#      24                 exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=GAMMA[gamnum])
#      25                 writer = SummaryWriter("Experiments/TENSORBOARD/lr"+str(learning_rate[lrnum])+"momentum"+
#
# IndexError: list index out of range

# %%
#cf_matrix = confusion_matrix_calc(data_loader_test, labels, model_ft)

# %%
# %tensorboard --logdir Experiments/TENSORBOARD
# Out:
#       <iframe id="tensorboard-frame-a33fa03a6468074e" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-a33fa03a6468074e");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
best_score
# Out:
# array(0.8568993, dtype=float32)

# %%
# %tensorboard dev upload --logdir \
    'Experiments/TENSORBOARD'
# Out:
# ERROR: Failed to launch TensorBoard (exited with 1).
# Contents of stderr:
# TensorFlow installation not found - running with reduced feature set.
#
# ***** TensorBoard Uploader *****
#
# This will upload your TensorBoard logs to https://tensorboard.dev/ from
# the following directory:
#
# Experiments/TENSORBOARD
#
# This TensorBoard will be visible to everyone. Do not upload sensitive
# data.
#
# Your use of this service is subject to Google's Terms of Service
# <https://policies.google.com/terms> and Privacy Policy
# <https://policies.google.com/privacy>, and TensorBoard.dev's Terms of Service
# <https://tensorboard.dev/policy/terms/>.
#
# This notice will not be shown again while you are logged into the uploader.
# To log out, run `tensorboard dev auth revoke`.
#
# Traceback (most recent call last):
#   File "/opt/conda/bin/tensorboard", line 8, in <module>
#     sys.exit(run_main())
#   File "/opt/conda/lib/python3.8/site-packages/tensorboard/main.py", line 46, in run_main
#     app.run(tensorboard.main, flags_parser=tensorboard.configure)
#   File "/opt/conda/lib/python3.8/site-packages/absl/app.py", line 312, in run
#     _run_main(main, args)
#   File "/opt/conda/lib/python3.8/site-packages/absl/app.py", line 258, in _run_main
#     sys.exit(main(argv))
#   File "/opt/conda/lib/python3.8/site-packages/tensorboard/program.py", line 276, in main
#     return runner(self.flags) or 0
#   File "/opt/conda/lib/python3.8/site-packages/tensorboard/uploader/uploader_subcommand.py", line 657, in run
#     return _run(flags, self._experiment_url_callback)
#   File "/opt/conda/lib/python3.8/site-packages/tensorboard/uploader/uploader_subcommand.py", line 94, in _run
#     _prompt_for_user_ack(intent)
#   File "/opt/conda/lib/python3.8/site-packages/tensorboard/uploader/uploader_subcommand.py", line 67, in _prompt_for_user_ack
#     response = input("Continue? (yes/NO) ")
# EOFError: EOF when reading a line
# Contents of stdout:
# Continue? (yes/NO)
