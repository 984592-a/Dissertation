# %% [markdown]
# ### To note: Running this on different systems (i.e. local, SCW, server) will result in slight changes needing to the code

# %%
# Load libraries
import os
import numpy as np
import torch
import sys
import torchvision
import torchvision.transforms as T
import torchvision.models as models
from PIL import Image
from PIL import ImageEnhance
import matplotlib.pyplot as plt
import imagesize
import subprocess
sys.path
from IPython.core.debugger import set_trace
import scipy.ndimage
import matplotlib.patches as patches
# plt.rcParams['figure.figsize'] = [12,12]
# sys.path.append('/workspace/myFile/Mask_RCNN_Tutorial/')
from tqdm import tqdm
from torch import nn as nn
from torch import optim as optim
from torch.optim import lr_scheduler
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
import re
import time
import copy
import pylab
from torch.utils.tensorboard import SummaryWriter
from tempfile import TemporaryDirectory
import torch.backends.cudnn as cudnn
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import seaborn as sn
import pandas as pd
import glob
# Rather than have a messy notebook with a load of functions we can store them in separate .py files and import them

cudnn.benchmark = True
plt.ion()   # interactive mode
# Out:
# /opt/conda/lib/python3.8/site-packages/scipy/__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
writer = SummaryWriter("Experiments/TENSORBOARD")    # This determines the tensorboard file name

# %%
class DNADataset(object):
    def __init__(self, root, transforms, labels, imDx = False):
        self.root, self.transforms, self.labels = root, transforms, labels
    
        # load all image files, sorting them to ensure they are aligned
        self.imgDir = glob.glob(root+"*/*.tiff")
        DamagedCyto= [x for x in paths if "damage_membrane_" in x]
        UndamagedCyto= [x for x in paths if "ok_membrane_" in x]
        np.random.shuffle(UndamagedCyto)
        UndamagedCyto=UndamagedCyto[:8900]
        self.imgDir= DamagedCyto+UndamagedCyto
        size350=[]
        for x in self.imgDir:
            img = Image.open(x) # Open image
            w,h=img.size
            if w<=350 and h<=350:
                size350.append(x)
        self.imgDir=size350              
        
        self.imgs = sorted(self.imgDir) # list of images

        

        
    def __getitem__(self, idx):
        img_path = self.imgs[idx]
       
        # Transform images into tensors
        img = Image.open(img_path) # Open image
        w,h=img.size
        img = np.array(img) # Convert image into an array
        img = np.float32(np.divide(img, 2**16)) # Ensure all values are floats
        
        result=np.zeros((350,350), dtype=np.float32)
        x_center = (350 - w) // 2
        y_center = (350 - h) // 2 # copy img image into center of result image
        result[y_center:y_center+h, x_center:x_center+w] = img
        img = result
        
        targetlab=""
        if img_path.find('ok_membrane_') != -1:
            targetlab= 'Undamaged'
        if img_path.find('damage_membrane_') != -1:
            targetlab= 'Damaged'  # Find labels corresponding to image
        target = self.labels.index(targetlab) # Get the label and assign to a value
        
        # Convert label to tensor
        #torch.to
        
        if self.transforms is not None:
            img = self.transforms(img)
#             #print('In the transforms')
        imNo = idx
        return img, target, imNo
        
    def __len__(self):
        return len(self.imgs)

# %%
root="/workspace/myFile/Output/17052023/"
paths= glob.glob(root+"*/*.tiff")
DamagedCyto= [x for x in paths if "damage_membrane_" in x]
UndamagedCyto= [x for x in paths if "ok_membrane_" in x]
np.random.shuffle(UndamagedCyto)
UndamagedCyto=UndamagedCyto[:10000]
UndamagedCyto
# Out:
# ['/workspace/myFile/Output/17052023/D1206/ok_membrane_5.tiff',
#  '/workspace/myFile/Output/17052023/B1104/ok_membrane_75.tiff',
#  '/workspace/myFile/Output/17052023/E1209/ok_membrane_73.tiff',
#  '/workspace/myFile/Output/17052023/E1108/ok_membrane_107.tiff',
#  '/workspace/myFile/Output/17052023/A1221/ok_membrane_103.tiff',
#  '/workspace/myFile/Output/17052023/A0518/ok_membrane_305.tiff',
#  '/workspace/myFile/Output/17052023/F0412/ok_membrane_14.tiff',
#  '/workspace/myFile/Output/17052023/B1121/ok_membrane_5.tiff',
#  '/workspace/myFile/Output/17052023/A0518/ok_membrane_173.tiff',
#  '/workspace/myFile/Output/17052023/F0517/ok_membrane_539.tiff',
#  '/workspace/myFile/Output/17052023/C1208/ok_membrane_65.tiff',
#  '/workspace/myFile/Output/17052023/A1118/ok_membrane_506.tiff',
#  '/workspace/myFile/Output/17052023/A0601/ok_membrane_74.tiff',
#  '/workspace/myFile/Output/17052023/A0624/ok_membrane_302.tiff',
#  '/workspace/myFile/Output/17052023/A0404/ok_membrane_70.tiff',
#  '/workspace/myFile/Output/17052023/B1001/ok_membrane_43.tiff',
#  '/workspace/myFile/Output/17052023/B0416/ok_membrane_2.tiff',
#  '/workspace/myFile/Output/17052023/C1209/ok_membrane_44.tiff',
#  '/workspace/myFile/Output/17052023/A1218/ok_membrane_366.tiff',
#  '/workspace/myFile/Output/17052023/A0510/ok_membrane_97.tiff',
#  '/workspace/myFile/Output/17052023/F0607/ok_membrane_250.tiff',
#  '/workspace/myFile/Output/17052023/A0413/ok_membrane_441.tiff',
#  '/workspace/myFile/Output/17052023/A1111/ok_membrane_65.tiff',
#  '/workspace/myFile/Output/17052023/A1118/ok_membrane_194.tiff',
#  '/workspace/myFile/Output/17052023/A1123/ok_membrane_97.tiff',
#  '/workspace/myFile/Output/17052023/E0411/ok_membrane_6.tiff',
#  '/workspace/myFile/Output/17052023/F1011/ok_membrane_13.tiff',
#  '/workspace/myFile/Output/17052023/F0625/ok_membrane_116.tiff',
#  '/workspace/myFile/Output/17052023/F1203/ok_membrane_30.tiff',
#  '/workspace/myFile/Output/17052023/A1209/ok_membrane_14.tiff',
#  '/workspace/myFile/Output/17052023/A1006/ok_membrane_8.tiff',
#  '/workspace/myFile/Output/17052023/A1215/ok_membrane_112.tiff',
#  '/workspace/myFile/Output/17052023/B0408/ok_membrane_59.tiff',
#  '/workspace/myFile/Output/17052023/A0403/ok_membrane_24.tiff',
#  '/workspace/myFile/Output/17052023/C0517/ok_membrane_82.tiff',
#  '/workspace/myFile/Output/17052023/A0613/ok_membrane_890.tiff',
#  '/workspace/myFile/Output/17052023/A0412/ok_membrane_365.tiff',
#  '/workspace/myFile/Output/17052023/A1114/ok_membrane_249.tiff',
#  '/workspace/myFile/Output/17052023/A1115/ok_membrane_262.tiff',
#  '/workspace/myFile/Output/17052023/B0422/ok_membrane_13.tiff',
#  '/workspace/myFile/Output/17052023/A0520/ok_membrane_118.tiff',
#  '/workspace/myFile/Output/17052023/E0403/ok_membrane_5.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_805.tiff',
#  '/workspace/myFile/Output/17052023/F1210/ok_membrane_101.tiff',
#  '/workspace/myFile/Output/17052023/E1013/ok_membrane_161.tiff',
#  '/workspace/myFile/Output/17052023/F0513/ok_membrane_263.tiff',
#  '/workspace/myFile/Output/17052023/E1205/ok_membrane_44.tiff',
#  '/workspace/myFile/Output/17052023/F0424/ok_membrane_3.tiff',
#  '/workspace/myFile/Output/17052023/A0409/ok_membrane_497.tiff',
#  '/workspace/myFile/Output/17052023/B0507/ok_membrane_32.tiff',
#  '/workspace/myFile/Output/17052023/A1211/ok_membrane_61.tiff',
#  '/workspace/myFile/Output/17052023/A0617/ok_membrane_309.tiff',
#  '/workspace/myFile/Output/17052023/A0422/ok_membrane_143.tiff',
#  '/workspace/myFile/Output/17052023/A1212/ok_membrane_43.tiff',
#  '/workspace/myFile/Output/17052023/D1111/ok_membrane_6.tiff',
#  '/workspace/myFile/Output/17052023/B0618/ok_membrane_15.tiff',
#  '/workspace/myFile/Output/17052023/A1008/ok_membrane_348.tiff',
#  '/workspace/myFile/Output/17052023/E1014/ok_membrane_23.tiff',
#  '/workspace/myFile/Output/17052023/E1017/ok_membrane_184.tiff',
#  '/workspace/myFile/Output/17052023/A0624/ok_membrane_224.tiff',
#  '/workspace/myFile/Output/17052023/E0607/ok_membrane_171.tiff',
#  '/workspace/myFile/Output/17052023/A0402/ok_membrane_171.tiff',
#  '/workspace/myFile/Output/17052023/A1209/ok_membrane_136.tiff',
#  '/workspace/myFile/Output/17052023/A0517/ok_membrane_27.tiff',
#  '/workspace/myFile/Output/17052023/A0404/ok_membrane_49.tiff',
#  '/workspace/myFile/Output/17052023/A0403/ok_membrane_20.tiff',
#  '/workspace/myFile/Output/17052023/B1213/ok_membrane_161.tiff',
#  '/workspace/myFile/Output/17052023/A1114/ok_membrane_375.tiff',
#  '/workspace/myFile/Output/17052023/C1124/ok_membrane_98.tiff',
#  '/workspace/myFile/Output/17052023/E0419/ok_membrane_92.tiff',
#  '/workspace/myFile/Output/17052023/F1203/ok_membrane_93.tiff',
#  '/workspace/myFile/Output/17052023/C1023/ok_membrane_72.tiff',
#  '/workspace/myFile/Output/17052023/A0522/ok_membrane_420.tiff',
#  '/workspace/myFile/Output/17052023/A1013/ok_membrane_165.tiff',
#  '/workspace/myFile/Output/17052023/E1103/ok_membrane_99.tiff',
#  '/workspace/myFile/Output/17052023/A0418/ok_membrane_551.tiff',
#  '/workspace/myFile/Output/17052023/C0517/ok_membrane_68.tiff',
#  '/workspace/myFile/Output/17052023/E0413/ok_membrane_296.tiff',
#  '/workspace/myFile/Output/17052023/A0403/ok_membrane_290.tiff',
#  '/workspace/myFile/Output/17052023/B1118/ok_membrane_45.tiff',
#  '/workspace/myFile/Output/17052023/B0422/ok_membrane_142.tiff',
#  '/workspace/myFile/Output/17052023/E1016/ok_membrane_30.tiff',
#  '/workspace/myFile/Output/17052023/B0504/ok_membrane_75.tiff',
#  '/workspace/myFile/Output/17052023/A0507/ok_membrane_323.tiff',
#  '/workspace/myFile/Output/17052023/A1202/ok_membrane_108.tiff',
#  '/workspace/myFile/Output/17052023/F0517/ok_membrane_502.tiff',
#  '/workspace/myFile/Output/17052023/F1014/ok_membrane_117.tiff',
#  '/workspace/myFile/Output/17052023/E0602/ok_membrane_15.tiff',
#  '/workspace/myFile/Output/17052023/B1103/ok_membrane_81.tiff',
#  '/workspace/myFile/Output/17052023/F1203/ok_membrane_43.tiff',
#  '/workspace/myFile/Output/17052023/F1224/ok_membrane_75.tiff',
#  '/workspace/myFile/Output/17052023/A1008/ok_membrane_34.tiff',
#  '/workspace/myFile/Output/17052023/E1106/ok_membrane_12.tiff',
#  '/workspace/myFile/Output/17052023/F1103/ok_membrane_144.tiff',
#  '/workspace/myFile/Output/17052023/A0518/ok_membrane_510.tiff',
#  '/workspace/myFile/Output/17052023/F1103/ok_membrane_130.tiff',
#  '/workspace/myFile/Output/17052023/E0620/ok_membrane_56.tiff',
#  '/workspace/myFile/Output/17052023/A1101/ok_membrane_51.tiff',
#  '/workspace/myFile/Output/17052023/A0512/ok_membrane_341.tiff',
#  '/workspace/myFile/Output/17052023/A0422/ok_membrane_239.tiff',
#  '/workspace/myFile/Output/17052023/A0614/ok_membrane_254.tiff',
#  '/workspace/myFile/Output/17052023/A1007/ok_membrane_385.tiff',
#  '/workspace/myFile/Output/17052023/A1017/ok_membrane_575.tiff',
#  '/workspace/myFile/Output/17052023/A1202/ok_membrane_202.tiff',
#  '/workspace/myFile/Output/17052023/B0602/ok_membrane_23.tiff',
#  '/workspace/myFile/Output/17052023/F0616/ok_membrane_17.tiff',
#  '/workspace/myFile/Output/17052023/D0524/ok_membrane_5.tiff',
#  '/workspace/myFile/Output/17052023/A1213/ok_membrane_390.tiff',
#  '/workspace/myFile/Output/17052023/A0521/ok_membrane_166.tiff',
#  '/workspace/myFile/Output/17052023/F1215/ok_membrane_71.tiff',
#  '/workspace/myFile/Output/17052023/D1225/ok_membrane_34.tiff',
#  '/workspace/myFile/Output/17052023/B0508/ok_membrane_142.tiff',
#  '/workspace/myFile/Output/17052023/A0517/ok_membrane_97.tiff',
#  '/workspace/myFile/Output/17052023/F0517/ok_membrane_159.tiff',
#  '/workspace/myFile/Output/17052023/E1023/ok_membrane_76.tiff',
#  '/workspace/myFile/Output/17052023/B0514/ok_membrane_51.tiff',
#  '/workspace/myFile/Output/17052023/A1109/ok_membrane_362.tiff',
#  '/workspace/myFile/Output/17052023/B0613/ok_membrane_105.tiff',
#  '/workspace/myFile/Output/17052023/A0418/ok_membrane_330.tiff',
#  '/workspace/myFile/Output/17052023/A1117/ok_membrane_443.tiff',
#  '/workspace/myFile/Output/17052023/C0615/ok_membrane_61.tiff',
#  '/workspace/myFile/Output/17052023/C0418/ok_membrane_71.tiff',
#  '/workspace/myFile/Output/17052023/A0422/ok_membrane_451.tiff',
#  '/workspace/myFile/Output/17052023/A1010/ok_membrane_21.tiff',
#  '/workspace/myFile/Output/17052023/E0406/ok_membrane_5.tiff',
#  '/workspace/myFile/Output/17052023/A1003/ok_membrane_142.tiff',
#  '/workspace/myFile/Output/17052023/F1203/ok_membrane_66.tiff',
#  '/workspace/myFile/Output/17052023/E1012/ok_membrane_158.tiff',
#  '/workspace/myFile/Output/17052023/F0504/ok_membrane_55.tiff',
#  '/workspace/myFile/Output/17052023/E0503/ok_membrane_84.tiff',
#  '/workspace/myFile/Output/17052023/A1109/ok_membrane_238.tiff',
#  '/workspace/myFile/Output/17052023/F1011/ok_membrane_31.tiff',
#  '/workspace/myFile/Output/17052023/F0424/ok_membrane_107.tiff',
#  '/workspace/myFile/Output/17052023/B0417/ok_membrane_83.tiff',
#  '/workspace/myFile/Output/17052023/F1020/ok_membrane_1.tiff',
#  '/workspace/myFile/Output/17052023/F1210/ok_membrane_99.tiff',
#  '/workspace/myFile/Output/17052023/E1011/ok_membrane_68.tiff',
#  '/workspace/myFile/Output/17052023/A0423/ok_membrane_398.tiff',
#  '/workspace/myFile/Output/17052023/D1218/ok_membrane_21.tiff',
#  '/workspace/myFile/Output/17052023/A0606/ok_membrane_390.tiff',
#  '/workspace/myFile/Output/17052023/E0508/ok_membrane_257.tiff',
#  '/workspace/myFile/Output/17052023/B1012/ok_membrane_47.tiff',
#  '/workspace/myFile/Output/17052023/E1008/ok_membrane_18.tiff',
#  '/workspace/myFile/Output/17052023/C0513/ok_membrane_117.tiff',
#  '/workspace/myFile/Output/17052023/C0620/ok_membrane_7.tiff',
#  '/workspace/myFile/Output/17052023/B0510/ok_membrane_31.tiff',
#  '/workspace/myFile/Output/17052023/F0507/ok_membrane_71.tiff',
#  '/workspace/myFile/Output/17052023/E0413/ok_membrane_220.tiff',
#  '/workspace/myFile/Output/17052023/B0619/ok_membrane_56.tiff',
#  '/workspace/myFile/Output/17052023/E1220/ok_membrane_97.tiff',
#  '/workspace/myFile/Output/17052023/F1008/ok_membrane_1.tiff',
#  '/workspace/myFile/Output/17052023/D1106/ok_membrane_4.tiff',
#  '/workspace/myFile/Output/17052023/E1108/ok_membrane_72.tiff',
#  '/workspace/myFile/Output/17052023/D0608/ok_membrane_9.tiff',
#  '/workspace/myFile/Output/17052023/A1113/ok_membrane_365.tiff',
#  '/workspace/myFile/Output/17052023/B0519/ok_membrane_52.tiff',
#  '/workspace/myFile/Output/17052023/F1111/ok_membrane_174.tiff',
#  '/workspace/myFile/Output/17052023/B1012/ok_membrane_108.tiff',
#  '/workspace/myFile/Output/17052023/A0512/ok_membrane_122.tiff',
#  '/workspace/myFile/Output/17052023/A1211/ok_membrane_216.tiff',
#  '/workspace/myFile/Output/17052023/A1007/ok_membrane_150.tiff',
#  '/workspace/myFile/Output/17052023/F0508/ok_membrane_288.tiff',
#  '/workspace/myFile/Output/17052023/C0603/ok_membrane_34.tiff',
#  '/workspace/myFile/Output/17052023/A1118/ok_membrane_56.tiff',
#  '/workspace/myFile/Output/17052023/A1117/ok_membrane_298.tiff',
#  '/workspace/myFile/Output/17052023/A1116/ok_membrane_84.tiff',
#  '/workspace/myFile/Output/17052023/C0618/ok_membrane_72.tiff',
#  '/workspace/myFile/Output/17052023/C0508/ok_membrane_60.tiff',
#  '/workspace/myFile/Output/17052023/B1206/ok_membrane_56.tiff',
#  '/workspace/myFile/Output/17052023/A1203/ok_membrane_68.tiff',
#  '/workspace/myFile/Output/17052023/A1005/ok_membrane_124.tiff',
#  '/workspace/myFile/Output/17052023/F0406/ok_membrane_26.tiff',
#  '/workspace/myFile/Output/17052023/A0624/ok_membrane_104.tiff',
#  '/workspace/myFile/Output/17052023/A1224/ok_membrane_39.tiff',
#  '/workspace/myFile/Output/17052023/A1007/ok_membrane_360.tiff',
#  '/workspace/myFile/Output/17052023/F1108/ok_membrane_282.tiff',
#  '/workspace/myFile/Output/17052023/A0422/ok_membrane_446.tiff',
#  '/workspace/myFile/Output/17052023/C0513/ok_membrane_131.tiff',
#  '/workspace/myFile/Output/17052023/F1203/ok_membrane_154.tiff',
#  '/workspace/myFile/Output/17052023/A1013/ok_membrane_588.tiff',
#  '/workspace/myFile/Output/17052023/A1217/ok_membrane_182.tiff',
#  '/workspace/myFile/Output/17052023/F1008/ok_membrane_64.tiff',
#  '/workspace/myFile/Output/17052023/A0624/ok_membrane_257.tiff',
#  '/workspace/myFile/Output/17052023/E0404/ok_membrane_14.tiff',
#  '/workspace/myFile/Output/17052023/A1221/ok_membrane_68.tiff',
#  '/workspace/myFile/Output/17052023/F0508/ok_membrane_83.tiff',
#  '/workspace/myFile/Output/17052023/A0418/ok_membrane_285.tiff',
#  '/workspace/myFile/Output/17052023/A1123/ok_membrane_126.tiff',
#  '/workspace/myFile/Output/17052023/A1022/ok_membrane_346.tiff',
#  '/workspace/myFile/Output/17052023/B1217/ok_membrane_21.tiff',
#  '/workspace/myFile/Output/17052023/E0405/ok_membrane_36.tiff',
#  '/workspace/myFile/Output/17052023/E1222/ok_membrane_104.tiff',
#  '/workspace/myFile/Output/17052023/D0510/ok_membrane_13.tiff',
#  '/workspace/myFile/Output/17052023/A0412/ok_membrane_152.tiff',
#  '/workspace/myFile/Output/17052023/B1105/ok_membrane_24.tiff',
#  '/workspace/myFile/Output/17052023/A0615/ok_membrane_30.tiff',
#  '/workspace/myFile/Output/17052023/B0414/ok_membrane_55.tiff',
#  '/workspace/myFile/Output/17052023/B1114/ok_membrane_21.tiff',
#  '/workspace/myFile/Output/17052023/B0512/ok_membrane_64.tiff',
#  '/workspace/myFile/Output/17052023/E1108/ok_membrane_391.tiff',
#  '/workspace/myFile/Output/17052023/F0408/ok_membrane_429.tiff',
#  '/workspace/myFile/Output/17052023/F1213/ok_membrane_49.tiff',
#  '/workspace/myFile/Output/17052023/A1217/ok_membrane_447.tiff',
#  '/workspace/myFile/Output/17052023/A1215/ok_membrane_102.tiff',
#  '/workspace/myFile/Output/17052023/E1208/ok_membrane_57.tiff',
#  '/workspace/myFile/Output/17052023/A0418/ok_membrane_329.tiff',
#  '/workspace/myFile/Output/17052023/D1112/ok_membrane_1.tiff',
#  '/workspace/myFile/Output/17052023/A1008/ok_membrane_619.tiff',
#  '/workspace/myFile/Output/17052023/E0408/ok_membrane_7.tiff',
#  '/workspace/myFile/Output/17052023/F0417/ok_membrane_140.tiff',
#  '/workspace/myFile/Output/17052023/F1211/ok_membrane_68.tiff',
#  '/workspace/myFile/Output/17052023/A0415/ok_membrane_62.tiff',
#  '/workspace/myFile/Output/17052023/A0409/ok_membrane_332.tiff',
#  '/workspace/myFile/Output/17052023/C0615/ok_membrane_4.tiff',
#  '/workspace/myFile/Output/17052023/F1215/ok_membrane_41.tiff',
#  '/workspace/myFile/Output/17052023/E1023/ok_membrane_61.tiff',
#  '/workspace/myFile/Output/17052023/B0422/ok_membrane_44.tiff',
#  '/workspace/myFile/Output/17052023/E1111/ok_membrane_125.tiff',
#  '/workspace/myFile/Output/17052023/A0518/ok_membrane_121.tiff',
#  '/workspace/myFile/Output/17052023/F0512/ok_membrane_118.tiff',
#  '/workspace/myFile/Output/17052023/E0407/ok_membrane_172.tiff',
#  '/workspace/myFile/Output/17052023/D1004/ok_membrane_29.tiff',
#  '/workspace/myFile/Output/17052023/A0601/ok_membrane_271.tiff',
#  '/workspace/myFile/Output/17052023/E1222/ok_membrane_165.tiff',
#  '/workspace/myFile/Output/17052023/F0425/ok_membrane_55.tiff',
#  '/workspace/myFile/Output/17052023/C1108/ok_membrane_162.tiff',
#  '/workspace/myFile/Output/17052023/A0624/ok_membrane_64.tiff',
#  '/workspace/myFile/Output/17052023/A1007/ok_membrane_147.tiff',
#  '/workspace/myFile/Output/17052023/E0424/ok_membrane_57.tiff',
#  '/workspace/myFile/Output/17052023/A0513/ok_membrane_310.tiff',
#  '/workspace/myFile/Output/17052023/F0514/ok_membrane_99.tiff',
#  '/workspace/myFile/Output/17052023/F0417/ok_membrane_83.tiff',
#  '/workspace/myFile/Output/17052023/F1010/ok_membrane_10.tiff',
#  '/workspace/myFile/Output/17052023/F1111/ok_membrane_136.tiff',
#  '/workspace/myFile/Output/17052023/A1215/ok_membrane_217.tiff',
#  '/workspace/myFile/Output/17052023/B0504/ok_membrane_24.tiff',
#  '/workspace/myFile/Output/17052023/A1211/ok_membrane_287.tiff',
#  '/workspace/myFile/Output/17052023/A1018/ok_membrane_325.tiff',
#  '/workspace/myFile/Output/17052023/B0416/ok_membrane_16.tiff',
#  '/workspace/myFile/Output/17052023/A1003/ok_membrane_383.tiff',
#  '/workspace/myFile/Output/17052023/E0425/ok_membrane_43.tiff',
#  '/workspace/myFile/Output/17052023/A1208/ok_membrane_40.tiff',
#  '/workspace/myFile/Output/17052023/A1212/ok_membrane_61.tiff',
#  '/workspace/myFile/Output/17052023/B1123/ok_membrane_55.tiff',
#  '/workspace/myFile/Output/17052023/A0422/ok_membrane_149.tiff',
#  '/workspace/myFile/Output/17052023/A0425/ok_membrane_237.tiff',
#  '/workspace/myFile/Output/17052023/F0624/ok_membrane_71.tiff',
#  '/workspace/myFile/Output/17052023/A0524/ok_membrane_572.tiff',
#  '/workspace/myFile/Output/17052023/F1116/ok_membrane_99.tiff',
#  '/workspace/myFile/Output/17052023/A0412/ok_membrane_219.tiff',
#  '/workspace/myFile/Output/17052023/A1003/ok_membrane_462.tiff',
#  '/workspace/myFile/Output/17052023/A1007/ok_membrane_124.tiff',
#  '/workspace/myFile/Output/17052023/F1017/ok_membrane_189.tiff',
#  '/workspace/myFile/Output/17052023/B1005/ok_membrane_3.tiff',
#  '/workspace/myFile/Output/17052023/A1003/ok_membrane_354.tiff',
#  '/workspace/myFile/Output/17052023/F1118/ok_membrane_135.tiff',
#  '/workspace/myFile/Output/17052023/F1206/ok_membrane_134.tiff',
#  '/workspace/myFile/Output/17052023/F1017/ok_membrane_72.tiff',
#  '/workspace/myFile/Output/17052023/D1010/ok_membrane_21.tiff',
#  '/workspace/myFile/Output/17052023/C1009/ok_membrane_47.tiff',
#  '/workspace/myFile/Output/17052023/B0418/ok_membrane_13.tiff',
#  '/workspace/myFile/Output/17052023/A0403/ok_membrane_506.tiff',
#  '/workspace/myFile/Output/17052023/B1013/ok_membrane_222.tiff',
#  '/workspace/myFile/Output/17052023/A0612/ok_membrane_425.tiff',
#  '/workspace/myFile/Output/17052023/A0513/ok_membrane_695.tiff',
#  '/workspace/myFile/Output/17052023/A0412/ok_membrane_397.tiff',
#  '/workspace/myFile/Output/17052023/A0617/ok_membrane_22.tiff',
#  '/workspace/myFile/Output/17052023/A1116/ok_membrane_314.tiff',
#  '/workspace/myFile/Output/17052023/A1211/ok_membrane_70.tiff',
#  '/workspace/myFile/Output/17052023/B0621/ok_membrane_30.tiff',
#  '/workspace/myFile/Output/17052023/C1023/ok_membrane_64.tiff',
#  '/workspace/myFile/Output/17052023/A1216/ok_membrane_209.tiff',
#  '/workspace/myFile/Output/17052023/E1108/ok_membrane_256.tiff',
#  '/workspace/myFile/Output/17052023/A1222/ok_membrane_90.tiff',
#  '/workspace/myFile/Output/17052023/A0522/ok_membrane_253.tiff',
#  '/workspace/myFile/Output/17052023/E1108/ok_membrane_171.tiff',
#  '/workspace/myFile/Output/17052023/F1003/ok_membrane_196.tiff',
#  '/workspace/myFile/Output/17052023/E1213/ok_membrane_351.tiff',
#  '/workspace/myFile/Output/17052023/F0508/ok_membrane_251.tiff',
#  '/workspace/myFile/Output/17052023/E1013/ok_membrane_268.tiff',
#  '/workspace/myFile/Output/17052023/E0613/ok_membrane_100.tiff',
#  '/workspace/myFile/Output/17052023/B1124/ok_membrane_25.tiff',
#  '/workspace/myFile/Output/17052023/E1004/ok_membrane_81.tiff',
#  '/workspace/myFile/Output/17052023/A1012/ok_membrane_572.tiff',
#  '/workspace/myFile/Output/17052023/C0524/ok_membrane_34.tiff',
#  '/workspace/myFile/Output/17052023/A0422/ok_membrane_133.tiff',
#  '/workspace/myFile/Output/17052023/A1002/ok_membrane_283.tiff',
#  '/workspace/myFile/Output/17052023/C1013/ok_membrane_34.tiff',
#  '/workspace/myFile/Output/17052023/A1112/ok_membrane_69.tiff',
#  '/workspace/myFile/Output/17052023/F1011/ok_membrane_47.tiff',
#  '/workspace/myFile/Output/17052023/A0408/ok_membrane_619.tiff',
#  '/workspace/myFile/Output/17052023/A1215/ok_membrane_60.tiff',
#  '/workspace/myFile/Output/17052023/A1118/ok_membrane_222.tiff',
#  '/workspace/myFile/Output/17052023/E1103/ok_membrane_18.tiff',
#  '/workspace/myFile/Output/17052023/A1213/ok_membrane_506.tiff',
#  '/workspace/myFile/Output/17052023/A1109/ok_membrane_339.tiff',
#  '/workspace/myFile/Output/17052023/D0609/ok_membrane_34.tiff',
#  '/workspace/myFile/Output/17052023/A0509/ok_membrane_489.tiff',
#  '/workspace/myFile/Output/17052023/A0408/ok_membrane_669.tiff',
#  '/workspace/myFile/Output/17052023/B0513/ok_membrane_163.tiff',
#  '/workspace/myFile/Output/17052023/A0620/ok_membrane_189.tiff',
#  '/workspace/myFile/Output/17052023/A1212/ok_membrane_11.tiff',
#  '/workspace/myFile/Output/17052023/A1213/ok_membrane_694.tiff',
#  '/workspace/myFile/Output/17052023/B1018/ok_membrane_13.tiff',
#  '/workspace/myFile/Output/17052023/F1103/ok_membrane_268.tiff',
#  '/workspace/myFile/Output/17052023/F0413/ok_membrane_102.tiff',
#  '/workspace/myFile/Output/17052023/E1108/ok_membrane_58.tiff',
#  '/workspace/myFile/Output/17052023/A0408/ok_membrane_717.tiff',
#  '/workspace/myFile/Output/17052023/A0507/ok_membrane_228.tiff',
#  '/workspace/myFile/Output/17052023/E0403/ok_membrane_73.tiff',
#  '/workspace/myFile/Output/17052023/A0407/ok_membrane_250.tiff',
#  '/workspace/myFile/Output/17052023/A1025/ok_membrane_47.tiff',
#  '/workspace/myFile/Output/17052023/A1113/ok_membrane_151.tiff',
#  '/workspace/myFile/Output/17052023/F0416/ok_membrane_14.tiff',
#  '/workspace/myFile/Output/17052023/F1115/ok_membrane_10.tiff',
#  '/workspace/myFile/Output/17052023/A1213/ok_membrane_383.tiff',
#  '/workspace/myFile/Output/17052023/E1213/ok_membrane_257.tiff',
#  '/workspace/myFile/Output/17052023/A0607/ok_membrane_328.tiff',
#  '/workspace/myFile/Output/17052023/A0607/ok_membrane_138.tiff',
#  '/workspace/myFile/Output/17052023/A1111/ok_membrane_176.tiff',
#  '/workspace/myFile/Output/17052023/A0408/ok_membrane_169.tiff',
#  '/workspace/myFile/Output/17052023/A1111/ok_membrane_52.tiff',
#  '/workspace/myFile/Output/17052023/C0517/ok_membrane_73.tiff',
#  '/workspace/myFile/Output/17052023/E0420/ok_membrane_23.tiff',
#  '/workspace/myFile/Output/17052023/C1217/ok_membrane_81.tiff',
#  '/workspace/myFile/Output/17052023/E1012/ok_membrane_139.tiff',
#  '/workspace/myFile/Output/17052023/C0619/ok_membrane_61.tiff',
#  '/workspace/myFile/Output/17052023/F1108/ok_membrane_45.tiff',
#  '/workspace/myFile/Output/17052023/A1218/ok_membrane_249.tiff',
#  '/workspace/myFile/Output/17052023/A1007/ok_membrane_47.tiff',
#  '/workspace/myFile/Output/17052023/E1214/ok_membrane_126.tiff',
#  '/workspace/myFile/Output/17052023/D1213/ok_membrane_74.tiff',
#  '/workspace/myFile/Output/17052023/F1213/ok_membrane_117.tiff',
#  '/workspace/myFile/Output/17052023/E1208/ok_membrane_37.tiff',
#  '/workspace/myFile/Output/17052023/A1115/ok_membrane_32.tiff',
#  '/workspace/myFile/Output/17052023/A1207/ok_membrane_276.tiff',
#  '/workspace/myFile/Output/17052023/A1203/ok_membrane_287.tiff',
#  '/workspace/myFile/Output/17052023/A0624/ok_membrane_456.tiff',
#  '/workspace/myFile/Output/17052023/E0501/ok_membrane_41.tiff',
#  '/workspace/myFile/Output/17052023/A1204/ok_membrane_146.tiff',
#  '/workspace/myFile/Output/17052023/E1013/ok_membrane_274.tiff',
#  '/workspace/myFile/Output/17052023/C1111/ok_membrane_34.tiff',
#  '/workspace/myFile/Output/17052023/A0518/ok_membrane_338.tiff',
#  '/workspace/myFile/Output/17052023/F0521/ok_membrane_24.tiff',
#  '/workspace/myFile/Output/17052023/F0407/ok_membrane_94.tiff',
#  '/workspace/myFile/Output/17052023/F0608/ok_membrane_67.tiff',
#  '/workspace/myFile/Output/17052023/A1207/ok_membrane_36.tiff',
#  '/workspace/myFile/Output/17052023/A1223/ok_membrane_186.tiff',
#  '/workspace/myFile/Output/17052023/A0408/ok_membrane_921.tiff',
#  '/workspace/myFile/Output/17052023/D1008/ok_membrane_38.tiff',
#  '/workspace/myFile/Output/17052023/E0413/ok_membrane_66.tiff',
#  '/workspace/myFile/Output/17052023/A1212/ok_membrane_374.tiff',
#  '/workspace/myFile/Output/17052023/B0623/ok_membrane_15.tiff',
#  '/workspace/myFile/Output/17052023/E0621/ok_membrane_45.tiff',
#  '/workspace/myFile/Output/17052023/E1207/ok_membrane_220.tiff',
#  '/workspace/myFile/Output/17052023/F1203/ok_membrane_157.tiff',
#  '/workspace/myFile/Output/17052023/F0517/ok_membrane_97.tiff',
#  '/workspace/myFile/Output/17052023/C0517/ok_membrane_129.tiff',
#  '/workspace/myFile/Output/17052023/A0615/ok_membrane_22.tiff',
#  '/workspace/myFile/Output/17052023/A1201/ok_membrane_69.tiff',
#  '/workspace/myFile/Output/17052023/F0625/ok_membrane_134.tiff',
#  '/workspace/myFile/Output/17052023/A0413/ok_membrane_800.tiff',
#  '/workspace/myFile/Output/17052023/A1217/ok_membrane_332.tiff',
#  '/workspace/myFile/Output/17052023/F1103/ok_membrane_209.tiff',
#  '/workspace/myFile/Output/17052023/A0404/ok_membrane_4.tiff',
#  '/workspace/myFile/Output/17052023/E0514/ok_membrane_109.tiff',
#  '/workspace/myFile/Output/17052023/C1003/ok_membrane_16.tiff',
#  '/workspace/myFile/Output/17052023/F1224/ok_membrane_50.tiff',
#  '/workspace/myFile/Output/17052023/A1104/ok_membrane_134.tiff',
#  '/workspace/myFile/Output/17052023/A1001/ok_membrane_148.tiff',
#  '/workspace/myFile/Output/17052023/C1009/ok_membrane_74.tiff',
#  '/workspace/myFile/Output/17052023/E1008/ok_membrane_72.tiff',
#  '/workspace/myFile/Output/17052023/A0408/ok_membrane_492.tiff',
#  '/workspace/myFile/Output/17052023/A0413/ok_membrane_321.tiff',
#  '/workspace/myFile/Output/17052023/B1005/ok_membrane_23.tiff',
#  '/workspace/myFile/Output/17052023/E0509/ok_membrane_62.tiff',
#  '/workspace/myFile/Output/17052023/E0422/ok_membrane_168.tiff',
#  '/workspace/myFile/Output/17052023/A1025/ok_membrane_8.tiff',
#  '/workspace/myFile/Output/17052023/B1003/ok_membrane_125.tiff',
#  '/workspace/myFile/Output/17052023/A0607/ok_membrane_411.tiff',
#  '/workspace/myFile/Output/17052023/A0607/ok_membrane_368.tiff',
#  '/workspace/myFile/Output/17052023/A1020/ok_membrane_19.tiff',
#  '/workspace/myFile/Output/17052023/A1008/ok_membrane_526.tiff',
#  '/workspace/myFile/Output/17052023/D0414/ok_membrane_18.tiff',
#  '/workspace/myFile/Output/17052023/E1222/ok_membrane_163.tiff',
#  '/workspace/myFile/Output/17052023/A0518/ok_membrane_138.tiff',
#  '/workspace/myFile/Output/17052023/A0606/ok_membrane_77.tiff',
#  '/workspace/myFile/Output/17052023/A1123/ok_membrane_366.tiff',
#  '/workspace/myFile/Output/17052023/A0423/ok_membrane_104.tiff',
#  '/workspace/myFile/Output/17052023/E1008/ok_membrane_154.tiff',
#  '/workspace/myFile/Output/17052023/E0509/ok_membrane_108.tiff',
#  '/workspace/myFile/Output/17052023/B1223/ok_membrane_33.tiff',
#  '/workspace/myFile/Output/17052023/D1012/ok_membrane_83.tiff',
#  '/workspace/myFile/Output/17052023/A0616/ok_membrane_40.tiff',
#  '/workspace/myFile/Output/17052023/B1110/ok_membrane_46.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_2200.tiff',
#  '/workspace/myFile/Output/17052023/C0418/ok_membrane_69.tiff',
#  '/workspace/myFile/Output/17052023/C0510/ok_membrane_26.tiff',
#  '/workspace/myFile/Output/17052023/A1013/ok_membrane_728.tiff',
#  '/workspace/myFile/Output/17052023/A1214/ok_membrane_76.tiff',
#  '/workspace/myFile/Output/17052023/D1010/ok_membrane_18.tiff',
#  '/workspace/myFile/Output/17052023/A1017/ok_membrane_43.tiff',
#  '/workspace/myFile/Output/17052023/A1008/ok_membrane_491.tiff',
#  '/workspace/myFile/Output/17052023/A0617/ok_membrane_146.tiff',
#  '/workspace/myFile/Output/17052023/A0518/ok_membrane_36.tiff',
#  '/workspace/myFile/Output/17052023/B1204/ok_membrane_13.tiff',
#  '/workspace/myFile/Output/17052023/A0512/ok_membrane_370.tiff',
#  '/workspace/myFile/Output/17052023/E1023/ok_membrane_35.tiff',
#  '/workspace/myFile/Output/17052023/E1009/ok_membrane_7.tiff',
#  '/workspace/myFile/Output/17052023/E0502/ok_membrane_131.tiff',
#  '/workspace/myFile/Output/17052023/E1111/ok_membrane_152.tiff',
#  '/workspace/myFile/Output/17052023/C1011/ok_membrane_61.tiff',
#  '/workspace/myFile/Output/17052023/C0419/ok_membrane_28.tiff',
#  '/workspace/myFile/Output/17052023/B1012/ok_membrane_39.tiff',
#  '/workspace/myFile/Output/17052023/F0507/ok_membrane_164.tiff',
#  '/workspace/myFile/Output/17052023/D0609/ok_membrane_12.tiff',
#  '/workspace/myFile/Output/17052023/B0423/ok_membrane_4.tiff',
#  '/workspace/myFile/Output/17052023/A1214/ok_membrane_277.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_1100.tiff',
#  '/workspace/myFile/Output/17052023/A1224/ok_membrane_128.tiff',
#  '/workspace/myFile/Output/17052023/E0419/ok_membrane_5.tiff',
#  '/workspace/myFile/Output/17052023/C0413/ok_membrane_282.tiff',
#  '/workspace/myFile/Output/17052023/E1115/ok_membrane_92.tiff',
#  '/workspace/myFile/Output/17052023/B0604/ok_membrane_67.tiff',
#  '/workspace/myFile/Output/17052023/D1215/ok_membrane_27.tiff',
#  '/workspace/myFile/Output/17052023/F0619/ok_membrane_132.tiff',
#  '/workspace/myFile/Output/17052023/A1016/ok_membrane_224.tiff',
#  '/workspace/myFile/Output/17052023/C1124/ok_membrane_59.tiff',
#  '/workspace/myFile/Output/17052023/E1111/ok_membrane_154.tiff',
#  '/workspace/myFile/Output/17052023/A1023/ok_membrane_196.tiff',
#  '/workspace/myFile/Output/17052023/A0624/ok_membrane_54.tiff',
#  '/workspace/myFile/Output/17052023/E1217/ok_membrane_108.tiff',
#  '/workspace/myFile/Output/17052023/A0413/ok_membrane_542.tiff',
#  '/workspace/myFile/Output/17052023/E1008/ok_membrane_127.tiff',
#  '/workspace/myFile/Output/17052023/C1204/ok_membrane_9.tiff',
#  '/workspace/myFile/Output/17052023/C0418/ok_membrane_72.tiff',
#  '/workspace/myFile/Output/17052023/C0511/ok_membrane_26.tiff',
#  '/workspace/myFile/Output/17052023/E1003/ok_membrane_130.tiff',
#  '/workspace/myFile/Output/17052023/F0513/ok_membrane_1.tiff',
#  '/workspace/myFile/Output/17052023/B0608/ok_membrane_112.tiff',
#  '/workspace/myFile/Output/17052023/A1123/ok_membrane_285.tiff',
#  '/workspace/myFile/Output/17052023/A0602/ok_membrane_12.tiff',
#  '/workspace/myFile/Output/17052023/A0403/ok_membrane_629.tiff',
#  '/workspace/myFile/Output/17052023/E1208/ok_membrane_268.tiff',
#  '/workspace/myFile/Output/17052023/F1017/ok_membrane_152.tiff',
#  '/workspace/myFile/Output/17052023/A1123/ok_membrane_303.tiff',
#  '/workspace/myFile/Output/17052023/E0412/ok_membrane_45.tiff',
#  '/workspace/myFile/Output/17052023/C0418/ok_membrane_208.tiff',
#  '/workspace/myFile/Output/17052023/A1102/ok_membrane_1.tiff',
#  '/workspace/myFile/Output/17052023/C1014/ok_membrane_65.tiff',
#  '/workspace/myFile/Output/17052023/F1218/ok_membrane_166.tiff',
#  '/workspace/myFile/Output/17052023/A1123/ok_membrane_381.tiff',
#  '/workspace/myFile/Output/17052023/A0512/ok_membrane_66.tiff',
#  '/workspace/myFile/Output/17052023/F1213/ok_membrane_60.tiff',
#  '/workspace/myFile/Output/17052023/A0418/ok_membrane_589.tiff',
#  '/workspace/myFile/Output/17052023/B1220/ok_membrane_14.tiff',
#  '/workspace/myFile/Output/17052023/E0609/ok_membrane_17.tiff',
#  '/workspace/myFile/Output/17052023/A0412/ok_membrane_25.tiff',
#  '/workspace/myFile/Output/17052023/F0417/ok_membrane_104.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_1148.tiff',
#  '/workspace/myFile/Output/17052023/A0418/ok_membrane_563.tiff',
#  '/workspace/myFile/Output/17052023/A1014/ok_membrane_54.tiff',
#  '/workspace/myFile/Output/17052023/A0610/ok_membrane_12.tiff',
#  '/workspace/myFile/Output/17052023/A0620/ok_membrane_44.tiff',
#  '/workspace/myFile/Output/17052023/A0408/ok_membrane_527.tiff',
#  '/workspace/myFile/Output/17052023/C1112/ok_membrane_129.tiff',
#  '/workspace/myFile/Output/17052023/F0623/ok_membrane_24.tiff',
#  '/workspace/myFile/Output/17052023/F0413/ok_membrane_524.tiff',
#  '/workspace/myFile/Output/17052023/F0417/ok_membrane_5.tiff',
#  '/workspace/myFile/Output/17052023/E1104/ok_membrane_54.tiff',
#  '/workspace/myFile/Output/17052023/D0620/ok_membrane_41.tiff',
#  '/workspace/myFile/Output/17052023/E0509/ok_membrane_76.tiff',
#  '/workspace/myFile/Output/17052023/F0417/ok_membrane_100.tiff',
#  '/workspace/myFile/Output/17052023/F0521/ok_membrane_8.tiff',
#  '/workspace/myFile/Output/17052023/C1112/ok_membrane_34.tiff',
#  '/workspace/myFile/Output/17052023/A0424/ok_membrane_399.tiff',
#  '/workspace/myFile/Output/17052023/C1112/ok_membrane_227.tiff',
#  '/workspace/myFile/Output/17052023/A0513/ok_membrane_1083.tiff',
#  '/workspace/myFile/Output/17052023/A0423/ok_membrane_60.tiff',
#  '/workspace/myFile/Output/17052023/C1207/ok_membrane_63.tiff',
#  '/workspace/myFile/Output/17052023/A1203/ok_membrane_288.tiff',
#  '/workspace/myFile/Output/17052023/C0413/ok_membrane_272.tiff',
#  '/workspace/myFile/Output/17052023/A0519/ok_membrane_456.tiff',
#  '/workspace/myFile/Output/17052023/A0602/ok_membrane_146.tiff',
#  '/workspace/myFile/Output/17052023/E1213/ok_membrane_270.tiff',
#  '/workspace/myFile/Output/17052023/B0417/ok_membrane_156.tiff',
#  '/workspace/myFile/Output/17052023/B1110/ok_membrane_36.tiff',
#  '/workspace/myFile/Output/17052023/E0514/ok_membrane_83.tiff',
#  '/workspace/myFile/Output/17052023/A0418/ok_membrane_261.tiff',
#  '/workspace/myFile/Output/17052023/A0423/ok_membrane_412.tiff',
#  '/workspace/myFile/Output/17052023/A0423/ok_membrane_645.tiff',
#  '/workspace/myFile/Output/17052023/F0509/ok_membrane_122.tiff',
#  '/workspace/myFile/Output/17052023/F0511/ok_membrane_56.tiff',
#  '/workspace/myFile/Output/17052023/F1221/ok_membrane_19.tiff',
#  '/workspace/myFile/Output/17052023/C1013/ok_membrane_270.tiff',
#  '/workspace/myFile/Output/17052023/E0508/ok_membrane_148.tiff',
#  '/workspace/myFile/Output/17052023/B1121/ok_membrane_63.tiff',
#  '/workspace/myFile/Output/17052023/F0407/ok_membrane_51.tiff',
#  '/workspace/myFile/Output/17052023/A0515/ok_membrane_124.tiff',
#  '/workspace/myFile/Output/17052023/D1010/ok_membrane_3.tiff',
#  '/workspace/myFile/Output/17052023/F1003/ok_membrane_104.tiff',
#  '/workspace/myFile/Output/17052023/F1203/ok_membrane_7.tiff',
#  '/workspace/myFile/Output/17052023/F0622/ok_membrane_80.tiff',
#  '/workspace/myFile/Output/17052023/A1112/ok_membrane_467.tiff',
#  '/workspace/myFile/Output/17052023/E0611/ok_membrane_19.tiff',
#  '/workspace/myFile/Output/17052023/F0521/ok_membrane_6.tiff',
#  '/workspace/myFile/Output/17052023/A0423/ok_membrane_445.tiff',
#  '/workspace/myFile/Output/17052023/A1019/ok_membrane_211.tiff',
#  '/workspace/myFile/Output/17052023/A0424/ok_membrane_459.tiff',
#  '/workspace/myFile/Output/17052023/C1210/ok_membrane_8.tiff',
#  '/workspace/myFile/Output/17052023/A0522/ok_membrane_123.tiff',
#  '/workspace/myFile/Output/17052023/A1203/ok_membrane_225.tiff',
#  '/workspace/myFile/Output/17052023/E0403/ok_membrane_8.tiff',
#  '/workspace/myFile/Output/17052023/E1013/ok_membrane_33.tiff',
#  '/workspace/myFile/Output/17052023/A1017/ok_membrane_85.tiff',
#  '/workspace/myFile/Output/17052023/D1108/ok_membrane_62.tiff',
#  '/workspace/myFile/Output/17052023/C0423/ok_membrane_78.tiff',
#  '/workspace/myFile/Output/17052023/A0407/ok_membrane_689.tiff',
#  '/workspace/myFile/Output/17052023/A1019/ok_membrane_200.tiff',
#  '/workspace/myFile/Output/17052023/A0524/ok_membrane_141.tiff',
#  '/workspace/myFile/Output/17052023/B1001/ok_membrane_66.tiff',
#  '/workspace/myFile/Output/17052023/C0619/ok_membrane_82.tiff',
#  '/workspace/myFile/Output/17052023/F0412/ok_membrane_125.tiff',
#  '/workspace/myFile/Output/17052023/E0405/ok_membrane_41.tiff',
#  '/workspace/myFile/Output/17052023/F0509/ok_membrane_90.tiff',
#  '/workspace/myFile/Output/17052023/B0525/ok_membrane_1.tiff',
#  '/workspace/myFile/Output/17052023/E1118/ok_membrane_123.tiff',
#  '/workspace/myFile/Output/17052023/A1215/ok_membrane_201.tiff',
#  '/workspace/myFile/Output/17052023/F1207/ok_membrane_119.tiff',
#  '/workspace/myFile/Output/17052023/C0613/ok_membrane_22.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_1638.tiff',
#  '/workspace/myFile/Output/17052023/C1112/ok_membrane_77.tiff',
#  '/workspace/myFile/Output/17052023/A1007/ok_membrane_75.tiff',
#  '/workspace/myFile/Output/17052023/A0413/ok_membrane_383.tiff',
#  '/workspace/myFile/Output/17052023/D1212/ok_membrane_63.tiff',
#  '/workspace/myFile/Output/17052023/F1008/ok_membrane_9.tiff',
#  '/workspace/myFile/Output/17052023/A0601/ok_membrane_243.tiff',
#  '/workspace/myFile/Output/17052023/F0514/ok_membrane_5.tiff',
#  '/workspace/myFile/Output/17052023/A0424/ok_membrane_419.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_2126.tiff',
#  '/workspace/myFile/Output/17052023/F0525/ok_membrane_7.tiff',
#  '/workspace/myFile/Output/17052023/C1208/ok_membrane_43.tiff',
#  '/workspace/myFile/Output/17052023/A0418/ok_membrane_105.tiff',
#  '/workspace/myFile/Output/17052023/A1003/ok_membrane_374.tiff',
#  '/workspace/myFile/Output/17052023/E1213/ok_membrane_271.tiff',
#  '/workspace/myFile/Output/17052023/A1212/ok_membrane_269.tiff',
#  '/workspace/myFile/Output/17052023/A1212/ok_membrane_506.tiff',
#  '/workspace/myFile/Output/17052023/A1005/ok_membrane_84.tiff',
#  '/workspace/myFile/Output/17052023/A1203/ok_membrane_460.tiff',
#  '/workspace/myFile/Output/17052023/F1116/ok_membrane_73.tiff',
#  '/workspace/myFile/Output/17052023/C0503/ok_membrane_84.tiff',
#  '/workspace/myFile/Output/17052023/A1109/ok_membrane_56.tiff',
#  '/workspace/myFile/Output/17052023/A0524/ok_membrane_151.tiff',
#  '/workspace/myFile/Output/17052023/B1219/ok_membrane_70.tiff',
#  '/workspace/myFile/Output/17052023/A1218/ok_membrane_259.tiff',
#  '/workspace/myFile/Output/17052023/A0408/ok_membrane_5.tiff',
#  '/workspace/myFile/Output/17052023/C0524/ok_membrane_53.tiff',
#  '/workspace/myFile/Output/17052023/F0518/ok_membrane_156.tiff',
#  '/workspace/myFile/Output/17052023/A1021/ok_membrane_149.tiff',
#  '/workspace/myFile/Output/17052023/F1008/ok_membrane_108.tiff',
#  '/workspace/myFile/Output/17052023/D1114/ok_membrane_68.tiff',
#  '/workspace/myFile/Output/17052023/D1214/ok_membrane_1.tiff',
#  '/workspace/myFile/Output/17052023/A1225/ok_membrane_249.tiff',
#  '/workspace/myFile/Output/17052023/A0404/ok_membrane_134.tiff',
#  '/workspace/myFile/Output/17052023/A0614/ok_membrane_40.tiff',
#  '/workspace/myFile/Output/17052023/D1012/ok_membrane_1.tiff',
#  '/workspace/myFile/Output/17052023/E1213/ok_membrane_355.tiff',
#  '/workspace/myFile/Output/17052023/F1012/ok_membrane_103.tiff',
#  '/workspace/myFile/Output/17052023/C0408/ok_membrane_181.tiff',
#  '/workspace/myFile/Output/17052023/E1111/ok_membrane_213.tiff',
#  '/workspace/myFile/Output/17052023/F0613/ok_membrane_261.tiff',
#  '/workspace/myFile/Output/17052023/F0417/ok_membrane_19.tiff',
#  '/workspace/myFile/Output/17052023/A1104/ok_membrane_187.tiff',
#  '/workspace/myFile/Output/17052023/C0612/ok_membrane_63.tiff',
#  '/workspace/myFile/Output/17052023/B1116/ok_membrane_16.tiff',
#  '/workspace/myFile/Output/17052023/B1013/ok_membrane_87.tiff',
#  '/workspace/myFile/Output/17052023/A1214/ok_membrane_274.tiff',
#  '/workspace/myFile/Output/17052023/B0618/ok_membrane_48.tiff',
#  '/workspace/myFile/Output/17052023/A1208/ok_membrane_262.tiff',
#  '/workspace/myFile/Output/17052023/C1108/ok_membrane_248.tiff',
#  '/workspace/myFile/Output/17052023/D0409/ok_membrane_17.tiff',
#  '/workspace/myFile/Output/17052023/A1218/ok_membrane_205.tiff',
#  '/workspace/myFile/Output/17052023/A0510/ok_membrane_58.tiff',
#  '/workspace/myFile/Output/17052023/F0513/ok_membrane_374.tiff',
#  '/workspace/myFile/Output/17052023/F0513/ok_membrane_123.tiff',
#  '/workspace/myFile/Output/17052023/B1207/ok_membrane_13.tiff',
#  '/workspace/myFile/Output/17052023/A0522/ok_membrane_226.tiff',
#  '/workspace/myFile/Output/17052023/B1002/ok_membrane_86.tiff',
#  '/workspace/myFile/Output/17052023/D1112/ok_membrane_83.tiff',
#  '/workspace/myFile/Output/17052023/E0607/ok_membrane_61.tiff',
#  '/workspace/myFile/Output/17052023/F1125/ok_membrane_4.tiff',
#  '/workspace/myFile/Output/17052023/E1108/ok_membrane_349.tiff',
#  '/workspace/myFile/Output/17052023/B1209/ok_membrane_4.tiff',
#  '/workspace/myFile/Output/17052023/A1116/ok_membrane_186.tiff',
#  '/workspace/myFile/Output/17052023/D1004/ok_membrane_22.tiff',
#  '/workspace/myFile/Output/17052023/A0519/ok_membrane_99.tiff',
#  '/workspace/myFile/Output/17052023/D0503/ok_membrane_27.tiff',
#  '/workspace/myFile/Output/17052023/C1220/ok_membrane_69.tiff',
#  '/workspace/myFile/Output/17052023/A0620/ok_membrane_64.tiff',
#  '/workspace/myFile/Output/17052023/B0614/ok_membrane_60.tiff',
#  '/workspace/myFile/Output/17052023/C1207/ok_membrane_32.tiff',
#  '/workspace/myFile/Output/17052023/A0512/ok_membrane_412.tiff',
#  '/workspace/myFile/Output/17052023/A1116/ok_membrane_193.tiff',
#  '/workspace/myFile/Output/17052023/E0420/ok_membrane_21.tiff',
#  '/workspace/myFile/Output/17052023/D0624/ok_membrane_1.tiff',
#  '/workspace/myFile/Output/17052023/E1008/ok_membrane_14.tiff',
#  '/workspace/myFile/Output/17052023/E1217/ok_membrane_147.tiff',
#  '/workspace/myFile/Output/17052023/A1114/ok_membrane_341.tiff',
#  '/workspace/myFile/Output/17052023/A1217/ok_membrane_183.tiff',
#  '/workspace/myFile/Output/17052023/B1118/ok_membrane_23.tiff',
#  '/workspace/myFile/Output/17052023/E0418/ok_membrane_206.tiff',
#  '/workspace/myFile/Output/17052023/E0611/ok_membrane_7.tiff',
#  '/workspace/myFile/Output/17052023/F1122/ok_membrane_60.tiff',
#  '/workspace/myFile/Output/17052023/B0509/ok_membrane_10.tiff',
#  '/workspace/myFile/Output/17052023/F0412/ok_membrane_2.tiff',
#  '/workspace/myFile/Output/17052023/A0410/ok_membrane_129.tiff',
#  '/workspace/myFile/Output/17052023/A1112/ok_membrane_178.tiff',
#  '/workspace/myFile/Output/17052023/A0513/ok_membrane_1102.tiff',
#  '/workspace/myFile/Output/17052023/A0418/ok_membrane_308.tiff',
#  '/workspace/myFile/Output/17052023/C0622/ok_membrane_50.tiff',
#  '/workspace/myFile/Output/17052023/A1002/ok_membrane_62.tiff',
#  '/workspace/myFile/Output/17052023/A1211/ok_membrane_71.tiff',
#  '/workspace/myFile/Output/17052023/A0408/ok_membrane_454.tiff',
#  '/workspace/myFile/Output/17052023/E0519/ok_membrane_12.tiff',
#  '/workspace/myFile/Output/17052023/F0413/ok_membrane_66.tiff',
#  '/workspace/myFile/Output/17052023/A1106/ok_membrane_38.tiff',
#  '/workspace/myFile/Output/17052023/C1101/ok_membrane_5.tiff',
#  '/workspace/myFile/Output/17052023/F0406/ok_membrane_32.tiff',
#  '/workspace/myFile/Output/17052023/E0620/ok_membrane_44.tiff',
#  '/workspace/myFile/Output/17052023/A1111/ok_membrane_403.tiff',
#  '/workspace/myFile/Output/17052023/A1002/ok_membrane_103.tiff',
#  '/workspace/myFile/Output/17052023/D1112/ok_membrane_68.tiff',
#  '/workspace/myFile/Output/17052023/A0402/ok_membrane_343.tiff',
#  '/workspace/myFile/Output/17052023/E0611/ok_membrane_21.tiff',
#  '/workspace/myFile/Output/17052023/B1116/ok_membrane_23.tiff',
#  '/workspace/myFile/Output/17052023/A1022/ok_membrane_47.tiff',
#  '/workspace/myFile/Output/17052023/F1210/ok_membrane_18.tiff',
#  '/workspace/myFile/Output/17052023/A1117/ok_membrane_428.tiff',
#  '/workspace/myFile/Output/17052023/A0523/ok_membrane_310.tiff',
#  '/workspace/myFile/Output/17052023/A0507/ok_membrane_36.tiff',
#  '/workspace/myFile/Output/17052023/B1212/ok_membrane_14.tiff',
#  '/workspace/myFile/Output/17052023/A0513/ok_membrane_749.tiff',
#  '/workspace/myFile/Output/17052023/E1024/ok_membrane_5.tiff',
#  '/workspace/myFile/Output/17052023/A1116/ok_membrane_170.tiff',
#  '/workspace/myFile/Output/17052023/C1207/ok_membrane_78.tiff',
#  '/workspace/myFile/Output/17052023/A1214/ok_membrane_270.tiff',
#  '/workspace/myFile/Output/17052023/A0424/ok_membrane_127.tiff',
#  '/workspace/myFile/Output/17052023/A0403/ok_membrane_697.tiff',
#  '/workspace/myFile/Output/17052023/C0618/ok_membrane_15.tiff',
#  '/workspace/myFile/Output/17052023/A1002/ok_membrane_58.tiff',
#  '/workspace/myFile/Output/17052023/F0519/ok_membrane_88.tiff',
#  '/workspace/myFile/Output/17052023/B0612/ok_membrane_110.tiff',
#  '/workspace/myFile/Output/17052023/B0514/ok_membrane_84.tiff',
#  '/workspace/myFile/Output/17052023/A1112/ok_membrane_203.tiff',
#  '/workspace/myFile/Output/17052023/A0513/ok_membrane_1011.tiff',
#  '/workspace/myFile/Output/17052023/A0509/ok_membrane_564.tiff',
#  '/workspace/myFile/Output/17052023/A1208/ok_membrane_219.tiff',
#  '/workspace/myFile/Output/17052023/E1118/ok_membrane_17.tiff',
#  '/workspace/myFile/Output/17052023/A0413/ok_membrane_505.tiff',
#  '/workspace/myFile/Output/17052023/F1107/ok_membrane_23.tiff',
#  '/workspace/myFile/Output/17052023/A1209/ok_membrane_255.tiff',
#  '/workspace/myFile/Output/17052023/A0610/ok_membrane_43.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_693.tiff',
#  '/workspace/myFile/Output/17052023/B0402/ok_membrane_55.tiff',
#  '/workspace/myFile/Output/17052023/F0512/ok_membrane_177.tiff',
#  '/workspace/myFile/Output/17052023/A0613/ok_membrane_769.tiff',
#  '/workspace/myFile/Output/17052023/E1114/ok_membrane_39.tiff',
#  '/workspace/myFile/Output/17052023/A0604/ok_membrane_22.tiff',
#  '/workspace/myFile/Output/17052023/B0625/ok_membrane_5.tiff',
#  '/workspace/myFile/Output/17052023/E0624/ok_membrane_83.tiff',
#  '/workspace/myFile/Output/17052023/A0620/ok_membrane_93.tiff',
#  '/workspace/myFile/Output/17052023/A0407/ok_membrane_181.tiff',
#  '/workspace/myFile/Output/17052023/C1012/ok_membrane_179.tiff',
#  '/workspace/myFile/Output/17052023/A0422/ok_membrane_88.tiff',
#  '/workspace/myFile/Output/17052023/F1015/ok_membrane_2.tiff',
#  '/workspace/myFile/Output/17052023/F0408/ok_membrane_114.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_44.tiff',
#  '/workspace/myFile/Output/17052023/B0413/ok_membrane_39.tiff',
#  '/workspace/myFile/Output/17052023/A1209/ok_membrane_90.tiff',
#  '/workspace/myFile/Output/17052023/B0507/ok_membrane_15.tiff',
#  '/workspace/myFile/Output/17052023/C0512/ok_membrane_195.tiff',
#  '/workspace/myFile/Output/17052023/F0517/ok_membrane_471.tiff',
#  '/workspace/myFile/Output/17052023/F1108/ok_membrane_355.tiff',
#  '/workspace/myFile/Output/17052023/E1213/ok_membrane_129.tiff',
#  '/workspace/myFile/Output/17052023/A1109/ok_membrane_411.tiff',
#  '/workspace/myFile/Output/17052023/A0613/ok_membrane_551.tiff',
#  '/workspace/myFile/Output/17052023/A1120/ok_membrane_239.tiff',
#  '/workspace/myFile/Output/17052023/E1214/ok_membrane_154.tiff',
#  '/workspace/myFile/Output/17052023/E1207/ok_membrane_73.tiff',
#  '/workspace/myFile/Output/17052023/A0415/ok_membrane_186.tiff',
#  '/workspace/myFile/Output/17052023/A1202/ok_membrane_218.tiff',
#  '/workspace/myFile/Output/17052023/F0614/ok_membrane_27.tiff',
#  '/workspace/myFile/Output/17052023/F0517/ok_membrane_8.tiff',
#  '/workspace/myFile/Output/17052023/E1108/ok_membrane_306.tiff',
#  '/workspace/myFile/Output/17052023/D0618/ok_membrane_21.tiff',
#  '/workspace/myFile/Output/17052023/C0413/ok_membrane_169.tiff',
#  '/workspace/myFile/Output/17052023/D1112/ok_membrane_17.tiff',
#  '/workspace/myFile/Output/17052023/E0517/ok_membrane_183.tiff',
#  '/workspace/myFile/Output/17052023/D1217/ok_membrane_19.tiff',
#  '/workspace/myFile/Output/17052023/B0613/ok_membrane_18.tiff',
#  '/workspace/myFile/Output/17052023/A0513/ok_membrane_756.tiff',
#  '/workspace/myFile/Output/17052023/A1213/ok_membrane_280.tiff',
#  '/workspace/myFile/Output/17052023/A1021/ok_membrane_35.tiff',
#  '/workspace/myFile/Output/17052023/A0625/ok_membrane_277.tiff',
#  '/workspace/myFile/Output/17052023/B1002/ok_membrane_60.tiff',
#  '/workspace/myFile/Output/17052023/F1011/ok_membrane_8.tiff',
#  '/workspace/myFile/Output/17052023/A1002/ok_membrane_280.tiff',
#  '/workspace/myFile/Output/17052023/F1125/ok_membrane_59.tiff',
#  '/workspace/myFile/Output/17052023/F0624/ok_membrane_48.tiff',
#  '/workspace/myFile/Output/17052023/C1113/ok_membrane_107.tiff',
#  '/workspace/myFile/Output/17052023/E0502/ok_membrane_94.tiff',
#  '/workspace/myFile/Output/17052023/A0523/ok_membrane_65.tiff',
#  '/workspace/myFile/Output/17052023/E1013/ok_membrane_473.tiff',
#  '/workspace/myFile/Output/17052023/D0414/ok_membrane_12.tiff',
#  '/workspace/myFile/Output/17052023/E1012/ok_membrane_183.tiff',
#  '/workspace/myFile/Output/17052023/D0408/ok_membrane_9.tiff',
#  '/workspace/myFile/Output/17052023/A1019/ok_membrane_109.tiff',
#  '/workspace/myFile/Output/17052023/C0403/ok_membrane_17.tiff',
#  '/workspace/myFile/Output/17052023/E0407/ok_membrane_91.tiff',
#  '/workspace/myFile/Output/17052023/A1025/ok_membrane_273.tiff',
#  '/workspace/myFile/Output/17052023/A0422/ok_membrane_404.tiff',
#  '/workspace/myFile/Output/17052023/D1123/ok_membrane_2.tiff',
#  '/workspace/myFile/Output/17052023/A1114/ok_membrane_188.tiff',
#  '/workspace/myFile/Output/17052023/A1123/ok_membrane_119.tiff',
#  '/workspace/myFile/Output/17052023/A0409/ok_membrane_221.tiff',
#  '/workspace/myFile/Output/17052023/C0413/ok_membrane_201.tiff',
#  '/workspace/myFile/Output/17052023/A0423/ok_membrane_206.tiff',
#  '/workspace/myFile/Output/17052023/B1103/ok_membrane_71.tiff',
#  '/workspace/myFile/Output/17052023/A1118/ok_membrane_476.tiff',
#  '/workspace/myFile/Output/17052023/B1224/ok_membrane_79.tiff',
#  '/workspace/myFile/Output/17052023/A1207/ok_membrane_172.tiff',
#  '/workspace/myFile/Output/17052023/E0403/ok_membrane_131.tiff',
#  '/workspace/myFile/Output/17052023/A1216/ok_membrane_136.tiff',
#  '/workspace/myFile/Output/17052023/A0624/ok_membrane_398.tiff',
#  '/workspace/myFile/Output/17052023/A0505/ok_membrane_84.tiff',
#  '/workspace/myFile/Output/17052023/E1017/ok_membrane_129.tiff',
#  '/workspace/myFile/Output/17052023/B1123/ok_membrane_14.tiff',
#  '/workspace/myFile/Output/17052023/F0517/ok_membrane_573.tiff',
#  '/workspace/myFile/Output/17052023/F1204/ok_membrane_65.tiff',
#  '/workspace/myFile/Output/17052023/A1023/ok_membrane_288.tiff',
#  '/workspace/myFile/Output/17052023/A0423/ok_membrane_375.tiff',
#  '/workspace/myFile/Output/17052023/C1106/ok_membrane_57.tiff',
#  '/workspace/myFile/Output/17052023/A1002/ok_membrane_268.tiff',
#  '/workspace/myFile/Output/17052023/F0615/ok_membrane_108.tiff',
# ...
#  '/workspace/myFile/Output/17052023/A1212/ok_membrane_41.tiff',
#  '/workspace/myFile/Output/17052023/F1008/ok_membrane_290.tiff',
#  '/workspace/myFile/Output/17052023/A0614/ok_membrane_214.tiff',
#  '/workspace/myFile/Output/17052023/C0603/ok_membrane_28.tiff',
#  '/workspace/myFile/Output/17052023/A0613/ok_membrane_283.tiff',
#  '/workspace/myFile/Output/17052023/D1212/ok_membrane_83.tiff',
#  '/workspace/myFile/Output/17052023/A0423/ok_membrane_243.tiff',
#  '/workspace/myFile/Output/17052023/C0408/ok_membrane_232.tiff',
#  '/workspace/myFile/Output/17052023/D0417/ok_membrane_5.tiff',
#  '/workspace/myFile/Output/17052023/A1013/ok_membrane_727.tiff',
#  '/workspace/myFile/Output/17052023/B0511/ok_membrane_15.tiff',
#  '/workspace/myFile/Output/17052023/F1004/ok_membrane_32.tiff',
#  '/workspace/myFile/Output/17052023/A1118/ok_membrane_16.tiff',
#  '/workspace/myFile/Output/17052023/A0520/ok_membrane_245.tiff',
#  '/workspace/myFile/Output/17052023/A0409/ok_membrane_389.tiff',
#  '/workspace/myFile/Output/17052023/B0413/ok_membrane_73.tiff',
#  '/workspace/myFile/Output/17052023/A1112/ok_membrane_516.tiff',
#  '/workspace/myFile/Output/17052023/A1109/ok_membrane_55.tiff',
#  '/workspace/myFile/Output/17052023/A0507/ok_membrane_393.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_884.tiff',
#  '/workspace/myFile/Output/17052023/D1025/ok_membrane_29.tiff',
#  '/workspace/myFile/Output/17052023/F0605/ok_membrane_77.tiff',
#  '/workspace/myFile/Output/17052023/A0519/ok_membrane_175.tiff',
#  '/workspace/myFile/Output/17052023/E0425/ok_membrane_68.tiff',
#  '/workspace/myFile/Output/17052023/A0408/ok_membrane_111.tiff',
#  '/workspace/myFile/Output/17052023/F1012/ok_membrane_259.tiff',
#  '/workspace/myFile/Output/17052023/A1017/ok_membrane_237.tiff',
#  '/workspace/myFile/Output/17052023/F1212/ok_membrane_11.tiff',
#  '/workspace/myFile/Output/17052023/B1010/ok_membrane_1.tiff',
#  '/workspace/myFile/Output/17052023/B1111/ok_membrane_180.tiff',
#  '/workspace/myFile/Output/17052023/E1208/ok_membrane_102.tiff',
#  '/workspace/myFile/Output/17052023/A0617/ok_membrane_133.tiff',
#  '/workspace/myFile/Output/17052023/B0414/ok_membrane_85.tiff',
#  '/workspace/myFile/Output/17052023/C1022/ok_membrane_35.tiff',
#  '/workspace/myFile/Output/17052023/E0508/ok_membrane_205.tiff',
#  '/workspace/myFile/Output/17052023/F1118/ok_membrane_29.tiff',
#  '/workspace/myFile/Output/17052023/E1013/ok_membrane_522.tiff',
#  '/workspace/myFile/Output/17052023/D1112/ok_membrane_32.tiff',
#  '/workspace/myFile/Output/17052023/E0516/ok_membrane_19.tiff',
#  '/workspace/myFile/Output/17052023/A1112/ok_membrane_567.tiff',
#  '/workspace/myFile/Output/17052023/E0418/ok_membrane_58.tiff',
#  '/workspace/myFile/Output/17052023/B0608/ok_membrane_41.tiff',
#  '/workspace/myFile/Output/17052023/C1112/ok_membrane_194.tiff',
#  '/workspace/myFile/Output/17052023/F1107/ok_membrane_175.tiff',
#  '/workspace/myFile/Output/17052023/A1005/ok_membrane_116.tiff',
#  '/workspace/myFile/Output/17052023/F1004/ok_membrane_99.tiff',
#  '/workspace/myFile/Output/17052023/E1107/ok_membrane_56.tiff',
#  '/workspace/myFile/Output/17052023/A1214/ok_membrane_44.tiff',
#  '/workspace/myFile/Output/17052023/F1220/ok_membrane_8.tiff',
#  '/workspace/myFile/Output/17052023/A1023/ok_membrane_218.tiff',
#  '/workspace/myFile/Output/17052023/A0513/ok_membrane_895.tiff',
#  '/workspace/myFile/Output/17052023/E1012/ok_membrane_368.tiff',
#  '/workspace/myFile/Output/17052023/A1225/ok_membrane_174.tiff',
#  '/workspace/myFile/Output/17052023/A0507/ok_membrane_581.tiff',
#  '/workspace/myFile/Output/17052023/A0624/ok_membrane_101.tiff',
#  '/workspace/myFile/Output/17052023/B0603/ok_membrane_45.tiff',
#  '/workspace/myFile/Output/17052023/E1007/ok_membrane_203.tiff',
#  '/workspace/myFile/Output/17052023/F1109/ok_membrane_24.tiff',
#  '/workspace/myFile/Output/17052023/E0511/ok_membrane_74.tiff',
#  '/workspace/myFile/Output/17052023/E0605/ok_membrane_9.tiff',
#  '/workspace/myFile/Output/17052023/E1007/ok_membrane_129.tiff',
#  '/workspace/myFile/Output/17052023/A0625/ok_membrane_75.tiff',
#  '/workspace/myFile/Output/17052023/D1108/ok_membrane_26.tiff',
#  '/workspace/myFile/Output/17052023/F0407/ok_membrane_126.tiff',
#  '/workspace/myFile/Output/17052023/A0409/ok_membrane_59.tiff',
#  '/workspace/myFile/Output/17052023/E1124/ok_membrane_39.tiff',
#  '/workspace/myFile/Output/17052023/B0520/ok_membrane_27.tiff',
#  '/workspace/myFile/Output/17052023/E1208/ok_membrane_70.tiff',
#  '/workspace/myFile/Output/17052023/B1107/ok_membrane_110.tiff',
#  '/workspace/myFile/Output/17052023/B1217/ok_membrane_8.tiff',
#  '/workspace/myFile/Output/17052023/A1112/ok_membrane_49.tiff',
#  '/workspace/myFile/Output/17052023/B0417/ok_membrane_11.tiff',
#  '/workspace/myFile/Output/17052023/A0408/ok_membrane_995.tiff',
#  '/workspace/myFile/Output/17052023/A0413/ok_membrane_648.tiff',
#  '/workspace/myFile/Output/17052023/E1003/ok_membrane_104.tiff',
#  '/workspace/myFile/Output/17052023/B1124/ok_membrane_11.tiff',
#  '/workspace/myFile/Output/17052023/A0606/ok_membrane_62.tiff',
#  '/workspace/myFile/Output/17052023/E1008/ok_membrane_38.tiff',
#  '/workspace/myFile/Output/17052023/F1113/ok_membrane_84.tiff',
#  '/workspace/myFile/Output/17052023/F1221/ok_membrane_75.tiff',
#  '/workspace/myFile/Output/17052023/F0517/ok_membrane_117.tiff',
#  '/workspace/myFile/Output/17052023/A0412/ok_membrane_290.tiff',
#  '/workspace/myFile/Output/17052023/A1016/ok_membrane_165.tiff',
#  '/workspace/myFile/Output/17052023/F0508/ok_membrane_171.tiff',
#  '/workspace/myFile/Output/17052023/A0409/ok_membrane_240.tiff',
#  '/workspace/myFile/Output/17052023/A0418/ok_membrane_385.tiff',
#  '/workspace/myFile/Output/17052023/F1025/ok_membrane_18.tiff',
#  '/workspace/myFile/Output/17052023/A1205/ok_membrane_94.tiff',
#  '/workspace/myFile/Output/17052023/E1208/ok_membrane_262.tiff',
#  '/workspace/myFile/Output/17052023/D1213/ok_membrane_7.tiff',
#  '/workspace/myFile/Output/17052023/A1003/ok_membrane_18.tiff',
#  '/workspace/myFile/Output/17052023/A1215/ok_membrane_72.tiff',
#  '/workspace/myFile/Output/17052023/A0619/ok_membrane_189.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_2103.tiff',
#  '/workspace/myFile/Output/17052023/A1022/ok_membrane_196.tiff',
#  '/workspace/myFile/Output/17052023/B0423/ok_membrane_89.tiff',
#  '/workspace/myFile/Output/17052023/F0619/ok_membrane_112.tiff',
#  '/workspace/myFile/Output/17052023/A1016/ok_membrane_126.tiff',
#  '/workspace/myFile/Output/17052023/C0414/ok_membrane_28.tiff',
#  '/workspace/myFile/Output/17052023/A1005/ok_membrane_1.tiff',
#  '/workspace/myFile/Output/17052023/B0408/ok_membrane_117.tiff',
#  '/workspace/myFile/Output/17052023/F0413/ok_membrane_253.tiff',
#  '/workspace/myFile/Output/17052023/A1001/ok_membrane_146.tiff',
#  '/workspace/myFile/Output/17052023/A1107/ok_membrane_124.tiff',
#  '/workspace/myFile/Output/17052023/A0625/ok_membrane_54.tiff',
#  '/workspace/myFile/Output/17052023/F0518/ok_membrane_238.tiff',
#  '/workspace/myFile/Output/17052023/A0624/ok_membrane_330.tiff',
#  '/workspace/myFile/Output/17052023/F0512/ok_membrane_124.tiff',
#  '/workspace/myFile/Output/17052023/A1118/ok_membrane_280.tiff',
#  '/workspace/myFile/Output/17052023/A0521/ok_membrane_51.tiff',
#  '/workspace/myFile/Output/17052023/A0624/ok_membrane_91.tiff',
#  '/workspace/myFile/Output/17052023/E1114/ok_membrane_150.tiff',
#  '/workspace/myFile/Output/17052023/F1025/ok_membrane_34.tiff',
#  '/workspace/myFile/Output/17052023/A0513/ok_membrane_730.tiff',
#  '/workspace/myFile/Output/17052023/C0622/ok_membrane_7.tiff',
#  '/workspace/myFile/Output/17052023/A0422/ok_membrane_325.tiff',
#  '/workspace/myFile/Output/17052023/E1008/ok_membrane_502.tiff',
#  '/workspace/myFile/Output/17052023/A0606/ok_membrane_397.tiff',
#  '/workspace/myFile/Output/17052023/A1112/ok_membrane_38.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_2051.tiff',
#  '/workspace/myFile/Output/17052023/A0513/ok_membrane_778.tiff',
#  '/workspace/myFile/Output/17052023/E1103/ok_membrane_84.tiff',
#  '/workspace/myFile/Output/17052023/E0417/ok_membrane_96.tiff',
#  '/workspace/myFile/Output/17052023/E1213/ok_membrane_389.tiff',
#  '/workspace/myFile/Output/17052023/A1012/ok_membrane_181.tiff',
#  '/workspace/myFile/Output/17052023/A1203/ok_membrane_251.tiff',
#  '/workspace/myFile/Output/17052023/F1125/ok_membrane_60.tiff',
#  '/workspace/myFile/Output/17052023/A0409/ok_membrane_9.tiff',
#  '/workspace/myFile/Output/17052023/F0513/ok_membrane_353.tiff',
#  '/workspace/myFile/Output/17052023/E0413/ok_membrane_22.tiff',
#  '/workspace/myFile/Output/17052023/A0601/ok_membrane_53.tiff',
#  '/workspace/myFile/Output/17052023/A0607/ok_membrane_38.tiff',
#  '/workspace/myFile/Output/17052023/B1111/ok_membrane_232.tiff',
#  '/workspace/myFile/Output/17052023/E1123/ok_membrane_109.tiff',
#  '/workspace/myFile/Output/17052023/F0413/ok_membrane_397.tiff',
#  '/workspace/myFile/Output/17052023/F0605/ok_membrane_15.tiff',
#  '/workspace/myFile/Output/17052023/E1013/ok_membrane_219.tiff',
#  '/workspace/myFile/Output/17052023/E1013/ok_membrane_193.tiff',
#  '/workspace/myFile/Output/17052023/F1207/ok_membrane_129.tiff',
#  '/workspace/myFile/Output/17052023/E0422/ok_membrane_171.tiff',
#  '/workspace/myFile/Output/17052023/F0417/ok_membrane_77.tiff',
#  '/workspace/myFile/Output/17052023/E1114/ok_membrane_117.tiff',
#  '/workspace/myFile/Output/17052023/E1214/ok_membrane_118.tiff',
#  '/workspace/myFile/Output/17052023/E1122/ok_membrane_22.tiff',
#  '/workspace/myFile/Output/17052023/A0422/ok_membrane_5.tiff',
#  '/workspace/myFile/Output/17052023/A0513/ok_membrane_596.tiff',
#  '/workspace/myFile/Output/17052023/E0614/ok_membrane_83.tiff',
#  '/workspace/myFile/Output/17052023/E0602/ok_membrane_31.tiff',
#  '/workspace/myFile/Output/17052023/F0517/ok_membrane_498.tiff',
#  '/workspace/myFile/Output/17052023/F0417/ok_membrane_58.tiff',
#  '/workspace/myFile/Output/17052023/A1213/ok_membrane_146.tiff',
#  '/workspace/myFile/Output/17052023/B0522/ok_membrane_51.tiff',
#  '/workspace/myFile/Output/17052023/D1007/ok_membrane_20.tiff',
#  '/workspace/myFile/Output/17052023/A0519/ok_membrane_89.tiff',
#  '/workspace/myFile/Output/17052023/F0623/ok_membrane_160.tiff',
#  '/workspace/myFile/Output/17052023/C1003/ok_membrane_165.tiff',
#  '/workspace/myFile/Output/17052023/A1011/ok_membrane_77.tiff',
#  '/workspace/myFile/Output/17052023/E0417/ok_membrane_100.tiff',
#  '/workspace/myFile/Output/17052023/F0615/ok_membrane_105.tiff',
#  '/workspace/myFile/Output/17052023/A0424/ok_membrane_46.tiff',
#  '/workspace/myFile/Output/17052023/A1102/ok_membrane_53.tiff',
#  '/workspace/myFile/Output/17052023/A1118/ok_membrane_254.tiff',
#  '/workspace/myFile/Output/17052023/E1208/ok_membrane_156.tiff',
#  '/workspace/myFile/Output/17052023/B0423/ok_membrane_23.tiff',
#  '/workspace/myFile/Output/17052023/C0417/ok_membrane_129.tiff',
#  '/workspace/myFile/Output/17052023/A0507/ok_membrane_456.tiff',
#  '/workspace/myFile/Output/17052023/A0424/ok_membrane_335.tiff',
#  '/workspace/myFile/Output/17052023/E1020/ok_membrane_30.tiff',
#  '/workspace/myFile/Output/17052023/B1011/ok_membrane_3.tiff',
#  '/workspace/myFile/Output/17052023/A0612/ok_membrane_457.tiff',
#  '/workspace/myFile/Output/17052023/A1214/ok_membrane_265.tiff',
#  '/workspace/myFile/Output/17052023/E1208/ok_membrane_323.tiff',
#  '/workspace/myFile/Output/17052023/E0613/ok_membrane_132.tiff',
#  '/workspace/myFile/Output/17052023/A0625/ok_membrane_406.tiff',
#  '/workspace/myFile/Output/17052023/A1225/ok_membrane_11.tiff',
#  '/workspace/myFile/Output/17052023/F1115/ok_membrane_28.tiff',
#  '/workspace/myFile/Output/17052023/B1123/ok_membrane_83.tiff',
#  '/workspace/myFile/Output/17052023/E0518/ok_membrane_81.tiff',
#  '/workspace/myFile/Output/17052023/A0418/ok_membrane_588.tiff',
#  '/workspace/myFile/Output/17052023/D1203/ok_membrane_9.tiff',
#  '/workspace/myFile/Output/17052023/B0608/ok_membrane_48.tiff',
#  '/workspace/myFile/Output/17052023/E1017/ok_membrane_178.tiff',
#  '/workspace/myFile/Output/17052023/B0522/ok_membrane_42.tiff',
#  '/workspace/myFile/Output/17052023/A0403/ok_membrane_457.tiff',
#  '/workspace/myFile/Output/17052023/A0409/ok_membrane_67.tiff',
#  '/workspace/myFile/Output/17052023/A0409/ok_membrane_222.tiff',
#  '/workspace/myFile/Output/17052023/A0601/ok_membrane_274.tiff',
#  '/workspace/myFile/Output/17052023/A0524/ok_membrane_238.tiff',
#  '/workspace/myFile/Output/17052023/A0407/ok_membrane_450.tiff',
#  '/workspace/myFile/Output/17052023/A1008/ok_membrane_498.tiff',
#  '/workspace/myFile/Output/17052023/A1111/ok_membrane_73.tiff',
#  '/workspace/myFile/Output/17052023/A0520/ok_membrane_82.tiff',
#  '/workspace/myFile/Output/17052023/A0607/ok_membrane_216.tiff',
#  '/workspace/myFile/Output/17052023/E1021/ok_membrane_44.tiff',
#  '/workspace/myFile/Output/17052023/B0619/ok_membrane_10.tiff',
#  '/workspace/myFile/Output/17052023/A0402/ok_membrane_139.tiff',
#  '/workspace/myFile/Output/17052023/E0408/ok_membrane_133.tiff',
#  '/workspace/myFile/Output/17052023/F1003/ok_membrane_174.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_1460.tiff',
#  '/workspace/myFile/Output/17052023/F0615/ok_membrane_47.tiff',
#  '/workspace/myFile/Output/17052023/C1203/ok_membrane_61.tiff',
#  '/workspace/myFile/Output/17052023/F1118/ok_membrane_124.tiff',
#  '/workspace/myFile/Output/17052023/F0513/ok_membrane_192.tiff',
#  '/workspace/myFile/Output/17052023/F0519/ok_membrane_19.tiff',
#  '/workspace/myFile/Output/17052023/E0422/ok_membrane_42.tiff',
#  '/workspace/myFile/Output/17052023/A1020/ok_membrane_112.tiff',
#  '/workspace/myFile/Output/17052023/F0407/ok_membrane_142.tiff',
#  '/workspace/myFile/Output/17052023/A0612/ok_membrane_459.tiff',
#  '/workspace/myFile/Output/17052023/E0517/ok_membrane_173.tiff',
#  '/workspace/myFile/Output/17052023/A1118/ok_membrane_326.tiff',
#  '/workspace/myFile/Output/17052023/C0620/ok_membrane_114.tiff',
#  '/workspace/myFile/Output/17052023/F0412/ok_membrane_59.tiff',
#  '/workspace/myFile/Output/17052023/C0518/ok_membrane_39.tiff',
#  '/workspace/myFile/Output/17052023/A1212/ok_membrane_337.tiff',
#  '/workspace/myFile/Output/17052023/C1204/ok_membrane_89.tiff',
#  '/workspace/myFile/Output/17052023/A1023/ok_membrane_164.tiff',
#  '/workspace/myFile/Output/17052023/E1009/ok_membrane_59.tiff',
#  '/workspace/myFile/Output/17052023/F0407/ok_membrane_17.tiff',
#  '/workspace/myFile/Output/17052023/A1022/ok_membrane_39.tiff',
#  '/workspace/myFile/Output/17052023/E0414/ok_membrane_67.tiff',
#  '/workspace/myFile/Output/17052023/A0606/ok_membrane_150.tiff',
#  '/workspace/myFile/Output/17052023/D0618/ok_membrane_8.tiff',
#  '/workspace/myFile/Output/17052023/E0409/ok_membrane_80.tiff',
#  '/workspace/myFile/Output/17052023/A1022/ok_membrane_322.tiff',
#  '/workspace/myFile/Output/17052023/E0511/ok_membrane_65.tiff',
#  '/workspace/myFile/Output/17052023/F1108/ok_membrane_126.tiff',
#  '/workspace/myFile/Output/17052023/A1115/ok_membrane_115.tiff',
#  '/workspace/myFile/Output/17052023/B1010/ok_membrane_22.tiff',
#  '/workspace/myFile/Output/17052023/C1113/ok_membrane_177.tiff',
#  '/workspace/myFile/Output/17052023/A0413/ok_membrane_776.tiff',
#  '/workspace/myFile/Output/17052023/E1111/ok_membrane_67.tiff',
#  '/workspace/myFile/Output/17052023/E1021/ok_membrane_72.tiff',
#  '/workspace/myFile/Output/17052023/A1203/ok_membrane_506.tiff',
#  '/workspace/myFile/Output/17052023/A1123/ok_membrane_257.tiff',
#  '/workspace/myFile/Output/17052023/D1012/ok_membrane_134.tiff',
#  '/workspace/myFile/Output/17052023/A1123/ok_membrane_32.tiff',
#  '/workspace/myFile/Output/17052023/B1025/ok_membrane_2.tiff',
#  '/workspace/myFile/Output/17052023/F0607/ok_membrane_12.tiff',
#  '/workspace/myFile/Output/17052023/C1009/ok_membrane_10.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_1131.tiff',
#  '/workspace/myFile/Output/17052023/C1117/ok_membrane_106.tiff',
#  '/workspace/myFile/Output/17052023/A1011/ok_membrane_44.tiff',
#  '/workspace/myFile/Output/17052023/E1002/ok_membrane_82.tiff',
#  '/workspace/myFile/Output/17052023/A1112/ok_membrane_404.tiff',
#  '/workspace/myFile/Output/17052023/E1213/ok_membrane_143.tiff',
#  '/workspace/myFile/Output/17052023/B1207/ok_membrane_31.tiff',
#  '/workspace/myFile/Output/17052023/A1008/ok_membrane_584.tiff',
#  '/workspace/myFile/Output/17052023/B0507/ok_membrane_27.tiff',
#  ...]

# %%
imDr = "/workspace/myFile/Output/17052023/"  # Image patches directory

labels = ['Damaged', 'Undamaged']  # Your labels

# %%
# For data augmentation
def get_transform(train):
    transforms = []

    transforms.append(T.ToTensor())
    transforms.append(T.Normalize([0.0019368887995516483], [0.00672996630111016]))
    #transforms.append(T.RandomHorizontalFlip(0.5))
    
    if train:
        transforms.append(T.RandomHorizontalFlip())
        transforms.append(T.RandomVerticalFlip())
    
    return T.Compose(transforms)

# %%
def train_model(model, criterion, optimizer, scheduler, dataloaderTrain, dataloaderTest, num_epochs=25):
    since = time.time()
    # Create a temporary directory to save training checkpoints
    with TemporaryDirectory() as tempdir:
        best_model_params_path = os.path.join(tempdir, 'best_model_params.pt')

        torch.save(model.state_dict(), best_model_params_path)
        best_acc = 0.0

        for epoch in range(num_epochs):
            print(f'Epoch {epoch}/{num_epochs - 1}')
            print('-' * 10)

            # Each epoch has a training and validation phase
            for phase in ['train', 'val']:
                if phase == 'train':
                    model.train()  # Set model to training mode
                    dataloaders = dataloaderTrain
                else:
                    model.eval()   # Set model to evaluate mode
                    dataloaders = dataloaderTest

                running_loss = 0.0
                running_corrects = 0

                # Iterate over data.
                for inputs, labels, imNo in dataloaders:
                    inputs = inputs.to(device)
                    labels = labels.to(device)

                    # zero the parameter gradients
                    optimizer.zero_grad()

                    # forward
                    # track history if only in train
                    with torch.set_grad_enabled(phase == 'train'):
                        outputs = model(inputs)
                        _, preds = torch.max(outputs, 1)
                        loss = criterion(outputs, labels)
                        # backward + optimize only if in training phase
                        if phase == 'train':
                            loss.backward()
                            optimizer.step()

                    # statistics
                    running_loss += loss.item() * inputs.size(0)    # Loss
                    running_corrects += torch.sum(preds == labels.data) # Accuracy

                if phase == 'train':
                    scheduler.step()

                epoch_loss = running_loss / dataset_sizes[phase]    # Loss metric per epoch
                epoch_acc = running_corrects.double() / dataset_sizes[phase]    # Accuracy metric per epoch

                if phase == "train":    # This is the tensorboard code that writes accuracy and loss metrics
                    writer.add_scalar("Train/Accuracy", epoch_acc, epoch)
                    writer.add_scalar("Train/Loss", epoch_loss, epoch)
                else:
                    writer.add_scalar("Validation/Accuracy", epoch_acc, epoch)
                    writer.add_scalar("Validation/Loss", epoch_loss, epoch)

                print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

                # deep copy the model
                if phase == 'val' and epoch_acc > best_acc: 
                    # This compares validation accuracy to previous bests and adjusts model weights accordingly
                    best_acc = epoch_acc
                    torch.save(model.state_dict(), best_model_params_path)

            print()

        time_elapsed = time.time() - since  # Nice way to measure training time but info also stored (indirectly) by tensorboard
        print(
            f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
        print(f'Best val Acc: {best_acc:4f}')
        labels= labels.cpu().numpy()
        preds=preds.cpu().numpy()
        con_mat = confusion_matrix(labels, preds)   # Confusion matrix compares true class with predicted class
        # load best model weights
        model.load_state_dict(torch.load(best_model_params_path))
    writer.close()
    return model, con_mat   # We want to return the model because its the model, also confusion matrix for later analysis

# %%
# This is your RESNET
# Initialize CNN with kaiming
def init_cnn(m):
    # Set the weights of the RESNET
    if getattr(m, 'bias', None) is not None: nn.init.constant_(m.bias, 0)
    if isinstance(m, (nn.Conv2d,nn.Linear)): nn.init.kaiming_normal_(m.weight)
    for l in m.children(): init_cnn(l)


# noop function for returning nothing
def noop(x): return x
# activation function(RELU)
act_fn = nn.ReLU(inplace=True)

# Flatten
class Flatten(nn.Module):
    def forward(self, x): return x.view(x.size(0), -1)

# Make a convolution
def conv(ni, nf, ks=3, stride=1, bias=False):
    return nn.Conv2d(ni, nf, kernel_size=ks, stride=stride, padding=ks//2, bias=bias)

# Create a convuolutional layer with convolution and batch norm
def conv_layer(ni, nf, ks=3, stride=1, zero_bn=False, act=True):
    bn = nn.BatchNorm2d(nf) # get a 2d batch norm from Pytorhc
    nn.init.constant_(bn.weight, 0. if zero_bn else 1.)
    layers = [conv(ni, nf, ks, stride=stride), bn]
    if act: layers.append(act_fn) # add in the activation function if act is true
    return nn.Sequential(*layers)


# Resblock
class ResBlock(nn.Module):
    def __init__(self, expansion, ni, nh, stride = 1):
        super().__init__()
        # ni - number of inputs channels, nf - number of filters
        # nh - number of filters in first conv
        # expansion is 1 for resnet 18, 34 and 4 for larger networks
        nf, ni = nh*expansion, ni*expansion
        layers = [conv_layer(ni, nh, 3, stride = stride), # for resnet < 34 2 convs per resblock
                 conv_layer(nh, nf, 3, zero_bn = True, act = False)
                 ] if expansion == 1 else [ # for RESNET > 34 then 3 convs per block with bottleneck
                            conv_layer(ni, nh, 1),
                            conv_layer(nh, nh, 3, stride = stride),
                            conv_layer(nh, nf, 1, zero_bn = True, act = False)
        ]
        self.convs = nn.Sequential(*layers) # Creates the conv layers
        self.idconv = noop if ni==nf else conv_layer(ni, nf, 1, act = False) # id convolution ()
        self.pool = noop if stride== 1 else nn.AvgPool2d(2, ceil_mode = True) # average pool on 
        
    def forward(self, x): 
        # Forward function adds the convolution part to the id part 
        #return act_fn(self.convs(x)) + self.idconv(self.pool(x))
        return act_fn(self.convs(x) + self.idconv(self.pool(x)))

# XResnet
class XResNet(nn.Sequential):
    @classmethod
    def create(cls, expansion, layers, c_in=3, c_out=1000):
        nfs = [c_in, (c_in + 1)*8, 64, 64] # number of filters in stem layer (c_in is number of image channels)
        stem = [conv_layer(nfs[i], nfs[i+1], stride=2 if i==0 else 1)
            for i in range(3)]

        nfs = [64//expansion,64,128,256,512]
        res_layers = [cls._make_layer(expansion, nfs[i], nfs[i+1],
                                      n_blocks=l, stride=1 if i==0 else 2)
                  for i,l in enumerate(layers)]
        res = cls(
        *stem,
        nn.MaxPool2d(kernel_size=3, stride = 2, padding = 1), # then a max pooling layer
        *res_layers,
        nn.AdaptiveAvgPool2d(1), Flatten(), 
        nn.Linear(nfs[-1]*expansion, c_out)
        )
        init_cnn(res)
        return res
        
    @staticmethod
    def _make_layer(expansion, ni, nf, n_blocks, stride): # returns a resblock
        return nn.Sequential(
        *[ResBlock(expansion, ni if i==0 else nf, nf, stride if i==0 else 1)
         for i in range(n_blocks)])

# %%
def xresnet18 (**kwargs): return XResNet.create(1, [2, 2,  2, 2], **kwargs)
def xresnet34 (**kwargs): return XResNet.create(1, [3, 4,  6, 3], **kwargs)
def xresnet50 (**kwargs): return XResNet.create(4, [3, 4,  6, 3], **kwargs)
model = xresnet18(c_in = 1, c_out = 2)
#model = xresnet34(c_in = 1, c_out = 2)
#model = xresnet50(c_in = 1, c_out = 2)
model = model.to(device)

# Label smoothing cross entropy
import torch.nn.functional as F


def reduce_loss(loss, reduction='mean'):
    return loss.mean() if reduction=='mean' else loss.sum() if reduction=='sum' else loss

class LabelSmoothingCrossEntropy(nn.Module):
    def __init__(self, ε:float=0.1, reduction='mean'):
        super().__init__()
        self.ε,self.reduction = ε,reduction
    
    def forward(self, output, target):
        c = output.size()[-1]
        log_preds = F.log_softmax(output, dim=-1)
        loss = reduce_loss(-log_preds.sum(dim=-1), self.reduction)
        nll = F.nll_loss(log_preds, target, reduction=self.reduction)
        return lin_comb(loss/c, nll, self.ε)

# %%
# Helper functions that shows the image, true class, predicted class and degree of prediction

def images_to_probs(net, images):
    '''
    Generates predictions and corresponding probabilities from a trained
    network and a list of images
    '''
    output = net(images)
    # convert output probabilities to predicted class
    _, preds_tensor = torch.max(output, 1)
    preds = np.squeeze(preds_tensor.numpy())
    return preds, [F.softmax(el, dim=0)[i].item() for i, el in zip(preds, output)]


def plot_classes_preds(net, images, labels):
    '''
    Generates matplotlib Figure using a trained network, along with images
    and labels from a batch, that shows the network's top prediction along
    with its probability, alongside the actual label, coloring this
    information based on whether the prediction was correct or not.
    Uses the "images_to_probs" function.
    '''
    preds, probs = images_to_probs(net, images)
    # plot the images in the batch, along with predicted and true labels
    fig = plt.figure(figsize=(12, 48))
    for idx in np.arange(4):
        ax = fig.add_subplot(1, 4, idx+1, xticks=[], yticks=[])
        matplotlib_imshow(images[idx], one_channel=True)
        ax.set_title("{0}, {1:.1f}%\n(label: {2})".format(
            labels[preds[idx]],
            probs[idx] * 100.0,
            labels[labels[idx]]),
                    color=("green" if preds[idx]==labels[idx].item() else "red"))
    return fig

def matplotlib_imshow(img, one_channel=True):
    if one_channel:
        img = img.mean(dim=0)
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    if one_channel:
        plt.imshow(npimg, cmap="Greys")
    else:
        plt.imshow(np.transpose(npimg, (1, 2, 0)))

# %%
def confusion_matrix_calc(data_loader_test, classes, model_ft):       
        y_pred = []
        y_true = []
        for inputs, labels, imNo in data_loader_test:
                inputs = inputs.to(device)
                labels = labels.to(device)
                output = model_ft(inputs) # Feed Network

                output = (torch.max(torch.exp(output), 1)[1]).data.cpu().numpy()
                y_pred.extend(output) # Save Prediction
                
                labels = labels.data.cpu().numpy()
                y_true.extend(labels) # Save Truth

        # constant for classes
        # classes = ('Alive', 'Dead')

        # Build confusion matrix
        cf_matrix = confusion_matrix(y_true, y_pred)
        return cf_matrix

# %%
torch.manual_seed(10)
imIdx = torch.randperm(101106).tolist()

## Create dataset
dataSetTrain = DNADataset(imDr, get_transform(train = True), labels, imDx=imIdx)
dataSetTest = DNADataset(imDr, get_transform(train = False), labels, imDx=imIdx)

# ## Create dataloaders
# Get subset
torch.manual_seed(10)
indices = torch.randperm(len(dataSetTrain)).tolist()

noTrain = int(len(dataSetTrain)*0.7)

dataset_train = torch.utils.data.Subset(dataSetTrain, indices[-noTrain:])
dataset_test = torch.utils.data.Subset(dataSetTest, indices[:-noTrain])
#len(indices), len(indices[:-50]), len(indices[-50:]), 50/191, type(dataset_test)

dataset_sizes = {'train': len(dataset_train), 'val': len(dataset_test)}

# define training and validation data loaders
data_loader_train = torch.utils.data.DataLoader(
    dataset_train, batch_size=20, shuffle=True, num_workers=0)

data_loader_test = torch.utils.data.DataLoader(
    dataset_test, batch_size=1, shuffle=False, num_workers=0)


# Collate function (gathers together the outputs)
# def collate_fn(batch):
#     return tuple(zip(*batch))

len(indices[-noTrain:]), dataset_sizes
#dataset_test[0][1], dataset_test[3][1], dataset_test[-1][1], dataSetTrain.imgs
# Out:
# (12429, {'train': 12429, 'val': 5328})

# %%
criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.Adam(model.parameters(), weight_decay=1e-2) # standard ADAM optimiser

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %%
model_ft, con_mat = train_model(model, criterion, optimizer_ft, exp_lr_scheduler,
                       data_loader_train,data_loader_test,num_epochs=20)
# Out:
# Epoch 0/19
# ----------
# train Loss: 0.5875 Acc: 0.6968
# val Loss: 0.7457 Acc: 0.4979
#
# Epoch 1/19
# ----------
# train Loss: 0.5759 Acc: 0.7108
# val Loss: 0.6008 Acc: 0.7104
#
# Epoch 2/19
# ----------
# train Loss: 0.5664 Acc: 0.7178
# val Loss: 2.0932 Acc: 0.4979
#
# Epoch 3/19
# ----------
# train Loss: 0.5543 Acc: 0.7291
# val Loss: 0.5260 Acc: 0.7577
#
# Epoch 4/19
# ----------
# train Loss: 0.5387 Acc: 0.7384
# val Loss: 0.8008 Acc: 0.4979
#
# Epoch 5/19
# ----------
# train Loss: 0.5304 Acc: 0.7465
# val Loss: 0.8966 Acc: 0.4979
#
# Epoch 6/19
# ----------
# train Loss: 0.5256 Acc: 0.7483
# val Loss: 0.6156 Acc: 0.6520
#
# Epoch 7/19
# ----------
# train Loss: 0.5138 Acc: 0.7544
# val Loss: 0.5049 Acc: 0.7605
#
# Epoch 8/19
# ----------
# train Loss: 0.5115 Acc: 0.7557
# val Loss: 0.5096 Acc: 0.7551
#
# Epoch 9/19
# ----------
# train Loss: 0.5117 Acc: 0.7565
# val Loss: 0.5004 Acc: 0.7614
#
# Epoch 10/19
# ----------
# train Loss: 0.5097 Acc: 0.7608
# val Loss: 0.4975 Acc: 0.7626
#
# Epoch 11/19
# ----------
# train Loss: 0.5087 Acc: 0.7559
# val Loss: 0.5134 Acc: 0.7598
#
# Epoch 12/19
# ----------
# train Loss: 0.5093 Acc: 0.7628
# val Loss: 0.4958 Acc: 0.7675
#
# Epoch 13/19
# ----------
# train Loss: 0.5053 Acc: 0.7596
# val Loss: 0.5325 Acc: 0.7571
#
# Epoch 14/19
# ----------
# train Loss: 0.5076 Acc: 0.7569
# val Loss: 0.4954 Acc: 0.7626
#
# Epoch 15/19
# ----------
# train Loss: 0.5010 Acc: 0.7637
# val Loss: 0.4923 Acc: 0.7661
#
# Epoch 16/19
# ----------
# train Loss: 0.5055 Acc: 0.7583
# val Loss: 0.4918 Acc: 0.7667
#
# Epoch 17/19
# ----------
# train Loss: 0.5019 Acc: 0.7671
# val Loss: 0.4924 Acc: 0.7678
#
# Epoch 18/19
# ----------
# train Loss: 0.5034 Acc: 0.7611
# val Loss: 0.4929 Acc: 0.7691
#
# Epoch 19/19
# ----------
# train Loss: 0.5034 Acc: 0.7607
# val Loss: 0.4952 Acc: 0.7645
#
# Training complete in 38m 22s
# Best val Acc: 0.769144

# %%
cf_matrix = confusion_matrix_calc(data_loader_test, labels, model_ft)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_590/1423241247.py in <module>
# ----> 1 cf_matrix = confusion_matrix_calc(data_loader_test, labels, model_ft)
#
# NameError: name 'confusion_matrix_calc' is not defined

# %%
df_cm_ratio = pd.DataFrame(cf_matrix / np.sum(cf_matrix, axis=1)[:, None], index=[i for i in labels],
                     columns=[i for i in labels])
plt.figure(figsize=(12, 7))
sn.heatmap(df_cm_ratio, annot=True)
# plt.save("Confusion_matrix_ratio.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_590/3366797743.py in <module>
# ----> 1 df_cm_ratio = pd.DataFrame(cf_matrix / np.sum(cf_matrix, axis=1)[:, None], index=[i for i in labels],
#       2                      columns=[i for i in labels])
#       3 plt.figure(figsize=(12, 7))
#       4 sn.heatmap(df_cm_ratio, annot=True)
#       5 # plt.save("Confusion_matrix_ratio.png")
#
# NameError: name 'cf_matrix' is not defined

# %%
df_cm_raw = pd.DataFrame(cf_matrix, index=[i for i in labels],
                     columns=[i for i in labels])
plt.figure(figsize=(12, 7))
sn.heatmap(df_cm_raw, annot=True)
# plt.save("Confusion_matrix_raw.png")
# Out:
# <AxesSubplot:>

# %%
cf_matrix
# Out:
# array([[1994,  659],
#        [ 571, 2104]])
