# %% [markdown]
# ### To note: Running this on different systems (i.e. local, SCW, server) will result in slight changes needing to the code

# %%
# Load libraries
import os
import numpy as np
import torch
import sys
import torchvision
import torchvision.transforms as T
import torchvision.models as models
from PIL import Image
from PIL import ImageEnhance
import matplotlib.pyplot as plt
import imagesize
import subprocess
sys.path
from IPython.core.debugger import set_trace
import scipy.ndimage
import matplotlib.patches as patches
# plt.rcParams['figure.figsize'] = [12,12]
# sys.path.append('/workspace/myFile/Mask_RCNN_Tutorial/')
from tqdm import tqdm
from torch import nn as nn
from torch import optim as optim
from torch.optim import lr_scheduler
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
import re
import time
import copy
import pylab
from torch.utils.tensorboard import SummaryWriter
from tempfile import TemporaryDirectory
import torch.backends.cudnn as cudnn
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import seaborn as sn
import pandas as pd
import glob
# Rather than have a messy notebook with a load of functions we can store them in separate .py files and import them

cudnn.benchmark = True
plt.ion()   # interactive mode
# Out:
# /opt/conda/lib/python3.8/site-packages/scipy/__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
# %load_ext tensorboard
writer = SummaryWriter("Experiments/09085epoch")    # This determines the tensorboard file name

# %%
class DNADataset(object):
    def __init__(self, root, transforms, labels, imDx = False):
        self.root, self.transforms, self.labels = root, transforms, labels
        self.imgDir=[]
        # load all image files, sorting them to ensure they are aligned
        for drug in ["A","B","C","D","E","F"]:
            subset=glob.glob(root+drug+"*/*.tiff")
            np.random.shuffle(subset)
            subset=subset[:]
            self.imgDir=self.imgDir+subset
        Damagednuclei= [x for x in self.imgDir if 'Damaged_nuclei_' in x]
        Undamagednuclei= [x for x in self.imgDir if "No_damage_nuclei" in x]
        #np.random.shuffle(Undamagednuclei)
        #Undamagednuclei=Undamagednuclei[:10000]
        self.imgDir= Damagednuclei+Undamagednuclei
        size80=[]
        for x in self.imgDir:
            img = Image.open(x) # Open image
            w,h=img.size
            if w<=80 and h<=80:
                size80.append(x)
        self.imgDir=size80              
        
        self.imgs = sorted(self.imgDir) # list of images

        

        
    def __getitem__(self, idx):
        img_path = self.imgs[idx]
       
        # Transform images into tensors
        img = Image.open(img_path) # Open image
        w,h=img.size
        img = np.array(img) # Convert image into an array
        img = np.float32(np.divide(img, 2**16)) # Ensure all values are floats
        
        result=np.zeros((80,80), dtype=np.float32)
        x_center = (80 - w) // 2
        y_center = (80 - h) // 2 # copy img image into center of result image
        result[y_center:y_center+h, x_center:x_center+w] = img
        img = result
        
        targetlab=""
        if img_path.find('No_damage_nuclei') != -1:
            targetlab= 'Undamaged'
        if img_path.find('Damaged_nuclei_') != -1:
            targetlab= 'Damaged'  # Find labels corresponding to image
        target = self.labels.index(targetlab) # Get the label and assign to a value
        
        # Convert label to tensor
        #torch.to
        
        if self.transforms is not None:
            img = self.transforms(img)
#             #print('In the transforms')
        imNo = idx
        return img, target, imNo
        
    def __len__(self):
        return len(self.imgs)

# %%
root="/workspace/myFile/Output/17052023/"
p= glob.glob(root+"*/*.tiff")
Damagednuclei= [x for x in p if 'Damaged_nuclei_' in x]
Undamagednuclei= [x for x in p if "No_damage_nuclei" in x]
#np.random.shuffle(Undamagednuclei)
#Undamagednuclei=Undamagednuclei[:10000]
#Undamagednuclei

# %%
imDr = "/workspace/myFile/Output/17052023/"  # Image patches directory

labels = ['Damaged', 'Undamaged']  # Your labels

# %%
# For data augmentation
def get_transform(train):
    transforms = []

    transforms.append(T.ToTensor())
    #transforms.append(T.Normalize([0.0019368887995516483], [0.00672996630111016]))
    #transforms.append(T.RandomHorizontalFlip(0.5))
    
    if train:
        transforms.append(T.RandomHorizontalFlip(p=0.5))
        transforms.append(T.RandomVerticalFlip(p=0.5))
    
    return T.Compose(transforms)

# %%
def train_model(model, criterion, optimizer, scheduler, train, test, num_epochs=25):
    since = time.time()
    # Create a temporary directory to save training checkpoints
    with TemporaryDirectory() as tempdir:
        best_model_params_path = os.path.join(tempdir, 'best_model_params.pt')

        torch.save(model.state_dict(), best_model_params_path)
        best_acc = 0.0
        
        for epoch in range(num_epochs):
            print(f'Epoch {epoch}/{num_epochs - 1}')
            print('-' * 10)
            dataset_train = torch.utils.data.Subset(dataSetTrain, train[epoch])
            dataset_test = torch.utils.data.Subset(dataSetTest, test[epoch])
            data_loader_train = torch.utils.data.DataLoader(
                dataset_train, batch_size=128, shuffle=True, num_workers=0)

            data_loader_test = torch.utils.data.DataLoader(
                dataset_test, batch_size=128, shuffle=False, num_workers=0)
            # Each epoch has a training and validation phase
            for phase in ['train', 'val']:
                if phase == 'train':
                    model.train()  # Set model to training mode
                    dataloaders = data_loader_train
                else:
                    model.eval()   # Set model to evaluate mode
                    dataloaders = data_loader_test

                running_loss = 0.0
                running_corrects = 0
                damaged_len=0
                damaged_corrects = 0
                undamaged_len=0
                undamaged_corrects = 0

                # Iterate over data.
                for inputs, labels, imNo in dataloaders:
                    inputs = inputs.to(device)
                    labels = labels.to(device)

                    # zero the parameter gradients
                    optimizer.zero_grad()

                    # forward
                    # track history if only in train
                    with torch.set_grad_enabled(phase == 'train'):
                        outputs = model(inputs)
                        _, preds = torch.max(outputs, 1)
                        loss = criterion(outputs, labels)
                        # backward + optimize only if in training phase
                        if phase == 'train':
                            loss.backward()
                            optimizer.step()

                    # statistics
                    running_loss += loss.item() * inputs.size(0)    # Loss
                    nada=torch.tensor(np.zeros(len(labels))).to(device)
                    uno=nada+1
                    falseneg=preds+1
                    falsepos=preds-1
                    FPplusTN=torch.sum(labels==nada)
                    TPplusFN=torch.sum(labels==uno)
                    FN=torch.sum(labels==falseneg)
                    FP=torch.sum(labels==falsepos)
                    TN=FPplusTN-FP
                    TP=TPplusFN-FN
                    running_corrects += torch.sum(preds == labels.data) # Accuracy
                    damaged_len+=TPplusFN
                    damaged_corrects += TP
                    undamaged_len+=FPplusTN
                    undamaged_corrects += TN
                damaged_acc = damaged_corrects / damaged_len
                undamaged_acc = undamaged_corrects/undamaged_len
                epoch_acc= (damaged_acc+undamaged_acc)/2
                
                if phase == 'train':
                    scheduler.step()

                epoch_loss = running_loss / dataset_sizes[phase]    # Loss metric per epoch
                #epoch_acc = running_corrects.double() / dataset_sizes[phase]    # Accuracy metric per epoch

                if phase == "train":    # This is the tensorboard code that writes accuracy and loss metrics
                    writer.add_scalar("Train/Accuracy", epoch_acc, epoch)
                    writer.add_scalar("Train/Loss", epoch_loss, epoch)
                else:
                    writer.add_scalar("Validation/Accuracy", epoch_acc, epoch)
                    writer.add_scalar("Validation/Loss", epoch_loss, epoch)

                print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

                # deep copy the model
                if phase == 'val' and epoch_acc >= best_acc: 
                    # This compares validation accuracy to previous bests and adjusts model weights accordingly
                    best_acc = epoch_acc
                    torch.save(model.state_dict(), best_model_params_path)
                    con_mat= torch.tensor([[damaged_corrects, damaged_len-damaged_corrects],[undamaged_len-undamaged_corrects,undamaged_corrects]])

            print()

        time_elapsed = time.time() - since  # Nice way to measure training time but info also stored (indirectly) by tensorboard
        print(
            f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
        print(f'Best val Acc: {best_acc:4f}')
        #labels= labels.cpu().numpy()
        #preds=preds.cpu().numpy()
        model.load_state_dict(torch.load(best_model_params_path))
    writer.close()
    return model, con_mat, best_acc   # We want to return the model because its the model, also confusion matrix for later analysis

# %%
# This is your RESNET
# Initialize CNN with kaiming
def init_cnn(m):
    # Set the weights of the RESNET
    if getattr(m, 'bias', None) is not None: nn.init.constant_(m.bias, 0)
    if isinstance(m, (nn.Conv2d,nn.Linear)): nn.init.kaiming_normal_(m.weight)
    for l in m.children(): init_cnn(l)


# noop function for returning nothing
def noop(x): return x
# activation function(RELU)
act_fn = nn.ReLU(inplace=True)

# Flatten
class Flatten(nn.Module):
    def forward(self, x): return x.view(x.size(0), -1)

# Make a convolution
def conv(ni, nf, ks=3, stride=1, bias=False):
    return nn.Conv2d(ni, nf, kernel_size=ks, stride=stride, padding=ks//2, bias=bias)

# Create a convuolutional layer with convolution and batch norm
def conv_layer(ni, nf, ks=3, stride=1, zero_bn=False, act=True):
    bn = nn.BatchNorm2d(nf) # get a 2d batch norm from Pytorhc
    nn.init.constant_(bn.weight, 0. if zero_bn else 1.)
    layers = [conv(ni, nf, ks, stride=stride), bn]
    if act: layers.append(act_fn) # add in the activation function if act is true
    return nn.Sequential(*layers)


# Resblock
class ResBlock(nn.Module):
    def __init__(self, expansion, ni, nh, stride = 1):
        super().__init__()
        # ni - number of inputs channels, nf - number of filters
        # nh - number of filters in first conv
        # expansion is 1 for resnet 18, 34 and 4 for larger networks
        nf, ni = nh*expansion, ni*expansion
        layers = [conv_layer(ni, nh, 3, stride = stride), # for resnet < 34 2 convs per resblock
                 conv_layer(nh, nf, 3, zero_bn = True, act = False)
                 ] if expansion == 1 else [ # for RESNET > 34 then 3 convs per block with bottleneck
                            conv_layer(ni, nh, 1),
                            conv_layer(nh, nh, 3, stride = stride),
                            conv_layer(nh, nf, 1, zero_bn = True, act = False)
        ]
        self.convs = nn.Sequential(*layers) # Creates the conv layers
        self.idconv = noop if ni==nf else conv_layer(ni, nf, 1, act = False) # id convolution ()
        self.pool = noop if stride== 1 else nn.AvgPool2d(2, ceil_mode = True) # average pool on 
        
    def forward(self, x): 
        # Forward function adds the convolution part to the id part 
        #return act_fn(self.convs(x)) + self.idconv(self.pool(x))
        return act_fn(self.convs(x) + self.idconv(self.pool(x)))

# XResnet
class XResNet(nn.Sequential):
    @classmethod
    def create(cls, expansion, layers, c_in=3, c_out=1000):
        nfs = [c_in, (c_in + 1)*8, 64, 64] # number of filters in stem layer (c_in is number of image channels)
        stem = [conv_layer(nfs[i], nfs[i+1], stride=2 if i==0 else 1)
            for i in range(3)]

        nfs = [64//expansion,64,128,256,512]
        res_layers = [cls._make_layer(expansion, nfs[i], nfs[i+1],
                                      n_blocks=l, stride=1 if i==0 else 2)
                  for i,l in enumerate(layers)]
        res = cls(
        *stem,
        nn.MaxPool2d(kernel_size=3, stride = 2, padding = 1), # then a max pooling layer
        *res_layers,
        nn.AdaptiveAvgPool2d(1), Flatten(), 
        nn.Linear(nfs[-1]*expansion, c_out)
        )
        init_cnn(res)
        return res
        
    @staticmethod
    def _make_layer(expansion, ni, nf, n_blocks, stride): # returns a resblock
        return nn.Sequential(
        *[ResBlock(expansion, ni if i==0 else nf, nf, stride if i==0 else 1)
         for i in range(n_blocks)])

# %%
def xresnet18 (**kwargs): return XResNet.create(1, [2, 2,  2, 2], **kwargs)
def xresnet34 (**kwargs): return XResNet.create(1, [3, 4,  6, 3], **kwargs)
def xresnet50 (**kwargs): return XResNet.create(4, [3, 4,  6, 3], **kwargs)
model18 = xresnet18(c_in = 1, c_out = 2)
model34 = xresnet34(c_in = 1, c_out = 2)
model50 = xresnet50(c_in = 1, c_out = 2)

# Label smoothing cross entropy
import torch.nn.functional as F


def reduce_loss(loss, reduction='mean'):
    return loss.mean() if reduction=='mean' else loss.sum() if reduction=='sum' else loss

class LabelSmoothingCrossEntropy(nn.Module):
    def __init__(self, ε:float=0.1, reduction='mean'):
        super().__init__()
        self.ε,self.reduction = ε,reduction
    
    def forward(self, output, target):
        c = output.size()[-1]
        log_preds = F.log_softmax(output, dim=-1)
        loss = reduce_loss(-log_preds.sum(dim=-1), self.reduction)
        nll = F.nll_loss(log_preds, target, reduction=self.reduction)
        return lin_comb(loss/c, nll, self.ε)

# %%
# Helper functions that shows the image, true class, predicted class and degree of prediction

def images_to_probs(net, images):
    '''
    Generates predictions and corresponding probabilities from a trained
    network and a list of images
    '''
    output = net(images)
    # convert output probabilities to predicted class
    _, preds_tensor = torch.max(output, 1)
    preds = np.squeeze(preds_tensor.numpy())
    return preds, [F.softmax(el, dim=0)[i].item() for i, el in zip(preds, output)]


def plot_classes_preds(net, images, labels):
    '''
    Generates matplotlib Figure using a trained network, along with images
    and labels from a batch, that shows the network's top prediction along
    with its probability, alongside the actual label, coloring this
    information based on whether the prediction was correct or not.
    Uses the "images_to_probs" function.
    '''
    preds, probs = images_to_probs(net, images)
    # plot the images in the batch, along with predicted and true labels
    fig = plt.figure(figsize=(12, 48))
    for idx in np.arange(4):
        ax = fig.add_subplot(1, 4, idx+1, xticks=[], yticks=[])
        matplotlib_imshow(images[idx], one_channel=True)
        ax.set_title("{0}, {1:.1f}%\n(label: {2})".format(
            labels[preds[idx]],
            probs[idx] * 100.0,
            labels[labels[idx]]),
                    color=("green" if preds[idx]==labels[idx].item() else "red"))
    return fig

def matplotlib_imshow(img, one_channel=True):
    if one_channel:
        img = img.mean(dim=0)
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    if one_channel:
        plt.imshow(npimg, cmap="Greys")
    else:
        plt.imshow(np.transpose(npimg, (1, 2, 0)))

# %%
def confusion_matrix_calc(data_loader_test, classes, model_ft):       
        y_pred = []
        y_true = []
        for inputs, labels, imNo in data_loader_test:
                inputs = inputs.to(device)
                labels = labels.to(device)
                output = model_ft(inputs) # Feed Network

                output = (torch.max(torch.exp(output), 1)[1]).data.cpu().numpy()
                y_pred.extend(output) # Save Prediction
                
                labels = labels.data.cpu().numpy()
                y_true.extend(labels) # Save Truth

        # constant for classes
        # classes = ('Alive', 'Dead')

        # Build confusion matrix
        cf_matrix = confusion_matrix(y_true, y_pred)
        return cf_matrix

# %%
k=5 #NUMBER OF K FOLDS
epoch=range(30) #NUMBER OF EPOCHS

torch.manual_seed(10)
imIdx = torch.randperm(1).tolist()

## Create dataset
dataSetTrain = DNADataset(imDr, get_transform(train = True), labels, imDx=imIdx)
dataSetTest = DNADataset(imDr, get_transform(train = False), labels, imDx=imIdx)

data_loader_train=[]
data_loader_test=[]

# ## Create dataloaders
# Get subset
torch.manual_seed(10)
TotalSetTrain=list(range(len(dataSetTrain)))
np.random.shuffle(TotalSetTrain)
TotalSetTest=list(range(len(dataSetTest)))
np.random.shuffle(TotalSetTest)

train=[]
test=[]
for epoch in epoch:
    
    Kfifth = len(dataSetTrain)//k
    split= epoch%k
    train.append(TotalSetTrain[(split+1)*Kfifth:]+TotalSetTrain[:Kfifth*split])
    test.append(TotalSetTest[split*Kfifth:(split+1)*Kfifth])

#dataset_train = torch.utils.data.Subset(dataSetTrain, indices[-noTrain:])

#dataset_test = torch.utils.data.Subset(dataSetTest, indices[:-noTrain])
#len(indices), len(indices[:-50]), len(indices[-50:]), 50/191, type(dataset_test)

dataset_sizes = {'train': len(train[0]), 'val': len(test[0])}

#dataset_train = torch.utils.data.Subset(dataSetTrain, train)
#data_loader_train.append(dataset_train)
#dataset_testo = torch.utils.data.Subset(dataSetTest, test)
#data_loader_test.append(dataset_testo)
# define training and validation data loaders


# Collate function (gathers together the outputs)
# def collate_fn(batch):
#     return tuple(zip(*batch))

#len(indices[-noTrain:]), dataset_sizes
#dataset_test[0][1], dataset_test[3][1], dataset_test[-1][1], dataSetTrain.imgs

# %%
class_weights= [0.924865,0.075135] #1-(#inclass/ #intotal )
class_weights = torch.Tensor(class_weights)
class_weights=class_weights.to(device)
criterion = nn.CrossEntropyLoss(weight = class_weights) 

# Observe that all parameters are being optimized
learning_rate=[0.05, 0.1,0.2]
Momentum=[0.5,0.9,0.99]
GAMMA=[0.05, 0.1, 0.5]
#Batch_size= [16,32]#,64,128]
models=[model18, model34, model50]
modelnames=["model18","model34","model50"]
#ADD IN A THING SO IT SAVES THE TENSORBOARD TO DIFFERENT BITS
best_params = None
best_score=0.00
Current_params=None
for lrnum in range(3):
    for gamnum in range(3):
        for Momnum in range(3):
            for modnum in range(3):
                model=models[modnum]
                model = model.to(device)
                optimizer_ft = optim.SGD(model.parameters(), lr=learning_rate[lrnum], momentum=Momentum[Momnum])
                exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=GAMMA[gamnum])
                writer = SummaryWriter("Experiments/undersampledrug/lr"+str(learning_rate[lrnum])+"momentum"+
                        str(Momentum[Momnum])+"gamma"+str(GAMMA[gamnum])+"model"+modelnames[modnum])  
                model_ft, con_mat, current_score = train_model(model, criterion, optimizer_ft, exp_lr_scheduler,
                   train,test,num_epochs=5)
                con_mat=con_mat.cpu().numpy()
                current_score=current_score.cpu().numpy()
                Current_params= {'learning rate': learning_rate[lrnum], 'gamma': GAMMA[gamnum], 
                                   'Momentum': Momentum[Momnum], 'Model': modelnames[modnum]}
                print(con_mat)
                print("Current hyperparameters:", Current_params)
                df_cm_ratio = pd.DataFrame(con_mat / np.sum(con_mat, axis=1)[:, None], index=[i for i in labels],
                                     columns=[i for i in labels])
                plt.figure(figsize=(12, 7))
                sn.heatmap(df_cm_ratio, annot=True)
                if current_score > best_score:
                    best_score = current_score
                    best_params = {'learning rate': learning_rate[lrnum], 'gamma': GAMMA[gamnum], 
                                   'Momentum': Momentum[Momnum], 'Model': modelnames[modnum]}
                            
print("Best hyperparameters:", best_params)
print("Best score:", best_score)
# Out:
# Epoch 0/4
# ----------
# train Loss: 0.5325 Acc: 0.7525
# val Loss: 0.5109 Acc: 0.7581
#
# Epoch 1/4
# ----------
# train Loss: 0.4560 Acc: 0.7983
# val Loss: 0.5409 Acc: 0.7643
#
# Epoch 2/4
# ----------
# train Loss: 0.4259 Acc: 0.8139
# val Loss: 0.8610 Acc: 0.6150
#
# Epoch 3/4
# ----------
# train Loss: 0.4129 Acc: 0.8197
# val Loss: 0.6788 Acc: 0.7186
#
# Epoch 4/4
# ----------
# train Loss: 0.4061 Acc: 0.8204
# val Loss: 0.4388 Acc: 0.8035
#
# Training complete in 14m 23s
# Best val Acc: 0.803528
# [[21775  2646]
#  [  545  1370]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.5370 Acc: 0.7496
# val Loss: 0.8912 Acc: 0.5135
#
# Epoch 1/4
# ----------
# train Loss: 0.4465 Acc: 0.8010
# val Loss: 0.9348 Acc: 0.5303
#
# Epoch 2/4
# ----------
# train Loss: 0.4247 Acc: 0.8132
# val Loss: 0.5472 Acc: 0.7453
#
# Epoch 3/4
# ----------
# train Loss: 0.4122 Acc: 0.8192
# val Loss: 0.9273 Acc: 0.5154
#
# Epoch 4/4
# ----------
# train Loss: 0.4060 Acc: 0.8218
# val Loss: 1.2582 Acc: 0.5057
#
# Training complete in 15m 48s
# Best val Acc: 0.745332
# [[23165  1209]
#  [  902  1060]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.6434 Acc: 0.7362
# val Loss: 0.7785 Acc: 0.6413
#
# Epoch 1/4
# ----------
# train Loss: 0.4896 Acc: 0.7952
# val Loss: 1.8817 Acc: 0.5023
#
# Epoch 2/4
# ----------
# train Loss: 0.4497 Acc: 0.8085
# val Loss: 0.4246 Acc: 0.8218
#
# Epoch 3/4
# ----------
# train Loss: 0.4239 Acc: 0.8164
# val Loss: 0.7695 Acc: 0.6541
#
# Epoch 4/4
# ----------
# train Loss: 0.4168 Acc: 0.8181
# val Loss: 0.4182 Acc: 0.8252
#
# Training complete in 17m 45s
# Best val Acc: 0.825225
# [[20297  4124]
#  [  346  1569]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4572 Acc: 0.7960
# val Loss: 0.4604 Acc: 0.7894
#
# Epoch 1/4
# ----------
# train Loss: 0.4290 Acc: 0.8098
# val Loss: 1.1210 Acc: 0.5366
#
# Epoch 2/4
# ----------
# train Loss: 0.4029 Acc: 0.8240
# val Loss: 0.8699 Acc: 0.6498
#
# Epoch 3/4
# ----------
# train Loss: 0.4203 Acc: 0.8136
# val Loss: 0.4147 Acc: 0.8127
#
# Epoch 4/4
# ----------
# train Loss: 0.3956 Acc: 0.8255
# val Loss: 1.1397 Acc: 0.5938
#
# Training complete in 14m 5s
# Best val Acc: 0.812675
# [[19079  5196]
#  [  331  1730]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4842 Acc: 0.7837
# val Loss: 1.8169 Acc: 0.5072
#
# Epoch 1/4
# ----------
# train Loss: 0.4262 Acc: 0.8089
# val Loss: 0.4277 Acc: 0.7954
#
# Epoch 2/4
# ----------
# train Loss: 0.4053 Acc: 0.8239
# val Loss: 0.6342 Acc: 0.6842
#
# Epoch 3/4
# ----------
# train Loss: 0.4032 Acc: 0.8225
# val Loss: 0.4218 Acc: 0.8126
#
# Epoch 4/4
# ----------
# train Loss: 0.3896 Acc: 0.8292
# val Loss: 0.3905 Acc: 0.8335
#
# Training complete in 15m 58s
# Best val Acc: 0.833536
# [[21213  3208]
#  [  386  1529]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4858 Acc: 0.7869
# val Loss: 0.5178 Acc: 0.7650
#
# Epoch 1/4
# ----------
# train Loss: 0.4250 Acc: 0.8098
# val Loss: 0.4904 Acc: 0.7790
#
# Epoch 2/4
# ----------
# train Loss: 0.4205 Acc: 0.8158
# val Loss: 0.5058 Acc: 0.7485
#
# Epoch 3/4
# ----------
# train Loss: 0.3976 Acc: 0.8275
# val Loss: 0.6039 Acc: 0.6726
#
# Epoch 4/4
# ----------
# train Loss: 0.3916 Acc: 0.8288
# val Loss: 0.4812 Acc: 0.7753
#
# Training complete in 17m 47s
# Best val Acc: 0.778950
# [[16088  8263]
#  [  204  1781]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4848 Acc: 0.7821
# val Loss: 0.4893 Acc: 0.7739
#
# Epoch 1/4
# ----------
# train Loss: 0.4786 Acc: 0.7852
# val Loss: 0.4738 Acc: 0.7744
#
# Epoch 2/4
# ----------
# train Loss: 0.4682 Acc: 0.7865
# val Loss: 1.1702 Acc: 0.5472
#
# Epoch 3/4
# ----------
# train Loss: 0.4527 Acc: 0.7952
# val Loss: 0.4196 Acc: 0.8057
#
# Epoch 4/4
# ----------
# train Loss: 0.4259 Acc: 0.8113
# val Loss: 0.4737 Acc: 0.7598
#
# Training complete in 14m 7s
# Best val Acc: 0.805670
# [[19422  4853]
#  [  389  1672]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4899 Acc: 0.7708
# val Loss: 0.4610 Acc: 0.7937
#
# Epoch 1/4
# ----------
# train Loss: 0.4702 Acc: 0.7890
# val Loss: 0.4949 Acc: 0.7417
#
# Epoch 2/4
# ----------
# train Loss: 0.4415 Acc: 0.8051
# val Loss: 0.4281 Acc: 0.8078
#
# Epoch 3/4
# ----------
# train Loss: 0.4333 Acc: 0.8089
# val Loss: 0.4253 Acc: 0.8059
#
# Epoch 4/4
# ----------
# train Loss: 0.4324 Acc: 0.8100
# val Loss: 0.4234 Acc: 0.8150
#
# Training complete in 15m 50s
# Best val Acc: 0.815021
# [[19161  5260]
#  [  296  1619]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.5126 Acc: 0.7681
# val Loss: 0.5227 Acc: 0.7253
#
# Epoch 1/4
# ----------
# train Loss: 0.4732 Acc: 0.7857
# val Loss: 2.0249 Acc: 0.5097
#
# Epoch 2/4
# ----------
# train Loss: 0.4489 Acc: 0.7998
# val Loss: 1.2107 Acc: 0.5738
#
# Epoch 3/4
# ----------
# train Loss: 0.4366 Acc: 0.8054
# val Loss: 0.4463 Acc: 0.7903
#
# Epoch 4/4
# ----------
# train Loss: 0.4365 Acc: 0.8082
# val Loss: 0.5992 Acc: 0.7031
#
# Training complete in 17m 39s
# Best val Acc: 0.790338
# [[16216  8059]
#  [  180  1881]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4096 Acc: 0.8192
# val Loss: 0.3994 Acc: 0.8275
#
# Epoch 1/4
# ----------
# train Loss: 0.4033 Acc: 0.8197
# val Loss: 0.3984 Acc: 0.8213
#
# Epoch 2/4
# ----------
# train Loss: 0.4020 Acc: 0.8219
# val Loss: 0.3965 Acc: 0.8227
#
# Epoch 3/4
# ----------
# train Loss: 0.4006 Acc: 0.8235
# val Loss: 0.4027 Acc: 0.8200
#
# Epoch 4/4
# ----------
# train Loss: 0.4018 Acc: 0.8230
# val Loss: 1.6601 Acc: 0.5240
#
# Training complete in 14m 8s
# Best val Acc: 0.827523
# [[20361  4004]
#  [  356  1615]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3921 Acc: 0.8280
# val Loss: 0.3862 Acc: 0.8324
#
# Epoch 1/4
# ----------
# train Loss: 0.3842 Acc: 0.8316
# val Loss: 0.3778 Acc: 0.8381
#
# Epoch 2/4
# ----------
# train Loss: 0.3825 Acc: 0.8337
# val Loss: 1.3297 Acc: 0.4371
#
# Epoch 3/4
# ----------
# train Loss: 0.3840 Acc: 0.8335
# val Loss: 0.4100 Acc: 0.8158
#
# Epoch 4/4
# ----------
# train Loss: 0.3811 Acc: 0.8341
# val Loss: 0.3983 Acc: 0.8282
#
# Training complete in 15m 49s
# Best val Acc: 0.838127
# [[20712  3639]
#  [  346  1639]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4020 Acc: 0.8245
# val Loss: 0.3894 Acc: 0.8337
#
# Epoch 1/4
# ----------
# train Loss: 0.3963 Acc: 0.8266
# val Loss: 0.3980 Acc: 0.8209
#
# Epoch 2/4
# ----------
# train Loss: 0.3945 Acc: 0.8254
# val Loss: 0.3843 Acc: 0.8340
#
# Epoch 3/4
# ----------
# train Loss: 0.3967 Acc: 0.8262
# val Loss: 0.3981 Acc: 0.8225
#
# Epoch 4/4
# ----------
# train Loss: 0.3927 Acc: 0.8294
# val Loss: 0.7521 Acc: 0.6636
#
# Training complete in 17m 56s
# Best val Acc: 0.834001
# [[20866  3508]
#  [  369  1593]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4064 Acc: 0.8200
# val Loss: 0.4154 Acc: 0.8136
#
# Epoch 1/4
# ----------
# train Loss: 0.3995 Acc: 0.8219
# val Loss: 0.3915 Acc: 0.8230
#
# Epoch 2/4
# ----------
# train Loss: 0.3962 Acc: 0.8241
# val Loss: 0.3899 Acc: 0.8277
#
# Epoch 3/4
# ----------
# train Loss: 0.3954 Acc: 0.8262
# val Loss: 0.3889 Acc: 0.8264
#
# Epoch 4/4
# ----------
# train Loss: 0.3941 Acc: 0.8267
# val Loss: 0.4122 Acc: 0.8205
#
# Training complete in 14m 9s
# Best val Acc: 0.827737
# [[20014  4360]
#  [  325  1637]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3876 Acc: 0.8316
# val Loss: 0.3819 Acc: 0.8355
#
# Epoch 1/4
# ----------
# train Loss: 0.3813 Acc: 0.8342
# val Loss: 0.3962 Acc: 0.8337
#
# Epoch 2/4
# ----------
# train Loss: 0.3931 Acc: 0.8274
# val Loss: 0.3850 Acc: 0.8316
#
# Epoch 3/4
# ----------
# train Loss: 0.3813 Acc: 0.8327
# val Loss: 0.3960 Acc: 0.8257
#
# Epoch 4/4
# ----------
# train Loss: 0.3771 Acc: 0.8348
# val Loss: 0.4918 Acc: 0.7839
#
# Training complete in 15m 50s
# Best val Acc: 0.835490
# [[21392  2973]
#  [  408  1563]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.3958 Acc: 0.8267
# val Loss: 0.3931 Acc: 0.8282
#
# Epoch 1/4
# ----------
# train Loss: 0.3917 Acc: 0.8293
# val Loss: 0.4395 Acc: 0.8058
#
# Epoch 2/4
# ----------
# train Loss: 0.3900 Acc: 0.8294
# val Loss: 0.3758 Acc: 0.8333
#
# Epoch 3/4
# ----------
# train Loss: 0.3900 Acc: 0.8277
# val Loss: 0.3979 Acc: 0.8221
#
# Epoch 4/4
# ----------
# train Loss: 0.3875 Acc: 0.8313
# val Loss: 0.6914 Acc: 0.6722
#
# Training complete in 17m 37s
# Best val Acc: 0.833281
# [[19924  4450]
#  [  296  1666]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4265 Acc: 0.8111
# val Loss: 0.4568 Acc: 0.7968
#
# Epoch 1/4
# ----------
# train Loss: 0.4183 Acc: 0.8127
# val Loss: 0.4134 Acc: 0.8144
#
# Epoch 2/4
# ----------
# train Loss: 0.4185 Acc: 0.8167
# val Loss: 1.2995 Acc: 0.5513
#
# Epoch 3/4
# ----------
# train Loss: 0.4220 Acc: 0.8126
# val Loss: 0.6917 Acc: 0.6835
#
# Epoch 4/4
# ----------
# train Loss: 0.4257 Acc: 0.8152
# val Loss: 0.4725 Acc: 0.7840
#
# Training complete in 14m 5s
# Best val Acc: 0.814422
# [[19717  4634]
#  [  359  1626]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4185 Acc: 0.8167
# val Loss: 0.3859 Acc: 0.8339
#
# Epoch 1/4
# ----------
# train Loss: 0.4336 Acc: 0.8071
# val Loss: 0.6442 Acc: 0.6952
#
# Epoch 2/4
# ----------
# train Loss: 0.4161 Acc: 0.8181
# val Loss: 0.3943 Acc: 0.8250
#
# Epoch 3/4
# ----------
# train Loss: 0.4138 Acc: 0.8201
# val Loss: 0.6609 Acc: 0.7177
#
# Epoch 4/4
# ----------
# train Loss: 0.4092 Acc: 0.8224
# val Loss: 0.5127 Acc: 0.7887
#
# Training complete in 15m 47s
# Best val Acc: 0.833875
# [[21165  3200]
#  [  396  1575]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4245 Acc: 0.8119
# val Loss: 0.4335 Acc: 0.8038
#
# Epoch 1/4
# ----------
# train Loss: 0.4265 Acc: 0.8115
# val Loss: 0.5659 Acc: 0.7190
#
# Epoch 2/4
# ----------
# train Loss: 0.4138 Acc: 0.8192
# val Loss: 0.5259 Acc: 0.7726
#
# Epoch 3/4
# ----------
# train Loss: 0.4185 Acc: 0.8179
# val Loss: 0.3985 Acc: 0.8221
#
# Epoch 4/4
# ----------
# train Loss: 0.4042 Acc: 0.8245
# val Loss: 1.2560 Acc: 0.5263
#
# Training complete in 17m 35s
# Best val Acc: 0.822086
# [[20007  4268]
#  [  371  1690]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3959 Acc: 0.8259
# val Loss: 0.3916 Acc: 0.8305
#
# Epoch 1/4
# ----------
# train Loss: 0.3914 Acc: 0.8264
# val Loss: 0.6634 Acc: 0.7064
#
# Epoch 2/4
# ----------
# train Loss: 0.3871 Acc: 0.8306
# val Loss: 0.9226 Acc: 0.6374
#
# Epoch 3/4
# ----------
# train Loss: 0.3883 Acc: 0.8296
# val Loss: 2.1279 Acc: 0.5120
#
# Epoch 4/4
# ----------
# train Loss: 0.3863 Acc: 0.8313
# val Loss: 0.3838 Acc: 0.8319
#
# Training complete in 14m 10s
# Best val Acc: 0.831932
# [[20191  4230]
#  [  312  1603]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3840 Acc: 0.8337
# val Loss: 0.4187 Acc: 0.8134
#
# Epoch 1/4
# ----------
# train Loss: 0.3791 Acc: 0.8368
# val Loss: 0.3765 Acc: 0.8346
#
# Epoch 2/4
# ----------
# train Loss: 0.3760 Acc: 0.8360
# val Loss: 0.3756 Acc: 0.8368
#
# Epoch 3/4
# ----------
# train Loss: 0.3784 Acc: 0.8369
# val Loss: 0.3724 Acc: 0.8390
#
# Epoch 4/4
# ----------
# train Loss: 0.3761 Acc: 0.8365
# val Loss: 0.4008 Acc: 0.8267
#
# Training complete in 15m 48s
# Best val Acc: 0.839040
# [[20359  3916]
#  [  331  1730]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.3822 Acc: 0.8352
# val Loss: 0.3933 Acc: 0.8265
#
# Epoch 1/4
# ----------
# train Loss: 0.3789 Acc: 0.8355
# val Loss: 0.3711 Acc: 0.8379
#
# Epoch 2/4
# ----------
# train Loss: 0.3761 Acc: 0.8380
# val Loss: 0.3869 Acc: 0.8311
#
# Epoch 3/4
# ----------
# train Loss: 0.3760 Acc: 0.8371
# val Loss: 0.3827 Acc: 0.8347
#
# Epoch 4/4
# ----------
# train Loss: 0.3758 Acc: 0.8375
# val Loss: 0.4067 Acc: 0.8247
#
# Training complete in 17m 36s
# Best val Acc: 0.837905
# [[20554  3797]
#  [  334  1651]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model50'}
# /tmp/ipykernel_7953/2409506580.py:37: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(12, 7))
# Epoch 0/4
# ----------
# train Loss: 0.3864 Acc: 0.8306
# val Loss: 0.3843 Acc: 0.8369
#
# Epoch 1/4
# ----------
# train Loss: 0.3841 Acc: 0.8328
# val Loss: 0.3808 Acc: 0.8294
#
# Epoch 2/4
# ----------
# train Loss: 0.3808 Acc: 0.8330
# val Loss: 0.3945 Acc: 0.8234
#
# Epoch 3/4
# ----------
# train Loss: 0.3843 Acc: 0.8343
# val Loss: 0.3915 Acc: 0.8280
#
# Epoch 4/4
# ----------
# train Loss: 0.3812 Acc: 0.8351
# val Loss: 0.3775 Acc: 0.8396
#
# Training complete in 14m 7s
# Best val Acc: 0.839580
# [[20386  4035]
#  [  298  1617]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3792 Acc: 0.8363
# val Loss: 0.3872 Acc: 0.8349
#
# Epoch 1/4
# ----------
# train Loss: 0.3734 Acc: 0.8373
# val Loss: 0.4182 Acc: 0.8163
#
# Epoch 2/4
# ----------
# train Loss: 0.3727 Acc: 0.8398
# val Loss: 0.3654 Acc: 0.8449
#
# Epoch 3/4
# ----------
# train Loss: 0.3745 Acc: 0.8393
# val Loss: 0.3701 Acc: 0.8418
#
# Epoch 4/4
# ----------
# train Loss: 0.3716 Acc: 0.8396
# val Loss: 0.3775 Acc: 0.8401
#
# Training complete in 15m 51s
# Best val Acc: 0.844896
# [[21248  3126]
#  [  357  1605]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.3794 Acc: 0.8363
# val Loss: 0.3693 Acc: 0.8438
#
# Epoch 1/4
# ----------
# train Loss: 0.3757 Acc: 0.8367
# val Loss: 0.4175 Acc: 0.8141
#
# Epoch 2/4
# ----------
# train Loss: 0.3700 Acc: 0.8404
# val Loss: 2.4087 Acc: 0.5064
#
# Epoch 3/4
# ----------
# train Loss: 0.3706 Acc: 0.8417
# val Loss: 0.5205 Acc: 0.7498
#
# Epoch 4/4
# ----------
# train Loss: 0.3691 Acc: 0.8419
# val Loss: 2.6771 Acc: 0.5054
#
# Training complete in 17m 37s
# Best val Acc: 0.843772
# [[20510  3855]
#  [  304  1667]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4117 Acc: 0.8227
# val Loss: 0.3966 Acc: 0.8291
#
# Epoch 1/4
# ----------
# train Loss: 0.4106 Acc: 0.8194
# val Loss: 0.4623 Acc: 0.8256
#
# Epoch 2/4
# ----------
# train Loss: 0.4211 Acc: 0.8176
# val Loss: 0.4109 Acc: 0.8330
#
# Epoch 3/4
# ----------
# train Loss: 0.4124 Acc: 0.8226
# val Loss: 0.4093 Acc: 0.8152
#
# Epoch 4/4
# ----------
# train Loss: 0.3997 Acc: 0.8251
# val Loss: 0.4369 Acc: 0.8179
#
# Training complete in 14m 12s
# Best val Acc: 0.833004
# [[19749  4625]
#  [  283  1679]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4111 Acc: 0.8217
# val Loss: 0.7939 Acc: 0.6392
#
# Epoch 1/4
# ----------
# train Loss: 0.3970 Acc: 0.8269
# val Loss: 0.4796 Acc: 0.7721
#
# Epoch 2/4
# ----------
# train Loss: 0.3919 Acc: 0.8270
# val Loss: 0.4186 Acc: 0.8238
#
# Epoch 3/4
# ----------
# train Loss: 0.4019 Acc: 0.8262
# val Loss: 0.4155 Acc: 0.8202
#
# Epoch 4/4
# ----------
# train Loss: 0.4014 Acc: 0.8270
# val Loss: 0.3833 Acc: 0.8342
#
# Training complete in 15m 49s
# Best val Acc: 0.834202
# [[21067  3354]
#  [  372  1543]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4003 Acc: 0.8237
# val Loss: 0.4957 Acc: 0.7627
#
# Epoch 1/4
# ----------
# train Loss: 0.4561 Acc: 0.7921
# val Loss: 0.4361 Acc: 0.7999
#
# Epoch 2/4
# ----------
# train Loss: 0.4254 Acc: 0.8129
# val Loss: 0.5381 Acc: 0.7683
#
# Epoch 3/4
# ----------
# train Loss: 0.4155 Acc: 0.8197
# val Loss: 0.5648 Acc: 0.7763
#
# Epoch 4/4
# ----------
# train Loss: 0.4013 Acc: 0.8251
# val Loss: 0.3885 Acc: 0.8346
#
# Training complete in 17m 37s
# Best val Acc: 0.834649
# [[19176  5245]
#  [  222  1693]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3830 Acc: 0.8336
# val Loss: 0.4109 Acc: 0.8186
#
# Epoch 1/4
# ----------
# train Loss: 0.3727 Acc: 0.8388
# val Loss: 0.3652 Acc: 0.8431
#
# Epoch 2/4
# ----------
# train Loss: 0.3706 Acc: 0.8412
# val Loss: 0.4291 Acc: 0.8147
#
# Epoch 3/4
# ----------
# train Loss: 0.3736 Acc: 0.8398
# val Loss: 0.3678 Acc: 0.8397
#
# Epoch 4/4
# ----------
# train Loss: 0.3712 Acc: 0.8399
# val Loss: 0.3853 Acc: 0.8326
#
# Training complete in 14m 6s
# Best val Acc: 0.843080
# [[20622  3729]
#  [  319  1666]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3730 Acc: 0.8378
# val Loss: 0.3668 Acc: 0.8422
#
# Epoch 1/4
# ----------
# train Loss: 0.3664 Acc: 0.8415
# val Loss: 0.3901 Acc: 0.8347
#
# Epoch 2/4
# ----------
# train Loss: 0.3628 Acc: 0.8452
# val Loss: 0.3754 Acc: 0.8341
#
# Epoch 3/4
# ----------
# train Loss: 0.3633 Acc: 0.8444
# val Loss: 0.3569 Acc: 0.8464
#
# Epoch 4/4
# ----------
# train Loss: 0.3599 Acc: 0.8444
# val Loss: 0.3752 Acc: 0.8423
#
# Training complete in 15m 48s
# Best val Acc: 0.846382
# [[20421  3854]
#  [  306  1755]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.3751 Acc: 0.8377
# val Loss: 0.4300 Acc: 0.8069
#
# Epoch 1/4
# ----------
# train Loss: 0.3723 Acc: 0.8382
# val Loss: 0.3649 Acc: 0.8407
#
# Epoch 2/4
# ----------
# train Loss: 0.3707 Acc: 0.8414
# val Loss: 0.3587 Acc: 0.8475
#
# Epoch 3/4
# ----------
# train Loss: 0.3709 Acc: 0.8414
# val Loss: 0.3718 Acc: 0.8395
#
# Epoch 4/4
# ----------
# train Loss: 0.3676 Acc: 0.8433
# val Loss: 0.3813 Acc: 0.8370
#
# Training complete in 17m 41s
# Best val Acc: 0.847453
# [[20267  4107]
#  [  268  1694]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3793 Acc: 0.8365
# val Loss: 0.3832 Acc: 0.8336
#
# Epoch 1/4
# ----------
# train Loss: 0.3729 Acc: 0.8396
# val Loss: 0.3583 Acc: 0.8468
#
# Epoch 2/4
# ----------
# train Loss: 0.3679 Acc: 0.8414
# val Loss: 0.3594 Acc: 0.8428
#
# Epoch 3/4
# ----------
# train Loss: 0.3734 Acc: 0.8394
# val Loss: 0.3624 Acc: 0.8444
#
# Epoch 4/4
# ----------
# train Loss: 0.3691 Acc: 0.8410
# val Loss: 0.3694 Acc: 0.8439
#
# Training complete in 14m 5s
# Best val Acc: 0.846818
# [[20571  3780]
#  [  300  1685]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3653 Acc: 0.8430
# val Loss: 0.3595 Acc: 0.8476
#
# Epoch 1/4
# ----------
# train Loss: 0.3613 Acc: 0.8443
# val Loss: 0.3775 Acc: 0.8400
#
# Epoch 2/4
# ----------
# train Loss: 0.3574 Acc: 0.8460
# val Loss: 0.3575 Acc: 0.8431
#
# Epoch 3/4
# ----------
# train Loss: 0.3589 Acc: 0.8451
# val Loss: 1.1399 Acc: 0.5717
#
# Epoch 4/4
# ----------
# train Loss: 0.3581 Acc: 0.8471
# val Loss: 0.4944 Acc: 0.7974
#
# Training complete in 15m 48s
# Best val Acc: 0.847649
# [[20736  3629]
#  [  307  1664]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.3747 Acc: 0.8394
# val Loss: 0.3761 Acc: 0.8400
#
# Epoch 1/4
# ----------
# train Loss: 0.3713 Acc: 0.8401
# val Loss: 0.3640 Acc: 0.8403
#
# Epoch 2/4
# ----------
# train Loss: 0.3671 Acc: 0.8411
# val Loss: 0.4182 Acc: 0.8114
#
# Epoch 3/4
# ----------
# train Loss: 0.3707 Acc: 0.8429
# val Loss: 0.3633 Acc: 0.8433
#
# Epoch 4/4
# ----------
# train Loss: 0.3666 Acc: 0.8440
# val Loss: 0.3710 Acc: 0.8438
#
# Training complete in 17m 41s
# Best val Acc: 0.843838
# [[19408  5013]
#  [  205  1710]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4117 Acc: 0.8203
# val Loss: 0.5300 Acc: 0.7642
#
# Epoch 1/4
# ----------
# train Loss: 0.4318 Acc: 0.8115
# val Loss: 2.5481 Acc: 0.5108
#
# Epoch 2/4
# ----------
# train Loss: 0.4247 Acc: 0.8160
# val Loss: 0.5016 Acc: 0.8016
#
# Epoch 3/4
# ----------
# train Loss: 0.4214 Acc: 0.8181
# val Loss: 0.8652 Acc: 0.6654
#
# Epoch 4/4
# ----------
# train Loss: 0.4233 Acc: 0.8147
# val Loss: 0.8124 Acc: 0.6773
#
# Training complete in 14m 5s
# Best val Acc: 0.801625
# [[17710  6664]
#  [  242  1720]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4424 Acc: 0.8053
# val Loss: 0.5553 Acc: 0.7456
#
# Epoch 1/4
# ----------
# train Loss: 0.4550 Acc: 0.8000
# val Loss: 0.4556 Acc: 0.7992
#
# Epoch 2/4
# ----------
# train Loss: 0.4247 Acc: 0.8155
# val Loss: 0.4493 Acc: 0.8107
#
# Epoch 3/4
# ----------
# train Loss: 0.4427 Acc: 0.8068
# val Loss: 0.4874 Acc: 0.7851
#
# Epoch 4/4
# ----------
# train Loss: 0.4476 Acc: 0.8086
# val Loss: 0.4440 Acc: 0.8246
#
# Training complete in 15m 52s
# Best val Acc: 0.824640
# [[20549  3872]
#  [  368  1547]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4323 Acc: 0.8122
# val Loss: 3.3714 Acc: 0.5102
#
# Epoch 1/4
# ----------
# train Loss: 0.4207 Acc: 0.8151
# val Loss: 0.4643 Acc: 0.7810
#
# Epoch 2/4
# ----------
# train Loss: 0.4295 Acc: 0.8121
# val Loss: 0.3800 Acc: 0.8368
#
# Epoch 3/4
# ----------
# train Loss: 0.4157 Acc: 0.8192
# val Loss: 0.4275 Acc: 0.7992
#
# Epoch 4/4
# ----------
# train Loss: 0.4215 Acc: 0.8192
# val Loss: 0.3844 Acc: 0.8366
#
# Training complete in 17m 43s
# Best val Acc: 0.836775
# [[19498  4876]
#  [  248  1714]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3817 Acc: 0.8343
# val Loss: 0.4292 Acc: 0.8023
#
# Epoch 1/4
# ----------
# train Loss: 0.3752 Acc: 0.8391
# val Loss: 0.3658 Acc: 0.8436
#
# Epoch 2/4
# ----------
# train Loss: 0.3715 Acc: 0.8395
# val Loss: 0.3666 Acc: 0.8418
#
# Epoch 3/4
# ----------
# train Loss: 0.3734 Acc: 0.8396
# val Loss: 0.3767 Acc: 0.8314
#
# Epoch 4/4
# ----------
# train Loss: 0.3704 Acc: 0.8402
# val Loss: 0.3722 Acc: 0.8395
#
# Training complete in 14m 3s
# Best val Acc: 0.843555
# [[20179  4172]
#  [  281  1704]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3887 Acc: 0.8297
# val Loss: 0.3729 Acc: 0.8385
#
# Epoch 1/4
# ----------
# train Loss: 0.3723 Acc: 0.8368
# val Loss: 0.3661 Acc: 0.8416
#
# Epoch 2/4
# ----------
# train Loss: 0.3697 Acc: 0.8380
# val Loss: 0.3764 Acc: 0.8337
#
# Epoch 3/4
# ----------
# train Loss: 0.3708 Acc: 0.8398
# val Loss: 0.3679 Acc: 0.8386
#
# Epoch 4/4
# ----------
# train Loss: 0.3694 Acc: 0.8382
# val Loss: 0.3656 Acc: 0.8416
#
# Training complete in 15m 43s
# Best val Acc: 0.841617
# [[20511  3910]
#  [  300  1615]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.3805 Acc: 0.8339
# val Loss: 0.3730 Acc: 0.8378
#
# Epoch 1/4
# ----------
# train Loss: 0.3728 Acc: 0.8375
# val Loss: 0.3753 Acc: 0.8395
#
# Epoch 2/4
# ----------
# train Loss: 0.3698 Acc: 0.8389
# val Loss: 0.3672 Acc: 0.8405
#
# Epoch 3/4
# ----------
# train Loss: 0.3727 Acc: 0.8373
# val Loss: 0.3663 Acc: 0.8376
#
# Epoch 4/4
# ----------
# train Loss: 0.3706 Acc: 0.8399
# val Loss: 0.3632 Acc: 0.8459
#
# Training complete in 17m 35s
# Best val Acc: 0.845924
# [[20224  4197]
#  [  261  1654]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3721 Acc: 0.8407
# val Loss: 0.3682 Acc: 0.8435
#
# Epoch 1/4
# ----------
# train Loss: 0.3694 Acc: 0.8412
# val Loss: 0.3773 Acc: 0.8392
#
# Epoch 2/4
# ----------
# train Loss: 0.3675 Acc: 0.8413
# val Loss: 0.3545 Acc: 0.8474
#
# Epoch 3/4
# ----------
# train Loss: 0.3674 Acc: 0.8430
# val Loss: 0.3612 Acc: 0.8407
#
# Epoch 4/4
# ----------
# train Loss: 0.3673 Acc: 0.8406
# val Loss: 0.3983 Acc: 0.8326
#
# Training complete in 14m 7s
# Best val Acc: 0.847426
# [[20216  4158]
#  [  264  1698]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3689 Acc: 0.8429
# val Loss: 0.3697 Acc: 0.8380
#
# Epoch 1/4
# ----------
# train Loss: 0.3669 Acc: 0.8397
# val Loss: 0.3537 Acc: 0.8483
#
# Epoch 2/4
# ----------
# train Loss: 0.3626 Acc: 0.8429
# val Loss: 1.6568 Acc: 0.5274
#
# Epoch 3/4
# ----------
# train Loss: 0.3624 Acc: 0.8443
# val Loss: 0.3557 Acc: 0.8450
#
# Epoch 4/4
# ----------
# train Loss: 0.3602 Acc: 0.8433
# val Loss: 0.3597 Acc: 0.8444
#
# Training complete in 15m 56s
# Best val Acc: 0.848266
# [[20298  4053]
#  [  272  1713]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.3714 Acc: 0.8401
# val Loss: 0.4328 Acc: 0.8119
#
# Epoch 1/4
# ----------
# train Loss: 0.3679 Acc: 0.8405
# val Loss: 0.4807 Acc: 0.7815
#
# Epoch 2/4
# ----------
# train Loss: 0.3650 Acc: 0.8422
# val Loss: 0.4867 Acc: 0.7818
#
# Epoch 3/4
# ----------
# train Loss: 0.3659 Acc: 0.8425
# val Loss: 0.4427 Acc: 0.8042
#
# Epoch 4/4
# ----------
# train Loss: 0.3622 Acc: 0.8445
# val Loss: 0.3785 Acc: 0.8414
#
# Training complete in 17m 42s
# Best val Acc: 0.841367
# [[18994  5427]
#  [  182  1733]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4221 Acc: 0.8184
# val Loss: 0.8155 Acc: 0.6779
#
# Epoch 1/4
# ----------
# train Loss: 0.4307 Acc: 0.8107
# val Loss: 0.4634 Acc: 0.8025
#
# Epoch 2/4
# ----------
# train Loss: 0.4113 Acc: 0.8206
# val Loss: 0.3799 Acc: 0.8389
#
# Epoch 3/4
# ----------
# train Loss: 0.4131 Acc: 0.8213
# val Loss: 0.3835 Acc: 0.8355
#
# Epoch 4/4
# ----------
# train Loss: 0.4328 Acc: 0.8199
# val Loss: 0.5181 Acc: 0.7682
#
# Training complete in 14m 9s
# Best val Acc: 0.838873
# [[19650  4724]
#  [  252  1710]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4082 Acc: 0.8246
# val Loss: 0.3737 Acc: 0.8416
#
# Epoch 1/4
# ----------
# train Loss: 0.4172 Acc: 0.8195
# val Loss: 0.3665 Acc: 0.8374
#
# Epoch 2/4
# ----------
# train Loss: 0.3976 Acc: 0.8300
# val Loss: 0.4559 Acc: 0.7820
#
# Epoch 3/4
# ----------
# train Loss: 0.4033 Acc: 0.8282
# val Loss: 0.3818 Acc: 0.8380
#
# Epoch 4/4
# ----------
# train Loss: 0.4086 Acc: 0.8285
# val Loss: 0.4508 Acc: 0.8205
#
# Training complete in 15m 44s
# Best val Acc: 0.841573
# [[21058  3307]
#  [  357  1614]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.3940 Acc: 0.8299
# val Loss: 0.4198 Acc: 0.8123
#
# Epoch 1/4
# ----------
# train Loss: 0.4361 Acc: 0.8097
# val Loss: 0.3932 Acc: 0.8342
#
# Epoch 2/4
# ----------
# train Loss: 0.4097 Acc: 0.8249
# val Loss: 0.3678 Acc: 0.8425
#
# Epoch 3/4
# ----------
# train Loss: 0.3976 Acc: 0.8294
# val Loss: 0.5100 Acc: 0.7852
#
# Epoch 4/4
# ----------
# train Loss: 0.4092 Acc: 0.8233
# val Loss: 0.4115 Acc: 0.8188
#
# Training complete in 17m 33s
# Best val Acc: 0.842479
# [[21242  3132]
#  [  366  1596]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3746 Acc: 0.8403
# val Loss: 1.2436 Acc: 0.5464
#
# Epoch 1/4
# ----------
# train Loss: 0.3661 Acc: 0.8433
# val Loss: 0.3652 Acc: 0.8421
#
# Epoch 2/4
# ----------
# train Loss: 0.3635 Acc: 0.8455
# val Loss: 0.3569 Acc: 0.8466
#
# Epoch 3/4
# ----------
# train Loss: 0.3672 Acc: 0.8420
# val Loss: 0.3767 Acc: 0.8323
#
# Epoch 4/4
# ----------
# train Loss: 0.3630 Acc: 0.8460
# val Loss: 0.3627 Acc: 0.8433
#
# Training complete in 14m 5s
# Best val Acc: 0.846632
# [[20873  3501]
#  [  320  1642]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3728 Acc: 0.8385
# val Loss: 0.3755 Acc: 0.8420
#
# Epoch 1/4
# ----------
# train Loss: 0.3686 Acc: 0.8411
# val Loss: 0.3653 Acc: 0.8433
#
# Epoch 2/4
# ----------
# train Loss: 0.3654 Acc: 0.8430
# val Loss: 0.5004 Acc: 0.7838
#
# Epoch 3/4
# ----------
# train Loss: 0.3671 Acc: 0.8406
# val Loss: 0.6433 Acc: 0.6941
#
# Epoch 4/4
# ----------
# train Loss: 0.3635 Acc: 0.8439
# val Loss: 0.3632 Acc: 0.8438
#
# Training complete in 15m 51s
# Best val Acc: 0.843826
# [[21129  3292]
#  [  340  1575]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.3676 Acc: 0.8436
# val Loss: 0.3744 Acc: 0.8384
#
# Epoch 1/4
# ----------
# train Loss: 0.3636 Acc: 0.8426
# val Loss: 0.3611 Acc: 0.8461
#
# Epoch 2/4
# ----------
# train Loss: 0.3604 Acc: 0.8454
# val Loss: 0.3557 Acc: 0.8480
#
# Epoch 3/4
# ----------
# train Loss: 0.3622 Acc: 0.8459
# val Loss: 0.3627 Acc: 0.8423
#
# Epoch 4/4
# ----------
# train Loss: 0.3599 Acc: 0.8457
# val Loss: 0.3636 Acc: 0.8449
#
# Training complete in 17m 36s
# Best val Acc: 0.848019
# [[19748  4626]
#  [  224  1738]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3656 Acc: 0.8435
# val Loss: 0.3788 Acc: 0.8373
#
# Epoch 1/4
# ----------
# train Loss: 0.3640 Acc: 0.8433
# val Loss: 0.3519 Acc: 0.8498
#
# Epoch 2/4
# ----------
# train Loss: 0.3627 Acc: 0.8453
# val Loss: 0.3449 Acc: 0.8514
#
# Epoch 3/4
# ----------
# train Loss: 0.3633 Acc: 0.8443
# val Loss: 0.3548 Acc: 0.8479
#
# Epoch 4/4
# ----------
# train Loss: 0.3594 Acc: 0.8457
# val Loss: 0.3542 Acc: 0.8486
#
# Training complete in 14m 2s
# Best val Acc: 0.851377
# [[20508  3866]
#  [  272  1690]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3660 Acc: 0.8442
# val Loss: 0.3847 Acc: 0.8313
#
# Epoch 1/4
# ----------
# train Loss: 0.3633 Acc: 0.8434
# val Loss: 0.3650 Acc: 0.8441
#
# Epoch 2/4
# ----------
# train Loss: 0.3608 Acc: 0.8463
# val Loss: 0.3419 Acc: 0.8540
#
# Epoch 3/4
# ----------
# train Loss: 0.3631 Acc: 0.8429
# val Loss: 0.3745 Acc: 0.8371
#
# Epoch 4/4
# ----------
# train Loss: 0.3634 Acc: 0.8435
# val Loss: 0.3672 Acc: 0.8458
#
# Training complete in 15m 46s
# Best val Acc: 0.853995
# [[20735  3639]
#  [  280  1682]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.3601 Acc: 0.8479
# val Loss: 0.4023 Acc: 0.8319
#
# Epoch 1/4
# ----------
# train Loss: 0.3580 Acc: 0.8472
# val Loss: 0.3733 Acc: 0.8441
#
# Epoch 2/4
# ----------
# train Loss: 0.3543 Acc: 0.8482
# val Loss: 0.3759 Acc: 0.8425
#
# Epoch 3/4
# ----------
# train Loss: 0.3581 Acc: 0.8464
# val Loss: 0.3689 Acc: 0.8437
#
# Epoch 4/4
# ----------
# train Loss: 0.3549 Acc: 0.8496
# val Loss: 0.3527 Acc: 0.8542
#
# Training complete in 17m 42s
# Best val Acc: 0.854249
# [[20095  4326]
#  [  219  1696]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4242 Acc: 0.8154
# val Loss: 0.3867 Acc: 0.8410
#
# Epoch 1/4
# ----------
# train Loss: 0.3999 Acc: 0.8264
# val Loss: 0.4152 Acc: 0.8212
#
# Epoch 2/4
# ----------
# train Loss: 0.4003 Acc: 0.8264
# val Loss: 0.3922 Acc: 0.8309
#
# Epoch 3/4
# ----------
# train Loss: 0.3959 Acc: 0.8324
# val Loss: 0.3837 Acc: 0.8391
#
# Epoch 4/4
# ----------
# train Loss: 0.4028 Acc: 0.8269
# val Loss: 0.3944 Acc: 0.8382
#
# Training complete in 14m 11s
# Best val Acc: 0.840979
# [[20275  4090]
#  [  296  1675]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3986 Acc: 0.8300
# val Loss: 0.4326 Acc: 0.8111
#
# Epoch 1/4
# ----------
# train Loss: 0.4004 Acc: 0.8269
# val Loss: 0.5583 Acc: 0.7704
#
# Epoch 2/4
# ----------
# train Loss: 0.4076 Acc: 0.8236
# val Loss: 0.3828 Acc: 0.8444
#
# Epoch 3/4
# ----------
# train Loss: 0.4188 Acc: 0.8208
# val Loss: 0.4205 Acc: 0.8185
#
# Epoch 4/4
# ----------
# train Loss: 0.3956 Acc: 0.8327
# val Loss: 0.4410 Acc: 0.8130
#
# Training complete in 15m 51s
# Best val Acc: 0.844409
# [[21187  3187]
#  [  354  1608]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.3946 Acc: 0.8287
# val Loss: 0.4162 Acc: 0.8387
#
# Epoch 1/4
# ----------
# train Loss: 0.4032 Acc: 0.8267
# val Loss: 0.4326 Acc: 0.8027
#
# Epoch 2/4
# ----------
# train Loss: 0.3945 Acc: 0.8314
# val Loss: 0.3641 Acc: 0.8460
#
# Epoch 3/4
# ----------
# train Loss: 0.4159 Acc: 0.8239
# val Loss: 0.3668 Acc: 0.8397
#
# Epoch 4/4
# ----------
# train Loss: 0.3837 Acc: 0.8341
# val Loss: 0.4171 Acc: 0.8283
#
# Training complete in 17m 49s
# Best val Acc: 0.845965
# [[20269  4105]
#  [  274  1688]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3679 Acc: 0.8420
# val Loss: 0.3686 Acc: 0.8432
#
# Epoch 1/4
# ----------
# train Loss: 0.3639 Acc: 0.8442
# val Loss: 0.5210 Acc: 0.7710
#
# Epoch 2/4
# ----------
# train Loss: 0.3614 Acc: 0.8453
# val Loss: 0.3472 Acc: 0.8515
#
# Epoch 3/4
# ----------
# train Loss: 0.3658 Acc: 0.8439
# val Loss: 0.3642 Acc: 0.8426
#
# Epoch 4/4
# ----------
# train Loss: 0.3604 Acc: 0.8469
# val Loss: 0.3583 Acc: 0.8469
#
# Training complete in 14m 6s
# Best val Acc: 0.851485
# [[20799  3575]
#  [  295  1667]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3653 Acc: 0.8421
# val Loss: 0.4350 Acc: 0.8069
#
# Epoch 1/4
# ----------
# train Loss: 0.3561 Acc: 0.8469
# val Loss: 0.3468 Acc: 0.8493
#
# Epoch 2/4
# ----------
# train Loss: 0.3526 Acc: 0.8482
# val Loss: 0.8728 Acc: 0.6327
#
# Epoch 3/4
# ----------
# train Loss: 0.3554 Acc: 0.8474
# val Loss: 0.3560 Acc: 0.8431
#
# Epoch 4/4
# ----------
# train Loss: 0.3525 Acc: 0.8483
# val Loss: 0.3672 Acc: 0.8506
#
# Training complete in 15m 52s
# Best val Acc: 0.850605
# [[19611  4810]
#  [  195  1720]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.3611 Acc: 0.8446
# val Loss: 0.3504 Acc: 0.8500
#
# Epoch 1/4
# ----------
# train Loss: 0.3530 Acc: 0.8492
# val Loss: 0.3476 Acc: 0.8481
#
# Epoch 2/4
# ----------
# train Loss: 0.3476 Acc: 0.8497
# val Loss: 0.3441 Acc: 0.8535
#
# Epoch 3/4
# ----------
# train Loss: 0.3534 Acc: 0.8485
# val Loss: 0.3475 Acc: 0.8482
#
# Epoch 4/4
# ----------
# train Loss: 0.3470 Acc: 0.8518
# val Loss: 0.3544 Acc: 0.8520
#
# Training complete in 17m 40s
# Best val Acc: 0.853472
# [[20225  4149]
#  [  241  1721]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3695 Acc: 0.8421
# val Loss: 0.3881 Acc: 0.8249
#
# Epoch 1/4
# ----------
# train Loss: 0.3642 Acc: 0.8434
# val Loss: 0.3556 Acc: 0.8463
#
# Epoch 2/4
# ----------
# train Loss: 0.3618 Acc: 0.8472
# val Loss: 0.6302 Acc: 0.6989
#
# Epoch 3/4
# ----------
# train Loss: 0.3652 Acc: 0.8422
# val Loss: 0.3582 Acc: 0.8455
#
# Epoch 4/4
# ----------
# train Loss: 0.3655 Acc: 0.8417
# val Loss: 0.3746 Acc: 0.8395
#
# Training complete in 14m 14s
# Best val Acc: 0.846282
# [[20091  4260]
#  [  263  1722]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3562 Acc: 0.8472
# val Loss: 0.3475 Acc: 0.8500
#
# Epoch 1/4
# ----------
# train Loss: 0.3564 Acc: 0.8478
# val Loss: 0.3558 Acc: 0.8496
#
# Epoch 2/4
# ----------
# train Loss: 0.3540 Acc: 0.8495
# val Loss: 0.3361 Acc: 0.8596
#
# Epoch 3/4
# ----------
# train Loss: 0.3564 Acc: 0.8469
# val Loss: 0.3812 Acc: 0.8285
#
# Epoch 4/4
# ----------
# train Loss: 0.3510 Acc: 0.8517
# val Loss: 0.3452 Acc: 0.8569
#
# Training complete in 15m 47s
# Best val Acc: 0.859560
# [[20733  3641]
#  [  258  1704]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.3563 Acc: 0.8483
# val Loss: 0.3795 Acc: 0.8366
#
# Epoch 1/4
# ----------
# train Loss: 0.3524 Acc: 0.8485
# val Loss: 0.3411 Acc: 0.8568
#
# Epoch 2/4
# ----------
# train Loss: 0.3493 Acc: 0.8511
# val Loss: 0.5499 Acc: 0.7133
#
# Epoch 3/4
# ----------
# train Loss: 0.3512 Acc: 0.8516
# val Loss: 0.3459 Acc: 0.8520
#
# Epoch 4/4
# ----------
# train Loss: 0.3512 Acc: 0.8487
# val Loss: 0.3684 Acc: 0.8399
#
# Training complete in 17m 36s
# Best val Acc: 0.856790
# [[20615  3736]
#  [  264  1721]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4501 Acc: 0.8083
# val Loss: 0.4607 Acc: 0.8064
#
# Epoch 1/4
# ----------
# train Loss: 0.4846 Acc: 0.7894
# val Loss: 0.5198 Acc: 0.7902
#
# Epoch 2/4
# ----------
# train Loss: 0.4803 Acc: 0.7927
# val Loss: 0.5593 Acc: 0.7556
#
# Epoch 3/4
# ----------
# train Loss: 0.4551 Acc: 0.8079
# val Loss: 0.8310 Acc: 0.7813
#
# Epoch 4/4
# ----------
# train Loss: 0.7012 Acc: 0.6941
# val Loss: 0.6480 Acc: 0.6354
#
# Training complete in 14m 6s
# Best val Acc: 0.806372
# [[21951  2414]
#  [  568  1403]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4563 Acc: 0.8047
# val Loss: 0.6078 Acc: 0.7193
#
# Epoch 1/4
# ----------
# train Loss: 0.4478 Acc: 0.8037
# val Loss: 0.9386 Acc: 0.6283
#
# Epoch 2/4
# ----------
# train Loss: 0.5405 Acc: 0.7638
# val Loss: 0.5585 Acc: 0.7928
#
# Epoch 3/4
# ----------
# train Loss: 191.9461 Acc: 0.5289
# val Loss: 8000.3192 Acc: 0.5009
#
# Epoch 4/4
# ----------
# train Loss: 6423.7571 Acc: 0.5036
# val Loss: 5202.2459 Acc: 0.4975
#
# Training complete in 15m 46s
# Best val Acc: 0.792809
# [[20945  3429]
#  [  537  1425]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4515 Acc: 0.8052
# val Loss: 0.7407 Acc: 0.5182
#
# Epoch 1/4
# ----------
# train Loss: 0.4778 Acc: 0.7939
# val Loss: 0.6463 Acc: 0.7701
#
# Epoch 2/4
# ----------
# train Loss: 0.4593 Acc: 0.8030
# val Loss: 0.6582 Acc: 0.7344
#
# Epoch 3/4
# ----------
# train Loss: 0.5041 Acc: 0.7836
# val Loss: 0.4961 Acc: 0.7835
#
# Epoch 4/4
# ----------
# train Loss: 0.5156 Acc: 0.7708
# val Loss: 0.4769 Acc: 0.7879
#
# Training complete in 17m 34s
# Best val Acc: 0.787911
# [[21076  3345]
#  [  550  1365]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3948 Acc: 0.8292
# val Loss: 0.3825 Acc: 0.8317
#
# Epoch 1/4
# ----------
# train Loss: 0.3842 Acc: 0.8328
# val Loss: 0.3916 Acc: 0.8289
#
# Epoch 2/4
# ----------
# train Loss: 0.3781 Acc: 0.8371
# val Loss: 0.3701 Acc: 0.8412
#
# Epoch 3/4
# ----------
# train Loss: 0.3806 Acc: 0.8342
# val Loss: 0.3701 Acc: 0.8393
#
# Epoch 4/4
# ----------
# train Loss: 0.3734 Acc: 0.8389
# val Loss: 0.4070 Acc: 0.8292
#
# Training complete in 14m 8s
# Best val Acc: 0.841204
# [[19863  4511]
#  [  260  1702]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4607 Acc: 0.7977
# val Loss: 44.8480 Acc: 0.5007
#
# Epoch 1/4
# ----------
# train Loss: 0.6830 Acc: 0.5860
# val Loss: 0.6629 Acc: 0.5982
#
# Epoch 2/4
# ----------
# train Loss: 0.6254 Acc: 0.6510
# val Loss: 0.6053 Acc: 0.6917
#
# Epoch 3/4
# ----------
# train Loss: 0.5646 Acc: 0.7127
# val Loss: 0.5370 Acc: 0.7414
#
# Epoch 4/4
# ----------
# train Loss: 0.4795 Acc: 0.7769
# val Loss: 0.5636 Acc: 0.7672
#
# Training complete in 15m 47s
# Best val Acc: 0.767218
# [[15806  8615]
#  [  216  1699]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4353 Acc: 0.8000
# val Loss: 0.4233 Acc: 0.8110
#
# Epoch 1/4
# ----------
# train Loss: 0.4293 Acc: 0.8059
# val Loss: 0.4233 Acc: 0.8053
#
# Epoch 2/4
# ----------
# train Loss: 0.4235 Acc: 0.8116
# val Loss: 0.4223 Acc: 0.8167
#
# Epoch 3/4
# ----------
# train Loss: 0.4245 Acc: 0.8102
# val Loss: 0.4127 Acc: 0.8142
#
# Epoch 4/4
# ----------
# train Loss: 0.4210 Acc: 0.8121
# val Loss: 0.4192 Acc: 0.8108
#
# Training complete in 17m 36s
# Best val Acc: 0.816670
# [[19400  4974]
#  [  319  1643]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3829 Acc: 0.8345
# val Loss: 0.3705 Acc: 0.8384
#
# Epoch 1/4
# ----------
# train Loss: 0.3774 Acc: 0.8387
# val Loss: 0.3648 Acc: 0.8444
#
# Epoch 2/4
# ----------
# train Loss: 0.3712 Acc: 0.8415
# val Loss: 0.3899 Acc: 0.8211
#
# Epoch 3/4
# ----------
# train Loss: 0.3732 Acc: 0.8404
# val Loss: 0.3682 Acc: 0.8393
#
# Epoch 4/4
# ----------
# train Loss: 0.3676 Acc: 0.8420
# val Loss: 1.2351 Acc: 0.5810
#
# Training complete in 14m 8s
# Best val Acc: 0.844387
# [[19692  4659]
#  [  238  1747]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4493 Acc: 0.7988
# val Loss: 0.4762 Acc: 0.7692
#
# Epoch 1/4
# ----------
# train Loss: 0.4182 Acc: 0.8171
# val Loss: 0.4525 Acc: 0.8073
#
# Epoch 2/4
# ----------
# train Loss: 0.4081 Acc: 0.8219
# val Loss: 0.4116 Acc: 0.8245
#
# Epoch 3/4
# ----------
# train Loss: 0.4073 Acc: 0.8245
# val Loss: 0.7402 Acc: 0.6804
#
# Epoch 4/4
# ----------
# train Loss: 0.4010 Acc: 0.8254
# val Loss: 0.4783 Acc: 0.7910
#
# Training complete in 15m 49s
# Best val Acc: 0.824470
# [[18687  5687]
#  [  231  1731]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4240 Acc: 0.8102
# val Loss: 0.4061 Acc: 0.8190
#
# Epoch 1/4
# ----------
# train Loss: 0.4134 Acc: 0.8171
# val Loss: 0.4086 Acc: 0.8205
#
# Epoch 2/4
# ----------
# train Loss: 0.4095 Acc: 0.8229
# val Loss: 0.4111 Acc: 0.8219
#
# Epoch 3/4
# ----------
# train Loss: 0.4077 Acc: 0.8215
# val Loss: 0.3995 Acc: 0.8219
#
# Epoch 4/4
# ----------
# train Loss: 0.4015 Acc: 0.8252
# val Loss: 2.1845 Acc: 0.5103
#
# Training complete in 17m 41s
# Best val Acc: 0.821945
# [[18999  5276]
#  [  286  1775]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4539 Acc: 0.8038
# val Loss: 0.6334 Acc: 0.7281
#
# Epoch 1/4
# ----------
# train Loss: 0.4698 Acc: 0.7959
# val Loss: 0.5488 Acc: 0.6680
#
# Epoch 2/4
# ----------
# train Loss: 0.4722 Acc: 0.7936
# val Loss: 2.8586 Acc: 0.5113
#
# Epoch 3/4
# ----------
# train Loss: 0.4660 Acc: 0.7993
# val Loss: 0.4956 Acc: 0.7761
#
# Epoch 4/4
# ----------
# train Loss: 0.4160 Acc: 0.8210
# val Loss: 0.3983 Acc: 0.8298
#
# Training complete in 14m 8s
# Best val Acc: 0.829819
# [[21057  3364]
#  [  388  1527]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 1.3427 Acc: 0.6678
# val Loss: 49.0679 Acc: 0.4818
#
# Epoch 1/4
# ----------
# train Loss: 35.0951 Acc: 0.4934
# val Loss: 365291.5034 Acc: 0.4877
#
# Epoch 2/4
# ----------
# train Loss: 222.0737 Acc: 0.4937
# val Loss: 430.6191 Acc: 0.5022
#
# Epoch 3/4
# ----------
# train Loss: 2810884.1920 Acc: 0.5039
# val Loss: 75930289670.8433 Acc: 0.5081
#
# Epoch 4/4
# ----------
# train Loss: 6014568521.9749 Acc: 0.5019
# val Loss: 226151559921.2390 Acc: 0.4968
#
# Training complete in 15m 50s
# Best val Acc: 0.508127
# [[  583 23692]
#  [   16  2045]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4785 Acc: 0.7891
# val Loss: 0.4648 Acc: 0.8003
#
# Epoch 1/4
# ----------
# train Loss: 0.4405 Acc: 0.8083
# val Loss: 0.7080 Acc: 0.6810
#
# Epoch 2/4
# ----------
# train Loss: 0.4431 Acc: 0.8073
# val Loss: 1.0536 Acc: 0.4739
#
# Epoch 3/4
# ----------
# train Loss: 0.4330 Acc: 0.8135
# val Loss: 0.3864 Acc: 0.8301
#
# Epoch 4/4
# ----------
# train Loss: 0.4790 Acc: 0.7973
# val Loss: 45.6958 Acc: 0.5000
#
# Training complete in 17m 42s
# Best val Acc: 0.830126
# [[20468  3807]
#  [  377  1684]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3778 Acc: 0.8360
# val Loss: 0.3693 Acc: 0.8413
#
# Epoch 1/4
# ----------
# train Loss: 0.3668 Acc: 0.8397
# val Loss: 0.3534 Acc: 0.8489
#
# Epoch 2/4
# ----------
# train Loss: 0.3618 Acc: 0.8431
# val Loss: 0.3503 Acc: 0.8498
#
# Epoch 3/4
# ----------
# train Loss: 0.3631 Acc: 0.8415
# val Loss: 0.3776 Acc: 0.8294
#
# Epoch 4/4
# ----------
# train Loss: 0.3611 Acc: 0.8442
# val Loss: 0.3670 Acc: 0.8421
#
# Training complete in 14m 2s
# Best val Acc: 0.849768
# [[20765  3609]
#  [  299  1663]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 258754.0024 Acc: 0.5112
# val Loss: 3265831.1307 Acc: 0.4938
#
# Epoch 1/4
# ----------
# train Loss: 11144.3130 Acc: 0.5090
# val Loss: 977370.7333 Acc: 0.5085
#
# Epoch 2/4
# ----------
# train Loss: 3533.8298 Acc: 0.5051
# val Loss: 189552.0815 Acc: 0.4994
#
# Epoch 3/4
# ----------
# train Loss: 93092.8576 Acc: 0.4968
# val Loss: 863396.3284 Acc: 0.5018
#
# Epoch 4/4
# ----------
# train Loss: 2397.0952 Acc: 0.5033
# val Loss: 1624059.6198 Acc: 0.5046
#
# Training complete in 15m 45s
# Best val Acc: 0.508459
# [[23892   459]
#  [ 1914    71]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.3813 Acc: 0.8364
# val Loss: 0.3722 Acc: 0.8379
#
# Epoch 1/4
# ----------
# train Loss: 0.3746 Acc: 0.8390
# val Loss: 0.3711 Acc: 0.8409
#
# Epoch 2/4
# ----------
# train Loss: 0.3705 Acc: 0.8399
# val Loss: 0.4089 Acc: 0.8141
#
# Epoch 3/4
# ----------
# train Loss: 0.3705 Acc: 0.8411
# val Loss: 0.3759 Acc: 0.8341
#
# Epoch 4/4
# ----------
# train Loss: 0.3714 Acc: 0.8404
# val Loss: 0.3679 Acc: 0.8449
#
# Training complete in 17m 41s
# Best val Acc: 0.844895
# [[20212  4209]
#  [  264  1651]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3651 Acc: 0.8446
# val Loss: 0.4107 Acc: 0.8137
#
# Epoch 1/4
# ----------
# train Loss: 0.3618 Acc: 0.8432
# val Loss: 0.3672 Acc: 0.8416
#
# Epoch 2/4
# ----------
# train Loss: 0.3639 Acc: 0.8414
# val Loss: 0.7162 Acc: 0.5154
#
# Epoch 3/4
# ----------
# train Loss: 0.3619 Acc: 0.8437
# val Loss: 0.3529 Acc: 0.8418
#
# Epoch 4/4
# ----------
# train Loss: 0.3591 Acc: 0.8459
# val Loss: 1.3063 Acc: 0.5351
#
# Training complete in 14m 5s
# Best val Acc: 0.841800
# [[20811  3464]
#  [  358  1703]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 2074.0233 Acc: 0.5005
# val Loss: 765018.1884 Acc: 0.4949
#
# Epoch 1/4
# ----------
# train Loss: 3750.0541 Acc: 0.4994
# val Loss: 139715.8503 Acc: 0.5060
#
# Epoch 2/4
# ----------
# train Loss: 372.3952 Acc: 0.5050
# val Loss: 1057036.1587 Acc: 0.5093
#
# Epoch 3/4
# ----------
# train Loss: 92.5715 Acc: 0.5052
# val Loss: 266548.2744 Acc: 0.4935
#
# Epoch 4/4
# ----------
# train Loss: 557.7779 Acc: 0.5016
# val Loss: 1193057.7829 Acc: 0.5047
#
# Training complete in 15m 45s
# Best val Acc: 0.509349
# [[23575   799]
#  [ 1861   101]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.3758 Acc: 0.8382
# val Loss: 0.3654 Acc: 0.8435
#
# Epoch 1/4
# ----------
# train Loss: 0.3760 Acc: 0.8389
# val Loss: 0.3919 Acc: 0.8380
#
# Epoch 2/4
# ----------
# train Loss: 0.3755 Acc: 0.8382
# val Loss: 0.3506 Acc: 0.8533
#
# Epoch 3/4
# ----------
# train Loss: 0.3701 Acc: 0.8422
# val Loss: 0.3661 Acc: 0.8456
#
# Epoch 4/4
# ----------
# train Loss: 0.3725 Acc: 0.8424
# val Loss: 0.4603 Acc: 0.8026
#
# Training complete in 17m 48s
# Best val Acc: 0.853313
# [[20503  3871]
#  [  264  1698]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4551 Acc: 0.8107
# val Loss: 1.9926 Acc: 0.4748
#
# Epoch 1/4
# ----------
# train Loss: 0.4582 Acc: 0.8064
# val Loss: 0.6226 Acc: 0.6751
#
# Epoch 2/4
# ----------
# train Loss: 0.4132 Acc: 0.8190
# val Loss: 0.5789 Acc: 0.7538
#
# Epoch 3/4
# ----------
# train Loss: 0.4624 Acc: 0.8025
# val Loss: 0.4239 Acc: 0.8244
#
# Epoch 4/4
# ----------
# train Loss: 0.4270 Acc: 0.8195
# val Loss: 0.3954 Acc: 0.8390
#
# Training complete in 14m 2s
# Best val Acc: 0.839017
# [[21570  2851]
#  [  393  1522]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 76.2228 Acc: 0.5011
# val Loss: 954042.0010 Acc: 0.4998
#
# Epoch 1/4
# ----------
# train Loss: 482.8143 Acc: 0.5012
# val Loss: 415654.0682 Acc: 0.4989
#
# Epoch 2/4
# ----------
# train Loss: 536.9183 Acc: 0.5011
# val Loss: 501396.5831 Acc: 0.5012
#
# Epoch 3/4
# ----------
# train Loss: 1707.9771 Acc: 0.4991
# val Loss: 112590.1876 Acc: 0.4991
#
# Epoch 4/4
# ----------
# train Loss: 0.8303 Acc: 0.5039
# val Loss: 460719.7443 Acc: 0.5005
#
# Training complete in 15m 44s
# Best val Acc: 0.501206
# [[24321    53]
#  [ 1953     9]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4033 Acc: 0.8310
# val Loss: 0.4351 Acc: 0.8002
#
# Epoch 1/4
# ----------
# train Loss: 0.4296 Acc: 0.8160
# val Loss: 0.4008 Acc: 0.8346
#
# Epoch 2/4
# ----------
# train Loss: 0.4375 Acc: 0.8144
# val Loss: 0.5538 Acc: 0.7600
#
# Epoch 3/4
# ----------
# train Loss: 0.4414 Acc: 0.8100
# val Loss: 0.4757 Acc: 0.8114
#
# Epoch 4/4
# ----------
# train Loss: 0.4675 Acc: 0.8033
# val Loss: 0.4376 Acc: 0.8116
#
# Training complete in 17m 47s
# Best val Acc: 0.834568
# [[18993  5358]
#  [  220  1765]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model50'}
# Best hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model34'}
# Best score: 0.8595605

# %%
#cf_matrix = confusion_matrix_calc(data_loader_test, labels, model_ft)

# %%
# !kill 8488

# %%
# %tensorboard --logdir Experiments/undersampledrug
# Out:
#       <iframe id="tensorboard-frame-9c46defa786a99d1" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-9c46defa786a99d1");
#           const url = new URL("/", window.location);
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
print(best_params)
best_score
# Out:
# {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model34'}
# array(0.8595605, dtype=float32)
