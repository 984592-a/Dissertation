# %% [markdown]
# ### To note: Running this on different systems (i.e. local, SCW, server) will result in slight changes needing to the code

# %%
# Load libraries
import os
import numpy as np
import torch
import sys
import torchvision
import torchvision.transforms as T
import torchvision.models as models
from PIL import Image
from PIL import ImageEnhance
import matplotlib.pyplot as plt
import imagesize
import subprocess
sys.path
from IPython.core.debugger import set_trace
import scipy.ndimage
import matplotlib.patches as patches
# plt.rcParams['figure.figsize'] = [12,12]
# sys.path.append('/workspace/myFile/Mask_RCNN_Tutorial/')
from tqdm import tqdm
from torch import nn as nn
from torch import optim as optim
from torch.optim import lr_scheduler
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
import re
import time
import copy
import pylab
from torch.utils.tensorboard import SummaryWriter
from tempfile import TemporaryDirectory
import torch.backends.cudnn as cudnn
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import seaborn as sn
import pandas as pd
import glob
# Rather than have a messy notebook with a load of functions we can store them in separate .py files and import them

cudnn.benchmark = True
plt.ion()   # interactive mode
# Out:
# /opt/conda/lib/python3.8/site-packages/scipy/__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
# %load_ext tensorboard
writer = SummaryWriter("Experiments/09085epoch")    # This determines the tensorboard file name

# %%
class DNADataset(object):
    def __init__(self, root, transforms, labels, imDx = False):
        self.root, self.transforms, self.labels = root, transforms, labels
    
        # load all image files, sorting them to ensure they are aligned
        self.imgDir = glob.glob(root+"*/*.tiff")
        Damagednuclei= [x for x in self.imgDir if 'Damaged_nuclei_' in x]
        Undamagednuclei= [x for x in self.imgDir if "No_damage_nuclei" in x]
        #np.random.shuffle(Undamagednuclei)
        #Undamagednuclei=Undamagednuclei[:10000]
        self.imgDir= Damagednuclei+Undamagednuclei
        size80=[]
        for x in self.imgDir:
            img = Image.open(x) # Open image
            w,h=img.size
            if w<=80 and h<=80:
                size80.append(x)
        self.imgDir=size80              
        
        self.imgs = sorted(self.imgDir) # list of images

        

        
    def __getitem__(self, idx):
        img_path = self.imgs[idx]
       
        # Transform images into tensors
        img = Image.open(img_path) # Open image
        w,h=img.size
        img = np.array(img) # Convert image into an array
        img = np.float32(np.divide(img, 2**16)) # Ensure all values are floats
        
        result=np.zeros((80,80), dtype=np.float32)
        x_center = (80 - w) // 2
        y_center = (80 - h) // 2 # copy img image into center of result image
        result[y_center:y_center+h, x_center:x_center+w] = img
        img = result
        
        targetlab=""
        if img_path.find('No_damage_nuclei') != -1:
            targetlab= 'Undamaged'
        if img_path.find('Damaged_nuclei_') != -1:
            targetlab= 'Damaged'  # Find labels corresponding to image
        target = self.labels.index(targetlab) # Get the label and assign to a value
        
        # Convert label to tensor
        #torch.to
        
        if self.transforms is not None:
            img = self.transforms(img)
#             #print('In the transforms')
        imNo = idx
        return img, target, imNo
        
    def __len__(self):
        return len(self.imgs)

# %%
root="/workspace/myFile/Output/17052023/"
p= glob.glob(root+"*/*.tiff")
Damagednuclei= [x for x in p if 'Damaged_nuclei_' in x]
Undamagednuclei= [x for x in p if "No_damage_nuclei" in x]
#np.random.shuffle(Undamagednuclei)
#Undamagednuclei=Undamagednuclei[:10000]
#Undamagednuclei

# %%
imDr = "/workspace/myFile/Output/17052023/"  # Image patches directory

labels = ['Damaged', 'Undamaged']  # Your labels

# %%
# For data augmentation
def get_transform(train):
    transforms = []

    transforms.append(T.ToTensor())
    #transforms.append(T.Normalize([0.0019368887995516483], [0.00672996630111016]))
    #transforms.append(T.RandomHorizontalFlip(0.5))
    
    if train:
        transforms.append(T.RandomHorizontalFlip(p=0.5))
        transforms.append(T.RandomVerticalFlip(p=0.5))
    
    return T.Compose(transforms)

# %%
def train_model(model, criterion, optimizer, scheduler, train, test, num_epochs=25):
    since = time.time()
    # Create a temporary directory to save training checkpoints
    with TemporaryDirectory() as tempdir:
        best_model_params_path = os.path.join(tempdir, 'best_model_params.pt')

        torch.save(model.state_dict(), best_model_params_path)
        best_acc = 0.0
        
        for epoch in range(num_epochs):
            print(f'Epoch {epoch}/{num_epochs - 1}')
            print('-' * 10)
            dataset_train = torch.utils.data.Subset(dataSetTrain, train[epoch])
            dataset_test = torch.utils.data.Subset(dataSetTest, test[epoch])
            data_loader_train = torch.utils.data.DataLoader(
                dataset_train, batch_size=128, shuffle=True, num_workers=0)

            data_loader_test = torch.utils.data.DataLoader(
                dataset_test, batch_size=128, shuffle=False, num_workers=0)
            # Each epoch has a training and validation phase
            for phase in ['train', 'val']:
                if phase == 'train':
                    model.train()  # Set model to training mode
                    dataloaders = data_loader_train
                else:
                    model.eval()   # Set model to evaluate mode
                    dataloaders = data_loader_test

                running_loss = 0.0
                running_corrects = 0
                damaged_len=0
                damaged_corrects = 0
                undamaged_len=0
                undamaged_corrects = 0

                # Iterate over data.
                for inputs, labels, imNo in dataloaders:
                    inputs = inputs.to(device)
                    labels = labels.to(device)

                    # zero the parameter gradients
                    optimizer.zero_grad()

                    # forward
                    # track history if only in train
                    with torch.set_grad_enabled(phase == 'train'):
                        outputs = model(inputs)
                        _, preds = torch.max(outputs, 1)
                        loss = criterion(outputs, labels)
                        # backward + optimize only if in training phase
                        if phase == 'train':
                            loss.backward()
                            optimizer.step()

                    # statistics
                    running_loss += loss.item() * inputs.size(0)    # Loss
                    nada=torch.tensor(np.zeros(len(labels))).to(device)
                    uno=nada+1
                    falseneg=preds+1
                    falsepos=preds-1
                    FPplusTN=torch.sum(labels==nada)
                    TPplusFN=torch.sum(labels==uno)
                    FN=torch.sum(labels==falseneg)
                    FP=torch.sum(labels==falsepos)
                    TN=FPplusTN-FP
                    TP=TPplusFN-FN
                    running_corrects += torch.sum(preds == labels.data) # Accuracy
                    damaged_len+=TPplusFN
                    damaged_corrects += TP
                    undamaged_len+=FPplusTN
                    undamaged_corrects += TN
                damaged_acc = damaged_corrects / damaged_len
                undamaged_acc = undamaged_corrects/undamaged_len
                epoch_acc= (damaged_acc+undamaged_acc)/2
                
                if phase == 'train':
                    scheduler.step()

                epoch_loss = running_loss / dataset_sizes[phase]    # Loss metric per epoch
                #epoch_acc = running_corrects.double() / dataset_sizes[phase]    # Accuracy metric per epoch

                if phase == "train":    # This is the tensorboard code that writes accuracy and loss metrics
                    writer.add_scalar("Train/Accuracy", epoch_acc, epoch)
                    writer.add_scalar("Train/Loss", epoch_loss, epoch)
                else:
                    writer.add_scalar("Validation/Accuracy", epoch_acc, epoch)
                    writer.add_scalar("Validation/Loss", epoch_loss, epoch)

                print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

                # deep copy the model
                if phase == 'val' and epoch_acc >= best_acc: 
                    # This compares validation accuracy to previous bests and adjusts model weights accordingly
                    best_acc = epoch_acc
                    torch.save(model.state_dict(), best_model_params_path)
                    con_mat= torch.tensor([[damaged_corrects, damaged_len-damaged_corrects],[undamaged_len-undamaged_corrects,undamaged_corrects]])

            print()

        time_elapsed = time.time() - since  # Nice way to measure training time but info also stored (indirectly) by tensorboard
        print(
            f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
        print(f'Best val Acc: {best_acc:4f}')
        #labels= labels.cpu().numpy()
        #preds=preds.cpu().numpy()
        model.load_state_dict(torch.load(best_model_params_path))
    writer.close()
    return model, con_mat, best_acc   # We want to return the model because its the model, also confusion matrix for later analysis

# %%
# This is your RESNET
# Initialize CNN with kaiming
def init_cnn(m):
    # Set the weights of the RESNET
    if getattr(m, 'bias', None) is not None: nn.init.constant_(m.bias, 0)
    if isinstance(m, (nn.Conv2d,nn.Linear)): nn.init.kaiming_normal_(m.weight)
    for l in m.children(): init_cnn(l)


# noop function for returning nothing
def noop(x): return x
# activation function(RELU)
act_fn = nn.ReLU(inplace=True)

# Flatten
class Flatten(nn.Module):
    def forward(self, x): return x.view(x.size(0), -1)

# Make a convolution
def conv(ni, nf, ks=3, stride=1, bias=False):
    return nn.Conv2d(ni, nf, kernel_size=ks, stride=stride, padding=ks//2, bias=bias)

# Create a convuolutional layer with convolution and batch norm
def conv_layer(ni, nf, ks=3, stride=1, zero_bn=False, act=True):
    bn = nn.BatchNorm2d(nf) # get a 2d batch norm from Pytorhc
    nn.init.constant_(bn.weight, 0. if zero_bn else 1.)
    layers = [conv(ni, nf, ks, stride=stride), bn]
    if act: layers.append(act_fn) # add in the activation function if act is true
    return nn.Sequential(*layers)


# Resblock
class ResBlock(nn.Module):
    def __init__(self, expansion, ni, nh, stride = 1):
        super().__init__()
        # ni - number of inputs channels, nf - number of filters
        # nh - number of filters in first conv
        # expansion is 1 for resnet 18, 34 and 4 for larger networks
        nf, ni = nh*expansion, ni*expansion
        layers = [conv_layer(ni, nh, 3, stride = stride), # for resnet < 34 2 convs per resblock
                 conv_layer(nh, nf, 3, zero_bn = True, act = False)
                 ] if expansion == 1 else [ # for RESNET > 34 then 3 convs per block with bottleneck
                            conv_layer(ni, nh, 1),
                            conv_layer(nh, nh, 3, stride = stride),
                            conv_layer(nh, nf, 1, zero_bn = True, act = False)
        ]
        self.convs = nn.Sequential(*layers) # Creates the conv layers
        self.idconv = noop if ni==nf else conv_layer(ni, nf, 1, act = False) # id convolution ()
        self.pool = noop if stride== 1 else nn.AvgPool2d(2, ceil_mode = True) # average pool on 
        
    def forward(self, x): 
        # Forward function adds the convolution part to the id part 
        #return act_fn(self.convs(x)) + self.idconv(self.pool(x))
        return act_fn(self.convs(x) + self.idconv(self.pool(x)))

# XResnet
class XResNet(nn.Sequential):
    @classmethod
    def create(cls, expansion, layers, c_in=3, c_out=1000):
        nfs = [c_in, (c_in + 1)*8, 64, 64] # number of filters in stem layer (c_in is number of image channels)
        stem = [conv_layer(nfs[i], nfs[i+1], stride=2 if i==0 else 1)
            for i in range(3)]

        nfs = [64//expansion,64,128,256,512]
        res_layers = [cls._make_layer(expansion, nfs[i], nfs[i+1],
                                      n_blocks=l, stride=1 if i==0 else 2)
                  for i,l in enumerate(layers)]
        res = cls(
        *stem,
        nn.MaxPool2d(kernel_size=3, stride = 2, padding = 1), # then a max pooling layer
        *res_layers,
        nn.AdaptiveAvgPool2d(1), Flatten(), 
        nn.Linear(nfs[-1]*expansion, c_out)
        )
        init_cnn(res)
        return res
        
    @staticmethod
    def _make_layer(expansion, ni, nf, n_blocks, stride): # returns a resblock
        return nn.Sequential(
        *[ResBlock(expansion, ni if i==0 else nf, nf, stride if i==0 else 1)
         for i in range(n_blocks)])

# %%
def xresnet18 (**kwargs): return XResNet.create(1, [2, 2,  2, 2], **kwargs)
def xresnet34 (**kwargs): return XResNet.create(1, [3, 4,  6, 3], **kwargs)
def xresnet50 (**kwargs): return XResNet.create(4, [3, 4,  6, 3], **kwargs)
model18 = xresnet18(c_in = 1, c_out = 2)
model34 = xresnet34(c_in = 1, c_out = 2)
model50 = xresnet50(c_in = 1, c_out = 2)

# Label smoothing cross entropy
import torch.nn.functional as F


def reduce_loss(loss, reduction='mean'):
    return loss.mean() if reduction=='mean' else loss.sum() if reduction=='sum' else loss

class LabelSmoothingCrossEntropy(nn.Module):
    def __init__(self, ε:float=0.1, reduction='mean'):
        super().__init__()
        self.ε,self.reduction = ε,reduction
    
    def forward(self, output, target):
        c = output.size()[-1]
        log_preds = F.log_softmax(output, dim=-1)
        loss = reduce_loss(-log_preds.sum(dim=-1), self.reduction)
        nll = F.nll_loss(log_preds, target, reduction=self.reduction)
        return lin_comb(loss/c, nll, self.ε)

# %%
# Helper functions that shows the image, true class, predicted class and degree of prediction

def images_to_probs(net, images):
    '''
    Generates predictions and corresponding probabilities from a trained
    network and a list of images
    '''
    output = net(images)
    # convert output probabilities to predicted class
    _, preds_tensor = torch.max(output, 1)
    preds = np.squeeze(preds_tensor.numpy())
    return preds, [F.softmax(el, dim=0)[i].item() for i, el in zip(preds, output)]


def plot_classes_preds(net, images, labels):
    '''
    Generates matplotlib Figure using a trained network, along with images
    and labels from a batch, that shows the network's top prediction along
    with its probability, alongside the actual label, coloring this
    information based on whether the prediction was correct or not.
    Uses the "images_to_probs" function.
    '''
    preds, probs = images_to_probs(net, images)
    # plot the images in the batch, along with predicted and true labels
    fig = plt.figure(figsize=(12, 48))
    for idx in np.arange(4):
        ax = fig.add_subplot(1, 4, idx+1, xticks=[], yticks=[])
        matplotlib_imshow(images[idx], one_channel=True)
        ax.set_title("{0}, {1:.1f}%\n(label: {2})".format(
            labels[preds[idx]],
            probs[idx] * 100.0,
            labels[labels[idx]]),
                    color=("green" if preds[idx]==labels[idx].item() else "red"))
    return fig

def matplotlib_imshow(img, one_channel=True):
    if one_channel:
        img = img.mean(dim=0)
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    if one_channel:
        plt.imshow(npimg, cmap="Greys")
    else:
        plt.imshow(np.transpose(npimg, (1, 2, 0)))

# %%
def confusion_matrix_calc(data_loader_test, classes, model_ft):       
        y_pred = []
        y_true = []
        for inputs, labels, imNo in data_loader_test:
                inputs = inputs.to(device)
                labels = labels.to(device)
                output = model_ft(inputs) # Feed Network

                output = (torch.max(torch.exp(output), 1)[1]).data.cpu().numpy()
                y_pred.extend(output) # Save Prediction
                
                labels = labels.data.cpu().numpy()
                y_true.extend(labels) # Save Truth

        # constant for classes
        # classes = ('Alive', 'Dead')

        # Build confusion matrix
        cf_matrix = confusion_matrix(y_true, y_pred)
        return cf_matrix

# %%
k=5 #NUMBER OF K FOLDS
epoch=range(30) #NUMBER OF EPOCHS

torch.manual_seed(10)
imIdx = torch.randperm(1).tolist()

## Create dataset
dataSetTrain = DNADataset(imDr, get_transform(train = True), labels, imDx=imIdx)
dataSetTest = DNADataset(imDr, get_transform(train = False), labels, imDx=imIdx)

data_loader_train=[]
data_loader_test=[]

# ## Create dataloaders
# Get subset
torch.manual_seed(10)
TotalSetTrain=list(range(len(dataSetTrain)))
np.random.shuffle(TotalSetTrain)
TotalSetTest=list(range(len(dataSetTest)))
np.random.shuffle(TotalSetTest)

train=[]
test=[]
for epoch in epoch:
    
    Kfifth = len(dataSetTrain)//k
    split= epoch%k
    train.append(TotalSetTrain[(split+1)*Kfifth:]+TotalSetTrain[:Kfifth*split])
    test.append(TotalSetTest[split*Kfifth:(split+1)*Kfifth])

#dataset_train = torch.utils.data.Subset(dataSetTrain, indices[-noTrain:])

#dataset_test = torch.utils.data.Subset(dataSetTest, indices[:-noTrain])
#len(indices), len(indices[:-50]), len(indices[-50:]), 50/191, type(dataset_test)

dataset_sizes = {'train': len(train[0]), 'val': len(test[0])}

#dataset_train = torch.utils.data.Subset(dataSetTrain, train)
#data_loader_train.append(dataset_train)
#dataset_testo = torch.utils.data.Subset(dataSetTest, test)
#data_loader_test.append(dataset_testo)
# define training and validation data loaders


# Collate function (gathers together the outputs)
# def collate_fn(batch):
#     return tuple(zip(*batch))

#len(indices[-noTrain:]), dataset_sizes
#dataset_test[0][1], dataset_test[3][1], dataset_test[-1][1], dataSetTrain.imgs

# %%
class_weights= [0.924865,0.075135] #1-(#inclass/ #intotal )
class_weights = torch.Tensor(class_weights)
class_weights=class_weights.to(device)
criterion = nn.CrossEntropyLoss(weight = class_weights) 

# Observe that all parameters are being optimized
learning_rate=[0.05, 0.1,0.2]
Momentum=[0.5,0.9,0.99]
GAMMA=[0.05, 0.1, 0.5]
#Batch_size= [16,32]#,64,128]
models=[model18, model34, model50]
modelnames=["model18","model34","model50"]
#ADD IN A THING SO IT SAVES THE TENSORBOARD TO DIFFERENT BITS
best_params = None
best_score=0.00
Current_params=None
for lrnum in range(3):
    for gamnum in range(3):
        for Momnum in range(3):
            for modnum in range(3):
                model=models[modnum]
                model = model.to(device)
                optimizer_ft = optim.SGD(model.parameters(), lr=learning_rate[lrnum], momentum=Momentum[Momnum])
                exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=GAMMA[gamnum])
                writer = SummaryWriter("Experiments/TENSORBOARD/lr"+str(learning_rate[lrnum])+"momentum"+
                        str(Momentum[Momnum])+"gamma"+str(GAMMA[gamnum])+"model"+modelnames[modnum])  
                model_ft, con_mat, current_score = train_model(model, criterion, optimizer_ft, exp_lr_scheduler,
                   train,test,num_epochs=5)
                con_mat=con_mat.cpu().numpy()
                current_score=current_score.cpu().numpy()
                Current_params= {'learning rate': learning_rate[lrnum], 'gamma': GAMMA[gamnum], 
                                   'Momentum': Momentum[Momnum], 'Model': modelnames[modnum]}
                print(con_mat)
                print("Current hyperparameters:", Current_params)
                df_cm_ratio = pd.DataFrame(con_mat / np.sum(con_mat, axis=1)[:, None], index=[i for i in labels],
                                     columns=[i for i in labels])
                plt.figure(figsize=(12, 7))
                sn.heatmap(df_cm_ratio, annot=True)
                if current_score > best_score:
                    best_score = current_score
                    best_params = {'learning rate': learning_rate[lrnum], 'gamma': GAMMA[gamnum], 
                                   'Momentum': Momentum[Momnum], 'Model': modelnames[modnum]}
                            
print("Best hyperparameters:", best_params)
print("Best score:", best_score)
# Out:
# Epoch 0/4
# ----------
# train Loss: 0.5244 Acc: 0.7587
# val Loss: 0.5679 Acc: 0.7593
#
# Epoch 1/4
# ----------
# train Loss: 0.4516 Acc: 0.8026
# val Loss: 0.6115 Acc: 0.6812
#
# Epoch 2/4
# ----------
# train Loss: 0.4288 Acc: 0.8114
# val Loss: 0.6143 Acc: 0.7151
#
# Epoch 3/4
# ----------
# train Loss: 0.4110 Acc: 0.8203
# val Loss: 1.3531 Acc: 0.5471
#
# Epoch 4/4
# ----------
# train Loss: 0.4184 Acc: 0.8152
# val Loss: 0.4327 Acc: 0.8014
#
# Training complete in 14m 18s
# Best val Acc: 0.801375
# [[17879  6451]
#  [  265  1741]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.5247 Acc: 0.7552
# val Loss: 0.5176 Acc: 0.7862
#
# Epoch 1/4
# ----------
# train Loss: 0.4485 Acc: 0.8025
# val Loss: 0.4607 Acc: 0.7933
#
# Epoch 2/4
# ----------
# train Loss: 0.4210 Acc: 0.8151
# val Loss: 0.7682 Acc: 0.5030
#
# Epoch 3/4
# ----------
# train Loss: 0.4071 Acc: 0.8220
# val Loss: 0.3951 Acc: 0.8221
#
# Epoch 4/4
# ----------
# train Loss: 0.3996 Acc: 0.8257
# val Loss: 0.5024 Acc: 0.7481
#
# Training complete in 16m 1s
# Best val Acc: 0.822117
# [[21061  3328]
#  [  427  1520]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.6581 Acc: 0.7319
# val Loss: 2.6217 Acc: 0.5057
#
# Epoch 1/4
# ----------
# train Loss: 0.4928 Acc: 0.7942
# val Loss: 2.9153 Acc: 0.5018
#
# Epoch 2/4
# ----------
# train Loss: 0.4460 Acc: 0.8093
# val Loss: 9.5509 Acc: 0.5000
#
# Epoch 3/4
# ----------
# train Loss: 0.4264 Acc: 0.8172
# val Loss: 0.4168 Acc: 0.8236
#
# Epoch 4/4
# ----------
# train Loss: 0.4113 Acc: 0.8234
# val Loss: 0.9627 Acc: 0.6541
#
# Training complete in 18m 3s
# Best val Acc: 0.823568
# [[20518  3871]
#  [  378  1569]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4536 Acc: 0.7994
# val Loss: 0.5162 Acc: 0.7396
#
# Epoch 1/4
# ----------
# train Loss: 0.4135 Acc: 0.8168
# val Loss: 0.5021 Acc: 0.7651
#
# Epoch 2/4
# ----------
# train Loss: 0.4032 Acc: 0.8225
# val Loss: 0.6778 Acc: 0.7218
#
# Epoch 3/4
# ----------
# train Loss: 0.3852 Acc: 0.8329
# val Loss: 0.4403 Acc: 0.8028
#
# Epoch 4/4
# ----------
# train Loss: 0.3907 Acc: 0.8287
# val Loss: 0.4146 Acc: 0.8185
#
# Training complete in 14m 15s
# Best val Acc: 0.818474
# [[22010  2320]
#  [  537  1469]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4710 Acc: 0.7883
# val Loss: 0.4426 Acc: 0.7974
#
# Epoch 1/4
# ----------
# train Loss: 0.4185 Acc: 0.8138
# val Loss: 0.4918 Acc: 0.7642
#
# Epoch 2/4
# ----------
# train Loss: 0.4050 Acc: 0.8221
# val Loss: 0.4246 Acc: 0.8134
#
# Epoch 3/4
# ----------
# train Loss: 0.3946 Acc: 0.8267
# val Loss: 0.4166 Acc: 0.8176
#
# Epoch 4/4
# ----------
# train Loss: 0.3889 Acc: 0.8293
# val Loss: 0.3699 Acc: 0.8365
#
# Training complete in 15m 55s
# Best val Acc: 0.836482
# [[20315  4015]
#  [  325  1681]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.5031 Acc: 0.7827
# val Loss: 0.7384 Acc: 0.5097
#
# Epoch 1/4
# ----------
# train Loss: 0.4224 Acc: 0.8115
# val Loss: 0.8240 Acc: 0.5642
#
# Epoch 2/4
# ----------
# train Loss: 0.4107 Acc: 0.8209
# val Loss: 4.0141 Acc: 0.5034
#
# Epoch 3/4
# ----------
# train Loss: 0.3966 Acc: 0.8273
# val Loss: 0.5056 Acc: 0.7658
#
# Epoch 4/4
# ----------
# train Loss: 0.4027 Acc: 0.8258
# val Loss: 0.5168 Acc: 0.7503
#
# Training complete in 18m 4s
# Best val Acc: 0.765776
# [[14843  9546]
#  [  150  1797]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4834 Acc: 0.7773
# val Loss: 0.4749 Acc: 0.7988
#
# Epoch 1/4
# ----------
# train Loss: 0.4484 Acc: 0.7993
# val Loss: 0.4725 Acc: 0.7866
#
# Epoch 2/4
# ----------
# train Loss: 0.4332 Acc: 0.8110
# val Loss: 0.4346 Acc: 0.8019
#
# Epoch 3/4
# ----------
# train Loss: 0.4268 Acc: 0.8089
# val Loss: 0.5020 Acc: 0.7787
#
# Epoch 4/4
# ----------
# train Loss: 0.4171 Acc: 0.8170
# val Loss: 0.4181 Acc: 0.8253
#
# Training complete in 14m 20s
# Best val Acc: 0.825317
# [[18947  5383]
#  [  257  1749]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4912 Acc: 0.7734
# val Loss: 0.4869 Acc: 0.7698
#
# Epoch 1/4
# ----------
# train Loss: 0.4641 Acc: 0.7906
# val Loss: 0.6003 Acc: 0.7028
#
# Epoch 2/4
# ----------
# train Loss: 0.4423 Acc: 0.8055
# val Loss: 0.4574 Acc: 0.7992
#
# Epoch 3/4
# ----------
# train Loss: 0.4352 Acc: 0.8058
# val Loss: 0.5558 Acc: 0.7370
#
# Epoch 4/4
# ----------
# train Loss: 0.4447 Acc: 0.7995
# val Loss: 0.4487 Acc: 0.8039
#
# Training complete in 16m 6s
# Best val Acc: 0.803926
# [[21387  2943]
#  [  544  1462]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4972 Acc: 0.7752
# val Loss: 0.5953 Acc: 0.6819
#
# Epoch 1/4
# ----------
# train Loss: 0.4775 Acc: 0.7841
# val Loss: 0.4285 Acc: 0.8165
#
# Epoch 2/4
# ----------
# train Loss: 0.4438 Acc: 0.8051
# val Loss: 1.6010 Acc: 0.5109
#
# Epoch 3/4
# ----------
# train Loss: 0.4424 Acc: 0.8059
# val Loss: 0.5184 Acc: 0.7595
#
# Epoch 4/4
# ----------
# train Loss: 0.4340 Acc: 0.8098
# val Loss: 0.4999 Acc: 0.8078
#
# Training complete in 18m 17s
# Best val Acc: 0.816546
# [[21026  3306]
#  [  463  1541]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3859 Acc: 0.8331
# val Loss: 0.3836 Acc: 0.8335
#
# Epoch 1/4
# ----------
# train Loss: 0.3815 Acc: 0.8344
# val Loss: 0.3742 Acc: 0.8350
#
# Epoch 2/4
# ----------
# train Loss: 0.3818 Acc: 0.8333
# val Loss: 0.4061 Acc: 0.8112
#
# Epoch 3/4
# ----------
# train Loss: 0.3759 Acc: 0.8374
# val Loss: 0.3785 Acc: 0.8353
#
# Epoch 4/4
# ----------
# train Loss: 0.3777 Acc: 0.8362
# val Loss: 0.3684 Acc: 0.8425
#
# Training complete in 14m 28s
# Best val Acc: 0.842523
# [[19954  4376]
#  [  271  1735]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4234 Acc: 0.8097
# val Loss: 0.4163 Acc: 0.8101
#
# Epoch 1/4
# ----------
# train Loss: 0.4147 Acc: 0.8127
# val Loss: 0.4029 Acc: 0.8186
#
# Epoch 2/4
# ----------
# train Loss: 0.4083 Acc: 0.8195
# val Loss: 0.4111 Acc: 0.8150
#
# Epoch 3/4
# ----------
# train Loss: 0.4014 Acc: 0.8219
# val Loss: 0.3969 Acc: 0.8231
#
# Epoch 4/4
# ----------
# train Loss: 0.4027 Acc: 0.8222
# val Loss: 0.3911 Acc: 0.8243
#
# Training complete in 16m 25s
# Best val Acc: 0.824320
# [[19420  4910]
#  [  300  1706]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4137 Acc: 0.8170
# val Loss: 0.4093 Acc: 0.8190
#
# Epoch 1/4
# ----------
# train Loss: 0.4052 Acc: 0.8209
# val Loss: 0.4171 Acc: 0.8136
#
# Epoch 2/4
# ----------
# train Loss: 0.4017 Acc: 0.8258
# val Loss: 0.3943 Acc: 0.8281
#
# Epoch 3/4
# ----------
# train Loss: 0.3944 Acc: 0.8284
# val Loss: 0.3938 Acc: 0.8265
#
# Epoch 4/4
# ----------
# train Loss: 0.3968 Acc: 0.8257
# val Loss: 0.4040 Acc: 0.8224
#
# Training complete in 18m 31s
# Best val Acc: 0.828143
# [[20359  4032]
#  [  347  1598]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3782 Acc: 0.8361
# val Loss: 0.3885 Acc: 0.8333
#
# Epoch 1/4
# ----------
# train Loss: 0.3795 Acc: 0.8344
# val Loss: 0.8452 Acc: 0.6377
#
# Epoch 2/4
# ----------
# train Loss: 0.3754 Acc: 0.8383
# val Loss: 0.4045 Acc: 0.8333
#
# Epoch 3/4
# ----------
# train Loss: 0.3721 Acc: 0.8390
# val Loss: 0.4351 Acc: 0.8109
#
# Epoch 4/4
# ----------
# train Loss: 0.3717 Acc: 0.8405
# val Loss: 0.3614 Acc: 0.8464
#
# Training complete in 56m 3s
# Best val Acc: 0.846420
# [[19707  4623]
#  [  235  1771]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3991 Acc: 0.8229
# val Loss: 0.3950 Acc: 0.8272
#
# Epoch 1/4
# ----------
# train Loss: 0.3945 Acc: 0.8280
# val Loss: 0.3866 Acc: 0.8255
#
# Epoch 2/4
# ----------
# train Loss: 0.3922 Acc: 0.8288
# val Loss: 0.4745 Acc: 0.7858
#
# Epoch 3/4
# ----------
# train Loss: 0.3858 Acc: 0.8305
# val Loss: 0.5496 Acc: 0.7564
#
# Epoch 4/4
# ----------
# train Loss: 0.3855 Acc: 0.8329
# val Loss: 0.4147 Acc: 0.8112
#
# Training complete in 16m 20s
# Best val Acc: 0.827187
# [[21103  3242]
#  [  423  1568]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4000 Acc: 0.8240
# val Loss: 0.4226 Acc: 0.8146
#
# Epoch 1/4
# ----------
# train Loss: 0.3941 Acc: 0.8270
# val Loss: 0.6804 Acc: 0.6762
#
# Epoch 2/4
# ----------
# train Loss: 0.3936 Acc: 0.8312
# val Loss: 0.5031 Acc: 0.7747
#
# Epoch 3/4
# ----------
# train Loss: 0.3840 Acc: 0.8338
# val Loss: 0.4542 Acc: 0.8006
#
# Epoch 4/4
# ----------
# train Loss: 0.3868 Acc: 0.8331
# val Loss: 0.3805 Acc: 0.8371
#
# Training complete in 18m 14s
# Best val Acc: 0.837076
# [[21484  2846]
#  [  419  1587]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4122 Acc: 0.8184
# val Loss: 0.7225 Acc: 0.6858
#
# Epoch 1/4
# ----------
# train Loss: 0.4089 Acc: 0.8188
# val Loss: 0.6196 Acc: 0.7312
#
# Epoch 2/4
# ----------
# train Loss: 0.4043 Acc: 0.8259
# val Loss: 0.4224 Acc: 0.8288
#
# Epoch 3/4
# ----------
# train Loss: 0.3993 Acc: 0.8249
# val Loss: 0.3864 Acc: 0.8290
#
# Epoch 4/4
# ----------
# train Loss: 0.4008 Acc: 0.8246
# val Loss: 0.4102 Acc: 0.8286
#
# Training complete in 14m 4s
# Best val Acc: 0.828960
# [[19115  5274]
#  [  245  1702]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4264 Acc: 0.8105
# val Loss: 0.4636 Acc: 0.7770
#
# Epoch 1/4
# ----------
# train Loss: 0.4434 Acc: 0.8063
# val Loss: 0.5636 Acc: 0.7751
#
# Epoch 2/4
# ----------
# train Loss: 0.4096 Acc: 0.8217
# val Loss: 0.6794 Acc: 0.6804
#
# Epoch 3/4
# ----------
# train Loss: 0.4051 Acc: 0.8225
# val Loss: 0.4573 Acc: 0.7795
#
# Epoch 4/4
# ----------
# train Loss: 0.4025 Acc: 0.8246
# val Loss: 0.4604 Acc: 0.7822
#
# Training complete in 15m 47s
# Best val Acc: 0.782244
# [[17033  7297]
#  [  272  1734]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4269 Acc: 0.8150
# val Loss: 0.4788 Acc: 0.7883
#
# Epoch 1/4
# ----------
# train Loss: 0.4307 Acc: 0.8119
# val Loss: 0.4595 Acc: 0.7844
#
# Epoch 2/4
# ----------
# train Loss: 0.4339 Acc: 0.8138
# val Loss: 0.6549 Acc: 0.6950
#
# Epoch 3/4
# ----------
# train Loss: 0.4112 Acc: 0.8234
# val Loss: 0.4013 Acc: 0.8167
#
# Epoch 4/4
# ----------
# train Loss: 0.3983 Acc: 0.8270
# val Loss: 0.4055 Acc: 0.8312
#
# Training complete in 18m 8s
# Best val Acc: 0.831189
# [[21525  2805]
#  [  446  1560]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3735 Acc: 0.8356
# val Loss: 0.3813 Acc: 0.8351
#
# Epoch 1/4
# ----------
# train Loss: 0.3711 Acc: 0.8370
# val Loss: 0.3604 Acc: 0.8440
#
# Epoch 2/4
# ----------
# train Loss: 0.3687 Acc: 0.8405
# val Loss: 0.3635 Acc: 0.8458
#
# Epoch 3/4
# ----------
# train Loss: 0.3604 Acc: 0.8450
# val Loss: 0.3635 Acc: 0.8429
#
# Epoch 4/4
# ----------
# train Loss: 0.3648 Acc: 0.8409
# val Loss: 0.3555 Acc: 0.8498
#
# Training complete in 14m 2s
# Best val Acc: 0.849797
# [[20029  4301]
#  [  248  1758]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3790 Acc: 0.8341
# val Loss: 0.3754 Acc: 0.8372
#
# Epoch 1/4
# ----------
# train Loss: 0.3720 Acc: 0.8366
# val Loss: 0.3653 Acc: 0.8367
#
# Epoch 2/4
# ----------
# train Loss: 0.3709 Acc: 0.8401
# val Loss: 0.3658 Acc: 0.8438
#
# Epoch 3/4
# ----------
# train Loss: 0.3658 Acc: 0.8424
# val Loss: 0.3617 Acc: 0.8458
#
# Epoch 4/4
# ----------
# train Loss: 0.3689 Acc: 0.8404
# val Loss: 0.3548 Acc: 0.8488
#
# Training complete in 15m 45s
# Best val Acc: 0.848832
# [[21013  3317]
#  [  333  1673]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.3811 Acc: 0.8340
# val Loss: 0.3770 Acc: 0.8418
#
# Epoch 1/4
# ----------
# train Loss: 0.3749 Acc: 0.8364
# val Loss: 0.3714 Acc: 0.8376
#
# Epoch 2/4
# ----------
# train Loss: 0.3723 Acc: 0.8404
# val Loss: 0.3761 Acc: 0.8385
#
# Epoch 3/4
# ----------
# train Loss: 0.3684 Acc: 0.8422
# val Loss: 0.3632 Acc: 0.8445
#
# Epoch 4/4
# ----------
# train Loss: 0.3696 Acc: 0.8422
# val Loss: 0.3530 Acc: 0.8500
#
# Training complete in 18m 8s
# Best val Acc: 0.849997
# [[20536  3794]
#  [  289  1717]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# /tmp/ipykernel_595/2697057278.py:37: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(12, 7))
# train Loss: 0.3662 Acc: 0.8420
# val Loss: 0.6944 Acc: 0.7048
#
# Epoch 1/4
# ----------
# train Loss: 0.3635 Acc: 0.8418
# val Loss: 0.3549 Acc: 0.8488
#
# Epoch 2/4
# ----------
# train Loss: 0.3642 Acc: 0.8435
# val Loss: 0.4203 Acc: 0.8181
#
# Epoch 3/4
# ----------
# train Loss: 0.3576 Acc: 0.8461
# val Loss: 0.3549 Acc: 0.8477
#
# Epoch 4/4
# ----------
# train Loss: 0.3590 Acc: 0.8473
# val Loss: 0.3429 Acc: 0.8579
#
# Training complete in 14m 9s
# Best val Acc: 0.857875
# [[20883  3447]
#  [  286  1720]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3707 Acc: 0.8408
# val Loss: 0.3944 Acc: 0.8299
#
# Epoch 1/4
# ----------
# train Loss: 0.3706 Acc: 0.8383
# val Loss: 0.3577 Acc: 0.8411
#
# Epoch 2/4
# ----------
# train Loss: 0.3681 Acc: 0.8397
# val Loss: 0.3594 Acc: 0.8449
#
# Epoch 3/4
# ----------
# train Loss: 0.3630 Acc: 0.8430
# val Loss: 0.3584 Acc: 0.8483
#
# Epoch 4/4
# ----------
# train Loss: 0.3649 Acc: 0.8410
# val Loss: 0.3589 Acc: 0.8507
#
# Training complete in 15m 46s
# Best val Acc: 0.850652
# [[21332  2998]
#  [  352  1654]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.3699 Acc: 0.8405
# val Loss: 0.3652 Acc: 0.8453
#
# Epoch 1/4
# ----------
# train Loss: 0.3692 Acc: 0.8406
# val Loss: 0.3622 Acc: 0.8406
#
# Epoch 2/4
# ----------
# train Loss: 0.3693 Acc: 0.8424
# val Loss: 0.3890 Acc: 0.8316
#
# Epoch 3/4
# ----------
# train Loss: 0.3645 Acc: 0.8436
# val Loss: 0.5085 Acc: 0.7773
#
# Epoch 4/4
# ----------
# train Loss: 0.3643 Acc: 0.8450
# val Loss: 0.5085 Acc: 0.7718
#
# Training complete in 18m 10s
# Best val Acc: 0.845259
# [[20699  3646]
#  [  318  1673]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3953 Acc: 0.8289
# val Loss: 0.3759 Acc: 0.8325
#
# Epoch 1/4
# ----------
# train Loss: 0.3854 Acc: 0.8334
# val Loss: 0.3825 Acc: 0.8310
#
# Epoch 2/4
# ----------
# train Loss: 0.3850 Acc: 0.8347
# val Loss: 0.3938 Acc: 0.8263
#
# Epoch 3/4
# ----------
# train Loss: 0.3893 Acc: 0.8333
# val Loss: 0.3734 Acc: 0.8381
#
# Epoch 4/4
# ----------
# train Loss: 0.3954 Acc: 0.8296
# val Loss: 0.3750 Acc: 0.8370
#
# Training complete in 14m 4s
# Best val Acc: 0.838102
# [[21014  3375]
#  [  361  1586]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4061 Acc: 0.8220
# val Loss: 0.4050 Acc: 0.8189
#
# Epoch 1/4
# ----------
# train Loss: 0.3991 Acc: 0.8244
# val Loss: 0.3996 Acc: 0.8248
#
# Epoch 2/4
# ----------
# train Loss: 0.4011 Acc: 0.8229
# val Loss: 0.5402 Acc: 0.7783
#
# Epoch 3/4
# ----------
# train Loss: 0.3979 Acc: 0.8249
# val Loss: 0.7395 Acc: 0.6416
#
# Epoch 4/4
# ----------
# train Loss: 0.3881 Acc: 0.8319
# val Loss: 0.7235 Acc: 0.6493
#
# Training complete in 15m 46s
# Best val Acc: 0.824750
# [[19519  4813]
#  [  306  1698]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.3918 Acc: 0.8305
# val Loss: 0.4996 Acc: 0.7624
#
# Epoch 1/4
# ----------
# train Loss: 0.4019 Acc: 0.8266
# val Loss: 0.4612 Acc: 0.7742
#
# Epoch 2/4
# ----------
# train Loss: 0.3930 Acc: 0.8295
# val Loss: 0.4084 Acc: 0.8183
#
# Epoch 3/4
# ----------
# train Loss: 0.3992 Acc: 0.8268
# val Loss: 0.3875 Acc: 0.8228
#
# Epoch 4/4
# ----------
# train Loss: 0.3896 Acc: 0.8296
# val Loss: 0.3764 Acc: 0.8345
#
# Training complete in 18m 20s
# Best val Acc: 0.834531
# [[18704  5626]
#  [  200  1806]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3657 Acc: 0.8411
# val Loss: 0.3746 Acc: 0.8372
#
# Epoch 1/4
# ----------
# train Loss: 0.3573 Acc: 0.8464
# val Loss: 0.3789 Acc: 0.8310
#
# Epoch 2/4
# ----------
# train Loss: 0.3577 Acc: 0.8479
# val Loss: 0.3732 Acc: 0.8415
#
# Epoch 3/4
# ----------
# train Loss: 0.3522 Acc: 0.8492
# val Loss: 0.3507 Acc: 0.8454
#
# Epoch 4/4
# ----------
# train Loss: 0.3526 Acc: 0.8492
# val Loss: 0.3972 Acc: 0.8273
#
# Training complete in 14m 7s
# Best val Acc: 0.845396
# [[20067  4322]
#  [  257  1690]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3708 Acc: 0.8378
# val Loss: 0.4228 Acc: 0.8094
#
# Epoch 1/4
# ----------
# train Loss: 0.3644 Acc: 0.8411
# val Loss: 0.3532 Acc: 0.8435
#
# Epoch 2/4
# ----------
# train Loss: 0.3653 Acc: 0.8429
# val Loss: 0.3846 Acc: 0.8357
#
# Epoch 3/4
# ----------
# train Loss: 0.3585 Acc: 0.8454
# val Loss: 0.3713 Acc: 0.8377
#
# Epoch 4/4
# ----------
# train Loss: 0.3630 Acc: 0.8451
# val Loss: 0.5806 Acc: 0.6870
#
# Training complete in 15m 46s
# Best val Acc: 0.843476
# [[20406  3926]
#  [  304  1700]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.3686 Acc: 0.8430
# val Loss: 1.1212 Acc: 0.5105
#
# Epoch 1/4
# ----------
# train Loss: 0.3628 Acc: 0.8432
# val Loss: 0.3559 Acc: 0.8447
#
# Epoch 2/4
# ----------
# train Loss: 0.3625 Acc: 0.8444
# val Loss: 0.3608 Acc: 0.8478
#
# Epoch 3/4
# ----------
# train Loss: 0.3560 Acc: 0.8474
# val Loss: 0.3506 Acc: 0.8473
#
# Epoch 4/4
# ----------
# train Loss: 0.3571 Acc: 0.8471
# val Loss: 0.3525 Acc: 0.8486
#
# Training complete in 18m 7s
# Best val Acc: 0.848628
# [[19487  4843]
#  [  208  1798]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3597 Acc: 0.8462
# val Loss: 0.4225 Acc: 0.8208
#
# Epoch 1/4
# ----------
# train Loss: 0.3590 Acc: 0.8477
# val Loss: 0.3452 Acc: 0.8529
#
# Epoch 2/4
# ----------
# train Loss: 0.3567 Acc: 0.8474
# val Loss: 0.3745 Acc: 0.8429
#
# Epoch 3/4
# ----------
# train Loss: 0.3506 Acc: 0.8498
# val Loss: 0.3433 Acc: 0.8493
#
# Epoch 4/4
# ----------
# train Loss: 0.3488 Acc: 0.8516
# val Loss: 0.3377 Acc: 0.8570
#
# Training complete in 14m 0s
# Best val Acc: 0.857003
# [[20695  3635]
#  [  274  1732]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3658 Acc: 0.8421
# val Loss: 0.5885 Acc: 0.7302
#
# Epoch 1/4
# ----------
# train Loss: 0.3637 Acc: 0.8415
# val Loss: 0.3618 Acc: 0.8433
#
# Epoch 2/4
# ----------
# train Loss: 0.3651 Acc: 0.8428
# val Loss: 0.3715 Acc: 0.8384
#
# Epoch 3/4
# ----------
# train Loss: 0.3578 Acc: 0.8440
# val Loss: 0.3513 Acc: 0.8485
#
# Epoch 4/4
# ----------
# train Loss: 0.3584 Acc: 0.8474
# val Loss: 0.5554 Acc: 0.7454
#
# Training complete in 15m 49s
# Best val Acc: 0.848461
# [[20442  3947]
#  [  275  1672]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.3637 Acc: 0.8442
# val Loss: 0.3731 Acc: 0.8401
#
# Epoch 1/4
# ----------
# train Loss: 0.3620 Acc: 0.8454
# val Loss: 0.4138 Acc: 0.8213
#
# Epoch 2/4
# ----------
# train Loss: 0.3619 Acc: 0.8455
# val Loss: 0.5351 Acc: 0.7385
#
# Epoch 3/4
# ----------
# train Loss: 0.3547 Acc: 0.8482
# val Loss: 0.4259 Acc: 0.8099
#
# Epoch 4/4
# ----------
# train Loss: 0.4161 Acc: 0.8109
# val Loss: 0.3586 Acc: 0.8429
#
# Training complete in 18m 11s
# Best val Acc: 0.842912
# [[20167  4163]
#  [  287  1719]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4186 Acc: 0.8178
# val Loss: 0.4285 Acc: 0.8091
#
# Epoch 1/4
# ----------
# train Loss: 0.4149 Acc: 0.8186
# val Loss: 0.4797 Acc: 0.7440
#
# Epoch 2/4
# ----------
# train Loss: 0.4189 Acc: 0.8208
# val Loss: 0.4909 Acc: 0.7729
#
# Epoch 3/4
# ----------
# train Loss: 0.4069 Acc: 0.8264
# val Loss: 0.3969 Acc: 0.8268
#
# Epoch 4/4
# ----------
# train Loss: 0.4246 Acc: 0.8145
# val Loss: 0.4098 Acc: 0.8242
#
# Training complete in 13m 59s
# Best val Acc: 0.826811
# [[19173  5216]
#  [  258  1689]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4090 Acc: 0.8211
# val Loss: 0.4066 Acc: 0.8255
#
# Epoch 1/4
# ----------
# train Loss: 0.4168 Acc: 0.8169
# val Loss: 0.3805 Acc: 0.8362
#
# Epoch 2/4
# ----------
# train Loss: 0.4166 Acc: 0.8184
# val Loss: 0.6017 Acc: 0.7353
#
# Epoch 3/4
# ----------
# train Loss: 0.4205 Acc: 0.8216
# val Loss: 0.4036 Acc: 0.8252
#
# Epoch 4/4
# ----------
# train Loss: 0.4226 Acc: 0.8162
# val Loss: 0.4269 Acc: 0.8063
#
# Training complete in 15m 50s
# Best val Acc: 0.836236
# [[20855  3477]
#  [  370  1634]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4115 Acc: 0.8226
# val Loss: 0.3977 Acc: 0.8241
#
# Epoch 1/4
# ----------
# train Loss: 0.4510 Acc: 0.8022
# val Loss: 0.4617 Acc: 0.7969
#
# Epoch 2/4
# ----------
# train Loss: 0.4385 Acc: 0.8073
# val Loss: 0.4694 Acc: 0.7703
#
# Epoch 3/4
# ----------
# train Loss: 0.4211 Acc: 0.8158
# val Loss: 0.4086 Acc: 0.8151
#
# Epoch 4/4
# ----------
# train Loss: 0.4370 Acc: 0.8119
# val Loss: 0.4513 Acc: 0.7922
#
# Training complete in 18m 8s
# Best val Acc: 0.824115
# [[20770  3575]
#  [  408  1583]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3726 Acc: 0.8361
# val Loss: 0.3695 Acc: 0.8387
#
# Epoch 1/4
# ----------
# train Loss: 0.3651 Acc: 0.8420
# val Loss: 0.3554 Acc: 0.8466
#
# Epoch 2/4
# ----------
# train Loss: 0.3631 Acc: 0.8447
# val Loss: 0.3718 Acc: 0.8373
#
# Epoch 3/4
# ----------
# train Loss: 0.3572 Acc: 0.8459
# val Loss: 0.3496 Acc: 0.8487
#
# Epoch 4/4
# ----------
# train Loss: 0.3587 Acc: 0.8470
# val Loss: 0.3572 Acc: 0.8436
#
# Training complete in 14m 3s
# Best val Acc: 0.848726
# [[20718  3671]
#  [  296  1651]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3788 Acc: 0.8343
# val Loss: 0.3736 Acc: 0.8387
#
# Epoch 1/4
# ----------
# train Loss: 0.3699 Acc: 0.8376
# val Loss: 0.3595 Acc: 0.8431
#
# Epoch 2/4
# ----------
# train Loss: 0.3698 Acc: 0.8405
# val Loss: 0.3721 Acc: 0.8476
#
# Epoch 3/4
# ----------
# train Loss: 0.3644 Acc: 0.8423
# val Loss: 0.3799 Acc: 0.8371
#
# Epoch 4/4
# ----------
# train Loss: 0.3656 Acc: 0.8428
# val Loss: 0.3495 Acc: 0.8538
#
# Training complete in 15m 47s
# Best val Acc: 0.853844
# [[20420  3910]
#  [  264  1742]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.3742 Acc: 0.8383
# val Loss: 0.3821 Acc: 0.8359
#
# Epoch 1/4
# ----------
# train Loss: 0.3679 Acc: 0.8400
# val Loss: 9.5637 Acc: 0.5000
#
# Epoch 2/4
# ----------
# train Loss: 0.3685 Acc: 0.8425
# val Loss: 0.4020 Acc: 0.8249
#
# Epoch 3/4
# ----------
# train Loss: 0.3622 Acc: 0.8455
# val Loss: 0.3650 Acc: 0.8420
#
# Epoch 4/4
# ----------
# train Loss: 0.3630 Acc: 0.8441
# val Loss: 0.3636 Acc: 0.8442
#
# Training complete in 18m 6s
# Best val Acc: 0.844172
# [[19634  4696]
#  [  238  1768]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3630 Acc: 0.8458
# val Loss: 0.3767 Acc: 0.8324
#
# Epoch 1/4
# ----------
# train Loss: 0.3565 Acc: 0.8449
# val Loss: 0.3404 Acc: 0.8518
#
# Epoch 2/4
# ----------
# train Loss: 0.3541 Acc: 0.8477
# val Loss: 0.3586 Acc: 0.8448
#
# Epoch 3/4
# ----------
# train Loss: 0.3498 Acc: 0.8510
# val Loss: 0.3645 Acc: 0.8416
#
# Epoch 4/4
# ----------
# train Loss: 0.3498 Acc: 0.8518
# val Loss: 0.3327 Acc: 0.8591
#
# Training complete in 13m 59s
# Best val Acc: 0.859121
# [[20507  3823]
#  [  250  1756]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3670 Acc: 0.8412
# val Loss: 0.3675 Acc: 0.8427
#
# Epoch 1/4
# ----------
# train Loss: 0.3632 Acc: 0.8436
# val Loss: 0.3497 Acc: 0.8489
#
# Epoch 2/4
# ----------
# train Loss: 0.3598 Acc: 0.8435
# val Loss: 0.3666 Acc: 0.8454
#
# Epoch 3/4
# ----------
# train Loss: 0.3545 Acc: 0.8482
# val Loss: 0.3626 Acc: 0.8412
#
# Epoch 4/4
# ----------
# train Loss: 0.3554 Acc: 0.8492
# val Loss: 0.4868 Acc: 0.7742
#
# Training complete in 15m 43s
# Best val Acc: 0.848892
# [[20791  3541]
#  [  314  1690]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.3650 Acc: 0.8429
# val Loss: 0.3714 Acc: 0.8405
#
# Epoch 1/4
# ----------
# train Loss: 0.3621 Acc: 0.8445
# val Loss: 0.3472 Acc: 0.8503
#
# Epoch 2/4
# ----------
# train Loss: 0.3614 Acc: 0.8462
# val Loss: 0.3844 Acc: 0.8341
#
# Epoch 3/4
# ----------
# train Loss: 0.3567 Acc: 0.8461
# val Loss: 0.3695 Acc: 0.8388
#
# Epoch 4/4
# ----------
# train Loss: 0.3611 Acc: 0.8466
# val Loss: 0.6403 Acc: 0.6298
#
# Training complete in 18m 5s
# Best val Acc: 0.850310
# [[20775  3557]
#  [  307  1697]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3939 Acc: 0.8309
# val Loss: 0.3766 Acc: 0.8354
#
# Epoch 1/4
# ----------
# train Loss: 0.4038 Acc: 0.8252
# val Loss: 0.4248 Acc: 0.7983
#
# Epoch 2/4
# ----------
# train Loss: 0.4132 Acc: 0.8244
# val Loss: 0.4244 Acc: 0.8224
#
# Epoch 3/4
# ----------
# train Loss: 0.4417 Acc: 0.8064
# val Loss: 0.3948 Acc: 0.8318
#
# Epoch 4/4
# ----------
# train Loss: 0.4183 Acc: 0.8203
# val Loss: 0.4005 Acc: 0.8343
#
# Training complete in 14m 0s
# Best val Acc: 0.835441
# [[20062  4283]
#  [  305  1686]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4053 Acc: 0.8226
# val Loss: 0.4238 Acc: 0.8196
#
# Epoch 1/4
# ----------
# train Loss: 0.4068 Acc: 0.8248
# val Loss: 0.6032 Acc: 0.7201
#
# Epoch 2/4
# ----------
# train Loss: 0.4746 Acc: 0.7880
# val Loss: 1.1642 Acc: 0.6758
#
# Epoch 3/4
# ----------
# train Loss: 0.4282 Acc: 0.8164
# val Loss: 1.0172 Acc: 0.5820
#
# Epoch 4/4
# ----------
# train Loss: 0.4246 Acc: 0.8162
# val Loss: 0.4567 Acc: 0.7772
#
# Training complete in 15m 45s
# Best val Acc: 0.819580
# [[18605  5740]
#  [  249  1742]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4236 Acc: 0.8165
# val Loss: 0.8894 Acc: 0.5104
#
# Epoch 1/4
# ----------
# train Loss: 0.4203 Acc: 0.8138
# val Loss: 0.4110 Acc: 0.8256
#
# Epoch 2/4
# ----------
# train Loss: 0.4173 Acc: 0.8205
# val Loss: 0.4164 Acc: 0.8108
#
# Epoch 3/4
# ----------
# train Loss: 0.4036 Acc: 0.8261
# val Loss: 0.3844 Acc: 0.8274
#
# Epoch 4/4
# ----------
# train Loss: 0.4206 Acc: 0.8175
# val Loss: 0.4311 Acc: 0.8124
#
# Training complete in 18m 7s
# Best val Acc: 0.827380
# [[18612  5777]
#  [  211  1736]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3582 Acc: 0.8482
# val Loss: 0.3655 Acc: 0.8467
#
# Epoch 1/4
# ----------
# train Loss: 0.3545 Acc: 0.8482
# val Loss: 0.3431 Acc: 0.8541
#
# Epoch 2/4
# ----------
# train Loss: 0.3524 Acc: 0.8500
# val Loss: 0.7181 Acc: 0.7084
#
# Epoch 3/4
# ----------
# train Loss: 0.3486 Acc: 0.8511
# val Loss: 0.3429 Acc: 0.8537
#
# Epoch 4/4
# ----------
# train Loss: 0.3494 Acc: 0.8523
# val Loss: 0.3413 Acc: 0.8568
#
# Training complete in 14m 2s
# Best val Acc: 0.856784
# [[19896  4434]
#  [  209  1797]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3802 Acc: 0.8355
# val Loss: 0.3848 Acc: 0.8341
#
# Epoch 1/4
# ----------
# train Loss: 0.3690 Acc: 0.8406
# val Loss: 0.3714 Acc: 0.8398
#
# Epoch 2/4
# ----------
# train Loss: 0.3674 Acc: 0.8417
# val Loss: 0.3780 Acc: 0.8421
#
# Epoch 3/4
# ----------
# train Loss: 0.3622 Acc: 0.8447
# val Loss: 0.3676 Acc: 0.8393
#
# Epoch 4/4
# ----------
# train Loss: 0.3624 Acc: 0.8448
# val Loss: 0.3456 Acc: 0.8528
#
# Training complete in 15m 46s
# Best val Acc: 0.852755
# [[20367  3963]
#  [  264  1742]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.3726 Acc: 0.8375
# val Loss: 0.4195 Acc: 0.8167
#
# Epoch 1/4
# ----------
# train Loss: 0.3663 Acc: 0.8417
# val Loss: 0.4022 Acc: 0.8219
#
# Epoch 2/4
# ----------
# train Loss: 0.3643 Acc: 0.8421
# val Loss: 0.3629 Acc: 0.8457
#
# Epoch 3/4
# ----------
# train Loss: 0.3557 Acc: 0.8459
# val Loss: 0.3595 Acc: 0.8463
#
# Epoch 4/4
# ----------
# train Loss: 0.3622 Acc: 0.8436
# val Loss: 0.3455 Acc: 0.8511
#
# Training complete in 17m 54s
# Best val Acc: 0.851113
# [[21221  3109]
#  [  341  1665]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3518 Acc: 0.8507
# val Loss: 0.3448 Acc: 0.8522
#
# Epoch 1/4
# ----------
# train Loss: 0.3498 Acc: 0.8518
# val Loss: 0.3372 Acc: 0.8571
#
# Epoch 2/4
# ----------
# train Loss: 0.3475 Acc: 0.8525
# val Loss: 7.2067 Acc: 0.5000
#
# Epoch 3/4
# ----------
# train Loss: 0.3427 Acc: 0.8532
# val Loss: 0.3382 Acc: 0.8543
#
# Epoch 4/4
# ----------
# train Loss: 0.3445 Acc: 0.8522
# val Loss: 0.3285 Acc: 0.8649
#
# Training complete in 14m 3s
# Best val Acc: 0.864915
# [[20607  3723]
#  [  235  1771]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3640 Acc: 0.8426
# val Loss: 0.3562 Acc: 0.8534
#
# Epoch 1/4
# ----------
# train Loss: 0.3619 Acc: 0.8426
# val Loss: 0.3567 Acc: 0.8490
#
# Epoch 2/4
# ----------
# train Loss: 0.3582 Acc: 0.8449
# val Loss: 0.3510 Acc: 0.8469
#
# Epoch 3/4
# ----------
# train Loss: 0.3540 Acc: 0.8451
# val Loss: 0.6226 Acc: 0.7413
#
# Epoch 4/4
# ----------
# train Loss: 0.3526 Acc: 0.8491
# val Loss: 3.5800 Acc: 0.5011
#
# Training complete in 15m 47s
# Best val Acc: 0.853376
# [[20275  4070]
#  [  251  1740]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.3634 Acc: 0.8426
# val Loss: 0.3584 Acc: 0.8445
#
# Epoch 1/4
# ----------
# train Loss: 0.3616 Acc: 0.8427
# val Loss: 0.3763 Acc: 0.8333
#
# Epoch 2/4
# ----------
# train Loss: 0.3607 Acc: 0.8473
# val Loss: 0.3575 Acc: 0.8483
#
# Epoch 3/4
# ----------
# train Loss: 0.3529 Acc: 0.8473
# val Loss: 0.3445 Acc: 0.8517
#
# Epoch 4/4
# ----------
# train Loss: 0.3574 Acc: 0.8462
# val Loss: 0.3495 Acc: 0.8492
#
# Training complete in 17m 56s
# Best val Acc: 0.851693
# [[20537  3852]
#  [  270  1677]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3981 Acc: 0.8304
# val Loss: 0.5930 Acc: 0.7353
#
# Epoch 1/4
# ----------
# train Loss: 0.3947 Acc: 0.8314
# val Loss: 0.3653 Acc: 0.8434
#
# Epoch 2/4
# ----------
# train Loss: 0.3846 Acc: 0.8360
# val Loss: 0.3656 Acc: 0.8444
#
# Epoch 3/4
# ----------
# train Loss: 0.3761 Acc: 0.8392
# val Loss: 0.4829 Acc: 0.8063
#
# Epoch 4/4
# ----------
# train Loss: 0.4001 Acc: 0.8281
# val Loss: 0.4294 Acc: 0.8431
#
# Training complete in 14m 2s
# Best val Acc: 0.844388
# [[19772  4619]
#  [  237  1708]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4107 Acc: 0.8227
# val Loss: 0.4372 Acc: 0.7916
#
# Epoch 1/4
# ----------
# train Loss: 0.4388 Acc: 0.8050
# val Loss: 0.5142 Acc: 0.6866
#
# Epoch 2/4
# ----------
# train Loss: 0.4111 Acc: 0.8206
# val Loss: 0.4495 Acc: 0.8228
#
# Epoch 3/4
# ----------
# train Loss: 0.4156 Acc: 0.8194
# val Loss: 0.4067 Acc: 0.8249
#
# Epoch 4/4
# ----------
# train Loss: 0.3957 Acc: 0.8321
# val Loss: 0.3628 Acc: 0.8406
#
# Training complete in 15m 44s
# Best val Acc: 0.840615
# [[20977  3353]
#  [  363  1643]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4061 Acc: 0.8226
# val Loss: 0.7080 Acc: 0.7993
#
# Epoch 1/4
# ----------
# train Loss: 0.4082 Acc: 0.8235
# val Loss: 0.4666 Acc: 0.7831
#
# Epoch 2/4
# ----------
# train Loss: 0.4007 Acc: 0.8303
# val Loss: 0.3906 Acc: 0.8306
#
# Epoch 3/4
# ----------
# train Loss: 0.3963 Acc: 0.8281
# val Loss: 0.5525 Acc: 0.6755
#
# Epoch 4/4
# ----------
# train Loss: 0.3934 Acc: 0.8312
# val Loss: 0.3770 Acc: 0.8453
#
# Training complete in 18m 0s
# Best val Acc: 0.845346
# [[20528  3802]
#  [  307  1699]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3511 Acc: 0.8492
# val Loss: 0.4029 Acc: 0.8207
#
# Epoch 1/4
# ----------
# train Loss: 0.3449 Acc: 0.8520
# val Loss: 0.5499 Acc: 0.7550
#
# Epoch 2/4
# ----------
# train Loss: 0.3451 Acc: 0.8536
# val Loss: 0.3423 Acc: 0.8527
#
# Epoch 3/4
# ----------
# train Loss: 0.3413 Acc: 0.8556
# val Loss: 0.5366 Acc: 0.7499
#
# Epoch 4/4
# ----------
# train Loss: 0.3410 Acc: 0.8544
# val Loss: 0.3314 Acc: 0.8591
#
# Training complete in 14m 1s
# Best val Acc: 0.859117
# [[19961  4369]
#  [  205  1801]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3612 Acc: 0.8427
# val Loss: 0.3537 Acc: 0.8487
#
# Epoch 1/4
# ----------
# train Loss: 0.3527 Acc: 0.8478
# val Loss: 0.3591 Acc: 0.8444
#
# Epoch 2/4
# ----------
# train Loss: 0.3516 Acc: 0.8484
# val Loss: 0.3532 Acc: 0.8449
#
# Epoch 3/4
# ----------
# train Loss: 0.3470 Acc: 0.8514
# val Loss: 0.3454 Acc: 0.8484
#
# Epoch 4/4
# ----------
# train Loss: 0.3482 Acc: 0.8504
# val Loss: 0.3488 Acc: 0.8488
#
# Training complete in 15m 42s
# Best val Acc: 0.848758
# [[19275  5055]
#  [  190  1816]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.3615 Acc: 0.8474
# val Loss: 0.3580 Acc: 0.8472
#
# Epoch 1/4
# ----------
# train Loss: 0.3558 Acc: 0.8472
# val Loss: 0.3538 Acc: 0.8458
#
# Epoch 2/4
# ----------
# train Loss: 0.3549 Acc: 0.8503
# val Loss: 0.3873 Acc: 0.8310
#
# Epoch 3/4
# ----------
# train Loss: 0.3472 Acc: 0.8523
# val Loss: 0.4088 Acc: 0.8253
#
# Epoch 4/4
# ----------
# train Loss: 0.3473 Acc: 0.8512
# val Loss: 0.3492 Acc: 0.8497
#
# Training complete in 17m 50s
# Best val Acc: 0.849686
# [[19587  4743]
#  [  212  1794]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3495 Acc: 0.8534
# val Loss: 0.3531 Acc: 0.8517
#
# Epoch 1/4
# ----------
# train Loss: 0.3463 Acc: 0.8525
# val Loss: 0.3336 Acc: 0.8598
#
# Epoch 2/4
# ----------
# train Loss: 0.3436 Acc: 0.8553
# val Loss: 0.3391 Acc: 0.8544
#
# Epoch 3/4
# ----------
# train Loss: 0.3401 Acc: 0.8576
# val Loss: 0.3340 Acc: 0.8534
#
# Epoch 4/4
# ----------
# train Loss: 0.3429 Acc: 0.8567
# val Loss: 0.3272 Acc: 0.8608
#
# Training complete in 14m 3s
# Best val Acc: 0.860763
# [[21351  2979]
#  [  313  1693]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3529 Acc: 0.8486
# val Loss: 0.4511 Acc: 0.7967
#
# Epoch 1/4
# ----------
# train Loss: 0.3528 Acc: 0.8491
# val Loss: 0.3495 Acc: 0.8482
#
# Epoch 2/4
# ----------
# train Loss: 0.3511 Acc: 0.8509
# val Loss: 0.3607 Acc: 0.8529
#
# Epoch 3/4
# ----------
# train Loss: 0.3465 Acc: 0.8521
# val Loss: 0.4061 Acc: 0.8134
#
# Epoch 4/4
# ----------
# train Loss: 0.3488 Acc: 0.8515
# val Loss: 0.4607 Acc: 0.7800
#
# Training complete in 15m 43s
# Best val Acc: 0.852892
# [[20701  3690]
#  [  278  1667]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.3545 Acc: 0.8484
# val Loss: 0.4511 Acc: 0.7911
#
# Epoch 1/4
# ----------
# train Loss: 0.3530 Acc: 0.8485
# val Loss: 0.3368 Acc: 0.8551
#
# Epoch 2/4
# ----------
# train Loss: 0.3516 Acc: 0.8508
# val Loss: 0.3433 Acc: 0.8570
#
# Epoch 3/4
# ----------
# train Loss: 0.3436 Acc: 0.8539
# val Loss: 0.3615 Acc: 0.8365
#
# Epoch 4/4
# ----------
# train Loss: 0.3503 Acc: 0.8517
# val Loss: 0.3372 Acc: 0.8603
#
# Training complete in 17m 57s
# Best val Acc: 0.860322
# [[21281  3049]
#  [  309  1697]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4600 Acc: 0.8035
# val Loss: 0.7324 Acc: 0.8172
#
# Epoch 1/4
# ----------
# train Loss: 0.4729 Acc: 0.7949
# val Loss: 0.4570 Acc: 0.8264
#
# Epoch 2/4
# ----------
# train Loss: 0.5104 Acc: 0.7820
# val Loss: 1.1209 Acc: 0.6018
#
# Epoch 3/4
# ----------
# train Loss: 0.4642 Acc: 0.8028
# val Loss: 0.4100 Acc: 0.8216
#
# Epoch 4/4
# ----------
# train Loss: 0.4797 Acc: 0.7918
# val Loss: 0.4091 Acc: 0.8191
#
# Training complete in 14m 1s
# Best val Acc: 0.826371
# [[21152  3180]
#  [  434  1570]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4401 Acc: 0.8041
# val Loss: 0.5200 Acc: 0.7412
#
# Epoch 1/4
# ----------
# train Loss: 23034.5767 Acc: 0.6073
# val Loss: 231061676.0146 Acc: 0.5116
#
# Epoch 2/4
# ----------
# train Loss: 1264240538.1129 Acc: 0.5065
# val Loss: 678143710.5116 Acc: 0.5183
#
# Epoch 3/4
# ----------
# train Loss: 5252213432.3832 Acc: 0.5008
# val Loss: 3665671967.5723 Acc: 0.5142
#
# Epoch 4/4
# ----------
# train Loss: 78872878127.2913 Acc: 0.5002
# val Loss: 2.4753 Acc: 0.5117
#
# Training complete in 15m 42s
# Best val Acc: 0.741240
# [[17175  7170]
#  [  444  1547]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4326 Acc: 0.8141
# val Loss: 0.9293 Acc: 0.5418
#
# Epoch 1/4
# ----------
# train Loss: 0.4767 Acc: 0.7861
# val Loss: 0.7487 Acc: 0.5187
#
# Epoch 2/4
# ----------
# train Loss: 0.5114 Acc: 0.7698
# val Loss: 0.5137 Acc: 0.7625
#
# Epoch 3/4
# ----------
# train Loss: 0.5377 Acc: 0.7559
# val Loss: 0.5217 Acc: 0.7791
#
# Epoch 4/4
# ----------
# train Loss: 0.5139 Acc: 0.7701
# val Loss: 0.5397 Acc: 0.7804
#
# Training complete in 17m 51s
# Best val Acc: 0.780368
# [[21405  2925]
#  [  640  1366]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3907 Acc: 0.8299
# val Loss: 0.3802 Acc: 0.8344
#
# Epoch 1/4
# ----------
# train Loss: 0.3747 Acc: 0.8371
# val Loss: 0.3860 Acc: 0.8265
#
# Epoch 2/4
# ----------
# train Loss: 0.3748 Acc: 0.8393
# val Loss: 0.3791 Acc: 0.8323
#
# Epoch 3/4
# ----------
# train Loss: 0.3661 Acc: 0.8412
# val Loss: 0.3611 Acc: 0.8439
#
# Epoch 4/4
# ----------
# train Loss: 0.3670 Acc: 0.8409
# val Loss: 0.3507 Acc: 0.8488
#
# Training complete in 14m 1s
# Best val Acc: 0.848841
# [[20880  3450]
#  [  322  1684]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3846 Acc: 0.8319
# val Loss: 0.3780 Acc: 0.8364
#
# Epoch 1/4
# ----------
# train Loss: 0.3779 Acc: 0.8347
# val Loss: 0.3620 Acc: 0.8414
#
# Epoch 2/4
# ----------
# train Loss: 0.3796 Acc: 0.8361
# val Loss: 0.3685 Acc: 0.8398
#
# Epoch 3/4
# ----------
# train Loss: 0.3676 Acc: 0.8414
# val Loss: 0.3608 Acc: 0.8429
#
# Epoch 4/4
# ----------
# train Loss: 0.3679 Acc: 0.8401
# val Loss: 0.3532 Acc: 0.8470
#
# Training complete in 15m 46s
# Best val Acc: 0.847014
# [[21252  3078]
#  [  360  1646]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4291 Acc: 0.8020
# val Loss: 0.4353 Acc: 0.8099
#
# Epoch 1/4
# ----------
# train Loss: 0.4292 Acc: 0.8061
# val Loss: 0.4165 Acc: 0.8157
#
# Epoch 2/4
# ----------
# train Loss: 0.4232 Acc: 0.8098
# val Loss: 0.4187 Acc: 0.8128
#
# Epoch 3/4
# ----------
# train Loss: 0.4197 Acc: 0.8110
# val Loss: 0.4172 Acc: 0.8162
#
# Epoch 4/4
# ----------
# train Loss: 0.4206 Acc: 0.8122
# val Loss: 0.4198 Acc: 0.8165
#
# Training complete in 17m 49s
# Best val Acc: 0.816520
# [[21733  2597]
#  [  522  1484]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3714 Acc: 0.8406
# val Loss: 0.3646 Acc: 0.8472
#
# Epoch 1/4
# ----------
# train Loss: 0.3644 Acc: 0.8437
# val Loss: 0.9750 Acc: 0.5935
#
# Epoch 2/4
# ----------
# train Loss: 0.3643 Acc: 0.8457
# val Loss: 0.3644 Acc: 0.8463
#
# Epoch 3/4
# ----------
# train Loss: 0.3534 Acc: 0.8504
# val Loss: 0.3408 Acc: 0.8576
#
# Epoch 4/4
# ----------
# train Loss: 0.3539 Acc: 0.8490
# val Loss: 0.3585 Acc: 0.8410
#
# Training complete in 14m 3s
# Best val Acc: 0.857560
# [[20961  3428]
#  [  281  1666]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3697 Acc: 0.8391
# val Loss: 0.3638 Acc: 0.8410
#
# Epoch 1/4
# ----------
# train Loss: 0.3667 Acc: 0.8419
# val Loss: 0.8677 Acc: 0.6115
#
# Epoch 2/4
# ----------
# train Loss: 0.3653 Acc: 0.8422
# val Loss: 0.4186 Acc: 0.8094
#
# Epoch 3/4
# ----------
# train Loss: 0.3568 Acc: 0.8458
# val Loss: 0.4548 Acc: 0.8056
#
# Epoch 4/4
# ----------
# train Loss: 0.3565 Acc: 0.8474
# val Loss: 0.3668 Acc: 0.8340
#
# Training complete in 15m 44s
# Best val Acc: 0.840952
# [[20795  3550]
#  [  343  1648]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4241 Acc: 0.8128
# val Loss: 0.4226 Acc: 0.8103
#
# Epoch 1/4
# ----------
# train Loss: 0.4170 Acc: 0.8123
# val Loss: 0.4002 Acc: 0.8205
#
# Epoch 2/4
# ----------
# train Loss: 0.4160 Acc: 0.8157
# val Loss: 0.3987 Acc: 0.8262
#
# Epoch 3/4
# ----------
# train Loss: 0.4113 Acc: 0.8183
# val Loss: 1.2021 Acc: 0.5035
#
# Epoch 4/4
# ----------
# train Loss: 0.4085 Acc: 0.8197
# val Loss: 0.4016 Acc: 0.8251
#
# Training complete in 17m 54s
# Best val Acc: 0.826194
# [[20289  4102]
#  [  349  1596]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4497 Acc: 0.8038
# val Loss: 0.4357 Acc: 0.8194
#
# Epoch 1/4
# ----------
# train Loss: 0.6549 Acc: 0.6767
# val Loss: 0.9603 Acc: 0.6713
#
# Epoch 2/4
# ----------
# train Loss: 0.6846 Acc: 0.6056
# val Loss: 0.6316 Acc: 0.6203
#
# Epoch 3/4
# ----------
# train Loss: 2.2601 Acc: 0.5845
# val Loss: 10.9637 Acc: 0.4725
#
# Epoch 4/4
# ----------
# train Loss: 17.0106 Acc: 0.5033
# val Loss: 0.6850 Acc: 0.5000
#
# Training complete in 13m 59s
# Best val Acc: 0.819439
# [[21814  2531]
#  [  512  1479]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4837 Acc: 0.7863
# val Loss: 0.7067 Acc: 0.7313
#
# Epoch 1/4
# ----------
# train Loss: 8.5963 Acc: 0.5802
# val Loss: 1.7744 Acc: 0.4999
#
# Epoch 2/4
# ----------
# train Loss: 0.8677 Acc: 0.5089
# val Loss: 0.9460 Acc: 0.5008
#
# Epoch 3/4
# ----------
# train Loss: 0.7754 Acc: 0.5009
# val Loss: 0.8896 Acc: 0.5002
#
# Epoch 4/4
# ----------
# train Loss: 0.7959 Acc: 0.4980
# val Loss: 1.1684 Acc: 0.5001
#
# Training complete in 15m 46s
# Best val Acc: 0.731263
# [[22644  1701]
#  [  931  1060]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4847 Acc: 0.7844
# val Loss: 0.4369 Acc: 0.8127
#
# Epoch 1/4
# ----------
# train Loss: 0.4615 Acc: 0.7980
# val Loss: 0.4683 Acc: 0.8056
#
# Epoch 2/4
# ----------
# train Loss: 0.5779 Acc: 0.7628
# val Loss: 0.7113 Acc: 0.6087
#
# Epoch 3/4
# ----------
# train Loss: 0.5321 Acc: 0.7601
# val Loss: 0.5764 Acc: 0.7635
#
# Epoch 4/4
# ----------
# train Loss: 0.5122 Acc: 0.7689
# val Loss: 0.5101 Acc: 0.7404
#
# Training complete in 17m 58s
# Best val Acc: 0.812712
# [[21193  3152]
#  [  488  1503]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3959 Acc: 0.8211
# val Loss: 0.6004 Acc: 0.7007
#
# Epoch 1/4
# ----------
# train Loss: 0.3790 Acc: 0.8323
# val Loss: 0.3680 Acc: 0.8401
#
# Epoch 2/4
# ----------
# train Loss: 0.3732 Acc: 0.8438
# val Loss: 0.3689 Acc: 0.8396
#
# Epoch 3/4
# ----------
# train Loss: 0.3656 Acc: 0.8446
# val Loss: 0.3624 Acc: 0.8474
#
# Epoch 4/4
# ----------
# train Loss: 0.3649 Acc: 0.8460
# val Loss: 0.3522 Acc: 0.8499
#
# Training complete in 14m 6s
# Best val Acc: 0.849892
# [[20446  3884]
#  [  282  1724]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4130 Acc: 0.8198
# val Loss: 0.3961 Acc: 0.8250
#
# Epoch 1/4
# ----------
# train Loss: 0.3930 Acc: 0.8256
# val Loss: 0.3812 Acc: 0.8296
#
# Epoch 2/4
# ----------
# train Loss: 0.3808 Acc: 0.8341
# val Loss: 0.3777 Acc: 0.8329
#
# Epoch 3/4
# ----------
# train Loss: 0.3724 Acc: 0.8402
# val Loss: 0.4363 Acc: 0.8049
#
# Epoch 4/4
# ----------
# train Loss: 0.3743 Acc: 0.8369
# val Loss: 0.3712 Acc: 0.8415
#
# Training complete in 15m 50s
# Best val Acc: 0.841533
# [[20015  4315]
#  [  280  1726]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4171 Acc: 0.8162
# val Loss: 0.4155 Acc: 0.8208
#
# Epoch 1/4
# ----------
# train Loss: 0.4094 Acc: 0.8171
# val Loss: 0.4932 Acc: 0.7644
#
# Epoch 2/4
# ----------
# train Loss: 0.4065 Acc: 0.8221
# val Loss: 0.4426 Acc: 0.7965
#
# Epoch 3/4
# ----------
# train Loss: 0.4002 Acc: 0.8262
# val Loss: 0.3969 Acc: 0.8233
#
# Epoch 4/4
# ----------
# train Loss: 0.4046 Acc: 0.8203
# val Loss: 0.4892 Acc: 0.8053
#
# Training complete in 17m 57s
# Best val Acc: 0.823340
# [[20319  4070]
#  [  363  1584]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3655 Acc: 0.8461
# val Loss: 0.3911 Acc: 0.8287
#
# Epoch 1/4
# ----------
# train Loss: 0.3605 Acc: 0.8474
# val Loss: 0.3434 Acc: 0.8494
#
# Epoch 2/4
# ----------
# train Loss: 0.3567 Acc: 0.8494
# val Loss: 0.3488 Acc: 0.8514
#
# Epoch 3/4
# ----------
# train Loss: 0.3512 Acc: 0.8508
# val Loss: 0.3541 Acc: 0.8481
#
# Epoch 4/4
# ----------
# train Loss: 0.3500 Acc: 0.8519
# val Loss: 0.3620 Acc: 0.8460
#
# Training complete in 13m 59s
# Best val Acc: 0.851444
# [[20668  3723]
#  [  281  1664]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3766 Acc: 0.8382
# val Loss: 0.4346 Acc: 0.8065
#
# Epoch 1/4
# ----------
# train Loss: 0.3711 Acc: 0.8390
# val Loss: 0.4229 Acc: 0.7987
#
# Epoch 2/4
# ----------
# train Loss: 0.3685 Acc: 0.8428
# val Loss: 0.3740 Acc: 0.8423
#
# Epoch 3/4
# ----------
# train Loss: 0.3593 Acc: 0.8453
# val Loss: 0.3864 Acc: 0.8315
#
# Epoch 4/4
# ----------
# train Loss: 0.3586 Acc: 0.8470
# val Loss: 0.3396 Acc: 0.8540
#
# Training complete in 15m 44s
# Best val Acc: 0.854048
# [[20248  4082]
#  [  249  1757]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4090 Acc: 0.8219
# val Loss: 0.4009 Acc: 0.8270
#
# Epoch 1/4
# ----------
# train Loss: 0.4045 Acc: 0.8234
# val Loss: 0.3903 Acc: 0.8295
#
# Epoch 2/4
# ----------
# train Loss: 0.4032 Acc: 0.8242
# val Loss: 0.3928 Acc: 0.8313
#
# Epoch 3/4
# ----------
# train Loss: 0.3950 Acc: 0.8281
# val Loss: 0.3902 Acc: 0.8282
#
# Epoch 4/4
# ----------
# train Loss: 0.4022 Acc: 0.8231
# val Loss: 0.3791 Acc: 0.8373
#
# Training complete in 18m 1s
# Best val Acc: 0.837304
# [[20355  3975]
#  [  325  1681]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4926 Acc: 0.7952
# val Loss: 0.6513 Acc: 0.6818
#
# Epoch 1/4
# ----------
# train Loss: 0.6875 Acc: 0.6422
# val Loss: 1.7664 Acc: 0.5906
#
# Epoch 2/4
# ----------
# train Loss: 0.6552 Acc: 0.6826
# val Loss: 0.7882 Acc: 0.5000
#
# Epoch 3/4
# ----------
# train Loss: 0.6215 Acc: 0.7212
# val Loss: 0.5544 Acc: 0.7684
#
# Epoch 4/4
# ----------
# train Loss: 0.5403 Acc: 0.7662
# val Loss: 0.4800 Acc: 0.7856
#
# Training complete in 14m 4s
# Best val Acc: 0.785596
# [[16905  7425]
#  [  248  1758]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.6304 Acc: 0.7124
# val Loss: 3.0633 Acc: 0.6584
#
# Epoch 1/4
# ----------
# train Loss: 14.6631 Acc: 0.4994
# val Loss: 1815.3484 Acc: 0.5000
#
# Epoch 2/4
# ----------
# train Loss: 4853969.7934 Acc: 0.5063
# val Loss: 1542927.2025 Acc: 0.5012
#
# Epoch 3/4
# ----------
# train Loss: 1781062.7585 Acc: 0.4985
# val Loss: 5777458347096.3398 Acc: 0.5000
#
# Epoch 4/4
# ----------
# train Loss: 65462599760.1555 Acc: 0.5009
# val Loss: 2104158372696.0291 Acc: 0.5000
#
# Training complete in 15m 54s
# Best val Acc: 0.658448
# [[21483  2862]
#  [ 1126   865]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.5025 Acc: 0.7794
# val Loss: 0.5876 Acc: 0.7927
#
# Epoch 1/4
# ----------
# train Loss: 0.5029 Acc: 0.7751
# val Loss: 0.4277 Acc: 0.8133
#
# Epoch 2/4
# ----------
# train Loss: 0.4702 Acc: 0.7998
# val Loss: 0.4422 Acc: 0.8235
#
# Epoch 3/4
# ----------
# train Loss: 0.4424 Acc: 0.8133
# val Loss: 0.4452 Acc: 0.8201
#
# Epoch 4/4
# ----------
# train Loss: 0.4700 Acc: 0.7963
# val Loss: 0.5188 Acc: 0.7956
#
# Training complete in 18m 5s
# Best val Acc: 0.823518
# [[20798  3593]
#  [  400  1545]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model50'}
# Best hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model18'}
# Best score: 0.86491525

# %%
#cf_matrix = confusion_matrix_calc(data_loader_test, labels, model_ft)

# %%
# !kill 1405

# %%
# %tensorboard --logdir Experiments/TENSORBOARD
# Out:
#       <iframe id="tensorboard-frame-a89220c14dc6b1f0" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-a89220c14dc6b1f0");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
print(best_params)
best_score
# Out:
# {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model18'}
# array(0.86491525, dtype=float32)
