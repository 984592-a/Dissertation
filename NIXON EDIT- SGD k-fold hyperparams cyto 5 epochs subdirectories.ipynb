# %% [markdown]
# ### To note: Running this on different systems (i.e. local, SCW, server) will result in slight changes needing to the code

# %%
# Load libraries
import os
import numpy as np
import torch
import sys
import torchvision
import torchvision.transforms as T
import torchvision.models as models
from PIL import Image
from PIL import ImageEnhance
import matplotlib.pyplot as plt
import imagesize
import subprocess
sys.path
from IPython.core.debugger import set_trace
import scipy.ndimage
import matplotlib.patches as patches
# plt.rcParams['figure.figsize'] = [12,12]
# sys.path.append('/workspace/myFile/Mask_RCNN_Tutorial/')
from tqdm import tqdm
from torch import nn as nn
from torch import optim as optim
from torch.optim import lr_scheduler
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
import re
import time
import copy
import pylab
from torch.utils.tensorboard import SummaryWriter
from tempfile import TemporaryDirectory
import torch.backends.cudnn as cudnn
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import seaborn as sn
import pandas as pd
import glob
# Rather than have a messy notebook with a load of functions we can store them in separate .py files and import them

cudnn.benchmark = True
plt.ion()   # interactive mode
# Out:
# /opt/conda/lib/python3.8/site-packages/scipy/__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
# %load_ext tensorboard
writer = SummaryWriter("Experiments/09085epoch")    # This determines the tensorboard file name

# %%
class DNADataset(object):
    def __init__(self, root, transforms, labels, imDx = False):
        self.root, self.transforms, self.labels = root, transforms, labels
    
        # load all image files, sorting them to ensure they are aligned
        self.imgDir = glob.glob(root+"*/*.tiff")
        DamagedCyto= [x for x in self.imgDir if "damage_membrane_" in x]
        UndamagedCyto= [x for x in self.imgDir if "ok_membrane_" in x]
        self.imgDir= DamagedCyto+UndamagedCyto
        size350=[]
        for x in self.imgDir:
            img = Image.open(x) # Open image
            w,h=img.size
            if w<=350 and h<=350:
                size350.append(x)
        self.imgDir=size350              
        
        self.imgs = sorted(self.imgDir) # list of images

        

        
    def __getitem__(self, idx):
        img_path = self.imgs[idx]
       
        # Transform images into tensors
        img = Image.open(img_path) # Open image
        w,h=img.size
        img = np.array(img) # Convert image into an array
        img = np.float32(np.divide(img, 2**16)) # Ensure all values are floats
        
        result=np.zeros((80,80), dtype=np.float32)
        x_center = (80 - w) // 2
        y_center = (80 - h) // 2 # copy img image into center of result image
        result[y_center:y_center+h, x_center:x_center+w] = img
        img = result
        
        targetlab=""
        if img_path.find('ok_membrane_') != -1:
            targetlab= 'Undamaged'
        if img_path.find('damage_membrane_') != -1:
            targetlab= 'Damaged'
        target = self.labels.index(targetlab) # Get the label and assign to a value
        
        # Convert label to tensor
        #torch.to
        
        if self.transforms is not None:
            img = self.transforms(img)
#             #print('In the transforms')
        imNo = idx
        return img, target, imNo
        
    def __len__(self):
        return len(self.imgs)

# %%
root="/workspace/myFile/Output/17052023/"
p= glob.glob(root+"*/*.tiff")
Damagednuclei= [x for x in p if 'Damaged_nuclei_' in x]
Undamagednuclei= [x for x in p if "No_damage_nuclei" in x]
#np.random.shuffle(Undamagednuclei)
#Undamagednuclei=Undamagednuclei[:10000]
#Undamagednuclei

# %%
imDr = "/workspace/myFile/Output/17052023/"  # Image patches directory

labels = ['Damaged', 'Undamaged']  # Your labels

# %%
# For data augmentation
def get_transform(train):
    transforms = []

    transforms.append(T.ToTensor())
    #transforms.append(T.Normalize([0.0019368887995516483], [0.00672996630111016]))
    #transforms.append(T.RandomHorizontalFlip(0.5))
    
    if train:
        transforms.append(T.RandomHorizontalFlip(p=0.5))
        transforms.append(T.RandomVerticalFlip(p=0.5))
    
    return T.Compose(transforms)

# %%
def train_model(model, criterion, optimizer, scheduler, train, test, num_epochs=25):
    since = time.time()
    # Create a temporary directory to save training checkpoints
    with TemporaryDirectory() as tempdir:
        best_model_params_path = os.path.join(tempdir, 'best_model_params.pt')

        torch.save(model.state_dict(), best_model_params_path)
        best_acc = 0.0
        
        for epoch in range(num_epochs):
            print(f'Epoch {epoch}/{num_epochs - 1}')
            print('-' * 10)
            dataset_train = torch.utils.data.Subset(dataSetTrain, train[epoch])
            dataset_test = torch.utils.data.Subset(dataSetTest, test[epoch])
            data_loader_train = torch.utils.data.DataLoader(
                dataset_train, batch_size=128, shuffle=True, num_workers=0)

            data_loader_test = torch.utils.data.DataLoader(
                dataset_test, batch_size=128, shuffle=False, num_workers=0)
            # Each epoch has a training and validation phase
            for phase in ['train', 'val']:
                if phase == 'train':
                    model.train()  # Set model to training mode
                    dataloaders = data_loader_train
                else:
                    model.eval()   # Set model to evaluate mode
                    dataloaders = data_loader_test

                running_loss = 0.0
                running_corrects = 0
                damaged_len=0
                damaged_corrects = 0
                undamaged_len=0
                undamaged_corrects = 0

                # Iterate over data.
                for inputs, labels, imNo in dataloaders:
                    inputs = inputs.to(device)
                    labels = labels.to(device)

                    # zero the parameter gradients
                    optimizer.zero_grad()

                    # forward
                    # track history if only in train
                    with torch.set_grad_enabled(phase == 'train'):
                        outputs = model(inputs)
                        _, preds = torch.max(outputs, 1)
                        loss = criterion(outputs, labels)
                        # backward + optimize only if in training phase
                        if phase == 'train':
                            loss.backward()
                            optimizer.step()

                    # statistics
                    running_loss += loss.item() * inputs.size(0)    # Loss
                    nada=torch.tensor(np.zeros(len(labels))).to(device)
                    uno=nada+1
                    falseneg=preds+1
                    falsepos=preds-1
                    FPplusTN=torch.sum(labels==nada)
                    TPplusFN=torch.sum(labels==uno)
                    FN=torch.sum(labels==falseneg)
                    FP=torch.sum(labels==falsepos)
                    TN=FPplusTN-FP
                    TP=TPplusFN-FN
                    running_corrects += torch.sum(preds == labels.data) # Accuracy
                    damaged_len+=TPplusFN
                    damaged_corrects += TP
                    undamaged_len+=FPplusTN
                    undamaged_corrects += TN
                damaged_acc = damaged_corrects / damaged_len
                undamaged_acc = undamaged_corrects/undamaged_len
                epoch_acc= (damaged_acc+undamaged_acc)/2
                
                if phase == 'train':
                    scheduler.step()

                epoch_loss = running_loss / dataset_sizes[phase]    # Loss metric per epoch
                #epoch_acc = running_corrects.double() / dataset_sizes[phase]    # Accuracy metric per epoch

                if phase == "train":    # This is the tensorboard code that writes accuracy and loss metrics
                    writer.add_scalar("Train/Accuracy", epoch_acc, epoch)
                    writer.add_scalar("Train/Loss", epoch_loss, epoch)
                else:
                    writer.add_scalar("Validation/Accuracy", epoch_acc, epoch)
                    writer.add_scalar("Validation/Loss", epoch_loss, epoch)

                print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

                # deep copy the model
                if phase == 'val' and epoch_acc >= best_acc: 
                    # This compares validation accuracy to previous bests and adjusts model weights accordingly
                    best_acc = epoch_acc
                    torch.save(model.state_dict(), best_model_params_path)
                    con_mat= torch.tensor([[damaged_corrects, damaged_len-damaged_corrects],[undamaged_len-undamaged_corrects,undamaged_corrects]])

            print()

        time_elapsed = time.time() - since  # Nice way to measure training time but info also stored (indirectly) by tensorboard
        print(
            f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
        print(f'Best val Acc: {best_acc:4f}')
        #labels= labels.cpu().numpy()
        #preds=preds.cpu().numpy()
        model.load_state_dict(torch.load(best_model_params_path))
    writer.close()
    return model, con_mat, best_acc   # We want to return the model because its the model, also confusion matrix for later analysis

# %%
# This is your RESNET
# Initialize CNN with kaiming
def init_cnn(m):
    # Set the weights of the RESNET
    if getattr(m, 'bias', None) is not None: nn.init.constant_(m.bias, 0)
    if isinstance(m, (nn.Conv2d,nn.Linear)): nn.init.kaiming_normal_(m.weight)
    for l in m.children(): init_cnn(l)


# noop function for returning nothing
def noop(x): return x
# activation function(RELU)
act_fn = nn.ReLU(inplace=True)

# Flatten
class Flatten(nn.Module):
    def forward(self, x): return x.view(x.size(0), -1)

# Make a convolution
def conv(ni, nf, ks=3, stride=1, bias=False):
    return nn.Conv2d(ni, nf, kernel_size=ks, stride=stride, padding=ks//2, bias=bias)

# Create a convuolutional layer with convolution and batch norm
def conv_layer(ni, nf, ks=3, stride=1, zero_bn=False, act=True):
    bn = nn.BatchNorm2d(nf) # get a 2d batch norm from Pytorhc
    nn.init.constant_(bn.weight, 0. if zero_bn else 1.)
    layers = [conv(ni, nf, ks, stride=stride), bn]
    if act: layers.append(act_fn) # add in the activation function if act is true
    return nn.Sequential(*layers)


# Resblock
class ResBlock(nn.Module):
    def __init__(self, expansion, ni, nh, stride = 1):
        super().__init__()
        # ni - number of inputs channels, nf - number of filters
        # nh - number of filters in first conv
        # expansion is 1 for resnet 18, 34 and 4 for larger networks
        nf, ni = nh*expansion, ni*expansion
        layers = [conv_layer(ni, nh, 3, stride = stride), # for resnet < 34 2 convs per resblock
                 conv_layer(nh, nf, 3, zero_bn = True, act = False)
                 ] if expansion == 1 else [ # for RESNET > 34 then 3 convs per block with bottleneck
                            conv_layer(ni, nh, 1),
                            conv_layer(nh, nh, 3, stride = stride),
                            conv_layer(nh, nf, 1, zero_bn = True, act = False)
        ]
        self.convs = nn.Sequential(*layers) # Creates the conv layers
        self.idconv = noop if ni==nf else conv_layer(ni, nf, 1, act = False) # id convolution ()
        self.pool = noop if stride== 1 else nn.AvgPool2d(2, ceil_mode = True) # average pool on 
        
    def forward(self, x): 
        # Forward function adds the convolution part to the id part 
        #return act_fn(self.convs(x)) + self.idconv(self.pool(x))
        return act_fn(self.convs(x) + self.idconv(self.pool(x)))

# XResnet
class XResNet(nn.Sequential):
    @classmethod
    def create(cls, expansion, layers, c_in=3, c_out=1000):
        nfs = [c_in, (c_in + 1)*8, 64, 64] # number of filters in stem layer (c_in is number of image channels)
        stem = [conv_layer(nfs[i], nfs[i+1], stride=2 if i==0 else 1)
            for i in range(3)]

        nfs = [64//expansion,64,128,256,512]
        res_layers = [cls._make_layer(expansion, nfs[i], nfs[i+1],
                                      n_blocks=l, stride=1 if i==0 else 2)
                  for i,l in enumerate(layers)]
        res = cls(
        *stem,
        nn.MaxPool2d(kernel_size=3, stride = 2, padding = 1), # then a max pooling layer
        *res_layers,
        nn.AdaptiveAvgPool2d(1), Flatten(), 
        nn.Linear(nfs[-1]*expansion, c_out)
        )
        init_cnn(res)
        return res
        
    @staticmethod
    def _make_layer(expansion, ni, nf, n_blocks, stride): # returns a resblock
        return nn.Sequential(
        *[ResBlock(expansion, ni if i==0 else nf, nf, stride if i==0 else 1)
         for i in range(n_blocks)])

# %%
def xresnet18 (**kwargs): return XResNet.create(1, [2, 2,  2, 2], **kwargs)
def xresnet34 (**kwargs): return XResNet.create(1, [3, 4,  6, 3], **kwargs)
def xresnet50 (**kwargs): return XResNet.create(4, [3, 4,  6, 3], **kwargs)
model18 = xresnet18(c_in = 1, c_out = 2)
model34 = xresnet34(c_in = 1, c_out = 2)
model50 = xresnet50(c_in = 1, c_out = 2)

# Label smoothing cross entropy
import torch.nn.functional as F


def reduce_loss(loss, reduction='mean'):
    return loss.mean() if reduction=='mean' else loss.sum() if reduction=='sum' else loss

class LabelSmoothingCrossEntropy(nn.Module):
    def __init__(self, ε:float=0.1, reduction='mean'):
        super().__init__()
        self.ε,self.reduction = ε,reduction
    
    def forward(self, output, target):
        c = output.size()[-1]
        log_preds = F.log_softmax(output, dim=-1)
        loss = reduce_loss(-log_preds.sum(dim=-1), self.reduction)
        nll = F.nll_loss(log_preds, target, reduction=self.reduction)
        return lin_comb(loss/c, nll, self.ε)

# %%
# Helper functions that shows the image, true class, predicted class and degree of prediction

def images_to_probs(net, images):
    '''
    Generates predictions and corresponding probabilities from a trained
    network and a list of images
    '''
    output = net(images)
    # convert output probabilities to predicted class
    _, preds_tensor = torch.max(output, 1)
    preds = np.squeeze(preds_tensor.numpy())
    return preds, [F.softmax(el, dim=0)[i].item() for i, el in zip(preds, output)]


def plot_classes_preds(net, images, labels):
    '''
    Generates matplotlib Figure using a trained network, along with images
    and labels from a batch, that shows the network's top prediction along
    with its probability, alongside the actual label, coloring this
    information based on whether the prediction was correct or not.
    Uses the "images_to_probs" function.
    '''
    preds, probs = images_to_probs(net, images)
    # plot the images in the batch, along with predicted and true labels
    fig = plt.figure(figsize=(12, 48))
    for idx in np.arange(4):
        ax = fig.add_subplot(1, 4, idx+1, xticks=[], yticks=[])
        matplotlib_imshow(images[idx], one_channel=True)
        ax.set_title("{0}, {1:.1f}%\n(label: {2})".format(
            labels[preds[idx]],
            probs[idx] * 100.0,
            labels[labels[idx]]),
                    color=("green" if preds[idx]==labels[idx].item() else "red"))
    return fig

def matplotlib_imshow(img, one_channel=True):
    if one_channel:
        img = img.mean(dim=0)
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    if one_channel:
        plt.imshow(npimg, cmap="Greys")
    else:
        plt.imshow(np.transpose(npimg, (1, 2, 0)))

# %%
def confusion_matrix_calc(data_loader_test, classes, model_ft):       
        y_pred = []
        y_true = []
        for inputs, labels, imNo in data_loader_test:
                inputs = inputs.to(device)
                labels = labels.to(device)
                output = model_ft(inputs) # Feed Network

                output = (torch.max(torch.exp(output), 1)[1]).data.cpu().numpy()
                y_pred.extend(output) # Save Prediction
                
                labels = labels.data.cpu().numpy()
                y_true.extend(labels) # Save Truth

        # constant for classes
        # classes = ('Alive', 'Dead')

        # Build confusion matrix
        cf_matrix = confusion_matrix(y_true, y_pred)
        return cf_matrix

# %%
k=5 #NUMBER OF K FOLDS
epoch=range(30) #NUMBER OF EPOCHS

torch.manual_seed(10)
imIdx = torch.randperm(1).tolist()

## Create dataset
dataSetTrain = DNADataset(imDr, get_transform(train = True), labels, imDx=imIdx)
dataSetTest = DNADataset(imDr, get_transform(train = False), labels, imDx=imIdx)

data_loader_train=[]
data_loader_test=[]

# ## Create dataloaders
# Get subset
torch.manual_seed(10)
TotalSetTrain=list(range(len(dataSetTrain)))
np.random.shuffle(TotalSetTrain)
TotalSetTest=list(range(len(dataSetTest)))
np.random.shuffle(TotalSetTest)

train=[]
test=[]
for epoch in epoch:
    
    Kfifth = len(dataSetTrain)//k
    split= epoch%k
    train.append(TotalSetTrain[(split+1)*Kfifth:]+TotalSetTrain[:Kfifth*split])
    test.append(TotalSetTest[split*Kfifth:(split+1)*Kfifth])

#dataset_train = torch.utils.data.Subset(dataSetTrain, indices[-noTrain:])

#dataset_test = torch.utils.data.Subset(dataSetTest, indices[:-noTrain])
#len(indices), len(indices[:-50]), len(indices[-50:]), 50/191, type(dataset_test)

dataset_sizes = {'train': len(train[0]), 'val': len(test[0])}

#dataset_train = torch.utils.data.Subset(dataSetTrain, train)
#data_loader_train.append(dataset_train)
#dataset_testo = torch.utils.data.Subset(dataSetTest, test)
#data_loader_test.append(dataset_testo)
# define training and validation data loaders


# Collate function (gathers together the outputs)
# def collate_fn(batch):
#     return tuple(zip(*batch))

#len(indices[-noTrain:]), dataset_sizes
#dataset_test[0][1], dataset_test[3][1], dataset_test[-1][1], dataSetTrain.imgs

# %%
class_weights= [0.691363,0.308636] #1-(#inclass/ #intotal )
class_weights = torch.Tensor(class_weights)
class_weights=class_weights.to(device)
criterion = nn.CrossEntropyLoss(weight = class_weights) 

# Observe that all parameters are being optimized
learning_rate=[0.05, 0.1,0.2]
Momentum=[0.5,0.9,0.99]
GAMMA=[0.05, 0.1, 0.5]
#Batch_size= [16,32]#,64,128]
models=[model18, model34, model50]
modelnames=["model18","model34","model50"]
#ADD IN A THING SO IT SAVES THE TENSORBOARD TO DIFFERENT BITS
best_params = None
best_score=0.00
Current_params=None
for lrnum in range(3):
    for gamnum in range(3):
        for Momnum in range(3):
            for modnum in range(3):
                model=models[modnum]
                model = model.to(device)
                optimizer_ft = optim.SGD(model.parameters(), lr=learning_rate[lrnum], momentum=Momentum[Momnum])
                exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=GAMMA[gamnum])
                writer = SummaryWriter("Experiments/TENSORBOARD/lr"+str(learning_rate[lrnum])+"momentum"+
                        str(Momentum[Momnum])+"gamma"+str(GAMMA[gamnum])+"model"+modelnames[modnum])  
                model_ft, con_mat, current_score = train_model(model, criterion, optimizer_ft, exp_lr_scheduler,
                   train,test,num_epochs=5)
                con_mat=con_mat.cpu().numpy()
                current_score=current_score.cpu().numpy()
                Current_params= {'learning rate': learning_rate[lrnum], 'gamma': GAMMA[gamnum], 
                                   'Momentum': Momentum[Momnum], 'Model': modelnames[modnum]}
                print(con_mat)
                print("Current hyperparameters:", Current_params)
                df_cm_ratio = pd.DataFrame(con_mat / np.sum(con_mat, axis=1)[:, None], index=[i for i in labels],
                                     columns=[i for i in labels])
                plt.figure(figsize=(12, 7))
                sn.heatmap(df_cm_ratio, annot=True)
                if current_score > best_score:
                    best_score = current_score
                    best_params = {'learning rate': learning_rate[lrnum], 'gamma': GAMMA[gamnum], 
                                   'Momentum': Momentum[Momnum], 'Model': modelnames[modnum]}
                            
print("Best hyperparameters:", best_params)
print("Best score:", best_score)
# Out:
# Epoch 0/4
# ----------
# train Loss: 0.6482 Acc: 0.6132
# val Loss: 0.7030 Acc: 0.5814
#
# Epoch 1/4
# ----------
# train Loss: 0.6132 Acc: 0.6533
# val Loss: 0.6625 Acc: 0.6278
#
# Epoch 2/4
# ----------
# train Loss: 0.6092 Acc: 0.6593
# val Loss: 0.5825 Acc: 0.6973
#
# Epoch 3/4
# ----------
# train Loss: 0.5920 Acc: 0.6793
# val Loss: 0.6110 Acc: 0.6534
#
# Epoch 4/4
# ----------
# train Loss: 0.5870 Acc: 0.6829
# val Loss: 0.5873 Acc: 0.6858
#
# Training complete in 3m 19s
# Best val Acc: 0.697337
# [[2663 1457]
#  [ 448 1332]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.6388 Acc: 0.6168
# val Loss: 0.9019 Acc: 0.5047
#
# Epoch 1/4
# ----------
# train Loss: 0.6108 Acc: 0.6565
# val Loss: 0.6757 Acc: 0.5694
#
# Epoch 2/4
# ----------
# train Loss: 0.5978 Acc: 0.6702
# val Loss: 0.6258 Acc: 0.6511
#
# Epoch 3/4
# ----------
# train Loss: 0.5916 Acc: 0.6808
# val Loss: 0.5841 Acc: 0.6869
#
# Epoch 4/4
# ----------
# train Loss: 0.5883 Acc: 0.6789
# val Loss: 0.6016 Acc: 0.6791
#
# Training complete in 3m 37s
# Best val Acc: 0.686899
# [[3184  896]
#  [ 740 1080]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.8524 Acc: 0.5683
# val Loss: 0.7725 Acc: 0.5800
#
# Epoch 1/4
# ----------
# train Loss: 0.6718 Acc: 0.6231
# val Loss: 0.8421 Acc: 0.5248
#
# Epoch 2/4
# ----------
# train Loss: 0.6458 Acc: 0.6515
# val Loss: 0.7759 Acc: 0.6134
#
# Epoch 3/4
# ----------
# train Loss: 0.6146 Acc: 0.6665
# val Loss: 0.5956 Acc: 0.6829
#
# Epoch 4/4
# ----------
# train Loss: 0.6081 Acc: 0.6775
# val Loss: 0.6139 Acc: 0.6776
#
# Training complete in 4m 3s
# Best val Acc: 0.682853
# [[2669 1411]
#  [ 525 1295]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.6346 Acc: 0.6393
# val Loss: 0.8397 Acc: 0.5738
#
# Epoch 1/4
# ----------
# train Loss: 0.6179 Acc: 0.6538
# val Loss: 0.7157 Acc: 0.5400
#
# Epoch 2/4
# ----------
# train Loss: 0.5921 Acc: 0.6802
# val Loss: 0.6248 Acc: 0.6578
#
# Epoch 3/4
# ----------
# train Loss: 0.5894 Acc: 0.6780
# val Loss: 0.5816 Acc: 0.6769
#
# Epoch 4/4
# ----------
# train Loss: 0.5777 Acc: 0.6895
# val Loss: 0.6064 Acc: 0.6654
#
# Training complete in 3m 16s
# Best val Acc: 0.676926
# [[3338  742]
#  [ 845  975]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.6381 Acc: 0.6356
# val Loss: 0.7134 Acc: 0.6021
#
# Epoch 1/4
# ----------
# train Loss: 0.6066 Acc: 0.6648
# val Loss: 0.5866 Acc: 0.6796
#
# Epoch 2/4
# ----------
# train Loss: 0.5844 Acc: 0.6845
# val Loss: 0.6022 Acc: 0.6590
#
# Epoch 3/4
# ----------
# train Loss: 0.5820 Acc: 0.6863
# val Loss: 0.6153 Acc: 0.6589
#
# Epoch 4/4
# ----------
# train Loss: 0.5765 Acc: 0.6919
# val Loss: 0.5788 Acc: 0.6946
#
# Training complete in 3m 38s
# Best val Acc: 0.694603
# [[2690 1363]
#  [ 507 1340]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.7139 Acc: 0.6171
# val Loss: 0.8513 Acc: 0.5191
#
# Epoch 1/4
# ----------
# train Loss: 0.6015 Acc: 0.6686
# val Loss: 0.5988 Acc: 0.6703
#
# Epoch 2/4
# ----------
# train Loss: 0.5805 Acc: 0.6864
# val Loss: 0.6006 Acc: 0.6744
#
# Epoch 3/4
# ----------
# train Loss: 0.5801 Acc: 0.6883
# val Loss: 0.6509 Acc: 0.6176
#
# Epoch 4/4
# ----------
# train Loss: 0.5711 Acc: 0.6966
# val Loss: 0.5780 Acc: 0.6895
#
# Training complete in 4m 2s
# Best val Acc: 0.689520
# [[2335 1718]
#  [ 364 1483]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.6043 Acc: 0.6628
# val Loss: 0.5934 Acc: 0.6776
#
# Epoch 1/4
# ----------
# train Loss: 0.5952 Acc: 0.6684
# val Loss: 0.5849 Acc: 0.6890
#
# Epoch 2/4
# ----------
# train Loss: 0.5893 Acc: 0.6792
# val Loss: 0.5729 Acc: 0.6961
#
# Epoch 3/4
# ----------
# train Loss: 0.5816 Acc: 0.6841
# val Loss: 0.6186 Acc: 0.6314
#
# Epoch 4/4
# ----------
# train Loss: 0.5883 Acc: 0.6764
# val Loss: 0.5848 Acc: 0.6782
#
# Training complete in 3m 3s
# Best val Acc: 0.696121
# [[3021 1099]
#  [ 607 1173]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.6046 Acc: 0.6591
# val Loss: 0.6853 Acc: 0.5037
#
# Epoch 1/4
# ----------
# train Loss: 0.6034 Acc: 0.6589
# val Loss: 0.6177 Acc: 0.6511
#
# Epoch 2/4
# ----------
# train Loss: 0.5884 Acc: 0.6797
# val Loss: 0.5745 Acc: 0.7072
#
# Epoch 3/4
# ----------
# train Loss: 0.5736 Acc: 0.6960
# val Loss: 0.5645 Acc: 0.7045
#
# Epoch 4/4
# ----------
# train Loss: 0.5774 Acc: 0.6906
# val Loss: 0.5798 Acc: 0.6856
#
# Training complete in 3m 37s
# Best val Acc: 0.707196
# [[2897 1223]
#  [ 514 1266]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.5949 Acc: 0.6727
# val Loss: 0.6263 Acc: 0.5950
#
# Epoch 1/4
# ----------
# train Loss: 0.5948 Acc: 0.6738
# val Loss: 0.7381 Acc: 0.5640
#
# Epoch 2/4
# ----------
# train Loss: 0.5885 Acc: 0.6765
# val Loss: 0.5892 Acc: 0.6850
#
# Epoch 3/4
# ----------
# train Loss: 0.5829 Acc: 0.6879
# val Loss: 0.5861 Acc: 0.6849
#
# Epoch 4/4
# ----------
# train Loss: 0.5869 Acc: 0.6845
# val Loss: 0.6255 Acc: 0.6548
#
# Training complete in 4m 1s
# Best val Acc: 0.684957
# [[3260  860]
#  [ 750 1030]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.5697 Acc: 0.6993
# val Loss: 0.5616 Acc: 0.7055
#
# Epoch 1/4
# ----------
# train Loss: 0.5644 Acc: 0.7025
# val Loss: 0.5633 Acc: 0.7040
#
# Epoch 2/4
# ----------
# train Loss: 0.5616 Acc: 0.7060
# val Loss: 0.5602 Acc: 0.7127
#
# Epoch 3/4
# ----------
# train Loss: 0.5623 Acc: 0.7070
# val Loss: 0.5583 Acc: 0.7039
#
# Epoch 4/4
# ----------
# train Loss: 0.5613 Acc: 0.7045
# val Loss: 0.5626 Acc: 0.7052
#
# Training complete in 3m 16s
# Best val Acc: 0.712699
# [[3109 1011]
#  [ 586 1194]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.5691 Acc: 0.6994
# val Loss: 0.5604 Acc: 0.7076
#
# Epoch 1/4
# ----------
# train Loss: 0.5648 Acc: 0.7007
# val Loss: 0.5636 Acc: 0.7000
#
# Epoch 2/4
# ----------
# train Loss: 0.5621 Acc: 0.7060
# val Loss: 0.6322 Acc: 0.6450
#
# Epoch 3/4
# ----------
# train Loss: 0.5611 Acc: 0.7047
# val Loss: 0.5609 Acc: 0.7019
#
# Epoch 4/4
# ----------
# train Loss: 0.5629 Acc: 0.7041
# val Loss: 0.5625 Acc: 0.7085
#
# Training complete in 3m 39s
# Best val Acc: 0.708483
# [[3000 1053]
#  [ 597 1250]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.5772 Acc: 0.6930
# val Loss: 0.5665 Acc: 0.7012
#
# Epoch 1/4
# ----------
# train Loss: 0.5696 Acc: 0.6963
# val Loss: 0.5646 Acc: 0.6994
#
# Epoch 2/4
# ----------
# train Loss: 0.5634 Acc: 0.7027
# val Loss: 0.5636 Acc: 0.7025
#
# Epoch 3/4
# ----------
# train Loss: 0.5615 Acc: 0.7079
# val Loss: 0.5624 Acc: 0.7032
#
# Epoch 4/4
# ----------
# train Loss: 0.5609 Acc: 0.7080
# val Loss: 0.5639 Acc: 0.7085
#
# Training complete in 4m 2s
# Best val Acc: 0.708503
# [[2987 1066]
#  [ 591 1256]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.5662 Acc: 0.7019
# val Loss: 0.6188 Acc: 0.6455
#
# Epoch 1/4
# ----------
# train Loss: 0.5629 Acc: 0.7031
# val Loss: 0.6834 Acc: 0.6242
#
# Epoch 2/4
# ----------
# train Loss: 0.5603 Acc: 0.7078
# val Loss: 0.5566 Acc: 0.7110
#
# Epoch 3/4
# ----------
# train Loss: 0.5584 Acc: 0.7092
# val Loss: 0.6998 Acc: 0.6213
#
# Epoch 4/4
# ----------
# train Loss: 0.5600 Acc: 0.7056
# val Loss: 0.5544 Acc: 0.7150
#
# Training complete in 3m 16s
# Best val Acc: 0.715014
# [[2873 1180]
#  [ 515 1332]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.5667 Acc: 0.7010
# val Loss: 0.5671 Acc: 0.6979
#
# Epoch 1/4
# ----------
# train Loss: 0.5633 Acc: 0.7031
# val Loss: 0.6072 Acc: 0.6511
#
# Epoch 2/4
# ----------
# train Loss: 0.5595 Acc: 0.7084
# val Loss: 0.5602 Acc: 0.7079
#
# Epoch 3/4
# ----------
# train Loss: 0.5606 Acc: 0.7055
# val Loss: 0.5736 Acc: 0.6989
#
# Epoch 4/4
# ----------
# train Loss: 0.5596 Acc: 0.7077
# val Loss: 0.6103 Acc: 0.6535
#
# Training complete in 3m 38s
# Best val Acc: 0.707862
# [[2840 1280]
#  [ 487 1293]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.5633 Acc: 0.7049
# val Loss: 0.5833 Acc: 0.6717
#
# Epoch 1/4
# ----------
# train Loss: 0.5627 Acc: 0.7051
# val Loss: 0.5709 Acc: 0.6884
#
# Epoch 2/4
# ----------
# train Loss: 0.5593 Acc: 0.7104
# val Loss: 0.6242 Acc: 0.6695
#
# Epoch 3/4
# ----------
# train Loss: 0.5571 Acc: 0.7122
# val Loss: 0.5597 Acc: 0.7012
#
# Epoch 4/4
# ----------
# train Loss: 0.5569 Acc: 0.7103
# val Loss: 0.5819 Acc: 0.6807
#
# Training complete in 4m 3s
# Best val Acc: 0.701151
# [[3177  903]
#  [ 685 1135]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.5729 Acc: 0.6942
# val Loss: 0.7265 Acc: 0.6044
#
# Epoch 1/4
# ----------
# train Loss: 0.5705 Acc: 0.6943
# val Loss: 0.5621 Acc: 0.7004
#
# Epoch 2/4
# ----------
# train Loss: 0.5676 Acc: 0.6999
# val Loss: 0.5728 Acc: 0.7008
#
# Epoch 3/4
# ----------
# train Loss: 0.5691 Acc: 0.7002
# val Loss: 0.5668 Acc: 0.7058
#
# Epoch 4/4
# ----------
# train Loss: 0.5692 Acc: 0.7012
# val Loss: 0.6076 Acc: 0.6588
#
# Training complete in 3m 16s
# Best val Acc: 0.705754
# [[2755 1325]
#  [ 480 1340]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.5729 Acc: 0.6960
# val Loss: 0.5773 Acc: 0.6921
#
# Epoch 1/4
# ----------
# train Loss: 0.5839 Acc: 0.6868
# val Loss: 0.5741 Acc: 0.6938
#
# Epoch 2/4
# ----------
# train Loss: 0.5797 Acc: 0.6913
# val Loss: 0.6290 Acc: 0.6331
#
# Epoch 3/4
# ----------
# train Loss: 0.5728 Acc: 0.6996
# val Loss: 0.5601 Acc: 0.7024
#
# Epoch 4/4
# ----------
# train Loss: 0.5707 Acc: 0.6993
# val Loss: 0.5706 Acc: 0.6933
#
# Training complete in 3m 37s
# Best val Acc: 0.702404
# [[2703 1377]
#  [ 469 1351]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.5732 Acc: 0.6973
# val Loss: 0.5722 Acc: 0.7058
#
# Epoch 1/4
# ----------
# train Loss: 0.5822 Acc: 0.6880
# val Loss: 1.0644 Acc: 0.5714
#
# Epoch 2/4
# ----------
# train Loss: 0.5886 Acc: 0.6811
# val Loss: 0.5688 Acc: 0.7028
#
# Epoch 3/4
# ----------
# train Loss: 0.5832 Acc: 0.6890
# val Loss: 0.5729 Acc: 0.6924
#
# Epoch 4/4
# ----------
# train Loss: 0.5647 Acc: 0.7021
# val Loss: 0.5666 Acc: 0.7051
#
# Training complete in 4m 2s
# Best val Acc: 0.705779
# [[2904 1188]
#  [ 539 1269]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.5617 Acc: 0.7066
# val Loss: 0.5488 Acc: 0.7151
#
# Epoch 1/4
# ----------
# train Loss: 0.5540 Acc: 0.7130
# val Loss: 0.5499 Acc: 0.7155
#
# Epoch 2/4
# ----------
# train Loss: 0.5504 Acc: 0.7132
# val Loss: 0.5534 Acc: 0.7171
#
# Epoch 3/4
# ----------
# train Loss: 0.5483 Acc: 0.7159
# val Loss: 0.5784 Acc: 0.6853
#
# Epoch 4/4
# ----------
# train Loss: 0.5489 Acc: 0.7147
# val Loss: 0.5515 Acc: 0.7138
#
# Training complete in 3m 16s
# Best val Acc: 0.717067
# [[2814 1306]
#  [ 443 1337]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.5603 Acc: 0.7071
# val Loss: 0.6290 Acc: 0.6429
#
# Epoch 1/4
# ----------
# train Loss: 0.5560 Acc: 0.7105
# val Loss: 0.5642 Acc: 0.7017
#
# Epoch 2/4
# ----------
# train Loss: 0.5534 Acc: 0.7139
# val Loss: 0.5531 Acc: 0.7150
#
# Epoch 3/4
# ----------
# train Loss: 0.5536 Acc: 0.7135
# val Loss: 0.5554 Acc: 0.7079
#
# Epoch 4/4
# ----------
# train Loss: 0.5542 Acc: 0.7115
# val Loss: 0.5540 Acc: 0.7150
#
# Training complete in 3m 38s
# Best val Acc: 0.715031
# [[3031 1089]
#  [ 544 1236]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.5657 Acc: 0.7027
# val Loss: 0.5521 Acc: 0.7161
#
# Epoch 1/4
# ----------
# train Loss: 0.5613 Acc: 0.7070
# val Loss: 0.5560 Acc: 0.7081
#
# Epoch 2/4
# ----------
# train Loss: 0.5564 Acc: 0.7120
# val Loss: 0.5566 Acc: 0.7119
#
# Epoch 3/4
# ----------
# train Loss: 0.5575 Acc: 0.7099
# val Loss: 0.5551 Acc: 0.7125
#
# Epoch 4/4
# ----------
# train Loss: 0.5575 Acc: 0.7084
# val Loss: 0.5567 Acc: 0.7182
#
# Training complete in 4m 2s
# Best val Acc: 0.718190
# [[2958 1095]
#  [ 542 1305]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# /tmp/ipykernel_6938/1918092647.py:37: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(12, 7))
# train Loss: 0.5531 Acc: 0.7125
# val Loss: 0.5869 Acc: 0.6695
#
# Epoch 1/4
# ----------
# train Loss: 0.5484 Acc: 0.7144
# val Loss: 0.5517 Acc: 0.7109
#
# Epoch 2/4
# ----------
# train Loss: 0.5435 Acc: 0.7216
# val Loss: 0.5443 Acc: 0.7190
#
# Epoch 3/4
# ----------
# train Loss: 0.5434 Acc: 0.7189
# val Loss: 0.5649 Acc: 0.6912
#
# Epoch 4/4
# ----------
# train Loss: 0.5411 Acc: 0.7211
# val Loss: 0.5422 Acc: 0.7228
#
# Training complete in 3m 17s
# Best val Acc: 0.722765
# [[2870 1183]
#  [ 485 1362]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.5583 Acc: 0.7114
# val Loss: 0.5456 Acc: 0.7208
#
# Epoch 1/4
# ----------
# train Loss: 0.5552 Acc: 0.7099
# val Loss: 0.5540 Acc: 0.7120
#
# Epoch 2/4
# ----------
# train Loss: 0.5524 Acc: 0.7148
# val Loss: 0.5591 Acc: 0.7040
#
# Epoch 3/4
# ----------
# train Loss: 0.5517 Acc: 0.7156
# val Loss: 0.5761 Acc: 0.6952
#
# Epoch 4/4
# ----------
# train Loss: 0.5518 Acc: 0.7155
# val Loss: 0.5589 Acc: 0.7037
#
# Training complete in 3m 37s
# Best val Acc: 0.720801
# [[3122  970]
#  [ 581 1227]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.5614 Acc: 0.7063
# val Loss: 0.5472 Acc: 0.7144
#
# Epoch 1/4
# ----------
# train Loss: 0.5584 Acc: 0.7092
# val Loss: 0.5653 Acc: 0.7018
#
# Epoch 2/4
# ----------
# train Loss: 0.5537 Acc: 0.7134
# val Loss: 0.5635 Acc: 0.7062
#
# Epoch 3/4
# ----------
# train Loss: 0.5537 Acc: 0.7136
# val Loss: 0.5515 Acc: 0.7122
#
# Epoch 4/4
# ----------
# train Loss: 0.5524 Acc: 0.7142
# val Loss: 0.5608 Acc: 0.7103
#
# Training complete in 4m 2s
# Best val Acc: 0.714447
# [[3156  936]
#  [ 619 1189]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.5555 Acc: 0.7085
# val Loss: 0.5910 Acc: 0.6673
#
# Epoch 1/4
# ----------
# train Loss: 0.5618 Acc: 0.7026
# val Loss: 0.5997 Acc: 0.6616
#
# Epoch 2/4
# ----------
# train Loss: 0.5555 Acc: 0.7087
# val Loss: 0.5647 Acc: 0.7010
#
# Epoch 3/4
# ----------
# train Loss: 0.5627 Acc: 0.7003
# val Loss: 0.6044 Acc: 0.6568
#
# Epoch 4/4
# ----------
# train Loss: 0.5599 Acc: 0.7074
# val Loss: 0.8586 Acc: 0.5901
#
# Training complete in 3m 16s
# Best val Acc: 0.700959
# [[3209  911]
#  [ 671 1109]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.5694 Acc: 0.6990
# val Loss: 0.6219 Acc: 0.6752
#
# Epoch 1/4
# ----------
# train Loss: 0.5717 Acc: 0.6966
# val Loss: 0.5622 Acc: 0.7082
#
# Epoch 2/4
# ----------
# train Loss: 0.5613 Acc: 0.7073
# val Loss: 0.8029 Acc: 0.5794
#
# Epoch 3/4
# ----------
# train Loss: 0.5598 Acc: 0.7087
# val Loss: 0.5787 Acc: 0.6796
#
# Epoch 4/4
# ----------
# train Loss: 0.5640 Acc: 0.7022
# val Loss: 0.6204 Acc: 0.6673
#
# Training complete in 3m 43s
# Best val Acc: 0.708212
# [[2560 1490]
#  [ 399 1451]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.5712 Acc: 0.7001
# val Loss: 0.5919 Acc: 0.6737
#
# Epoch 1/4
# ----------
# train Loss: 0.5746 Acc: 0.6898
# val Loss: 0.6071 Acc: 0.6529
#
# Epoch 2/4
# ----------
# train Loss: 0.5680 Acc: 0.7027
# val Loss: 0.9266 Acc: 0.5716
#
# Epoch 3/4
# ----------
# train Loss: 0.5687 Acc: 0.7008
# val Loss: 0.5740 Acc: 0.6943
#
# Epoch 4/4
# ----------
# train Loss: 0.5703 Acc: 0.6994
# val Loss: 0.6033 Acc: 0.6581
#
# Training complete in 4m 2s
# Best val Acc: 0.694328
# [[3276  804]
#  [ 754 1066]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.5482 Acc: 0.7171
# val Loss: 0.5352 Acc: 0.7223
#
# Epoch 1/4
# ----------
# train Loss: 0.5400 Acc: 0.7211
# val Loss: 0.5368 Acc: 0.7262
#
# Epoch 2/4
# ----------
# train Loss: 0.5360 Acc: 0.7280
# val Loss: 0.5464 Acc: 0.7191
#
# Epoch 3/4
# ----------
# train Loss: 0.5357 Acc: 0.7228
# val Loss: 0.5413 Acc: 0.7202
#
# Epoch 4/4
# ----------
# train Loss: 0.5343 Acc: 0.7253
# val Loss: 0.5322 Acc: 0.7295
#
# Training complete in 3m 15s
# Best val Acc: 0.729519
# [[2905 1148]
#  [ 476 1371]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.5575 Acc: 0.7095
# val Loss: 0.5468 Acc: 0.7214
#
# Epoch 1/4
# ----------
# train Loss: 0.5518 Acc: 0.7149
# val Loss: 0.5512 Acc: 0.7133
#
# Epoch 2/4
# ----------
# train Loss: 0.5511 Acc: 0.7144
# val Loss: 0.5544 Acc: 0.7151
#
# Epoch 3/4
# ----------
# train Loss: 0.5507 Acc: 0.7166
# val Loss: 0.5510 Acc: 0.7128
#
# Epoch 4/4
# ----------
# train Loss: 0.5516 Acc: 0.7148
# val Loss: 0.5543 Acc: 0.7104
#
# Training complete in 3m 38s
# Best val Acc: 0.721447
# [[2738 1354]
#  [ 409 1399]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.5581 Acc: 0.7104
# val Loss: 0.5415 Acc: 0.7234
#
# Epoch 1/4
# ----------
# train Loss: 0.5530 Acc: 0.7125
# val Loss: 0.5503 Acc: 0.7121
#
# Epoch 2/4
# ----------
# train Loss: 0.5509 Acc: 0.7148
# val Loss: 0.5545 Acc: 0.7178
#
# Epoch 3/4
# ----------
# train Loss: 0.5490 Acc: 0.7165
# val Loss: 0.5535 Acc: 0.7059
#
# Epoch 4/4
# ----------
# train Loss: 0.5508 Acc: 0.7153
# val Loss: 0.5501 Acc: 0.7207
#
# Training complete in 4m 2s
# Best val Acc: 0.723355
# [[2989 1103]
#  [ 513 1295]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.5445 Acc: 0.7151
# val Loss: 0.5335 Acc: 0.7212
#
# Epoch 1/4
# ----------
# train Loss: 0.5377 Acc: 0.7230
# val Loss: 0.5339 Acc: 0.7247
#
# Epoch 2/4
# ----------
# train Loss: 0.5341 Acc: 0.7300
# val Loss: 0.5348 Acc: 0.7265
#
# Epoch 3/4
# ----------
# train Loss: 0.5339 Acc: 0.7256
# val Loss: 0.5314 Acc: 0.7261
#
# Epoch 4/4
# ----------
# train Loss: 0.5353 Acc: 0.7256
# val Loss: 0.5384 Acc: 0.7267
#
# Training complete in 3m 13s
# Best val Acc: 0.726679
# [[3187  866]
#  [ 615 1232]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.5559 Acc: 0.7112
# val Loss: 0.5582 Acc: 0.7085
#
# Epoch 1/4
# ----------
# train Loss: 0.5521 Acc: 0.7144
# val Loss: 0.8074 Acc: 0.5900
#
# Epoch 2/4
# ----------
# train Loss: 0.5505 Acc: 0.7167
# val Loss: 0.6176 Acc: 0.6567
#
# Epoch 3/4
# ----------
# train Loss: 0.5471 Acc: 0.7186
# val Loss: 0.8391 Acc: 0.5842
#
# Epoch 4/4
# ----------
# train Loss: 0.5491 Acc: 0.7134
# val Loss: 0.6203 Acc: 0.6370
#
# Training complete in 3m 34s
# Best val Acc: 0.708478
# [[3166  926]
#  [ 645 1163]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.5577 Acc: 0.7098
# val Loss: 0.5778 Acc: 0.7048
#
# Epoch 1/4
# ----------
# train Loss: 0.5582 Acc: 0.7078
# val Loss: 0.5489 Acc: 0.7176
#
# Epoch 2/4
# ----------
# train Loss: 0.5507 Acc: 0.7194
# val Loss: 0.5536 Acc: 0.7149
#
# Epoch 3/4
# ----------
# train Loss: 0.5517 Acc: 0.7150
# val Loss: 0.5486 Acc: 0.7137
#
# Epoch 4/4
# ----------
# train Loss: 0.5508 Acc: 0.7156
# val Loss: 0.5660 Acc: 0.6968
#
# Training complete in 3m 59s
# Best val Acc: 0.717641
# [[2956 1094]
#  [ 545 1305]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.5673 Acc: 0.7010
# val Loss: 1.3861 Acc: 0.5689
#
# Epoch 1/4
# ----------
# train Loss: 0.5856 Acc: 0.6845
# val Loss: 1.1799 Acc: 0.5654
#
# Epoch 2/4
# ----------
# train Loss: 0.5666 Acc: 0.7012
# val Loss: 0.5890 Acc: 0.6721
#
# Epoch 3/4
# ----------
# train Loss: 0.5742 Acc: 0.6945
# val Loss: 0.6349 Acc: 0.6211
#
# Epoch 4/4
# ----------
# train Loss: 0.5595 Acc: 0.7093
# val Loss: 0.5549 Acc: 0.7130
#
# Training complete in 3m 11s
# Best val Acc: 0.712957
# [[2751 1302]
#  [ 467 1380]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.5754 Acc: 0.6927
# val Loss: 0.6340 Acc: 0.5971
#
# Epoch 1/4
# ----------
# train Loss: 0.5803 Acc: 0.6912
# val Loss: 0.6183 Acc: 0.6500
#
# Epoch 2/4
# ----------
# train Loss: 0.5721 Acc: 0.6950
# val Loss: 0.6090 Acc: 0.6564
#
# Epoch 3/4
# ----------
# train Loss: 0.5719 Acc: 0.7007
# val Loss: 0.7117 Acc: 0.6167
#
# Epoch 4/4
# ----------
# train Loss: 0.5671 Acc: 0.7007
# val Loss: 0.5687 Acc: 0.6993
#
# Training complete in 3m 36s
# Best val Acc: 0.699295
# [[2739 1314]
#  [ 512 1335]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.5757 Acc: 0.6898
# val Loss: 0.5716 Acc: 0.6946
#
# Epoch 1/4
# ----------
# train Loss: 0.5880 Acc: 0.6795
# val Loss: 0.7302 Acc: 0.6312
#
# Epoch 2/4
# ----------
# train Loss: 0.5711 Acc: 0.7017
# val Loss: 0.5913 Acc: 0.6665
#
# Epoch 3/4
# ----------
# train Loss: 0.5814 Acc: 0.6868
# val Loss: 0.7379 Acc: 0.6238
#
# Epoch 4/4
# ----------
# train Loss: 0.5889 Acc: 0.6816
# val Loss: 0.5690 Acc: 0.7049
#
# Training complete in 4m 1s
# Best val Acc: 0.704884
# [[2826 1227]
#  [ 531 1316]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.5458 Acc: 0.7177
# val Loss: 0.5304 Acc: 0.7298
#
# Epoch 1/4
# ----------
# train Loss: 0.5412 Acc: 0.7193
# val Loss: 0.5377 Acc: 0.7208
#
# Epoch 2/4
# ----------
# train Loss: 0.5361 Acc: 0.7256
# val Loss: 0.5406 Acc: 0.7228
#
# Epoch 3/4
# ----------
# train Loss: 0.5348 Acc: 0.7242
# val Loss: 0.5500 Acc: 0.7108
#
# Epoch 4/4
# ----------
# train Loss: 0.5367 Acc: 0.7222
# val Loss: 0.5383 Acc: 0.7188
#
# Training complete in 3m 12s
# Best val Acc: 0.729800
# [[3001 1091]
#  [ 495 1313]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.5575 Acc: 0.7081
# val Loss: 0.5703 Acc: 0.6950
#
# Epoch 1/4
# ----------
# train Loss: 0.5495 Acc: 0.7145
# val Loss: 0.5613 Acc: 0.7018
#
# Epoch 2/4
# ----------
# train Loss: 0.5466 Acc: 0.7195
# val Loss: 0.5454 Acc: 0.7238
#
# Epoch 3/4
# ----------
# train Loss: 0.5431 Acc: 0.7206
# val Loss: 0.5376 Acc: 0.7210
#
# Epoch 4/4
# ----------
# train Loss: 0.5443 Acc: 0.7183
# val Loss: 0.5465 Acc: 0.7182
#
# Training complete in 3m 35s
# Best val Acc: 0.723810
# [[2939 1181]
#  [ 473 1307]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.5632 Acc: 0.7069
# val Loss: 0.5456 Acc: 0.7180
#
# Epoch 1/4
# ----------
# train Loss: 0.5551 Acc: 0.7107
# val Loss: 0.5523 Acc: 0.7119
#
# Epoch 2/4
# ----------
# train Loss: 0.5507 Acc: 0.7158
# val Loss: 0.5520 Acc: 0.7161
#
# Epoch 3/4
# ----------
# train Loss: 0.5510 Acc: 0.7179
# val Loss: 0.5502 Acc: 0.7126
#
# Epoch 4/4
# ----------
# train Loss: 0.5506 Acc: 0.7172
# val Loss: 0.5495 Acc: 0.7175
#
# Training complete in 3m 60s
# Best val Acc: 0.718011
# [[2986 1106]
#  [ 531 1277]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.5446 Acc: 0.7171
# val Loss: 0.5248 Acc: 0.7316
#
# Epoch 1/4
# ----------
# train Loss: 0.5389 Acc: 0.7210
# val Loss: 0.5479 Acc: 0.7186
#
# Epoch 2/4
# ----------
# train Loss: 0.5364 Acc: 0.7243
# val Loss: 0.5544 Acc: 0.7132
#
# Epoch 3/4
# ----------
# train Loss: 0.5342 Acc: 0.7230
# val Loss: 0.5270 Acc: 0.7308
#
# Epoch 4/4
# ----------
# train Loss: 0.5334 Acc: 0.7245
# val Loss: 0.5777 Acc: 0.6849
#
# Training complete in 3m 11s
# Best val Acc: 0.731627
# [[2896 1196]
#  [ 442 1366]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.5499 Acc: 0.7150
# val Loss: 0.5466 Acc: 0.7097
#
# Epoch 1/4
# ----------
# train Loss: 0.5461 Acc: 0.7197
# val Loss: 0.5428 Acc: 0.7219
#
# Epoch 2/4
# ----------
# train Loss: 0.5402 Acc: 0.7219
# val Loss: 0.5412 Acc: 0.7255
#
# Epoch 3/4
# ----------
# train Loss: 0.5392 Acc: 0.7209
# val Loss: 0.5538 Acc: 0.7000
#
# Epoch 4/4
# ----------
# train Loss: 0.5392 Acc: 0.7235
# val Loss: 0.5518 Acc: 0.7128
#
# Training complete in 3m 35s
# Best val Acc: 0.725485
# [[2888 1232]
#  [ 445 1335]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.5563 Acc: 0.7106
# val Loss: 0.5606 Acc: 0.6990
#
# Epoch 1/4
# ----------
# train Loss: 0.5540 Acc: 0.7106
# val Loss: 0.5512 Acc: 0.7175
#
# Epoch 2/4
# ----------
# train Loss: 0.5478 Acc: 0.7167
# val Loss: 0.5489 Acc: 0.7183
#
# Epoch 3/4
# ----------
# train Loss: 0.5470 Acc: 0.7189
# val Loss: 0.5877 Acc: 0.6877
#
# Epoch 4/4
# ----------
# train Loss: 0.5453 Acc: 0.7207
# val Loss: 0.5477 Acc: 0.7188
#
# Training complete in 4m 4s
# Best val Acc: 0.718787
# [[3134  919]
#  [ 620 1227]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.5577 Acc: 0.7079
# val Loss: 0.5464 Acc: 0.7173
#
# Epoch 1/4
# ----------
# train Loss: 0.5793 Acc: 0.6891
# val Loss: 0.5657 Acc: 0.7047
#
# Epoch 2/4
# ----------
# train Loss: 0.5668 Acc: 0.7012
# val Loss: 0.5529 Acc: 0.7130
#
# Epoch 3/4
# ----------
# train Loss: 0.5557 Acc: 0.7053
# val Loss: 0.9490 Acc: 0.5889
#
# Epoch 4/4
# ----------
# train Loss: 0.5523 Acc: 0.7136
# val Loss: 0.5509 Acc: 0.7104
#
# Training complete in 3m 12s
# Best val Acc: 0.717286
# [[2713 1379]
#  [ 413 1395]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.5570 Acc: 0.7080
# val Loss: 0.6694 Acc: 0.6280
#
# Epoch 1/4
# ----------
# train Loss: 0.5636 Acc: 0.7042
# val Loss: 0.5898 Acc: 0.6788
#
# Epoch 2/4
# ----------
# train Loss: 0.5812 Acc: 0.6930
# val Loss: 0.6009 Acc: 0.6628
#
# Epoch 3/4
# ----------
# train Loss: 0.5608 Acc: 0.7086
# val Loss: 0.7255 Acc: 0.6031
#
# Epoch 4/4
# ----------
# train Loss: 0.5608 Acc: 0.7080
# val Loss: 0.9201 Acc: 0.5669
#
# Training complete in 3m 36s
# Best val Acc: 0.678779
# [[3171  879]
#  [ 787 1063]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.5728 Acc: 0.6897
# val Loss: 0.5856 Acc: 0.6580
#
# Epoch 1/4
# ----------
# train Loss: 0.5688 Acc: 0.6995
# val Loss: 0.5953 Acc: 0.6649
#
# Epoch 2/4
# ----------
# train Loss: 0.5939 Acc: 0.6760
# val Loss: 0.5913 Acc: 0.6704
#
# Epoch 3/4
# ----------
# train Loss: 0.5954 Acc: 0.6797
# val Loss: 0.6330 Acc: 0.6417
#
# Epoch 4/4
# ----------
# train Loss: 0.6138 Acc: 0.6615
# val Loss: 0.5989 Acc: 0.6750
#
# Training complete in 3m 60s
# Best val Acc: 0.674964
# [[3391  662]
#  [ 899  948]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.5461 Acc: 0.7180
# val Loss: 0.5337 Acc: 0.7308
#
# Epoch 1/4
# ----------
# train Loss: 0.5397 Acc: 0.7231
# val Loss: 0.5369 Acc: 0.7218
#
# Epoch 2/4
# ----------
# train Loss: 0.5355 Acc: 0.7268
# val Loss: 0.5394 Acc: 0.7267
#
# Epoch 3/4
# ----------
# train Loss: 0.5344 Acc: 0.7268
# val Loss: 0.5317 Acc: 0.7273
#
# Epoch 4/4
# ----------
# train Loss: 0.5349 Acc: 0.7283
# val Loss: 0.5361 Acc: 0.7263
#
# Training complete in 3m 11s
# Best val Acc: 0.730759
# [[2821 1271]
#  [ 412 1396]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.5521 Acc: 0.7135
# val Loss: 0.5445 Acc: 0.7158
#
# Epoch 1/4
# ----------
# train Loss: 0.5448 Acc: 0.7170
# val Loss: 0.6013 Acc: 0.6654
#
# Epoch 2/4
# ----------
# train Loss: 0.5422 Acc: 0.7237
# val Loss: 0.5788 Acc: 0.6901
#
# Epoch 3/4
# ----------
# train Loss: 0.5402 Acc: 0.7231
# val Loss: 0.5442 Acc: 0.7174
#
# Epoch 4/4
# ----------
# train Loss: 0.5417 Acc: 0.7223
# val Loss: 0.5402 Acc: 0.7203
#
# Training complete in 3m 34s
# Best val Acc: 0.720345
# [[2846 1207]
#  [ 483 1364]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.5583 Acc: 0.7078
# val Loss: 0.5399 Acc: 0.7190
#
# Epoch 1/4
# ----------
# train Loss: 0.5482 Acc: 0.7153
# val Loss: 0.5437 Acc: 0.7207
#
# Epoch 2/4
# ----------
# train Loss: 0.5432 Acc: 0.7218
# val Loss: 0.5433 Acc: 0.7217
#
# Epoch 3/4
# ----------
# train Loss: 0.5420 Acc: 0.7209
# val Loss: 0.5375 Acc: 0.7215
#
# Epoch 4/4
# ----------
# train Loss: 0.5398 Acc: 0.7226
# val Loss: 0.5398 Acc: 0.7226
#
# Training complete in 3m 60s
# Best val Acc: 0.722631
# [[2757 1296]
#  [ 434 1413]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.5415 Acc: 0.7193
# val Loss: 0.5491 Acc: 0.7127
#
# Epoch 1/4
# ----------
# train Loss: 0.5376 Acc: 0.7231
# val Loss: 0.5341 Acc: 0.7308
#
# Epoch 2/4
# ----------
# train Loss: 0.5338 Acc: 0.7281
# val Loss: 0.5354 Acc: 0.7285
#
# Epoch 3/4
# ----------
# train Loss: 0.5298 Acc: 0.7263
# val Loss: 0.5263 Acc: 0.7298
#
# Epoch 4/4
# ----------
# train Loss: 0.5304 Acc: 0.7286
# val Loss: 0.5406 Acc: 0.7213
#
# Training complete in 3m 7s
# Best val Acc: 0.730807
# [[2789 1261]
#  [ 420 1430]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.5420 Acc: 0.7213
# val Loss: 0.5488 Acc: 0.7101
#
# Epoch 1/4
# ----------
# train Loss: 0.5392 Acc: 0.7213
# val Loss: 0.6992 Acc: 0.6156
#
# Epoch 2/4
# ----------
# train Loss: 0.5372 Acc: 0.7238
# val Loss: 0.5419 Acc: 0.7238
#
# Epoch 3/4
# ----------
# train Loss: 0.5344 Acc: 0.7248
# val Loss: 0.5284 Acc: 0.7279
#
# Epoch 4/4
# ----------
# train Loss: 0.5360 Acc: 0.7248
# val Loss: 0.5368 Acc: 0.7232
#
# Training complete in 3m 34s
# Best val Acc: 0.727934
# [[2797 1283]
#  [ 418 1402]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.5447 Acc: 0.7189
# val Loss: 0.5359 Acc: 0.7235
#
# Epoch 1/4
# ----------
# train Loss: 0.5413 Acc: 0.7178
# val Loss: 0.5367 Acc: 0.7201
#
# Epoch 2/4
# ----------
# train Loss: 0.5359 Acc: 0.7246
# val Loss: 0.5385 Acc: 0.7270
#
# Epoch 3/4
# ----------
# train Loss: 0.5348 Acc: 0.7241
# val Loss: 0.5495 Acc: 0.7058
#
# Epoch 4/4
# ----------
# train Loss: 0.5363 Acc: 0.7229
# val Loss: 0.5362 Acc: 0.7280
#
# Training complete in 3m 59s
# Best val Acc: 0.727992
# [[3134  919]
#  [ 586 1261]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.5654 Acc: 0.6983
# val Loss: 0.5912 Acc: 0.6624
#
# Epoch 1/4
# ----------
# train Loss: 0.5601 Acc: 0.7061
# val Loss: 0.7500 Acc: 0.5814
#
# Epoch 2/4
# ----------
# train Loss: 0.5659 Acc: 0.7026
# val Loss: 0.6157 Acc: 0.6585
#
# Epoch 3/4
# ----------
# train Loss: 0.5505 Acc: 0.7171
# val Loss: 0.5501 Acc: 0.7253
#
# Epoch 4/4
# ----------
# train Loss: 0.5540 Acc: 0.7114
# val Loss: 0.5556 Acc: 0.6980
#
# Training complete in 3m 11s
# Best val Acc: 0.725283
# [[3078 1002]
#  [ 553 1267]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.5564 Acc: 0.7106
# val Loss: 0.5799 Acc: 0.6943
#
# Epoch 1/4
# ----------
# train Loss: 0.5675 Acc: 0.7031
# val Loss: 0.5904 Acc: 0.6653
#
# Epoch 2/4
# ----------
# train Loss: 0.5731 Acc: 0.6984
# val Loss: 0.5514 Acc: 0.7174
#
# Epoch 3/4
# ----------
# train Loss: 0.5673 Acc: 0.7025
# val Loss: 0.5521 Acc: 0.7189
#
# Epoch 4/4
# ----------
# train Loss: 0.5565 Acc: 0.7112
# val Loss: 0.5458 Acc: 0.7229
#
# Training complete in 3m 33s
# Best val Acc: 0.722871
# [[2895 1158]
#  [ 496 1351]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.5567 Acc: 0.7111
# val Loss: 0.5788 Acc: 0.7001
#
# Epoch 1/4
# ----------
# train Loss: 0.5740 Acc: 0.6963
# val Loss: 0.5930 Acc: 0.6556
#
# Epoch 2/4
# ----------
# train Loss: 0.5759 Acc: 0.6931
# val Loss: 0.6028 Acc: 0.7011
#
# Epoch 3/4
# ----------
# train Loss: 0.5802 Acc: 0.6906
# val Loss: 0.6440 Acc: 0.6826
#
# Epoch 4/4
# ----------
# train Loss: 0.5582 Acc: 0.7106
# val Loss: 0.6673 Acc: 0.6278
#
# Training complete in 3m 58s
# Best val Acc: 0.701110
# [[3282  838]
#  [ 702 1078]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.5380 Acc: 0.7223
# val Loss: 0.5337 Acc: 0.7198
#
# Epoch 1/4
# ----------
# train Loss: 0.5318 Acc: 0.7259
# val Loss: 0.5253 Acc: 0.7291
#
# Epoch 2/4
# ----------
# train Loss: 0.5291 Acc: 0.7319
# val Loss: 0.5297 Acc: 0.7319
#
# Epoch 3/4
# ----------
# train Loss: 0.5242 Acc: 0.7331
# val Loss: 0.5237 Acc: 0.7308
#
# Epoch 4/4
# ----------
# train Loss: 0.5258 Acc: 0.7340
# val Loss: 0.5518 Acc: 0.7055
#
# Training complete in 3m 10s
# Best val Acc: 0.731901
# [[2883 1237]
#  [ 420 1360]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.5422 Acc: 0.7195
# val Loss: 0.5273 Acc: 0.7311
#
# Epoch 1/4
# ----------
# train Loss: 0.5363 Acc: 0.7260
# val Loss: 0.5363 Acc: 0.7234
#
# Epoch 2/4
# ----------
# train Loss: 0.5323 Acc: 0.7289
# val Loss: 0.5313 Acc: 0.7301
#
# Epoch 3/4
# ----------
# train Loss: 0.5311 Acc: 0.7299
# val Loss: 0.5276 Acc: 0.7293
#
# Epoch 4/4
# ----------
# train Loss: 0.5303 Acc: 0.7303
# val Loss: 0.5304 Acc: 0.7309
#
# Training complete in 3m 33s
# Best val Acc: 0.731106
# [[2808 1284]
#  [ 405 1403]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.5499 Acc: 0.7129
# val Loss: 0.5317 Acc: 0.7278
#
# Epoch 1/4
# ----------
# train Loss: 0.5408 Acc: 0.7202
# val Loss: 0.5374 Acc: 0.7177
#
# Epoch 2/4
# ----------
# train Loss: 0.5354 Acc: 0.7266
# val Loss: 0.5389 Acc: 0.7260
#
# Epoch 3/4
# ----------
# train Loss: 0.5335 Acc: 0.7274
# val Loss: 0.5945 Acc: 0.6833
#
# Epoch 4/4
# ----------
# train Loss: 0.5352 Acc: 0.7233
# val Loss: 0.5368 Acc: 0.7209
#
# Training complete in 3m 58s
# Best val Acc: 0.727799
# [[3005 1087]
#  [ 504 1304]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.5356 Acc: 0.7235
# val Loss: 0.5302 Acc: 0.7186
#
# Epoch 1/4
# ----------
# train Loss: 0.5330 Acc: 0.7264
# val Loss: 0.5275 Acc: 0.7295
#
# Epoch 2/4
# ----------
# train Loss: 0.5290 Acc: 0.7304
# val Loss: 0.6176 Acc: 0.6713
#
# Epoch 3/4
# ----------
# train Loss: 0.5301 Acc: 0.7289
# val Loss: 0.6594 Acc: 0.6456
#
# Epoch 4/4
# ----------
# train Loss: 0.5288 Acc: 0.7275
# val Loss: 0.6719 Acc: 0.6332
#
# Training complete in 3m 11s
# Best val Acc: 0.729526
# [[2783 1267]
#  [ 422 1428]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.5395 Acc: 0.7247
# val Loss: 0.5553 Acc: 0.7007
#
# Epoch 1/4
# ----------
# train Loss: 0.5396 Acc: 0.7203
# val Loss: 0.5951 Acc: 0.6624
#
# Epoch 2/4
# ----------
# train Loss: 0.5328 Acc: 0.7301
# val Loss: 0.5326 Acc: 0.7325
#
# Epoch 3/4
# ----------
# train Loss: 0.5319 Acc: 0.7304
# val Loss: 0.5411 Acc: 0.7174
#
# Epoch 4/4
# ----------
# train Loss: 0.5327 Acc: 0.7309
# val Loss: 0.5968 Acc: 0.6598
#
# Training complete in 3m 34s
# Best val Acc: 0.732477
# [[3309  811]
#  [ 602 1178]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.5437 Acc: 0.7167
# val Loss: 0.5397 Acc: 0.7140
#
# Epoch 1/4
# ----------
# train Loss: 0.5387 Acc: 0.7217
# val Loss: 0.5440 Acc: 0.7133
#
# Epoch 2/4
# ----------
# train Loss: 0.5333 Acc: 0.7281
# val Loss: 0.5327 Acc: 0.7279
#
# Epoch 3/4
# ----------
# train Loss: 0.5336 Acc: 0.7271
# val Loss: 0.5328 Acc: 0.7271
#
# Epoch 4/4
# ----------
# train Loss: 0.5355 Acc: 0.7250
# val Loss: 0.5380 Acc: 0.7154
#
# Training complete in 3m 59s
# Best val Acc: 0.727868
# [[2903 1217]
#  [ 443 1337]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.5646 Acc: 0.6997
# val Loss: 0.5685 Acc: 0.7054
#
# Epoch 1/4
# ----------
# train Loss: 0.5789 Acc: 0.6905
# val Loss: 0.5882 Acc: 0.6738
#
# Epoch 2/4
# ----------
# train Loss: 0.5770 Acc: 0.6942
# val Loss: 0.5898 Acc: 0.6977
#
# Epoch 3/4
# ----------
# train Loss: 0.5744 Acc: 0.6951
# val Loss: 0.6985 Acc: 0.5933
#
# Epoch 4/4
# ----------
# train Loss: 0.5774 Acc: 0.6863
# val Loss: 0.5765 Acc: 0.6828
#
# Training complete in 3m 11s
# Best val Acc: 0.705408
# [[2652 1440]
#  [ 429 1379]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.5560 Acc: 0.7098
# val Loss: 0.5482 Acc: 0.7137
#
# Epoch 1/4
# ----------
# train Loss: 0.5860 Acc: 0.6821
# val Loss: 0.6217 Acc: 0.6353
#
# Epoch 2/4
# ----------
# train Loss: 0.5761 Acc: 0.6974
# val Loss: 0.8772 Acc: 0.5875
#
# Epoch 3/4
# ----------
# train Loss: 0.5641 Acc: 0.7063
# val Loss: 1.0773 Acc: 0.5673
#
# Epoch 4/4
# ----------
# train Loss: 0.5726 Acc: 0.6985
# val Loss: 1.4504 Acc: 0.5633
#
# Training complete in 3m 34s
# Best val Acc: 0.713732
# [[3252  840]
#  [ 664 1144]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.5593 Acc: 0.7071
# val Loss: 0.5953 Acc: 0.6740
#
# Epoch 1/4
# ----------
# train Loss: 0.5788 Acc: 0.6875
# val Loss: 0.6136 Acc: 0.6655
#
# Epoch 2/4
# ----------
# train Loss: 0.5715 Acc: 0.6939
# val Loss: 0.5721 Acc: 0.7159
#
# Epoch 3/4
# ----------
# train Loss: 0.6222 Acc: 0.6582
# val Loss: 0.7159 Acc: 0.6185
#
# Epoch 4/4
# ----------
# train Loss: 0.5696 Acc: 0.7004
# val Loss: 0.7322 Acc: 0.6446
#
# Training complete in 3m 60s
# Best val Acc: 0.715935
# [[3300  820]
#  [ 657 1123]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.5472 Acc: 0.7169
# val Loss: 0.5301 Acc: 0.7281
#
# Epoch 1/4
# ----------
# train Loss: 0.5377 Acc: 0.7242
# val Loss: 0.5326 Acc: 0.7283
#
# Epoch 2/4
# ----------
# train Loss: 0.5329 Acc: 0.7291
# val Loss: 0.5322 Acc: 0.7329
#
# Epoch 3/4
# ----------
# train Loss: 0.5312 Acc: 0.7274
# val Loss: 0.5318 Acc: 0.7238
#
# Epoch 4/4
# ----------
# train Loss: 0.5313 Acc: 0.7285
# val Loss: 0.5257 Acc: 0.7345
#
# Training complete in 3m 12s
# Best val Acc: 0.734450
# [[3013 1040]
#  [ 507 1340]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.5472 Acc: 0.7194
# val Loss: 0.5305 Acc: 0.7343
#
# Epoch 1/4
# ----------
# train Loss: 0.5392 Acc: 0.7246
# val Loss: 0.5331 Acc: 0.7283
#
# Epoch 2/4
# ----------
# train Loss: 0.5343 Acc: 0.7298
# val Loss: 0.5688 Acc: 0.6935
#
# Epoch 3/4
# ----------
# train Loss: 0.5338 Acc: 0.7288
# val Loss: 0.5466 Acc: 0.7096
#
# Epoch 4/4
# ----------
# train Loss: 0.5328 Acc: 0.7293
# val Loss: 0.5329 Acc: 0.7291
#
# Training complete in 3m 34s
# Best val Acc: 0.734295
# [[2945 1147]
#  [ 454 1354]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.5467 Acc: 0.7194
# val Loss: 0.5302 Acc: 0.7345
#
# Epoch 1/4
# ----------
# train Loss: 0.5400 Acc: 0.7230
# val Loss: 0.5405 Acc: 0.7259
#
# Epoch 2/4
# ----------
# train Loss: 0.5348 Acc: 0.7292
# val Loss: 0.5346 Acc: 0.7280
#
# Epoch 3/4
# ----------
# train Loss: 0.5342 Acc: 0.7291
# val Loss: 0.5313 Acc: 0.7301
#
# Epoch 4/4
# ----------
# train Loss: 0.5372 Acc: 0.7253
# val Loss: 0.5346 Acc: 0.7296
#
# Training complete in 4m 0s
# Best val Acc: 0.734540
# [[2990 1102]
#  [ 473 1335]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.5331 Acc: 0.7290
# val Loss: 0.5340 Acc: 0.7257
#
# Epoch 1/4
# ----------
# train Loss: 0.5334 Acc: 0.7251
# val Loss: 0.5932 Acc: 0.6663
#
# Epoch 2/4
# ----------
# train Loss: 0.5281 Acc: 0.7330
# val Loss: 0.5289 Acc: 0.7362
#
# Epoch 3/4
# ----------
# train Loss: 0.5251 Acc: 0.7343
# val Loss: 0.5350 Acc: 0.7191
#
# Epoch 4/4
# ----------
# train Loss: 0.5278 Acc: 0.7319
# val Loss: 0.5266 Acc: 0.7322
#
# Training complete in 3m 11s
# Best val Acc: 0.736160
# [[2888 1232]
#  [ 407 1373]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.5416 Acc: 0.7241
# val Loss: 0.5652 Acc: 0.6934
#
# Epoch 1/4
# ----------
# train Loss: 0.5363 Acc: 0.7255
# val Loss: 0.6115 Acc: 0.6443
#
# Epoch 2/4
# ----------
# train Loss: 0.5355 Acc: 0.7281
# val Loss: 0.5866 Acc: 0.6807
#
# Epoch 3/4
# ----------
# train Loss: 0.5328 Acc: 0.7302
# val Loss: 0.5334 Acc: 0.7198
#
# Epoch 4/4
# ----------
# train Loss: 0.5318 Acc: 0.7281
# val Loss: 0.5354 Acc: 0.7218
#
# Training complete in 3m 33s
# Best val Acc: 0.721784
# [[2726 1327]
#  [ 423 1424]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.5461 Acc: 0.7205
# val Loss: 0.5403 Acc: 0.7198
#
# Epoch 1/4
# ----------
# train Loss: 0.5407 Acc: 0.7223
# val Loss: 0.5665 Acc: 0.6977
#
# Epoch 2/4
# ----------
# train Loss: 0.5360 Acc: 0.7270
# val Loss: 0.5441 Acc: 0.7188
#
# Epoch 3/4
# ----------
# train Loss: 0.5367 Acc: 0.7254
# val Loss: 0.5415 Acc: 0.7222
#
# Epoch 4/4
# ----------
# train Loss: 0.5350 Acc: 0.7273
# val Loss: 0.5385 Acc: 0.7204
#
# Training complete in 3m 58s
# Best val Acc: 0.722171
# [[3353  727]
#  [ 687 1133]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.5619 Acc: 0.7010
# val Loss: 0.5776 Acc: 0.6789
#
# Epoch 1/4
# ----------
# train Loss: 0.5760 Acc: 0.6927
# val Loss: 0.5855 Acc: 0.6851
#
# Epoch 2/4
# ----------
# train Loss: 0.5855 Acc: 0.6832
# val Loss: 5.8770 Acc: 0.5629
#
# Epoch 3/4
# ----------
# train Loss: 0.5880 Acc: 0.6782
# val Loss: 0.5857 Acc: 0.6697
#
# Epoch 4/4
# ----------
# train Loss: 0.6015 Acc: 0.6740
# val Loss: 0.5801 Acc: 0.6865
#
# Training complete in 3m 10s
# Best val Acc: 0.686454
# [[2602 1451]
#  [ 497 1350]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.5763 Acc: 0.6951
# val Loss: 0.5618 Acc: 0.7070
#
# Epoch 1/4
# ----------
# train Loss: 0.5767 Acc: 0.6905
# val Loss: 0.6749 Acc: 0.5699
#
# Epoch 2/4
# ----------
# train Loss: 0.5757 Acc: 0.6989
# val Loss: 0.5862 Acc: 0.6770
#
# Epoch 3/4
# ----------
# train Loss: 0.5802 Acc: 0.6926
# val Loss: 0.6892 Acc: 0.5800
#
# Epoch 4/4
# ----------
# train Loss: 0.5928 Acc: 0.6736
# val Loss: 0.6873 Acc: 0.6238
#
# Training complete in 3m 35s
# Best val Acc: 0.707031
# [[3256  836]
#  [ 690 1118]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.5727 Acc: 0.6987
# val Loss: 0.5524 Acc: 0.7093
#
# Epoch 1/4
# ----------
# train Loss: 0.5723 Acc: 0.6946
# val Loss: 0.7041 Acc: 0.6261
#
# Epoch 2/4
# ----------
# train Loss: 0.5634 Acc: 0.7046
# val Loss: 0.5502 Acc: 0.7081
#
# Epoch 3/4
# ----------
# train Loss: 0.6039 Acc: 0.6769
# val Loss: 0.5809 Acc: 0.6712
#
# Epoch 4/4
# ----------
# train Loss: 0.6202 Acc: 0.6577
# val Loss: 0.6106 Acc: 0.7156
#
# Training complete in 3m 59s
# Best val Acc: 0.715644
# [[2843 1210]
#  [ 499 1348]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.5567 Acc: 0.7091
# val Loss: 0.5432 Acc: 0.7258
#
# Epoch 1/4
# ----------
# train Loss: 0.5522 Acc: 0.7138
# val Loss: 0.5466 Acc: 0.7155
#
# Epoch 2/4
# ----------
# train Loss: 0.5485 Acc: 0.7161
# val Loss: 0.5435 Acc: 0.7213
#
# Epoch 3/4
# ----------
# train Loss: 0.5474 Acc: 0.7171
# val Loss: 0.5593 Acc: 0.7035
#
# Epoch 4/4
# ----------
# train Loss: 0.5457 Acc: 0.7178
# val Loss: 0.5458 Acc: 0.7226
#
# Training complete in 3m 12s
# Best val Acc: 0.725799
# [[2966 1126]
#  [ 494 1314]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.5490 Acc: 0.7112
# val Loss: 0.5392 Acc: 0.7210
#
# Epoch 1/4
# ----------
# train Loss: 0.5408 Acc: 0.7206
# val Loss: 0.5407 Acc: 0.7254
#
# Epoch 2/4
# ----------
# train Loss: 0.5380 Acc: 0.7238
# val Loss: 0.5449 Acc: 0.7137
#
# Epoch 3/4
# ----------
# train Loss: 0.5352 Acc: 0.7265
# val Loss: 0.5340 Acc: 0.7230
#
# Epoch 4/4
# ----------
# train Loss: 0.5365 Acc: 0.7234
# val Loss: 0.5360 Acc: 0.7240
#
# Training complete in 3m 34s
# Best val Acc: 0.725392
# [[2894 1156]
#  [ 488 1362]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.5468 Acc: 0.7167
# val Loss: 0.5294 Acc: 0.7332
#
# Epoch 1/4
# ----------
# train Loss: 0.5405 Acc: 0.7202
# val Loss: 0.5379 Acc: 0.7217
#
# Epoch 2/4
# ----------
# train Loss: 0.5342 Acc: 0.7266
# val Loss: 0.5374 Acc: 0.7272
#
# Epoch 3/4
# ----------
# train Loss: 0.5332 Acc: 0.7269
# val Loss: 0.5282 Acc: 0.7253
#
# Epoch 4/4
# ----------
# train Loss: 0.5323 Acc: 0.7251
# val Loss: 0.5320 Acc: 0.7253
#
# Training complete in 3m 58s
# Best val Acc: 0.733194
# [[3194  898]
#  [ 568 1240]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.5526 Acc: 0.7167
# val Loss: 0.5366 Acc: 0.7272
#
# Epoch 1/4
# ----------
# train Loss: 0.5479 Acc: 0.7177
# val Loss: 0.5751 Acc: 0.6895
#
# Epoch 2/4
# ----------
# train Loss: 0.5428 Acc: 0.7235
# val Loss: 0.5377 Acc: 0.7264
#
# Epoch 3/4
# ----------
# train Loss: 0.5422 Acc: 0.7214
# val Loss: 0.5319 Acc: 0.7293
#
# Epoch 4/4
# ----------
# train Loss: 0.5400 Acc: 0.7218
# val Loss: 0.5439 Acc: 0.7165
#
# Training complete in 3m 13s
# Best val Acc: 0.729285
# [[2882 1198]
#  [ 451 1369]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.5450 Acc: 0.7171
# val Loss: 0.5252 Acc: 0.7307
#
# Epoch 1/4
# ----------
# train Loss: 0.5363 Acc: 0.7235
# val Loss: 0.5965 Acc: 0.6538
#
# Epoch 2/4
# ----------
# train Loss: 0.5331 Acc: 0.7293
# val Loss: 0.5334 Acc: 0.7289
#
# Epoch 3/4
# ----------
# train Loss: 0.5304 Acc: 0.7301
# val Loss: 0.5212 Acc: 0.7344
#
# Epoch 4/4
# ----------
# train Loss: 0.5309 Acc: 0.7292
# val Loss: 0.5262 Acc: 0.7289
#
# Training complete in 3m 37s
# Best val Acc: 0.734382
# [[2881 1199]
#  [ 432 1388]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.5435 Acc: 0.7146
# val Loss: 0.5204 Acc: 0.7357
#
# Epoch 1/4
# ----------
# train Loss: 0.5348 Acc: 0.7261
# val Loss: 0.5308 Acc: 0.7278
#
# Epoch 2/4
# ----------
# train Loss: 0.5290 Acc: 0.7305
# val Loss: 0.5714 Acc: 0.6953
#
# Epoch 3/4
# ----------
# train Loss: 0.5297 Acc: 0.7317
# val Loss: 0.5210 Acc: 0.7313
#
# Epoch 4/4
# ----------
# train Loss: 0.5338 Acc: 0.7232
# val Loss: 0.5296 Acc: 0.7339
#
# Training complete in 4m 1s
# Best val Acc: 0.735664
# [[3178  914]
#  [ 552 1256]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.5801 Acc: 0.6888
# val Loss: 0.6064 Acc: 0.6665
#
# Epoch 1/4
# ----------
# train Loss: 0.6402 Acc: 0.6497
# val Loss: 0.8601 Acc: 0.5548
#
# Epoch 2/4
# ----------
# train Loss: 0.6098 Acc: 0.6649
# val Loss: 0.6770 Acc: 0.6549
#
# Epoch 3/4
# ----------
# train Loss: 0.5745 Acc: 0.6968
# val Loss: 0.5496 Acc: 0.7152
#
# Epoch 4/4
# ----------
# train Loss: 0.5666 Acc: 0.7063
# val Loss: 0.5521 Acc: 0.7256
#
# Training complete in 3m 12s
# Best val Acc: 0.725572
# [[2952 1101]
#  [ 512 1335]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.5781 Acc: 0.6885
# val Loss: 0.5468 Acc: 0.7284
#
# Epoch 1/4
# ----------
# train Loss: 0.5647 Acc: 0.7011
# val Loss: 0.6074 Acc: 0.6377
#
# Epoch 2/4
# ----------
# train Loss: 0.5814 Acc: 0.6836
# val Loss: 0.7884 Acc: 0.6118
#
# Epoch 3/4
# ----------
# train Loss: 0.5879 Acc: 0.6836
# val Loss: 0.6777 Acc: 0.5848
#
# Epoch 4/4
# ----------
# train Loss: 0.6072 Acc: 0.6734
# val Loss: 0.8448 Acc: 0.5665
#
# Training complete in 3m 36s
# Best val Acc: 0.728390
# [[3166  926]
#  [ 573 1235]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.5633 Acc: 0.7014
# val Loss: 0.5643 Acc: 0.7192
#
# Epoch 1/4
# ----------
# train Loss: 0.5619 Acc: 0.7073
# val Loss: 0.5579 Acc: 0.7008
#
# Epoch 2/4
# ----------
# train Loss: 0.5608 Acc: 0.7123
# val Loss: 0.5655 Acc: 0.7151
#
# Epoch 3/4
# ----------
# train Loss: 0.5493 Acc: 0.7169
# val Loss: 0.5716 Acc: 0.6765
#
# Epoch 4/4
# ----------
# train Loss: 0.5807 Acc: 0.6938
# val Loss: 0.5409 Acc: 0.7225
#
# Training complete in 4m 1s
# Best val Acc: 0.722461
# [[3155  898]
#  [ 616 1231]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model50'}
# Best hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model18'}
# Best score: 0.73615956

# %%
#cf_matrix = confusion_matrix_calc(data_loader_test, labels, model_ft)

# %%
# !kill 1405
# Out:
# /bin/dash: 1: kill: No such process

# %%
# %tensorboard --logdir Experiments/TENSORBOARD
# Out:
#       <iframe id="tensorboard-frame-f7ea9ca97741e919" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-f7ea9ca97741e919");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
print(best_params)
best_score
# Out:
# {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model18'}
# array(0.73615956, dtype=float32)
