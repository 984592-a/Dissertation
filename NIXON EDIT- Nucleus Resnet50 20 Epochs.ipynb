# %% [markdown]
# ### To note: Running this on different systems (i.e. local, SCW, server) will result in slight changes needing to the code

# %%
# Load libraries
import os
import numpy as np
import torch
import sys
import torchvision
import torchvision.transforms as T
import torchvision.models as models
from PIL import Image
from PIL import ImageEnhance
import matplotlib.pyplot as plt
import imagesize
import subprocess
sys.path
from IPython.core.debugger import set_trace
import scipy.ndimage
import matplotlib.patches as patches
# plt.rcParams['figure.figsize'] = [12,12]
# sys.path.append('/workspace/myFile/Mask_RCNN_Tutorial/')
from tqdm import tqdm
from torch import nn as nn
from torch import optim as optim
from torch.optim import lr_scheduler
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
import re
import time
import copy
import pylab
from torch.utils.tensorboard import SummaryWriter
from tempfile import TemporaryDirectory
import torch.backends.cudnn as cudnn
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import seaborn as sn
import pandas as pd
import glob
# Rather than have a messy notebook with a load of functions we can store them in separate .py files and import them

cudnn.benchmark = True
plt.ion()   # interactive mode
# Out:
# /opt/conda/lib/python3.8/site-packages/scipy/__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
writer = SummaryWriter("Experiments/TENSORBOARD")    # This determines the tensorboard file name

# %%
class DNADataset(object):
    def __init__(self, root, transforms, labels, imDx = False):
        self.root, self.transforms, self.labels = root, transforms, labels
    
        # load all image files, sorting them to ensure they are aligned
        self.imgDir = glob.glob(root+"*/*.tiff")
        Damagednuclei= [x for x in self.imgDir if 'Damaged_nuclei_' in x]
        Undamagednuclei= [x for x in self.imgDir if "No_damage_nuclei" in x]
        np.random.shuffle(Undamagednuclei)
        Undamagednuclei=Undamagednuclei[:10000]
        self.imgDir= Damagednuclei+Undamagednuclei
        size80=[]
        for x in self.imgDir:
            img = Image.open(x) # Open image
            w,h=img.size
            if w<=80 and h<=80:
                size80.append(x)
        self.imgDir=size80              
        
        self.imgs = sorted(self.imgDir) # list of images

        

        
    def __getitem__(self, idx):
        img_path = self.imgs[idx]
       
        # Transform images into tensors
        img = Image.open(img_path) # Open image
        w,h=img.size
        img = np.array(img) # Convert image into an array
        img = np.float32(np.divide(img, 2**16)) # Ensure all values are floats
        
        result=np.zeros((80,80), dtype=np.float32)
        x_center = (80 - w) // 2
        y_center = (80 - h) // 2 # copy img image into center of result image
        result[y_center:y_center+h, x_center:x_center+w] = img
        img = result
        
        targetlab=""
        if img_path.find('No_damage_nuclei') != -1:
            targetlab= 'Undamaged'
        if img_path.find('Damaged_nuclei_') != -1:
            targetlab= 'Damaged'  # Find labels corresponding to image
        target = self.labels.index(targetlab) # Get the label and assign to a value
        
        # Convert label to tensor
        #torch.to
        
        if self.transforms is not None:
            img = self.transforms(img)
#             #print('In the transforms')
        imNo = idx
        return img, target, imNo
        
    def __len__(self):
        return len(self.imgs)

# %%
root="/workspace/myFile/Output/17052023/"
p= glob.glob(root+"*/*.tiff")
Damagednuclei= [x for x in p if 'Damaged_nuclei_' in x]
Undamagednuclei= [x for x in p if "No_damage_nuclei" in x]
np.random.shuffle(Undamagednuclei)
Undamagednuclei=Undamagednuclei[:10000]
Undamagednuclei
# Out:
# ['/workspace/myFile/Output/17052023/A1223/No_damage_nuclei_204.tiff',
#  '/workspace/myFile/Output/17052023/E1104/No_damage_nuclei_106.tiff',
#  '/workspace/myFile/Output/17052023/E1003/No_damage_nuclei_23.tiff',
#  '/workspace/myFile/Output/17052023/F1207/No_damage_nuclei_116.tiff',
#  '/workspace/myFile/Output/17052023/E0515/No_damage_nuclei_82.tiff',
#  '/workspace/myFile/Output/17052023/E0502/No_damage_nuclei_90.tiff',
#  '/workspace/myFile/Output/17052023/F1025/No_damage_nuclei_4.tiff',
#  '/workspace/myFile/Output/17052023/A1208/No_damage_nuclei_291.tiff',
#  '/workspace/myFile/Output/17052023/A0515/No_damage_nuclei_32.tiff',
#  '/workspace/myFile/Output/17052023/C1016/No_damage_nuclei_6.tiff',
#  '/workspace/myFile/Output/17052023/E0618/No_damage_nuclei_179.tiff',
#  '/workspace/myFile/Output/17052023/A0607/No_damage_nuclei_490.tiff',
#  '/workspace/myFile/Output/17052023/A1113/No_damage_nuclei_255.tiff',
#  '/workspace/myFile/Output/17052023/F0408/No_damage_nuclei_315.tiff',
#  '/workspace/myFile/Output/17052023/F0506/No_damage_nuclei_34.tiff',
#  '/workspace/myFile/Output/17052023/E1108/No_damage_nuclei_131.tiff',
#  '/workspace/myFile/Output/17052023/B1101/No_damage_nuclei_1594.tiff',
#  '/workspace/myFile/Output/17052023/A1211/No_damage_nuclei_59.tiff',
#  '/workspace/myFile/Output/17052023/D1109/No_damage_nuclei_8.tiff',
#  '/workspace/myFile/Output/17052023/A0513/No_damage_nuclei_997.tiff',
#  '/workspace/myFile/Output/17052023/E1013/No_damage_nuclei_218.tiff',
#  '/workspace/myFile/Output/17052023/A1023/No_damage_nuclei_243.tiff',
#  '/workspace/myFile/Output/17052023/E1115/No_damage_nuclei_62.tiff',
#  '/workspace/myFile/Output/17052023/A1206/No_damage_nuclei_9.tiff',
#  '/workspace/myFile/Output/17052023/A1017/No_damage_nuclei_447.tiff',
#  '/workspace/myFile/Output/17052023/D1006/No_damage_nuclei_31.tiff',
#  '/workspace/myFile/Output/17052023/C0403/No_damage_nuclei_36.tiff',
#  '/workspace/myFile/Output/17052023/B1204/No_damage_nuclei_83.tiff',
#  '/workspace/myFile/Output/17052023/D1017/No_damage_nuclei_24.tiff',
#  '/workspace/myFile/Output/17052023/A1016/No_damage_nuclei_162.tiff',
#  '/workspace/myFile/Output/17052023/A0413/No_damage_nuclei_488.tiff',
#  '/workspace/myFile/Output/17052023/B1101/No_damage_nuclei_691.tiff',
#  '/workspace/myFile/Output/17052023/B1003/No_damage_nuclei_119.tiff',
#  '/workspace/myFile/Output/17052023/A0513/No_damage_nuclei_1217.tiff',
#  '/workspace/myFile/Output/17052023/C1013/No_damage_nuclei_319.tiff',
#  '/workspace/myFile/Output/17052023/A0613/No_damage_nuclei_488.tiff',
#  '/workspace/myFile/Output/17052023/C0411/No_damage_nuclei_29.tiff',
#  '/workspace/myFile/Output/17052023/A0518/No_damage_nuclei_718.tiff',
#  '/workspace/myFile/Output/17052023/F0407/No_damage_nuclei_41.tiff',
#  '/workspace/myFile/Output/17052023/E1213/No_damage_nuclei_325.tiff',
#  '/workspace/myFile/Output/17052023/A1125/No_damage_nuclei_103.tiff',
#  '/workspace/myFile/Output/17052023/A1207/No_damage_nuclei_14.tiff',
#  '/workspace/myFile/Output/17052023/E1105/No_damage_nuclei_27.tiff',
#  '/workspace/myFile/Output/17052023/C0408/No_damage_nuclei_3.tiff',
#  '/workspace/myFile/Output/17052023/D1212/No_damage_nuclei_121.tiff',
#  '/workspace/myFile/Output/17052023/A0620/No_damage_nuclei_154.tiff',
#  '/workspace/myFile/Output/17052023/E0508/No_damage_nuclei_42.tiff',
#  '/workspace/myFile/Output/17052023/E1118/No_damage_nuclei_84.tiff',
#  '/workspace/myFile/Output/17052023/A1002/No_damage_nuclei_177.tiff',
#  '/workspace/myFile/Output/17052023/F0619/No_damage_nuclei_85.tiff',
#  '/workspace/myFile/Output/17052023/A1218/No_damage_nuclei_195.tiff',
#  '/workspace/myFile/Output/17052023/A0415/No_damage_nuclei_142.tiff',
#  '/workspace/myFile/Output/17052023/B1212/No_damage_nuclei_217.tiff',
#  '/workspace/myFile/Output/17052023/A0509/No_damage_nuclei_655.tiff',
#  '/workspace/myFile/Output/17052023/C0419/No_damage_nuclei_31.tiff',
#  '/workspace/myFile/Output/17052023/D0418/No_damage_nuclei_7.tiff',
#  '/workspace/myFile/Output/17052023/D0417/No_damage_nuclei_16.tiff',
#  '/workspace/myFile/Output/17052023/E0418/No_damage_nuclei_30.tiff',
#  '/workspace/myFile/Output/17052023/F1116/No_damage_nuclei_28.tiff',
#  '/workspace/myFile/Output/17052023/A0615/No_damage_nuclei_146.tiff',
#  '/workspace/myFile/Output/17052023/A0408/No_damage_nuclei_1123.tiff',
#  '/workspace/myFile/Output/17052023/A1207/No_damage_nuclei_57.tiff',
#  '/workspace/myFile/Output/17052023/A0610/No_damage_nuclei_250.tiff',
#  '/workspace/myFile/Output/17052023/A1217/No_damage_nuclei_68.tiff',
#  '/workspace/myFile/Output/17052023/F0413/No_damage_nuclei_309.tiff',
#  '/workspace/myFile/Output/17052023/B0501/No_damage_nuclei_4.tiff',
#  '/workspace/myFile/Output/17052023/E1103/No_damage_nuclei_204.tiff',
#  '/workspace/myFile/Output/17052023/A1009/No_damage_nuclei_115.tiff',
#  '/workspace/myFile/Output/17052023/C1113/No_damage_nuclei_35.tiff',
#  '/workspace/myFile/Output/17052023/B1112/No_damage_nuclei_123.tiff',
#  '/workspace/myFile/Output/17052023/A1112/No_damage_nuclei_502.tiff',
#  '/workspace/myFile/Output/17052023/A1018/No_damage_nuclei_444.tiff',
#  '/workspace/myFile/Output/17052023/A1113/No_damage_nuclei_394.tiff',
#  '/workspace/myFile/Output/17052023/E0414/No_damage_nuclei_56.tiff',
#  '/workspace/myFile/Output/17052023/B1101/No_damage_nuclei_416.tiff',
#  '/workspace/myFile/Output/17052023/A1212/No_damage_nuclei_288.tiff',
#  '/workspace/myFile/Output/17052023/A0409/No_damage_nuclei_241.tiff',
#  '/workspace/myFile/Output/17052023/E1024/No_damage_nuclei_28.tiff',
#  '/workspace/myFile/Output/17052023/A0413/No_damage_nuclei_103.tiff',
#  '/workspace/myFile/Output/17052023/F1108/No_damage_nuclei_39.tiff',
#  '/workspace/myFile/Output/17052023/A1211/No_damage_nuclei_233.tiff',
#  '/workspace/myFile/Output/17052023/F1108/No_damage_nuclei_269.tiff',
#  '/workspace/myFile/Output/17052023/B1101/No_damage_nuclei_375.tiff',
#  '/workspace/myFile/Output/17052023/D1212/No_damage_nuclei_102.tiff',
#  '/workspace/myFile/Output/17052023/F0525/No_damage_nuclei_42.tiff',
#  '/workspace/myFile/Output/17052023/A0523/No_damage_nuclei_393.tiff',
#  '/workspace/myFile/Output/17052023/A1008/No_damage_nuclei_441.tiff',
#  '/workspace/myFile/Output/17052023/A1123/No_damage_nuclei_336.tiff',
#  '/workspace/myFile/Output/17052023/C1104/No_damage_nuclei_131.tiff',
#  '/workspace/myFile/Output/17052023/F0525/No_damage_nuclei_19.tiff',
#  '/workspace/myFile/Output/17052023/A0617/No_damage_nuclei_286.tiff',
#  '/workspace/myFile/Output/17052023/D0408/No_damage_nuclei_15.tiff',
#  '/workspace/myFile/Output/17052023/C0605/No_damage_nuclei_56.tiff',
#  '/workspace/myFile/Output/17052023/F0408/No_damage_nuclei_140.tiff',
#  '/workspace/myFile/Output/17052023/F1112/No_damage_nuclei_308.tiff',
#  '/workspace/myFile/Output/17052023/C1220/No_damage_nuclei_14.tiff',
#  '/workspace/myFile/Output/17052023/F0608/No_damage_nuclei_271.tiff',
#  '/workspace/myFile/Output/17052023/C0403/No_damage_nuclei_126.tiff',
#  '/workspace/myFile/Output/17052023/F0424/No_damage_nuclei_55.tiff',
#  '/workspace/myFile/Output/17052023/F1206/No_damage_nuclei_104.tiff',
#  '/workspace/myFile/Output/17052023/E0602/No_damage_nuclei_2.tiff',
#  '/workspace/myFile/Output/17052023/F0625/No_damage_nuclei_103.tiff',
#  '/workspace/myFile/Output/17052023/E1017/No_damage_nuclei_120.tiff',
#  '/workspace/myFile/Output/17052023/A0510/No_damage_nuclei_292.tiff',
#  '/workspace/myFile/Output/17052023/E1205/No_damage_nuclei_46.tiff',
#  '/workspace/myFile/Output/17052023/C0513/No_damage_nuclei_125.tiff',
#  '/workspace/myFile/Output/17052023/B0613/No_damage_nuclei_14.tiff',
#  '/workspace/myFile/Output/17052023/A1009/No_damage_nuclei_1.tiff',
#  '/workspace/myFile/Output/17052023/A0523/No_damage_nuclei_187.tiff',
#  '/workspace/myFile/Output/17052023/D0615/No_damage_nuclei_11.tiff',
#  '/workspace/myFile/Output/17052023/A1125/No_damage_nuclei_119.tiff',
#  '/workspace/myFile/Output/17052023/B1103/No_damage_nuclei_130.tiff',
#  '/workspace/myFile/Output/17052023/A0607/No_damage_nuclei_735.tiff',
#  '/workspace/myFile/Output/17052023/B0402/No_damage_nuclei_30.tiff',
#  '/workspace/myFile/Output/17052023/E1212/No_damage_nuclei_11.tiff',
#  '/workspace/myFile/Output/17052023/F0620/No_damage_nuclei_71.tiff',
#  '/workspace/myFile/Output/17052023/A0408/No_damage_nuclei_360.tiff',
#  '/workspace/myFile/Output/17052023/E0413/No_damage_nuclei_267.tiff',
#  '/workspace/myFile/Output/17052023/E0623/No_damage_nuclei_45.tiff',
#  '/workspace/myFile/Output/17052023/B1004/No_damage_nuclei_6.tiff',
#  '/workspace/myFile/Output/17052023/A1117/No_damage_nuclei_24.tiff',
#  '/workspace/myFile/Output/17052023/D0614/No_damage_nuclei_71.tiff',
#  '/workspace/myFile/Output/17052023/F1102/No_damage_nuclei_3.tiff',
#  '/workspace/myFile/Output/17052023/A0518/No_damage_nuclei_285.tiff',
#  '/workspace/myFile/Output/17052023/B1101/No_damage_nuclei_55.tiff',
#  '/workspace/myFile/Output/17052023/A0424/No_damage_nuclei_469.tiff',
#  '/workspace/myFile/Output/17052023/E1212/No_damage_nuclei_113.tiff',
#  '/workspace/myFile/Output/17052023/A1213/No_damage_nuclei_633.tiff',
#  '/workspace/myFile/Output/17052023/A1222/No_damage_nuclei_296.tiff',
#  '/workspace/myFile/Output/17052023/E0408/No_damage_nuclei_133.tiff',
#  '/workspace/myFile/Output/17052023/A0614/No_damage_nuclei_217.tiff',
#  '/workspace/myFile/Output/17052023/A1218/No_damage_nuclei_11.tiff',
#  '/workspace/myFile/Output/17052023/F0523/No_damage_nuclei_46.tiff',
#  '/workspace/myFile/Output/17052023/C0620/No_damage_nuclei_96.tiff',
#  '/workspace/myFile/Output/17052023/A1007/No_damage_nuclei_417.tiff',
#  '/workspace/myFile/Output/17052023/E1207/No_damage_nuclei_45.tiff',
#  '/workspace/myFile/Output/17052023/F0407/No_damage_nuclei_69.tiff',
#  '/workspace/myFile/Output/17052023/F0407/No_damage_nuclei_137.tiff',
#  '/workspace/myFile/Output/17052023/F0408/No_damage_nuclei_549.tiff',
#  '/workspace/myFile/Output/17052023/B0413/No_damage_nuclei_197.tiff',
#  '/workspace/myFile/Output/17052023/E1114/No_damage_nuclei_19.tiff',
#  '/workspace/myFile/Output/17052023/C1115/No_damage_nuclei_37.tiff',
#  '/workspace/myFile/Output/17052023/C1205/No_damage_nuclei_19.tiff',
#  '/workspace/myFile/Output/17052023/E0413/No_damage_nuclei_125.tiff',
#  '/workspace/myFile/Output/17052023/F0614/No_damage_nuclei_62.tiff',
#  '/workspace/myFile/Output/17052023/A0413/No_damage_nuclei_302.tiff',
#  '/workspace/myFile/Output/17052023/A1011/No_damage_nuclei_28.tiff',
#  '/workspace/myFile/Output/17052023/A0522/No_damage_nuclei_121.tiff',
#  '/workspace/myFile/Output/17052023/A0408/No_damage_nuclei_71.tiff',
#  '/workspace/myFile/Output/17052023/A1111/No_damage_nuclei_279.tiff',
#  '/workspace/myFile/Output/17052023/C0605/No_damage_nuclei_81.tiff',
#  '/workspace/myFile/Output/17052023/E1020/No_damage_nuclei_2.tiff',
#  '/workspace/myFile/Output/17052023/A0408/No_damage_nuclei_1001.tiff',
#  '/workspace/myFile/Output/17052023/B1215/No_damage_nuclei_69.tiff',
#  '/workspace/myFile/Output/17052023/A0510/No_damage_nuclei_91.tiff',
#  '/workspace/myFile/Output/17052023/E1222/No_damage_nuclei_14.tiff',
#  '/workspace/myFile/Output/17052023/F0608/No_damage_nuclei_43.tiff',
#  '/workspace/myFile/Output/17052023/A1118/No_damage_nuclei_192.tiff',
#  '/workspace/myFile/Output/17052023/E0605/No_damage_nuclei_22.tiff',
#  '/workspace/myFile/Output/17052023/A0513/No_damage_nuclei_91.tiff',
#  '/workspace/myFile/Output/17052023/F0508/No_damage_nuclei_54.tiff',
#  '/workspace/myFile/Output/17052023/A1010/No_damage_nuclei_125.tiff',
#  '/workspace/myFile/Output/17052023/A1114/No_damage_nuclei_138.tiff',
#  '/workspace/myFile/Output/17052023/E1211/No_damage_nuclei_49.tiff',
#  '/workspace/myFile/Output/17052023/A1113/No_damage_nuclei_86.tiff',
#  '/workspace/myFile/Output/17052023/E0422/No_damage_nuclei_2.tiff',
#  '/workspace/myFile/Output/17052023/F1213/No_damage_nuclei_186.tiff',
#  '/workspace/myFile/Output/17052023/D1012/No_damage_nuclei_31.tiff',
#  '/workspace/myFile/Output/17052023/A1021/No_damage_nuclei_79.tiff',
#  '/workspace/myFile/Output/17052023/A1118/No_damage_nuclei_350.tiff',
#  '/workspace/myFile/Output/17052023/C1011/No_damage_nuclei_112.tiff',
#  '/workspace/myFile/Output/17052023/E0503/No_damage_nuclei_85.tiff',
#  '/workspace/myFile/Output/17052023/A1206/No_damage_nuclei_73.tiff',
#  '/workspace/myFile/Output/17052023/E0615/No_damage_nuclei_3.tiff',
#  '/workspace/myFile/Output/17052023/C0616/No_damage_nuclei_60.tiff',
#  '/workspace/myFile/Output/17052023/B1020/No_damage_nuclei_52.tiff',
#  '/workspace/myFile/Output/17052023/B1101/No_damage_nuclei_2403.tiff',
#  '/workspace/myFile/Output/17052023/A0520/No_damage_nuclei_68.tiff',
#  '/workspace/myFile/Output/17052023/B1119/No_damage_nuclei_25.tiff',
#  '/workspace/myFile/Output/17052023/B1020/No_damage_nuclei_56.tiff',
#  '/workspace/myFile/Output/17052023/B1109/No_damage_nuclei_36.tiff',
#  '/workspace/myFile/Output/17052023/A1114/No_damage_nuclei_376.tiff',
#  '/workspace/myFile/Output/17052023/B0614/No_damage_nuclei_66.tiff',
#  '/workspace/myFile/Output/17052023/B1101/No_damage_nuclei_166.tiff',
#  '/workspace/myFile/Output/17052023/B1101/No_damage_nuclei_805.tiff',
#  '/workspace/myFile/Output/17052023/F0507/No_damage_nuclei_271.tiff',
#  '/workspace/myFile/Output/17052023/A1018/No_damage_nuclei_316.tiff',
#  '/workspace/myFile/Output/17052023/A1125/No_damage_nuclei_224.tiff',
#  '/workspace/myFile/Output/17052023/F1007/No_damage_nuclei_24.tiff',
#  '/workspace/myFile/Output/17052023/A1013/No_damage_nuclei_324.tiff',
#  '/workspace/myFile/Output/17052023/F1108/No_damage_nuclei_74.tiff',
#  '/workspace/myFile/Output/17052023/C0503/No_damage_nuclei_74.tiff',
#  '/workspace/myFile/Output/17052023/A1019/No_damage_nuclei_110.tiff',
#  '/workspace/myFile/Output/17052023/A0524/No_damage_nuclei_472.tiff',
#  '/workspace/myFile/Output/17052023/B1101/No_damage_nuclei_30.tiff',
#  '/workspace/myFile/Output/17052023/C0417/No_damage_nuclei_12.tiff',
#  '/workspace/myFile/Output/17052023/A0523/No_damage_nuclei_114.tiff',
#  '/workspace/myFile/Output/17052023/A1212/No_damage_nuclei_679.tiff',
#  '/workspace/myFile/Output/17052023/C1019/No_damage_nuclei_103.tiff',
#  '/workspace/myFile/Output/17052023/A1003/No_damage_nuclei_455.tiff',
#  '/workspace/myFile/Output/17052023/A0408/No_damage_nuclei_1072.tiff',
#  '/workspace/myFile/Output/17052023/F1009/No_damage_nuclei_4.tiff',
#  '/workspace/myFile/Output/17052023/A1104/No_damage_nuclei_99.tiff',
#  '/workspace/myFile/Output/17052023/A1214/No_damage_nuclei_177.tiff',
#  '/workspace/myFile/Output/17052023/A1218/No_damage_nuclei_57.tiff',
#  '/workspace/myFile/Output/17052023/E0517/No_damage_nuclei_153.tiff',
#  '/workspace/myFile/Output/17052023/A1118/No_damage_nuclei_487.tiff',
#  '/workspace/myFile/Output/17052023/C0411/No_damage_nuclei_1.tiff',
#  '/workspace/myFile/Output/17052023/B0512/No_damage_nuclei_72.tiff',
#  '/workspace/myFile/Output/17052023/C1208/No_damage_nuclei_23.tiff',
#  '/workspace/myFile/Output/17052023/F0610/No_damage_nuclei_27.tiff',
#  '/workspace/myFile/Output/17052023/C1013/No_damage_nuclei_371.tiff',
#  '/workspace/myFile/Output/17052023/A1212/No_damage_nuclei_101.tiff',
#  '/workspace/myFile/Output/17052023/A0407/No_damage_nuclei_79.tiff',
#  '/workspace/myFile/Output/17052023/E0518/No_damage_nuclei_157.tiff',
#  '/workspace/myFile/Output/17052023/B0405/No_damage_nuclei_46.tiff',
#  '/workspace/myFile/Output/17052023/A1204/No_damage_nuclei_140.tiff',
#  '/workspace/myFile/Output/17052023/C0624/No_damage_nuclei_58.tiff',
#  '/workspace/myFile/Output/17052023/A0404/No_damage_nuclei_218.tiff',
#  '/workspace/myFile/Output/17052023/B0424/No_damage_nuclei_22.tiff',
#  '/workspace/myFile/Output/17052023/A0515/No_damage_nuclei_4.tiff',
#  '/workspace/myFile/Output/17052023/E0413/No_damage_nuclei_66.tiff',
#  '/workspace/myFile/Output/17052023/E1205/No_damage_nuclei_51.tiff',
#  '/workspace/myFile/Output/17052023/B0423/No_damage_nuclei_66.tiff',
#  '/workspace/myFile/Output/17052023/A0517/No_damage_nuclei_252.tiff',
#  '/workspace/myFile/Output/17052023/A0407/No_damage_nuclei_38.tiff',
#  '/workspace/myFile/Output/17052023/F1212/No_damage_nuclei_107.tiff',
#  '/workspace/myFile/Output/17052023/D1011/No_damage_nuclei_32.tiff',
#  '/workspace/myFile/Output/17052023/E1103/No_damage_nuclei_311.tiff',
#  '/workspace/myFile/Output/17052023/A1209/No_damage_nuclei_309.tiff',
#  '/workspace/myFile/Output/17052023/E0524/No_damage_nuclei_8.tiff',
#  '/workspace/myFile/Output/17052023/A0602/No_damage_nuclei_284.tiff',
#  '/workspace/myFile/Output/17052023/A1017/No_damage_nuclei_584.tiff',
#  '/workspace/myFile/Output/17052023/C1114/No_damage_nuclei_137.tiff',
#  '/workspace/myFile/Output/17052023/D0508/No_damage_nuclei_86.tiff',
#  '/workspace/myFile/Output/17052023/F1206/No_damage_nuclei_125.tiff',
#  '/workspace/myFile/Output/17052023/E0501/No_damage_nuclei_41.tiff',
#  '/workspace/myFile/Output/17052023/E0625/No_damage_nuclei_39.tiff',
#  '/workspace/myFile/Output/17052023/A0424/No_damage_nuclei_175.tiff',
#  '/workspace/myFile/Output/17052023/B1213/No_damage_nuclei_28.tiff',
#  '/workspace/myFile/Output/17052023/A0518/No_damage_nuclei_687.tiff',
#  '/workspace/myFile/Output/17052023/C1212/No_damage_nuclei_180.tiff',
#  '/workspace/myFile/Output/17052023/A1008/No_damage_nuclei_358.tiff',
#  '/workspace/myFile/Output/17052023/F1213/No_damage_nuclei_203.tiff',
#  '/workspace/myFile/Output/17052023/A0512/No_damage_nuclei_497.tiff',
#  '/workspace/myFile/Output/17052023/A0612/No_damage_nuclei_108.tiff',
#  '/workspace/myFile/Output/17052023/A0418/No_damage_nuclei_293.tiff',
#  '/workspace/myFile/Output/17052023/C1112/No_damage_nuclei_45.tiff',
#  '/workspace/myFile/Output/17052023/E0413/No_damage_nuclei_269.tiff',
#  '/workspace/myFile/Output/17052023/E1124/No_damage_nuclei_89.tiff',
#  '/workspace/myFile/Output/17052023/F1109/No_damage_nuclei_112.tiff',
#  '/workspace/myFile/Output/17052023/F1114/No_damage_nuclei_32.tiff',
#  '/workspace/myFile/Output/17052023/C1012/No_damage_nuclei_58.tiff',
#  '/workspace/myFile/Output/17052023/F0521/No_damage_nuclei_16.tiff',
#  '/workspace/myFile/Output/17052023/A1115/No_damage_nuclei_189.tiff',
#  '/workspace/myFile/Output/17052023/F0413/No_damage_nuclei_85.tiff',
#  '/workspace/myFile/Output/17052023/A1208/No_damage_nuclei_125.tiff',
#  '/workspace/myFile/Output/17052023/E0413/No_damage_nuclei_67.tiff',
#  '/workspace/myFile/Output/17052023/F1013/No_damage_nuclei_396.tiff',
#  '/workspace/myFile/Output/17052023/F0507/No_damage_nuclei_155.tiff',
#  '/workspace/myFile/Output/17052023/E1108/No_damage_nuclei_283.tiff',
#  '/workspace/myFile/Output/17052023/C1105/No_damage_nuclei_57.tiff',
#  '/workspace/myFile/Output/17052023/A0408/No_damage_nuclei_143.tiff',
#  '/workspace/myFile/Output/17052023/A1008/No_damage_nuclei_273.tiff',
#  '/workspace/myFile/Output/17052023/E0609/No_damage_nuclei_86.tiff',
#  '/workspace/myFile/Output/17052023/C0616/No_damage_nuclei_6.tiff',
#  '/workspace/myFile/Output/17052023/A0524/No_damage_nuclei_224.tiff',
#  '/workspace/myFile/Output/17052023/A1018/No_damage_nuclei_270.tiff',
#  '/workspace/myFile/Output/17052023/E0613/No_damage_nuclei_158.tiff',
#  '/workspace/myFile/Output/17052023/F1114/No_damage_nuclei_28.tiff',
#  '/workspace/myFile/Output/17052023/B0613/No_damage_nuclei_140.tiff',
#  '/workspace/myFile/Output/17052023/A1125/No_damage_nuclei_209.tiff',
#  '/workspace/myFile/Output/17052023/A0410/No_damage_nuclei_50.tiff',
#  '/workspace/myFile/Output/17052023/A1208/No_damage_nuclei_176.tiff',
#  '/workspace/myFile/Output/17052023/E0509/No_damage_nuclei_83.tiff',
#  '/workspace/myFile/Output/17052023/A1114/No_damage_nuclei_223.tiff',
#  '/workspace/myFile/Output/17052023/A1120/No_damage_nuclei_330.tiff',
#  '/workspace/myFile/Output/17052023/A0610/No_damage_nuclei_240.tiff',
#  '/workspace/myFile/Output/17052023/A0408/No_damage_nuclei_141.tiff',
#  '/workspace/myFile/Output/17052023/F1117/No_damage_nuclei_6.tiff',
#  '/workspace/myFile/Output/17052023/E0417/No_damage_nuclei_71.tiff',
#  '/workspace/myFile/Output/17052023/A1023/No_damage_nuclei_135.tiff',
#  '/workspace/myFile/Output/17052023/F0511/No_damage_nuclei_22.tiff',
#  '/workspace/myFile/Output/17052023/A1202/No_damage_nuclei_106.tiff',
#  '/workspace/myFile/Output/17052023/A0512/No_damage_nuclei_558.tiff',
#  '/workspace/myFile/Output/17052023/F1109/No_damage_nuclei_82.tiff',
#  '/workspace/myFile/Output/17052023/E1220/No_damage_nuclei_77.tiff',
#  '/workspace/myFile/Output/17052023/A1109/No_damage_nuclei_414.tiff',
#  '/workspace/myFile/Output/17052023/E1014/No_damage_nuclei_98.tiff',
#  '/workspace/myFile/Output/17052023/A0523/No_damage_nuclei_429.tiff',
#  '/workspace/myFile/Output/17052023/A1023/No_damage_nuclei_400.tiff',
#  '/workspace/myFile/Output/17052023/B1112/No_damage_nuclei_72.tiff',
#  '/workspace/myFile/Output/17052023/C1021/No_damage_nuclei_80.tiff',
#  '/workspace/myFile/Output/17052023/A0403/No_damage_nuclei_230.tiff',
#  '/workspace/myFile/Output/17052023/A0619/No_damage_nuclei_81.tiff',
#  '/workspace/myFile/Output/17052023/B1218/No_damage_nuclei_64.tiff',
#  '/workspace/myFile/Output/17052023/B1025/No_damage_nuclei_6.tiff',
#  '/workspace/myFile/Output/17052023/E0524/No_damage_nuclei_79.tiff',
#  '/workspace/myFile/Output/17052023/C1217/No_damage_nuclei_68.tiff',
#  '/workspace/myFile/Output/17052023/A0505/No_damage_nuclei_170.tiff',
#  '/workspace/myFile/Output/17052023/A0607/No_damage_nuclei_503.tiff',
#  '/workspace/myFile/Output/17052023/F0507/No_damage_nuclei_143.tiff',
#  '/workspace/myFile/Output/17052023/F0414/No_damage_nuclei_139.tiff',
#  '/workspace/myFile/Output/17052023/E0625/No_damage_nuclei_59.tiff',
#  '/workspace/myFile/Output/17052023/A1118/No_damage_nuclei_30.tiff',
#  '/workspace/myFile/Output/17052023/A0409/No_damage_nuclei_306.tiff',
#  '/workspace/myFile/Output/17052023/A1003/No_damage_nuclei_144.tiff',
#  '/workspace/myFile/Output/17052023/F0412/No_damage_nuclei_141.tiff',
#  '/workspace/myFile/Output/17052023/F1208/No_damage_nuclei_186.tiff',
#  '/workspace/myFile/Output/17052023/A1222/No_damage_nuclei_50.tiff',
#  '/workspace/myFile/Output/17052023/B1005/No_damage_nuclei_31.tiff',
#  '/workspace/myFile/Output/17052023/F0625/No_damage_nuclei_36.tiff',
#  '/workspace/myFile/Output/17052023/B0418/No_damage_nuclei_146.tiff',
#  '/workspace/myFile/Output/17052023/A0418/No_damage_nuclei_54.tiff',
#  '/workspace/myFile/Output/17052023/B1002/No_damage_nuclei_75.tiff',
#  '/workspace/myFile/Output/17052023/A1013/No_damage_nuclei_11.tiff',
#  '/workspace/myFile/Output/17052023/A0505/No_damage_nuclei_55.tiff',
#  '/workspace/myFile/Output/17052023/E1207/No_damage_nuclei_96.tiff',
#  '/workspace/myFile/Output/17052023/B0407/No_damage_nuclei_94.tiff',
#  '/workspace/myFile/Output/17052023/D0413/No_damage_nuclei_103.tiff',
#  '/workspace/myFile/Output/17052023/F1208/No_damage_nuclei_153.tiff',
#  '/workspace/myFile/Output/17052023/F1107/No_damage_nuclei_212.tiff',
#  '/workspace/myFile/Output/17052023/A1214/No_damage_nuclei_343.tiff',
#  '/workspace/myFile/Output/17052023/A1123/No_damage_nuclei_152.tiff',
#  '/workspace/myFile/Output/17052023/B0509/No_damage_nuclei_73.tiff',
#  '/workspace/myFile/Output/17052023/C1220/No_damage_nuclei_66.tiff',
#  '/workspace/myFile/Output/17052023/C1217/No_damage_nuclei_36.tiff',
#  '/workspace/myFile/Output/17052023/E1011/No_damage_nuclei_47.tiff',
#  '/workspace/myFile/Output/17052023/D0517/No_damage_nuclei_16.tiff',
#  '/workspace/myFile/Output/17052023/A1018/No_damage_nuclei_538.tiff',
#  '/workspace/myFile/Output/17052023/A1012/No_damage_nuclei_289.tiff',
#  '/workspace/myFile/Output/17052023/F0407/No_damage_nuclei_136.tiff',
#  '/workspace/myFile/Output/17052023/C0613/No_damage_nuclei_1.tiff',
#  '/workspace/myFile/Output/17052023/A1222/No_damage_nuclei_323.tiff',
#  '/workspace/myFile/Output/17052023/A0617/No_damage_nuclei_42.tiff',
#  '/workspace/myFile/Output/17052023/E1013/No_damage_nuclei_47.tiff',
#  '/workspace/myFile/Output/17052023/C1207/No_damage_nuclei_172.tiff',
#  '/workspace/myFile/Output/17052023/A1203/No_damage_nuclei_130.tiff',
#  '/workspace/myFile/Output/17052023/A1203/No_damage_nuclei_611.tiff',
#  '/workspace/myFile/Output/17052023/C0422/No_damage_nuclei_86.tiff',
#  '/workspace/myFile/Output/17052023/D1105/No_damage_nuclei_12.tiff',
#  '/workspace/myFile/Output/17052023/C0510/No_damage_nuclei_70.tiff',
#  '/workspace/myFile/Output/17052023/E1017/No_damage_nuclei_244.tiff',
#  '/workspace/myFile/Output/17052023/F0625/No_damage_nuclei_123.tiff',
#  '/workspace/myFile/Output/17052023/E1018/No_damage_nuclei_190.tiff',
#  '/workspace/myFile/Output/17052023/A1206/No_damage_nuclei_194.tiff',
#  '/workspace/myFile/Output/17052023/C1113/No_damage_nuclei_116.tiff',
#  '/workspace/myFile/Output/17052023/F1125/No_damage_nuclei_57.tiff',
#  '/workspace/myFile/Output/17052023/C0403/No_damage_nuclei_66.tiff',
#  '/workspace/myFile/Output/17052023/A0402/No_damage_nuclei_3.tiff',
#  '/workspace/myFile/Output/17052023/B1118/No_damage_nuclei_76.tiff',
#  '/workspace/myFile/Output/17052023/A1117/No_damage_nuclei_19.tiff',
#  '/workspace/myFile/Output/17052023/B0614/No_damage_nuclei_26.tiff',
#  '/workspace/myFile/Output/17052023/A0424/No_damage_nuclei_127.tiff',
#  '/workspace/myFile/Output/17052023/E1213/No_damage_nuclei_181.tiff',
#  '/workspace/myFile/Output/17052023/D0408/No_damage_nuclei_63.tiff',
#  '/workspace/myFile/Output/17052023/A0624/No_damage_nuclei_433.tiff',
#  '/workspace/myFile/Output/17052023/E1209/No_damage_nuclei_29.tiff',
#  '/workspace/myFile/Output/17052023/F1105/No_damage_nuclei_60.tiff',
#  '/workspace/myFile/Output/17052023/C1117/No_damage_nuclei_66.tiff',
#  '/workspace/myFile/Output/17052023/F0608/No_damage_nuclei_236.tiff',
#  '/workspace/myFile/Output/17052023/F1113/No_damage_nuclei_263.tiff',
#  '/workspace/myFile/Output/17052023/A1016/No_damage_nuclei_63.tiff',
#  '/workspace/myFile/Output/17052023/E1212/No_damage_nuclei_184.tiff',
#  '/workspace/myFile/Output/17052023/B1204/No_damage_nuclei_59.tiff',
#  '/workspace/myFile/Output/17052023/F1208/No_damage_nuclei_57.tiff',
#  '/workspace/myFile/Output/17052023/B1101/No_damage_nuclei_2431.tiff',
#  '/workspace/myFile/Output/17052023/A0403/No_damage_nuclei_452.tiff',
#  '/workspace/myFile/Output/17052023/C1220/No_damage_nuclei_50.tiff',
#  '/workspace/myFile/Output/17052023/A1213/No_damage_nuclei_382.tiff',
#  '/workspace/myFile/Output/17052023/F0416/No_damage_nuclei_12.tiff',
#  '/workspace/myFile/Output/17052023/A0613/No_damage_nuclei_604.tiff',
#  '/workspace/myFile/Output/17052023/F1013/No_damage_nuclei_156.tiff',
#  '/workspace/myFile/Output/17052023/E0602/No_damage_nuclei_51.tiff',
#  '/workspace/myFile/Output/17052023/B0614/No_damage_nuclei_60.tiff',
#  '/workspace/myFile/Output/17052023/A0423/No_damage_nuclei_146.tiff',
#  '/workspace/myFile/Output/17052023/C0512/No_damage_nuclei_152.tiff',
#  '/workspace/myFile/Output/17052023/F1117/No_damage_nuclei_58.tiff',
#  '/workspace/myFile/Output/17052023/F0521/No_damage_nuclei_45.tiff',
#  '/workspace/myFile/Output/17052023/E0522/No_damage_nuclei_73.tiff',
#  '/workspace/myFile/Output/17052023/D1008/No_damage_nuclei_111.tiff',
#  '/workspace/myFile/Output/17052023/C1210/No_damage_nuclei_15.tiff',
#  '/workspace/myFile/Output/17052023/F0413/No_damage_nuclei_552.tiff',
#  '/workspace/myFile/Output/17052023/C1117/No_damage_nuclei_11.tiff',
#  '/workspace/myFile/Output/17052023/B0409/No_damage_nuclei_6.tiff',
#  '/workspace/myFile/Output/17052023/E1115/No_damage_nuclei_52.tiff',
#  '/workspace/myFile/Output/17052023/A0423/No_damage_nuclei_666.tiff',
#  '/workspace/myFile/Output/17052023/C1024/No_damage_nuclei_31.tiff',
#  '/workspace/myFile/Output/17052023/E1017/No_damage_nuclei_61.tiff',
#  '/workspace/myFile/Output/17052023/F0625/No_damage_nuclei_163.tiff',
#  '/workspace/myFile/Output/17052023/E0613/No_damage_nuclei_2.tiff',
#  '/workspace/myFile/Output/17052023/A1211/No_damage_nuclei_238.tiff',
#  '/workspace/myFile/Output/17052023/B1116/No_damage_nuclei_39.tiff',
#  '/workspace/myFile/Output/17052023/A0612/No_damage_nuclei_327.tiff',
#  '/workspace/myFile/Output/17052023/B0513/No_damage_nuclei_87.tiff',
#  '/workspace/myFile/Output/17052023/A1209/No_damage_nuclei_288.tiff',
#  '/workspace/myFile/Output/17052023/B0610/No_damage_nuclei_78.tiff',
#  '/workspace/myFile/Output/17052023/B1111/No_damage_nuclei_1.tiff',
#  '/workspace/myFile/Output/17052023/A0519/No_damage_nuclei_1.tiff',
#  '/workspace/myFile/Output/17052023/E1017/No_damage_nuclei_248.tiff',
#  '/workspace/myFile/Output/17052023/A0424/No_damage_nuclei_310.tiff',
#  '/workspace/myFile/Output/17052023/A1223/No_damage_nuclei_300.tiff',
#  '/workspace/myFile/Output/17052023/B0513/No_damage_nuclei_121.tiff',
#  '/workspace/myFile/Output/17052023/A1120/No_damage_nuclei_217.tiff',
#  '/workspace/myFile/Output/17052023/C1013/No_damage_nuclei_43.tiff',
#  '/workspace/myFile/Output/17052023/C1114/No_damage_nuclei_87.tiff',
#  '/workspace/myFile/Output/17052023/E1213/No_damage_nuclei_305.tiff',
#  '/workspace/myFile/Output/17052023/E1016/No_damage_nuclei_136.tiff',
#  '/workspace/myFile/Output/17052023/B0408/No_damage_nuclei_79.tiff',
#  '/workspace/myFile/Output/17052023/D1017/No_damage_nuclei_27.tiff',
#  '/workspace/myFile/Output/17052023/A0402/No_damage_nuclei_115.tiff',
#  '/workspace/myFile/Output/17052023/A0407/No_damage_nuclei_17.tiff',
#  '/workspace/myFile/Output/17052023/B1101/No_damage_nuclei_631.tiff',
#  '/workspace/myFile/Output/17052023/A0510/No_damage_nuclei_78.tiff',
#  '/workspace/myFile/Output/17052023/A0412/No_damage_nuclei_72.tiff',
#  '/workspace/myFile/Output/17052023/A1125/No_damage_nuclei_109.tiff',
#  '/workspace/myFile/Output/17052023/A0624/No_damage_nuclei_286.tiff',
#  '/workspace/myFile/Output/17052023/D0418/No_damage_nuclei_39.tiff',
#  '/workspace/myFile/Output/17052023/A0620/No_damage_nuclei_51.tiff',
#  '/workspace/myFile/Output/17052023/C0403/No_damage_nuclei_47.tiff',
#  '/workspace/myFile/Output/17052023/F0624/No_damage_nuclei_98.tiff',
#  '/workspace/myFile/Output/17052023/D1109/No_damage_nuclei_1.tiff',
#  '/workspace/myFile/Output/17052023/F1209/No_damage_nuclei_64.tiff',
#  '/workspace/myFile/Output/17052023/F1112/No_damage_nuclei_176.tiff',
#  '/workspace/myFile/Output/17052023/F1117/No_damage_nuclei_156.tiff',
#  '/workspace/myFile/Output/17052023/E1003/No_damage_nuclei_163.tiff',
#  '/workspace/myFile/Output/17052023/A0523/No_damage_nuclei_368.tiff',
#  '/workspace/myFile/Output/17052023/A1213/No_damage_nuclei_187.tiff',
#  '/workspace/myFile/Output/17052023/F1203/No_damage_nuclei_73.tiff',
#  '/workspace/myFile/Output/17052023/E0507/No_damage_nuclei_48.tiff',
#  '/workspace/myFile/Output/17052023/C1003/No_damage_nuclei_182.tiff',
#  '/workspace/myFile/Output/17052023/E0408/No_damage_nuclei_278.tiff',
#  '/workspace/myFile/Output/17052023/D1104/No_damage_nuclei_5.tiff',
#  '/workspace/myFile/Output/17052023/B1005/No_damage_nuclei_70.tiff',
#  '/workspace/myFile/Output/17052023/C1012/No_damage_nuclei_72.tiff',
#  '/workspace/myFile/Output/17052023/B0612/No_damage_nuclei_107.tiff',
#  '/workspace/myFile/Output/17052023/C1111/No_damage_nuclei_20.tiff',
#  '/workspace/myFile/Output/17052023/D0620/No_damage_nuclei_40.tiff',
#  '/workspace/myFile/Output/17052023/F1122/No_damage_nuclei_15.tiff',
#  '/workspace/myFile/Output/17052023/A1013/No_damage_nuclei_722.tiff',
#  '/workspace/myFile/Output/17052023/B1101/No_damage_nuclei_209.tiff',
#  '/workspace/myFile/Output/17052023/E0425/No_damage_nuclei_67.tiff',
#  '/workspace/myFile/Output/17052023/F0408/No_damage_nuclei_317.tiff',
#  '/workspace/myFile/Output/17052023/D1111/No_damage_nuclei_71.tiff',
#  '/workspace/myFile/Output/17052023/D1012/No_damage_nuclei_132.tiff',
#  '/workspace/myFile/Output/17052023/D0409/No_damage_nuclei_8.tiff',
#  '/workspace/myFile/Output/17052023/E1008/No_damage_nuclei_235.tiff',
#  '/workspace/myFile/Output/17052023/A0404/No_damage_nuclei_75.tiff',
#  '/workspace/myFile/Output/17052023/F1207/No_damage_nuclei_103.tiff',
#  '/workspace/myFile/Output/17052023/E0417/No_damage_nuclei_73.tiff',
#  '/workspace/myFile/Output/17052023/B1224/No_damage_nuclei_83.tiff',
#  '/workspace/myFile/Output/17052023/A1008/No_damage_nuclei_559.tiff',
#  '/workspace/myFile/Output/17052023/D1025/No_damage_nuclei_3.tiff',
#  '/workspace/myFile/Output/17052023/E0403/No_damage_nuclei_90.tiff',
#  '/workspace/myFile/Output/17052023/F0608/No_damage_nuclei_273.tiff',
#  '/workspace/myFile/Output/17052023/A1013/No_damage_nuclei_816.tiff',
#  '/workspace/myFile/Output/17052023/E0421/No_damage_nuclei_24.tiff',
#  '/workspace/myFile/Output/17052023/A1022/No_damage_nuclei_489.tiff',
#  '/workspace/myFile/Output/17052023/C0417/No_damage_nuclei_7.tiff',
#  '/workspace/myFile/Output/17052023/F1008/No_damage_nuclei_301.tiff',
#  '/workspace/myFile/Output/17052023/A1213/No_damage_nuclei_343.tiff',
#  '/workspace/myFile/Output/17052023/D1013/No_damage_nuclei_78.tiff',
#  '/workspace/myFile/Output/17052023/A0403/No_damage_nuclei_562.tiff',
#  '/workspace/myFile/Output/17052023/D1008/No_damage_nuclei_65.tiff',
#  '/workspace/myFile/Output/17052023/D1220/No_damage_nuclei_32.tiff',
#  '/workspace/myFile/Output/17052023/C0513/No_damage_nuclei_162.tiff',
#  '/workspace/myFile/Output/17052023/A1207/No_damage_nuclei_108.tiff',
#  '/workspace/myFile/Output/17052023/F0511/No_damage_nuclei_56.tiff',
#  '/workspace/myFile/Output/17052023/A1017/No_damage_nuclei_588.tiff',
#  '/workspace/myFile/Output/17052023/B1012/No_damage_nuclei_24.tiff',
#  '/workspace/myFile/Output/17052023/A1118/No_damage_nuclei_414.tiff',
#  '/workspace/myFile/Output/17052023/F0508/No_damage_nuclei_76.tiff',
#  '/workspace/myFile/Output/17052023/A1117/No_damage_nuclei_45.tiff',
#  '/workspace/myFile/Output/17052023/A0519/No_damage_nuclei_528.tiff',
#  '/workspace/myFile/Output/17052023/E0417/No_damage_nuclei_69.tiff',
#  '/workspace/myFile/Output/17052023/B1018/No_damage_nuclei_5.tiff',
#  '/workspace/myFile/Output/17052023/E0612/No_damage_nuclei_82.tiff',
#  '/workspace/myFile/Output/17052023/A1211/No_damage_nuclei_58.tiff',
#  '/workspace/myFile/Output/17052023/E1207/No_damage_nuclei_51.tiff',
#  '/workspace/myFile/Output/17052023/A1211/No_damage_nuclei_290.tiff',
#  '/workspace/myFile/Output/17052023/D0421/No_damage_nuclei_9.tiff',
#  '/workspace/myFile/Output/17052023/B1101/No_damage_nuclei_1132.tiff',
#  '/workspace/myFile/Output/17052023/A0402/No_damage_nuclei_109.tiff',
#  '/workspace/myFile/Output/17052023/A0518/No_damage_nuclei_696.tiff',
#  '/workspace/myFile/Output/17052023/A1203/No_damage_nuclei_359.tiff',
#  '/workspace/myFile/Output/17052023/E1123/No_damage_nuclei_48.tiff',
#  '/workspace/myFile/Output/17052023/A0509/No_damage_nuclei_355.tiff',
#  '/workspace/myFile/Output/17052023/A0424/No_damage_nuclei_318.tiff',
#  '/workspace/myFile/Output/17052023/B1013/No_damage_nuclei_143.tiff',
#  '/workspace/myFile/Output/17052023/A1023/No_damage_nuclei_269.tiff',
#  '/workspace/myFile/Output/17052023/A1109/No_damage_nuclei_380.tiff',
#  '/workspace/myFile/Output/17052023/B1108/No_damage_nuclei_103.tiff',
#  '/workspace/myFile/Output/17052023/D1008/No_damage_nuclei_109.tiff',
#  '/workspace/myFile/Output/17052023/D1118/No_damage_nuclei_66.tiff',
#  '/workspace/myFile/Output/17052023/A0617/No_damage_nuclei_170.tiff',
#  '/workspace/myFile/Output/17052023/A0403/No_damage_nuclei_678.tiff',
#  '/workspace/myFile/Output/17052023/A1012/No_damage_nuclei_602.tiff',
#  '/workspace/myFile/Output/17052023/F0615/No_damage_nuclei_50.tiff',
#  '/workspace/myFile/Output/17052023/E0402/No_damage_nuclei_83.tiff',
#  '/workspace/myFile/Output/17052023/C0413/No_damage_nuclei_271.tiff',
#  '/workspace/myFile/Output/17052023/E0508/No_damage_nuclei_241.tiff',
#  '/workspace/myFile/Output/17052023/F1224/No_damage_nuclei_83.tiff',
#  '/workspace/myFile/Output/17052023/A1217/No_damage_nuclei_538.tiff',
#  '/workspace/myFile/Output/17052023/F0408/No_damage_nuclei_102.tiff',
#  '/workspace/myFile/Output/17052023/A1023/No_damage_nuclei_70.tiff',
#  '/workspace/myFile/Output/17052023/C0413/No_damage_nuclei_250.tiff',
#  '/workspace/myFile/Output/17052023/A0501/No_damage_nuclei_105.tiff',
#  '/workspace/myFile/Output/17052023/A1025/No_damage_nuclei_53.tiff',
#  '/workspace/myFile/Output/17052023/A0407/No_damage_nuclei_279.tiff',
#  '/workspace/myFile/Output/17052023/F1003/No_damage_nuclei_120.tiff',
#  '/workspace/myFile/Output/17052023/A1218/No_damage_nuclei_388.tiff',
#  '/workspace/myFile/Output/17052023/A0507/No_damage_nuclei_242.tiff',
#  '/workspace/myFile/Output/17052023/E1009/No_damage_nuclei_112.tiff',
#  '/workspace/myFile/Output/17052023/A1022/No_damage_nuclei_202.tiff',
#  '/workspace/myFile/Output/17052023/E1014/No_damage_nuclei_67.tiff',
#  '/workspace/myFile/Output/17052023/A0520/No_damage_nuclei_54.tiff',
#  '/workspace/myFile/Output/17052023/C0613/No_damage_nuclei_43.tiff',
#  '/workspace/myFile/Output/17052023/A1008/No_damage_nuclei_55.tiff',
#  '/workspace/myFile/Output/17052023/E1209/No_damage_nuclei_14.tiff',
#  '/workspace/myFile/Output/17052023/B1003/No_damage_nuclei_65.tiff',
#  '/workspace/myFile/Output/17052023/B1014/No_damage_nuclei_83.tiff',
#  '/workspace/myFile/Output/17052023/F1114/No_damage_nuclei_2.tiff',
#  '/workspace/myFile/Output/17052023/F1002/No_damage_nuclei_101.tiff',
#  '/workspace/myFile/Output/17052023/A1114/No_damage_nuclei_226.tiff',
#  '/workspace/myFile/Output/17052023/D0609/No_damage_nuclei_72.tiff',
#  '/workspace/myFile/Output/17052023/E1209/No_damage_nuclei_27.tiff',
#  '/workspace/myFile/Output/17052023/D1211/No_damage_nuclei_2.tiff',
#  '/workspace/myFile/Output/17052023/F0517/No_damage_nuclei_451.tiff',
#  '/workspace/myFile/Output/17052023/C0403/No_damage_nuclei_14.tiff',
#  '/workspace/myFile/Output/17052023/A1218/No_damage_nuclei_2.tiff',
#  '/workspace/myFile/Output/17052023/E1013/No_damage_nuclei_294.tiff',
#  '/workspace/myFile/Output/17052023/F1211/No_damage_nuclei_63.tiff',
#  '/workspace/myFile/Output/17052023/B1220/No_damage_nuclei_59.tiff',
#  '/workspace/myFile/Output/17052023/D1103/No_damage_nuclei_42.tiff',
#  '/workspace/myFile/Output/17052023/C1117/No_damage_nuclei_65.tiff',
#  '/workspace/myFile/Output/17052023/B1123/No_damage_nuclei_60.tiff',
#  '/workspace/myFile/Output/17052023/A1206/No_damage_nuclei_193.tiff',
#  '/workspace/myFile/Output/17052023/A1016/No_damage_nuclei_45.tiff',
#  '/workspace/myFile/Output/17052023/D1021/No_damage_nuclei_21.tiff',
#  '/workspace/myFile/Output/17052023/D1012/No_damage_nuclei_103.tiff',
#  '/workspace/myFile/Output/17052023/E1104/No_damage_nuclei_76.tiff',
#  '/workspace/myFile/Output/17052023/F0508/No_damage_nuclei_353.tiff',
#  '/workspace/myFile/Output/17052023/A1018/No_damage_nuclei_546.tiff',
#  '/workspace/myFile/Output/17052023/F1007/No_damage_nuclei_51.tiff',
#  '/workspace/myFile/Output/17052023/A1111/No_damage_nuclei_73.tiff',
#  '/workspace/myFile/Output/17052023/E1211/No_damage_nuclei_10.tiff',
#  '/workspace/myFile/Output/17052023/A1002/No_damage_nuclei_66.tiff',
#  '/workspace/myFile/Output/17052023/F1220/No_damage_nuclei_11.tiff',
#  '/workspace/myFile/Output/17052023/A0523/No_damage_nuclei_420.tiff',
#  '/workspace/myFile/Output/17052023/F1116/No_damage_nuclei_118.tiff',
#  '/workspace/myFile/Output/17052023/B1114/No_damage_nuclei_71.tiff',
#  '/workspace/myFile/Output/17052023/F0423/No_damage_nuclei_209.tiff',
#  '/workspace/myFile/Output/17052023/C1011/No_damage_nuclei_95.tiff',
#  '/workspace/myFile/Output/17052023/E1209/No_damage_nuclei_74.tiff',
#  '/workspace/myFile/Output/17052023/A0602/No_damage_nuclei_144.tiff',
#  '/workspace/myFile/Output/17052023/A1025/No_damage_nuclei_90.tiff',
#  '/workspace/myFile/Output/17052023/B1101/No_damage_nuclei_2635.tiff',
#  '/workspace/myFile/Output/17052023/F0616/No_damage_nuclei_28.tiff',
#  '/workspace/myFile/Output/17052023/A1022/No_damage_nuclei_557.tiff',
#  '/workspace/myFile/Output/17052023/A0524/No_damage_nuclei_638.tiff',
#  '/workspace/myFile/Output/17052023/A1002/No_damage_nuclei_249.tiff',
#  '/workspace/myFile/Output/17052023/B1207/No_damage_nuclei_17.tiff',
#  '/workspace/myFile/Output/17052023/F1103/No_damage_nuclei_173.tiff',
#  '/workspace/myFile/Output/17052023/C1022/No_damage_nuclei_10.tiff',
#  '/workspace/myFile/Output/17052023/E1112/No_damage_nuclei_15.tiff',
#  '/workspace/myFile/Output/17052023/A0409/No_damage_nuclei_51.tiff',
#  '/workspace/myFile/Output/17052023/C1113/No_damage_nuclei_174.tiff',
#  '/workspace/myFile/Output/17052023/A1022/No_damage_nuclei_499.tiff',
#  '/workspace/myFile/Output/17052023/E1016/No_damage_nuclei_127.tiff',
#  '/workspace/myFile/Output/17052023/A0520/No_damage_nuclei_246.tiff',
#  '/workspace/myFile/Output/17052023/A0518/No_damage_nuclei_509.tiff',
#  '/workspace/myFile/Output/17052023/A0522/No_damage_nuclei_352.tiff',
#  '/workspace/myFile/Output/17052023/A1217/No_damage_nuclei_96.tiff',
#  '/workspace/myFile/Output/17052023/A0408/No_damage_nuclei_920.tiff',
#  '/workspace/myFile/Output/17052023/E1214/No_damage_nuclei_60.tiff',
#  '/workspace/myFile/Output/17052023/B1108/No_damage_nuclei_94.tiff',
#  '/workspace/myFile/Output/17052023/F1117/No_damage_nuclei_5.tiff',
#  '/workspace/myFile/Output/17052023/B1101/No_damage_nuclei_997.tiff',
#  '/workspace/myFile/Output/17052023/A1217/No_damage_nuclei_250.tiff',
#  '/workspace/myFile/Output/17052023/A1023/No_damage_nuclei_483.tiff',
#  '/workspace/myFile/Output/17052023/A1118/No_damage_nuclei_529.tiff',
#  '/workspace/myFile/Output/17052023/A1008/No_damage_nuclei_504.tiff',
#  '/workspace/myFile/Output/17052023/F1202/No_damage_nuclei_17.tiff',
#  '/workspace/myFile/Output/17052023/C1216/No_damage_nuclei_43.tiff',
#  '/workspace/myFile/Output/17052023/A1008/No_damage_nuclei_751.tiff',
#  '/workspace/myFile/Output/17052023/A0607/No_damage_nuclei_313.tiff',
#  '/workspace/myFile/Output/17052023/A0413/No_damage_nuclei_239.tiff',
#  '/workspace/myFile/Output/17052023/A1216/No_damage_nuclei_138.tiff',
#  '/workspace/myFile/Output/17052023/A1008/No_damage_nuclei_443.tiff',
#  '/workspace/myFile/Output/17052023/A0507/No_damage_nuclei_230.tiff',
#  '/workspace/myFile/Output/17052023/B1110/No_damage_nuclei_53.tiff',
#  '/workspace/myFile/Output/17052023/A0408/No_damage_nuclei_532.tiff',
#  '/workspace/myFile/Output/17052023/D1214/No_damage_nuclei_23.tiff',
#  '/workspace/myFile/Output/17052023/F1125/No_damage_nuclei_83.tiff',
#  '/workspace/myFile/Output/17052023/A1003/No_damage_nuclei_567.tiff',
#  '/workspace/myFile/Output/17052023/A0522/No_damage_nuclei_218.tiff',
#  '/workspace/myFile/Output/17052023/E1017/No_damage_nuclei_23.tiff',
#  '/workspace/myFile/Output/17052023/A0404/No_damage_nuclei_158.tiff',
#  '/workspace/myFile/Output/17052023/B1209/No_damage_nuclei_117.tiff',
#  '/workspace/myFile/Output/17052023/A0408/No_damage_nuclei_1047.tiff',
#  '/workspace/myFile/Output/17052023/A0507/No_damage_nuclei_121.tiff',
#  '/workspace/myFile/Output/17052023/F1001/No_damage_nuclei_15.tiff',
#  '/workspace/myFile/Output/17052023/D0513/No_damage_nuclei_13.tiff',
#  '/workspace/myFile/Output/17052023/C0517/No_damage_nuclei_86.tiff',
#  '/workspace/myFile/Output/17052023/C0413/No_damage_nuclei_155.tiff',
#  '/workspace/myFile/Output/17052023/C1108/No_damage_nuclei_107.tiff',
#  '/workspace/myFile/Output/17052023/C0511/No_damage_nuclei_68.tiff',
#  '/workspace/myFile/Output/17052023/B0407/No_damage_nuclei_7.tiff',
#  '/workspace/myFile/Output/17052023/E1013/No_damage_nuclei_447.tiff',
#  '/workspace/myFile/Output/17052023/A1112/No_damage_nuclei_77.tiff',
#  '/workspace/myFile/Output/17052023/A1111/No_damage_nuclei_183.tiff',
#  '/workspace/myFile/Output/17052023/A0607/No_damage_nuclei_41.tiff',
#  '/workspace/myFile/Output/17052023/E0616/No_damage_nuclei_65.tiff',
#  '/workspace/myFile/Output/17052023/E1211/No_damage_nuclei_3.tiff',
#  '/workspace/myFile/Output/17052023/A1215/No_damage_nuclei_116.tiff',
#  '/workspace/myFile/Output/17052023/A0418/No_damage_nuclei_575.tiff',
#  '/workspace/myFile/Output/17052023/B0605/No_damage_nuclei_73.tiff',
#  '/workspace/myFile/Output/17052023/A0607/No_damage_nuclei_502.tiff',
#  '/workspace/myFile/Output/17052023/A0601/No_damage_nuclei_290.tiff',
#  '/workspace/myFile/Output/17052023/C1208/No_damage_nuclei_19.tiff',
#  '/workspace/myFile/Output/17052023/A0513/No_damage_nuclei_800.tiff',
#  '/workspace/myFile/Output/17052023/C0407/No_damage_nuclei_159.tiff',
#  '/workspace/myFile/Output/17052023/A1209/No_damage_nuclei_302.tiff',
#  '/workspace/myFile/Output/17052023/A1218/No_damage_nuclei_459.tiff',
#  '/workspace/myFile/Output/17052023/A0524/No_damage_nuclei_322.tiff',
#  '/workspace/myFile/Output/17052023/A1017/No_damage_nuclei_612.tiff',
#  '/workspace/myFile/Output/17052023/B0507/No_damage_nuclei_110.tiff',
#  '/workspace/myFile/Output/17052023/F1002/No_damage_nuclei_124.tiff',
#  '/workspace/myFile/Output/17052023/A0517/No_damage_nuclei_103.tiff',
#  '/workspace/myFile/Output/17052023/F0623/No_damage_nuclei_180.tiff',
#  '/workspace/myFile/Output/17052023/E1213/No_damage_nuclei_254.tiff',
#  '/workspace/myFile/Output/17052023/B1001/No_damage_nuclei_2.tiff',
#  '/workspace/myFile/Output/17052023/F1112/No_damage_nuclei_222.tiff',
#  '/workspace/myFile/Output/17052023/A0407/No_damage_nuclei_235.tiff',
#  '/workspace/myFile/Output/17052023/F1202/No_damage_nuclei_78.tiff',
#  '/workspace/myFile/Output/17052023/A1117/No_damage_nuclei_279.tiff',
#  '/workspace/myFile/Output/17052023/C1204/No_damage_nuclei_84.tiff',
#  '/workspace/myFile/Output/17052023/C1012/No_damage_nuclei_194.tiff',
#  '/workspace/myFile/Output/17052023/B0417/No_damage_nuclei_152.tiff',
#  '/workspace/myFile/Output/17052023/E0402/No_damage_nuclei_2.tiff',
#  '/workspace/myFile/Output/17052023/E1013/No_damage_nuclei_195.tiff',
#  '/workspace/myFile/Output/17052023/A0602/No_damage_nuclei_20.tiff',
#  '/workspace/myFile/Output/17052023/F0413/No_damage_nuclei_439.tiff',
#  '/workspace/myFile/Output/17052023/E0408/No_damage_nuclei_227.tiff',
#  '/workspace/myFile/Output/17052023/A1016/No_damage_nuclei_303.tiff',
#  '/workspace/myFile/Output/17052023/A0613/No_damage_nuclei_926.tiff',
#  '/workspace/myFile/Output/17052023/A1022/No_damage_nuclei_401.tiff',
#  '/workspace/myFile/Output/17052023/C1109/No_damage_nuclei_39.tiff',
#  '/workspace/myFile/Output/17052023/E0607/No_damage_nuclei_126.tiff',
#  '/workspace/myFile/Output/17052023/A1118/No_damage_nuclei_559.tiff',
#  '/workspace/myFile/Output/17052023/F1123/No_damage_nuclei_5.tiff',
#  '/workspace/myFile/Output/17052023/F0423/No_damage_nuclei_148.tiff',
#  '/workspace/myFile/Output/17052023/A1118/No_damage_nuclei_297.tiff',
#  '/workspace/myFile/Output/17052023/F0619/No_damage_nuclei_110.tiff',
#  '/workspace/myFile/Output/17052023/A1107/No_damage_nuclei_251.tiff',
#  '/workspace/myFile/Output/17052023/A1018/No_damage_nuclei_355.tiff',
#  '/workspace/myFile/Output/17052023/A0423/No_damage_nuclei_51.tiff',
#  '/workspace/myFile/Output/17052023/A1006/No_damage_nuclei_56.tiff',
#  '/workspace/myFile/Output/17052023/E1112/No_damage_nuclei_135.tiff',
#  '/workspace/myFile/Output/17052023/B1101/No_damage_nuclei_851.tiff',
#  '/workspace/myFile/Output/17052023/B0603/No_damage_nuclei_77.tiff',
#  '/workspace/myFile/Output/17052023/A1023/No_damage_nuclei_454.tiff',
#  '/workspace/myFile/Output/17052023/D1108/No_damage_nuclei_76.tiff',
#  '/workspace/myFile/Output/17052023/E1002/No_damage_nuclei_43.tiff',
#  '/workspace/myFile/Output/17052023/D0610/No_damage_nuclei_19.tiff',
#  '/workspace/myFile/Output/17052023/E1209/No_damage_nuclei_99.tiff',
#  '/workspace/myFile/Output/17052023/A0513/No_damage_nuclei_290.tiff',
#  '/workspace/myFile/Output/17052023/E0414/No_damage_nuclei_50.tiff',
#  '/workspace/myFile/Output/17052023/C1117/No_damage_nuclei_169.tiff',
#  '/workspace/myFile/Output/17052023/A0404/No_damage_nuclei_254.tiff',
#  '/workspace/myFile/Output/17052023/A1023/No_damage_nuclei_90.tiff',
#  '/workspace/myFile/Output/17052023/A0403/No_damage_nuclei_471.tiff',
#  '/workspace/myFile/Output/17052023/F0619/No_damage_nuclei_74.tiff',
#  '/workspace/myFile/Output/17052023/E0413/No_damage_nuclei_12.tiff',
#  '/workspace/myFile/Output/17052023/E0519/No_damage_nuclei_15.tiff',
#  '/workspace/myFile/Output/17052023/B0623/No_damage_nuclei_83.tiff',
#  '/workspace/myFile/Output/17052023/D0613/No_damage_nuclei_10.tiff',
#  '/workspace/myFile/Output/17052023/A0507/No_damage_nuclei_319.tiff',
#  '/workspace/myFile/Output/17052023/F0608/No_damage_nuclei_257.tiff',
#  '/workspace/myFile/Output/17052023/C1014/No_damage_nuclei_8.tiff',
#  '/workspace/myFile/Output/17052023/A1116/No_damage_nuclei_262.tiff',
#  '/workspace/myFile/Output/17052023/E1209/No_damage_nuclei_160.tiff',
#  '/workspace/myFile/Output/17052023/D1013/No_damage_nuclei_198.tiff',
#  '/workspace/myFile/Output/17052023/B0524/No_damage_nuclei_11.tiff',
#  '/workspace/myFile/Output/17052023/A0615/No_damage_nuclei_168.tiff',
#  '/workspace/myFile/Output/17052023/A0412/No_damage_nuclei_246.tiff',
#  '/workspace/myFile/Output/17052023/E1112/No_damage_nuclei_95.tiff',
#  '/workspace/myFile/Output/17052023/A0408/No_damage_nuclei_1126.tiff',
#  '/workspace/myFile/Output/17052023/A0402/No_damage_nuclei_19.tiff',
#  '/workspace/myFile/Output/17052023/A1112/No_damage_nuclei_243.tiff',
# ...
#  '/workspace/myFile/Output/17052023/B1101/No_damage_nuclei_1415.tiff',
#  '/workspace/myFile/Output/17052023/F0413/No_damage_nuclei_180.tiff',
#  '/workspace/myFile/Output/17052023/A1213/No_damage_nuclei_381.tiff',
#  '/workspace/myFile/Output/17052023/E1112/No_damage_nuclei_182.tiff',
#  '/workspace/myFile/Output/17052023/A1207/No_damage_nuclei_33.tiff',
#  '/workspace/myFile/Output/17052023/A0403/No_damage_nuclei_298.tiff',
#  '/workspace/myFile/Output/17052023/B1101/No_damage_nuclei_1507.tiff',
#  '/workspace/myFile/Output/17052023/E1215/No_damage_nuclei_3.tiff',
#  '/workspace/myFile/Output/17052023/F1114/No_damage_nuclei_90.tiff',
#  '/workspace/myFile/Output/17052023/F1212/No_damage_nuclei_128.tiff',
#  '/workspace/myFile/Output/17052023/A0601/No_damage_nuclei_45.tiff',
#  '/workspace/myFile/Output/17052023/A1013/No_damage_nuclei_97.tiff',
#  '/workspace/myFile/Output/17052023/A0501/No_damage_nuclei_89.tiff',
#  '/workspace/myFile/Output/17052023/E1207/No_damage_nuclei_81.tiff',
#  '/workspace/myFile/Output/17052023/E1208/No_damage_nuclei_250.tiff',
#  '/workspace/myFile/Output/17052023/A1214/No_damage_nuclei_141.tiff',
#  '/workspace/myFile/Output/17052023/F0512/No_damage_nuclei_63.tiff',
#  '/workspace/myFile/Output/17052023/B0417/No_damage_nuclei_77.tiff',
#  '/workspace/myFile/Output/17052023/A0507/No_damage_nuclei_628.tiff',
#  '/workspace/myFile/Output/17052023/F1113/No_damage_nuclei_172.tiff',
#  '/workspace/myFile/Output/17052023/A1102/No_damage_nuclei_52.tiff',
#  '/workspace/myFile/Output/17052023/F1012/No_damage_nuclei_176.tiff',
#  '/workspace/myFile/Output/17052023/A1007/No_damage_nuclei_428.tiff',
#  '/workspace/myFile/Output/17052023/A0505/No_damage_nuclei_14.tiff',
#  '/workspace/myFile/Output/17052023/F0417/No_damage_nuclei_176.tiff',
#  '/workspace/myFile/Output/17052023/A0407/No_damage_nuclei_371.tiff',
#  '/workspace/myFile/Output/17052023/C0413/No_damage_nuclei_281.tiff',
#  '/workspace/myFile/Output/17052023/F1117/No_damage_nuclei_13.tiff',
#  '/workspace/myFile/Output/17052023/F0618/No_damage_nuclei_104.tiff',
#  '/workspace/myFile/Output/17052023/A1115/No_damage_nuclei_46.tiff',
#  '/workspace/myFile/Output/17052023/E1017/No_damage_nuclei_201.tiff',
#  '/workspace/myFile/Output/17052023/E0503/No_damage_nuclei_65.tiff',
#  '/workspace/myFile/Output/17052023/A1113/No_damage_nuclei_162.tiff',
#  '/workspace/myFile/Output/17052023/A1008/No_damage_nuclei_18.tiff',
#  '/workspace/myFile/Output/17052023/C1111/No_damage_nuclei_12.tiff',
#  '/workspace/myFile/Output/17052023/F0623/No_damage_nuclei_66.tiff',
#  '/workspace/myFile/Output/17052023/A0520/No_damage_nuclei_191.tiff',
#  '/workspace/myFile/Output/17052023/A0413/No_damage_nuclei_621.tiff',
#  '/workspace/myFile/Output/17052023/A1018/No_damage_nuclei_630.tiff',
#  '/workspace/myFile/Output/17052023/C0413/No_damage_nuclei_23.tiff',
#  '/workspace/myFile/Output/17052023/C1015/No_damage_nuclei_42.tiff',
#  '/workspace/myFile/Output/17052023/A1212/No_damage_nuclei_316.tiff',
#  '/workspace/myFile/Output/17052023/E1105/No_damage_nuclei_32.tiff',
#  '/workspace/myFile/Output/17052023/A0606/No_damage_nuclei_428.tiff',
#  '/workspace/myFile/Output/17052023/F0623/No_damage_nuclei_198.tiff',
#  '/workspace/myFile/Output/17052023/B1101/No_damage_nuclei_1898.tiff',
#  '/workspace/myFile/Output/17052023/A0513/No_damage_nuclei_600.tiff',
#  '/workspace/myFile/Output/17052023/A0601/No_damage_nuclei_306.tiff',
#  '/workspace/myFile/Output/17052023/D0604/No_damage_nuclei_34.tiff',
#  '/workspace/myFile/Output/17052023/C0513/No_damage_nuclei_17.tiff',
#  '/workspace/myFile/Output/17052023/A0425/No_damage_nuclei_120.tiff',
#  '/workspace/myFile/Output/17052023/A1005/No_damage_nuclei_105.tiff',
#  '/workspace/myFile/Output/17052023/F0513/No_damage_nuclei_48.tiff',
#  '/workspace/myFile/Output/17052023/A1203/No_damage_nuclei_141.tiff',
#  '/workspace/myFile/Output/17052023/A0625/No_damage_nuclei_411.tiff',
#  '/workspace/myFile/Output/17052023/C0512/No_damage_nuclei_178.tiff',
#  '/workspace/myFile/Output/17052023/F1218/No_damage_nuclei_94.tiff',
#  '/workspace/myFile/Output/17052023/C0512/No_damage_nuclei_34.tiff',
#  '/workspace/myFile/Output/17052023/A1102/No_damage_nuclei_113.tiff',
#  '/workspace/myFile/Output/17052023/F0509/No_damage_nuclei_60.tiff',
#  '/workspace/myFile/Output/17052023/E1114/No_damage_nuclei_182.tiff',
#  '/workspace/myFile/Output/17052023/A0513/No_damage_nuclei_327.tiff',
#  '/workspace/myFile/Output/17052023/E0407/No_damage_nuclei_128.tiff',
#  '/workspace/myFile/Output/17052023/A1225/No_damage_nuclei_37.tiff',
#  '/workspace/myFile/Output/17052023/C0408/No_damage_nuclei_41.tiff',
#  '/workspace/myFile/Output/17052023/A1102/No_damage_nuclei_169.tiff',
#  '/workspace/myFile/Output/17052023/A0413/No_damage_nuclei_414.tiff',
#  '/workspace/myFile/Output/17052023/F1203/No_damage_nuclei_42.tiff',
#  '/workspace/myFile/Output/17052023/A0606/No_damage_nuclei_298.tiff',
#  '/workspace/myFile/Output/17052023/A1113/No_damage_nuclei_585.tiff',
#  '/workspace/myFile/Output/17052023/A1003/No_damage_nuclei_474.tiff',
#  '/workspace/myFile/Output/17052023/E1016/No_damage_nuclei_62.tiff',
#  '/workspace/myFile/Output/17052023/E0413/No_damage_nuclei_354.tiff',
#  '/workspace/myFile/Output/17052023/A1211/No_damage_nuclei_432.tiff',
#  '/workspace/myFile/Output/17052023/E0412/No_damage_nuclei_72.tiff',
#  '/workspace/myFile/Output/17052023/F0423/No_damage_nuclei_1.tiff',
#  '/workspace/myFile/Output/17052023/E0422/No_damage_nuclei_115.tiff',
#  '/workspace/myFile/Output/17052023/A1008/No_damage_nuclei_695.tiff',
#  '/workspace/myFile/Output/17052023/A1022/No_damage_nuclei_33.tiff',
#  '/workspace/myFile/Output/17052023/A0612/No_damage_nuclei_276.tiff',
#  '/workspace/myFile/Output/17052023/E1108/No_damage_nuclei_17.tiff',
#  '/workspace/myFile/Output/17052023/E0601/No_damage_nuclei_17.tiff',
#  '/workspace/myFile/Output/17052023/E1011/No_damage_nuclei_52.tiff',
#  '/workspace/myFile/Output/17052023/A1005/No_damage_nuclei_110.tiff',
#  '/workspace/myFile/Output/17052023/B1002/No_damage_nuclei_143.tiff',
#  '/workspace/myFile/Output/17052023/F1008/No_damage_nuclei_168.tiff',
#  '/workspace/myFile/Output/17052023/A0625/No_damage_nuclei_148.tiff',
#  '/workspace/myFile/Output/17052023/A1111/No_damage_nuclei_434.tiff',
#  '/workspace/myFile/Output/17052023/E1013/No_damage_nuclei_189.tiff',
#  '/workspace/myFile/Output/17052023/A1117/No_damage_nuclei_93.tiff',
#  '/workspace/myFile/Output/17052023/B0508/No_damage_nuclei_137.tiff',
#  '/workspace/myFile/Output/17052023/A0614/No_damage_nuclei_55.tiff',
#  '/workspace/myFile/Output/17052023/E0509/No_damage_nuclei_62.tiff',
#  '/workspace/myFile/Output/17052023/B0620/No_damage_nuclei_19.tiff',
#  '/workspace/myFile/Output/17052023/C1113/No_damage_nuclei_146.tiff',
#  '/workspace/myFile/Output/17052023/F1005/No_damage_nuclei_23.tiff',
#  '/workspace/myFile/Output/17052023/A1114/No_damage_nuclei_62.tiff',
#  '/workspace/myFile/Output/17052023/D0509/No_damage_nuclei_9.tiff',
#  '/workspace/myFile/Output/17052023/D1002/No_damage_nuclei_38.tiff',
#  '/workspace/myFile/Output/17052023/E1208/No_damage_nuclei_97.tiff',
#  '/workspace/myFile/Output/17052023/A0617/No_damage_nuclei_351.tiff',
#  '/workspace/myFile/Output/17052023/B0604/No_damage_nuclei_55.tiff',
#  '/workspace/myFile/Output/17052023/E0620/No_damage_nuclei_88.tiff',
#  '/workspace/myFile/Output/17052023/C1112/No_damage_nuclei_187.tiff',
#  '/workspace/myFile/Output/17052023/A0413/No_damage_nuclei_112.tiff',
#  '/workspace/myFile/Output/17052023/C1108/No_damage_nuclei_66.tiff',
#  '/workspace/myFile/Output/17052023/F1103/No_damage_nuclei_62.tiff',
#  '/workspace/myFile/Output/17052023/E1011/No_damage_nuclei_79.tiff',
#  '/workspace/myFile/Output/17052023/E1114/No_damage_nuclei_154.tiff',
#  '/workspace/myFile/Output/17052023/A1006/No_damage_nuclei_113.tiff',
#  '/workspace/myFile/Output/17052023/C1012/No_damage_nuclei_51.tiff',
#  '/workspace/myFile/Output/17052023/B1101/No_damage_nuclei_242.tiff',
#  '/workspace/myFile/Output/17052023/A1109/No_damage_nuclei_480.tiff',
#  '/workspace/myFile/Output/17052023/A1012/No_damage_nuclei_648.tiff',
#  '/workspace/myFile/Output/17052023/A0617/No_damage_nuclei_18.tiff',
#  '/workspace/myFile/Output/17052023/C1204/No_damage_nuclei_42.tiff',
#  '/workspace/myFile/Output/17052023/A0515/No_damage_nuclei_75.tiff',
#  '/workspace/myFile/Output/17052023/A1112/No_damage_nuclei_486.tiff',
#  '/workspace/myFile/Output/17052023/F1224/No_damage_nuclei_36.tiff',
#  '/workspace/myFile/Output/17052023/A1204/No_damage_nuclei_86.tiff',
#  '/workspace/myFile/Output/17052023/F0506/No_damage_nuclei_2.tiff',
#  '/workspace/myFile/Output/17052023/C1113/No_damage_nuclei_282.tiff',
#  '/workspace/myFile/Output/17052023/F0608/No_damage_nuclei_204.tiff',
#  '/workspace/myFile/Output/17052023/A1012/No_damage_nuclei_196.tiff',
#  '/workspace/myFile/Output/17052023/F1216/No_damage_nuclei_6.tiff',
#  '/workspace/myFile/Output/17052023/E1211/No_damage_nuclei_71.tiff',
#  '/workspace/myFile/Output/17052023/A1123/No_damage_nuclei_285.tiff',
#  '/workspace/myFile/Output/17052023/E1204/No_damage_nuclei_71.tiff',
#  '/workspace/myFile/Output/17052023/E1123/No_damage_nuclei_39.tiff',
#  '/workspace/myFile/Output/17052023/F0618/No_damage_nuclei_50.tiff',
#  '/workspace/myFile/Output/17052023/F1113/No_damage_nuclei_82.tiff',
#  '/workspace/myFile/Output/17052023/F0621/No_damage_nuclei_116.tiff',
#  '/workspace/myFile/Output/17052023/A0613/No_damage_nuclei_1072.tiff',
#  '/workspace/myFile/Output/17052023/F1112/No_damage_nuclei_307.tiff',
#  '/workspace/myFile/Output/17052023/D1114/No_damage_nuclei_81.tiff',
#  '/workspace/myFile/Output/17052023/A1008/No_damage_nuclei_634.tiff',
#  '/workspace/myFile/Output/17052023/A0425/No_damage_nuclei_217.tiff',
#  '/workspace/myFile/Output/17052023/A1019/No_damage_nuclei_1.tiff',
#  '/workspace/myFile/Output/17052023/E0618/No_damage_nuclei_175.tiff',
#  '/workspace/myFile/Output/17052023/A0413/No_damage_nuclei_552.tiff',
#  '/workspace/myFile/Output/17052023/A0408/No_damage_nuclei_644.tiff',
#  '/workspace/myFile/Output/17052023/C0418/No_damage_nuclei_101.tiff',
#  '/workspace/myFile/Output/17052023/A1123/No_damage_nuclei_11.tiff',
#  '/workspace/myFile/Output/17052023/E1103/No_damage_nuclei_149.tiff',
#  '/workspace/myFile/Output/17052023/A1112/No_damage_nuclei_374.tiff',
#  '/workspace/myFile/Output/17052023/F1215/No_damage_nuclei_7.tiff',
#  '/workspace/myFile/Output/17052023/A0418/No_damage_nuclei_98.tiff',
#  '/workspace/myFile/Output/17052023/A1212/No_damage_nuclei_499.tiff',
#  '/workspace/myFile/Output/17052023/E1222/No_damage_nuclei_159.tiff',
#  '/workspace/myFile/Output/17052023/B1121/No_damage_nuclei_91.tiff',
#  '/workspace/myFile/Output/17052023/A0408/No_damage_nuclei_424.tiff',
#  '/workspace/myFile/Output/17052023/F1206/No_damage_nuclei_80.tiff',
#  '/workspace/myFile/Output/17052023/B1101/No_damage_nuclei_1735.tiff',
#  '/workspace/myFile/Output/17052023/A0523/No_damage_nuclei_444.tiff',
#  '/workspace/myFile/Output/17052023/B1101/No_damage_nuclei_140.tiff',
#  '/workspace/myFile/Output/17052023/A1007/No_damage_nuclei_208.tiff',
#  '/workspace/myFile/Output/17052023/C0514/No_damage_nuclei_167.tiff',
#  '/workspace/myFile/Output/17052023/A0523/No_damage_nuclei_424.tiff',
#  '/workspace/myFile/Output/17052023/C0619/No_damage_nuclei_68.tiff',
#  '/workspace/myFile/Output/17052023/F1003/No_damage_nuclei_113.tiff',
#  '/workspace/myFile/Output/17052023/B0510/No_damage_nuclei_48.tiff',
#  '/workspace/myFile/Output/17052023/B1101/No_damage_nuclei_2649.tiff',
#  '/workspace/myFile/Output/17052023/E1119/No_damage_nuclei_119.tiff',
#  '/workspace/myFile/Output/17052023/D1117/No_damage_nuclei_45.tiff',
#  '/workspace/myFile/Output/17052023/E1220/No_damage_nuclei_59.tiff',
#  '/workspace/myFile/Output/17052023/C0512/No_damage_nuclei_220.tiff',
#  '/workspace/myFile/Output/17052023/B1109/No_damage_nuclei_136.tiff',
#  '/workspace/myFile/Output/17052023/E1104/No_damage_nuclei_58.tiff',
#  '/workspace/myFile/Output/17052023/E0610/No_damage_nuclei_34.tiff',
#  '/workspace/myFile/Output/17052023/A1211/No_damage_nuclei_355.tiff',
#  '/workspace/myFile/Output/17052023/C1116/No_damage_nuclei_138.tiff',
#  '/workspace/myFile/Output/17052023/E1013/No_damage_nuclei_2.tiff',
#  '/workspace/myFile/Output/17052023/F1116/No_damage_nuclei_44.tiff',
#  '/workspace/myFile/Output/17052023/A1107/No_damage_nuclei_85.tiff',
#  '/workspace/myFile/Output/17052023/F0610/No_damage_nuclei_99.tiff',
#  '/workspace/myFile/Output/17052023/A0604/No_damage_nuclei_180.tiff',
#  '/workspace/myFile/Output/17052023/A1003/No_damage_nuclei_318.tiff',
#  '/workspace/myFile/Output/17052023/D0617/No_damage_nuclei_5.tiff',
#  '/workspace/myFile/Output/17052023/C1207/No_damage_nuclei_85.tiff',
#  '/workspace/myFile/Output/17052023/F1205/No_damage_nuclei_19.tiff',
#  '/workspace/myFile/Output/17052023/C1108/No_damage_nuclei_23.tiff',
#  '/workspace/myFile/Output/17052023/A1008/No_damage_nuclei_102.tiff',
#  '/workspace/myFile/Output/17052023/B0413/No_damage_nuclei_44.tiff',
#  '/workspace/myFile/Output/17052023/A1215/No_damage_nuclei_27.tiff',
#  '/workspace/myFile/Output/17052023/F0507/No_damage_nuclei_16.tiff',
#  '/workspace/myFile/Output/17052023/A0402/No_damage_nuclei_91.tiff',
#  '/workspace/myFile/Output/17052023/F1215/No_damage_nuclei_72.tiff',
#  '/workspace/myFile/Output/17052023/A1208/No_damage_nuclei_63.tiff',
#  '/workspace/myFile/Output/17052023/A0420/No_damage_nuclei_236.tiff',
#  '/workspace/myFile/Output/17052023/E0613/No_damage_nuclei_44.tiff',
#  '/workspace/myFile/Output/17052023/F1003/No_damage_nuclei_144.tiff',
#  '/workspace/myFile/Output/17052023/A0517/No_damage_nuclei_448.tiff',
#  '/workspace/myFile/Output/17052023/F0607/No_damage_nuclei_163.tiff',
#  '/workspace/myFile/Output/17052023/F1115/No_damage_nuclei_34.tiff',
#  '/workspace/myFile/Output/17052023/F1121/No_damage_nuclei_30.tiff',
#  '/workspace/myFile/Output/17052023/E0521/No_damage_nuclei_38.tiff',
#  '/workspace/myFile/Output/17052023/A1120/No_damage_nuclei_294.tiff',
#  '/workspace/myFile/Output/17052023/E0608/No_damage_nuclei_54.tiff',
#  '/workspace/myFile/Output/17052023/A1206/No_damage_nuclei_140.tiff',
#  '/workspace/myFile/Output/17052023/A0417/No_damage_nuclei_227.tiff',
#  '/workspace/myFile/Output/17052023/B0602/No_damage_nuclei_19.tiff',
#  '/workspace/myFile/Output/17052023/B1221/No_damage_nuclei_27.tiff',
#  '/workspace/myFile/Output/17052023/A0518/No_damage_nuclei_726.tiff',
#  '/workspace/myFile/Output/17052023/A0523/No_damage_nuclei_367.tiff',
#  '/workspace/myFile/Output/17052023/A1023/No_damage_nuclei_507.tiff',
#  '/workspace/myFile/Output/17052023/A0424/No_damage_nuclei_30.tiff',
#  '/workspace/myFile/Output/17052023/D1111/No_damage_nuclei_59.tiff',
#  '/workspace/myFile/Output/17052023/F1215/No_damage_nuclei_86.tiff',
#  '/workspace/myFile/Output/17052023/A0601/No_damage_nuclei_339.tiff',
#  '/workspace/myFile/Output/17052023/F1218/No_damage_nuclei_15.tiff',
#  '/workspace/myFile/Output/17052023/A0510/No_damage_nuclei_268.tiff',
#  '/workspace/myFile/Output/17052023/F0613/No_damage_nuclei_325.tiff',
#  '/workspace/myFile/Output/17052023/A0603/No_damage_nuclei_111.tiff',
#  '/workspace/myFile/Output/17052023/C1111/No_damage_nuclei_51.tiff',
#  '/workspace/myFile/Output/17052023/E1119/No_damage_nuclei_34.tiff',
#  '/workspace/myFile/Output/17052023/E1215/No_damage_nuclei_50.tiff',
#  '/workspace/myFile/Output/17052023/A0604/No_damage_nuclei_205.tiff',
#  '/workspace/myFile/Output/17052023/A1211/No_damage_nuclei_20.tiff',
#  '/workspace/myFile/Output/17052023/B1112/No_damage_nuclei_157.tiff',
#  '/workspace/myFile/Output/17052023/E0508/No_damage_nuclei_220.tiff',
#  '/workspace/myFile/Output/17052023/C1113/No_damage_nuclei_90.tiff',
#  '/workspace/myFile/Output/17052023/F0518/No_damage_nuclei_183.tiff',
#  '/workspace/myFile/Output/17052023/B0408/No_damage_nuclei_25.tiff',
#  '/workspace/myFile/Output/17052023/A0417/No_damage_nuclei_199.tiff',
#  '/workspace/myFile/Output/17052023/A0611/No_damage_nuclei_27.tiff',
#  '/workspace/myFile/Output/17052023/C1023/No_damage_nuclei_87.tiff',
#  '/workspace/myFile/Output/17052023/A0519/No_damage_nuclei_353.tiff',
#  '/workspace/myFile/Output/17052023/C0612/No_damage_nuclei_21.tiff',
#  '/workspace/myFile/Output/17052023/F0616/No_damage_nuclei_43.tiff',
#  '/workspace/myFile/Output/17052023/A1117/No_damage_nuclei_368.tiff',
#  ...]

# %%
imDr = "/workspace/myFile/Output/17052023/"  # Image patches directory

labels = ['Damaged', 'Undamaged']  # Your labels

# %%
# For data augmentation
def get_transform(train):
    transforms = []

    transforms.append(T.ToTensor())
    transforms.append(T.Normalize([0.0019368887995516483], [0.00672996630111016]))
    #transforms.append(T.RandomHorizontalFlip(0.5))
    
    if train:
        transforms.append(T.RandomHorizontalFlip())
        transforms.append(T.RandomVerticalFlip())
    
    return T.Compose(transforms)

# %%
def train_model(model, criterion, optimizer, scheduler, dataloaderTrain, dataloaderTest, num_epochs=25):
    since = time.time()
    # Create a temporary directory to save training checkpoints
    with TemporaryDirectory() as tempdir:
        best_model_params_path = os.path.join(tempdir, 'best_model_params.pt')

        torch.save(model.state_dict(), best_model_params_path)
        best_acc = 0.0

        for epoch in range(num_epochs):
            print(f'Epoch {epoch}/{num_epochs - 1}')
            print('-' * 10)

            # Each epoch has a training and validation phase
            for phase in ['train', 'val']:
                if phase == 'train':
                    model.train()  # Set model to training mode
                    dataloaders = dataloaderTrain
                else:
                    model.eval()   # Set model to evaluate mode
                    dataloaders = dataloaderTest

                running_loss = 0.0
                running_corrects = 0

                # Iterate over data.
                for inputs, labels, imNo in dataloaders:
                    inputs = inputs.to(device)
                    labels = labels.to(device)

                    # zero the parameter gradients
                    optimizer.zero_grad()

                    # forward
                    # track history if only in train
                    with torch.set_grad_enabled(phase == 'train'):
                        outputs = model(inputs)
                        _, preds = torch.max(outputs, 1)
                        loss = criterion(outputs, labels)
                        # backward + optimize only if in training phase
                        if phase == 'train':
                            loss.backward()
                            optimizer.step()

                    # statistics
                    running_loss += loss.item() * inputs.size(0)    # Loss
                    running_corrects += torch.sum(preds == labels.data) # Accuracy

                if phase == 'train':
                    scheduler.step()

                epoch_loss = running_loss / dataset_sizes[phase]    # Loss metric per epoch
                epoch_acc = running_corrects.double() / dataset_sizes[phase]    # Accuracy metric per epoch

                if phase == "train":    # This is the tensorboard code that writes accuracy and loss metrics
                    writer.add_scalar("Train/Accuracy", epoch_acc, epoch)
                    writer.add_scalar("Train/Loss", epoch_loss, epoch)
                else:
                    writer.add_scalar("Validation/Accuracy", epoch_acc, epoch)
                    writer.add_scalar("Validation/Loss", epoch_loss, epoch)

                print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

                # deep copy the model
                if phase == 'val' and epoch_acc > best_acc: 
                    # This compares validation accuracy to previous bests and adjusts model weights accordingly
                    best_acc = epoch_acc
                    torch.save(model.state_dict(), best_model_params_path)

            print()

        time_elapsed = time.time() - since  # Nice way to measure training time but info also stored (indirectly) by tensorboard
        print(
            f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
        print(f'Best val Acc: {best_acc:4f}')
        labels= labels.cpu().numpy()
        preds=preds.cpu().numpy()
        con_mat = confusion_matrix(labels, preds)   # Confusion matrix compares true class with predicted class
        # load best model weights
        model.load_state_dict(torch.load(best_model_params_path))
    writer.close()
    return model, con_mat   # We want to return the model because its the model, also confusion matrix for later analysis

# %%
# This is your RESNET
# Initialize CNN with kaiming
def init_cnn(m):
    # Set the weights of the RESNET
    if getattr(m, 'bias', None) is not None: nn.init.constant_(m.bias, 0)
    if isinstance(m, (nn.Conv2d,nn.Linear)): nn.init.kaiming_normal_(m.weight)
    for l in m.children(): init_cnn(l)


# noop function for returning nothing
def noop(x): return x
# activation function(RELU)
act_fn = nn.ReLU(inplace=True)

# Flatten
class Flatten(nn.Module):
    def forward(self, x): return x.view(x.size(0), -1)

# Make a convolution
def conv(ni, nf, ks=3, stride=1, bias=False):
    return nn.Conv2d(ni, nf, kernel_size=ks, stride=stride, padding=ks//2, bias=bias)

# Create a convuolutional layer with convolution and batch norm
def conv_layer(ni, nf, ks=3, stride=1, zero_bn=False, act=True):
    bn = nn.BatchNorm2d(nf) # get a 2d batch norm from Pytorhc
    nn.init.constant_(bn.weight, 0. if zero_bn else 1.)
    layers = [conv(ni, nf, ks, stride=stride), bn]
    if act: layers.append(act_fn) # add in the activation function if act is true
    return nn.Sequential(*layers)


# Resblock
class ResBlock(nn.Module):
    def __init__(self, expansion, ni, nh, stride = 1):
        super().__init__()
        # ni - number of inputs channels, nf - number of filters
        # nh - number of filters in first conv
        # expansion is 1 for resnet 18, 34 and 4 for larger networks
        nf, ni = nh*expansion, ni*expansion
        layers = [conv_layer(ni, nh, 3, stride = stride), # for resnet < 34 2 convs per resblock
                 conv_layer(nh, nf, 3, zero_bn = True, act = False)
                 ] if expansion == 1 else [ # for RESNET > 34 then 3 convs per block with bottleneck
                            conv_layer(ni, nh, 1),
                            conv_layer(nh, nh, 3, stride = stride),
                            conv_layer(nh, nf, 1, zero_bn = True, act = False)
        ]
        self.convs = nn.Sequential(*layers) # Creates the conv layers
        self.idconv = noop if ni==nf else conv_layer(ni, nf, 1, act = False) # id convolution ()
        self.pool = noop if stride== 1 else nn.AvgPool2d(2, ceil_mode = True) # average pool on 
        
    def forward(self, x): 
        # Forward function adds the convolution part to the id part 
        #return act_fn(self.convs(x)) + self.idconv(self.pool(x))
        return act_fn(self.convs(x) + self.idconv(self.pool(x)))

# XResnet
class XResNet(nn.Sequential):
    @classmethod
    def create(cls, expansion, layers, c_in=3, c_out=1000):
        nfs = [c_in, (c_in + 1)*8, 64, 64] # number of filters in stem layer (c_in is number of image channels)
        stem = [conv_layer(nfs[i], nfs[i+1], stride=2 if i==0 else 1)
            for i in range(3)]

        nfs = [64//expansion,64,128,256,512]
        res_layers = [cls._make_layer(expansion, nfs[i], nfs[i+1],
                                      n_blocks=l, stride=1 if i==0 else 2)
                  for i,l in enumerate(layers)]
        res = cls(
        *stem,
        nn.MaxPool2d(kernel_size=3, stride = 2, padding = 1), # then a max pooling layer
        *res_layers,
        nn.AdaptiveAvgPool2d(1), Flatten(), 
        nn.Linear(nfs[-1]*expansion, c_out)
        )
        init_cnn(res)
        return res
        
    @staticmethod
    def _make_layer(expansion, ni, nf, n_blocks, stride): # returns a resblock
        return nn.Sequential(
        *[ResBlock(expansion, ni if i==0 else nf, nf, stride if i==0 else 1)
         for i in range(n_blocks)])

# %%
def xresnet18 (**kwargs): return XResNet.create(1, [2, 2,  2, 2], **kwargs)
def xresnet34 (**kwargs): return XResNet.create(1, [3, 4,  6, 3], **kwargs)
def xresnet50 (**kwargs): return XResNet.create(4, [3, 4,  6, 3], **kwargs)
#model = xresnet18(c_in = 1, c_out = 2)
#model = xresnet34(c_in = 1, c_out = 2)
model = xresnet50(c_in = 1, c_out = 2)
model = model.to(device)

# Label smoothing cross entropy
import torch.nn.functional as F


def reduce_loss(loss, reduction='mean'):
    return loss.mean() if reduction=='mean' else loss.sum() if reduction=='sum' else loss

class LabelSmoothingCrossEntropy(nn.Module):
    def __init__(self, ε:float=0.1, reduction='mean'):
        super().__init__()
        self.ε,self.reduction = ε,reduction
    
    def forward(self, output, target):
        c = output.size()[-1]
        log_preds = F.log_softmax(output, dim=-1)
        loss = reduce_loss(-log_preds.sum(dim=-1), self.reduction)
        nll = F.nll_loss(log_preds, target, reduction=self.reduction)
        return lin_comb(loss/c, nll, self.ε)

# %%
# Helper functions that shows the image, true class, predicted class and degree of prediction

def images_to_probs(net, images):
    '''
    Generates predictions and corresponding probabilities from a trained
    network and a list of images
    '''
    output = net(images)
    # convert output probabilities to predicted class
    _, preds_tensor = torch.max(output, 1)
    preds = np.squeeze(preds_tensor.numpy())
    return preds, [F.softmax(el, dim=0)[i].item() for i, el in zip(preds, output)]


def plot_classes_preds(net, images, labels):
    '''
    Generates matplotlib Figure using a trained network, along with images
    and labels from a batch, that shows the network's top prediction along
    with its probability, alongside the actual label, coloring this
    information based on whether the prediction was correct or not.
    Uses the "images_to_probs" function.
    '''
    preds, probs = images_to_probs(net, images)
    # plot the images in the batch, along with predicted and true labels
    fig = plt.figure(figsize=(12, 48))
    for idx in np.arange(4):
        ax = fig.add_subplot(1, 4, idx+1, xticks=[], yticks=[])
        matplotlib_imshow(images[idx], one_channel=True)
        ax.set_title("{0}, {1:.1f}%\n(label: {2})".format(
            labels[preds[idx]],
            probs[idx] * 100.0,
            labels[labels[idx]]),
                    color=("green" if preds[idx]==labels[idx].item() else "red"))
    return fig

def matplotlib_imshow(img, one_channel=True):
    if one_channel:
        img = img.mean(dim=0)
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    if one_channel:
        plt.imshow(npimg, cmap="Greys")
    else:
        plt.imshow(np.transpose(npimg, (1, 2, 0)))

# %%
def confusion_matrix_calc(data_loader_test, classes, model_ft):       
        y_pred = []
        y_true = []
        for inputs, labels, imNo in data_loader_test:
                inputs = inputs.to(device)
                labels = labels.to(device)
                output = model_ft(inputs) # Feed Network

                output = (torch.max(torch.exp(output), 1)[1]).data.cpu().numpy()
                y_pred.extend(output) # Save Prediction
                
                labels = labels.data.cpu().numpy()
                y_true.extend(labels) # Save Truth

        # constant for classes
        # classes = ('Alive', 'Dead')

        # Build confusion matrix
        cf_matrix = confusion_matrix(y_true, y_pred)
        return cf_matrix

# %%
torch.manual_seed(10)
imIdx = torch.randperm(101106).tolist()

## Create dataset
dataSetTrain = DNADataset(imDr, get_transform(train = True), labels, imDx=imIdx)
dataSetTest = DNADataset(imDr, get_transform(train = False), labels, imDx=imIdx)

# ## Create dataloaders
# Get subset
torch.manual_seed(10)
indices = torch.randperm(len(dataSetTrain)).tolist()

noTrain = int(len(dataSetTrain)*0.7)

dataset_train = torch.utils.data.Subset(dataSetTrain, indices[-noTrain:])
dataset_test = torch.utils.data.Subset(dataSetTest, indices[:-noTrain])
#len(indices), len(indices[:-50]), len(indices[-50:]), 50/191, type(dataset_test)

dataset_sizes = {'train': len(dataset_train), 'val': len(dataset_test)}

# define training and validation data loaders
data_loader_train = torch.utils.data.DataLoader(
    dataset_train, batch_size=20, shuffle=True, num_workers=0)

data_loader_test = torch.utils.data.DataLoader(
    dataset_test, batch_size=1, shuffle=False, num_workers=0)


# Collate function (gathers together the outputs)
# def collate_fn(batch):
#     return tuple(zip(*batch))

len(indices[-noTrain:]), dataset_sizes
#dataset_test[0][1], dataset_test[3][1], dataset_test[-1][1], dataSetTrain.imgs
# Out:
# (13903, {'train': 13903, 'val': 5959})

# %%
criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.Adam(model.parameters(), weight_decay=1e-2) # standard ADAM optimiser

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %%
model_ft, con_mat = train_model(model, criterion, optimizer_ft, exp_lr_scheduler,
                       data_loader_train,data_loader_test,num_epochs=20)
# Out:
# Epoch 0/19
# ----------
# train Loss: 0.6054 Acc: 0.6992
# val Loss: 0.5474 Acc: 0.7431
#
# Epoch 1/19
# ----------
# train Loss: 0.5582 Acc: 0.7388
# val Loss: 0.6068 Acc: 0.6624
#
# Epoch 2/19
# ----------
# train Loss: 0.5369 Acc: 0.7424
# val Loss: 0.5375 Acc: 0.7406
#
# Epoch 3/19
# ----------
# train Loss: 0.5162 Acc: 0.7598
# val Loss: 0.4723 Acc: 0.7874
#
# Epoch 4/19
# ----------
# train Loss: 0.5030 Acc: 0.7685
# val Loss: 0.4924 Acc: 0.7797
#
# Epoch 5/19
# ----------
# train Loss: 0.4930 Acc: 0.7759
# val Loss: 0.9195 Acc: 0.5576
#
# Epoch 6/19
# ----------
# train Loss: 0.4907 Acc: 0.7765
# val Loss: 0.5122 Acc: 0.7510
#
# Epoch 7/19
# ----------
# train Loss: 0.4783 Acc: 0.7847
# val Loss: 0.4497 Acc: 0.8105
#
# Epoch 8/19
# ----------
# train Loss: 0.4743 Acc: 0.7890
# val Loss: 0.5379 Acc: 0.7317
#
# Epoch 9/19
# ----------
# train Loss: 0.4710 Acc: 0.7931
# val Loss: 0.4481 Acc: 0.8094
#
# Epoch 10/19
# ----------
# train Loss: 0.4663 Acc: 0.7913
# val Loss: 0.4495 Acc: 0.8045
#
# Epoch 11/19
# ----------
# train Loss: 0.4659 Acc: 0.7924
# val Loss: 0.4449 Acc: 0.8080
#
# Epoch 12/19
# ----------
# train Loss: 0.4681 Acc: 0.7931
# val Loss: 0.4582 Acc: 0.7964
#
# Epoch 13/19
# ----------
# train Loss: 0.4673 Acc: 0.7919
# val Loss: 0.4411 Acc: 0.8129
#
# Epoch 14/19
# ----------
# train Loss: 0.4649 Acc: 0.7938
# val Loss: 0.4308 Acc: 0.8186
#
# Epoch 15/19
# ----------
# train Loss: 0.4615 Acc: 0.7978
# val Loss: 0.4342 Acc: 0.8174
#
# Epoch 16/19
# ----------
# train Loss: 0.4619 Acc: 0.7944
# val Loss: 0.4402 Acc: 0.8065
#
# Epoch 17/19
# ----------
# train Loss: 0.4628 Acc: 0.7972
# val Loss: 0.4284 Acc: 0.8194
#
# Epoch 18/19
# ----------
# train Loss: 0.4597 Acc: 0.7977
# val Loss: 0.4285 Acc: 0.8213
#
# Epoch 19/19
# ----------
# train Loss: 0.4599 Acc: 0.7963
# val Loss: 0.4326 Acc: 0.8164
#
# Training complete in 44m 36s
# Best val Acc: 0.821279

# %%
cf_matrix = confusion_matrix_calc(data_loader_test, labels, model_ft)

# %%
df_cm_ratio = pd.DataFrame(cf_matrix / np.sum(cf_matrix, axis=1)[:, None], index=[i for i in labels],
                     columns=[i for i in labels])
plt.figure(figsize=(12, 7))
sn.heatmap(df_cm_ratio, annot=True).set(xlabel='Predicted Result', ylabel='True Result')
# plt.save("Confusion_matrix_ratio.png")
# Out:
# [Text(0.5, 42.0, 'Predicted Result'), Text(87.0, 0.5, 'True Result')]

# %%
df_cm_raw = pd.DataFrame(cf_matrix, index=[i for i in labels],
                     columns=[i for i in labels])
plt.figure(figsize=(12, 7))
sn.heatmap(df_cm_raw, annot=True).set(xlabel='Predicted Result', ylabel='True Result')
# plt.save("Confusion_matrix_raw.png")
# Out:
# [Text(0.5, 42.0, 'Predicted Result'), Text(87.0, 0.5, 'True Result')]

# %%
cf_matrix
# Out:
# array([[2379,  588],
#        [ 477, 2515]])
