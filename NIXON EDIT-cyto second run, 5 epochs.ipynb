# %% [markdown]
# ### To note: Running this on different systems (i.e. local, SCW, server) will result in slight changes needing to the code

# %%
# Load libraries
import os
import numpy as np
import torch
import sys
import torchvision
import torchvision.transforms as T
import torchvision.models as models
from PIL import Image
from PIL import ImageEnhance
import matplotlib.pyplot as plt
import imagesize
import subprocess
sys.path
from IPython.core.debugger import set_trace
import scipy.ndimage
import matplotlib.patches as patches
# plt.rcParams['figure.figsize'] = [12,12]
# sys.path.append('/workspace/myFile/Mask_RCNN_Tutorial/')
from tqdm import tqdm
from torch import nn as nn
from torch import optim as optim
from torch.optim import lr_scheduler
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
import re
import time
import copy
import pylab
from torch.utils.tensorboard import SummaryWriter
from tempfile import TemporaryDirectory
import torch.backends.cudnn as cudnn
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import seaborn as sn
import pandas as pd
import glob
# Rather than have a messy notebook with a load of functions we can store them in separate .py files and import them

cudnn.benchmark = True
plt.ion()   # interactive mode
# Out:
# /opt/conda/lib/python3.8/site-packages/scipy/__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
writer = SummaryWriter("Experiments/TENSORBOARD")    # This determines the tensorboard file name

# %%
class DNADataset(object):
    def __init__(self, root, transforms, labels, imDx = False):
        self.root, self.transforms, self.labels = root, transforms, labels
    
        # load all image files, sorting them to ensure they are aligned
        self.imgDir = glob.glob(root+"*/*.tiff")
        DamagedCyto= [x for x in paths if "damage_membrane_" in x]
        UndamagedCyto= [x for x in paths if "ok_membrane_" in x]
        np.random.shuffle(UndamagedCyto)
        UndamagedCyto=UndamagedCyto[:8900]
        self.imgDir= DamagedCyto+UndamagedCyto
        size350=[]
        for x in self.imgDir:
            img = Image.open(x) # Open image
            w,h=img.size
            if w<=350 and h<=350:
                size350.append(x)
        self.imgDir=size350              
        
        self.imgs = sorted(self.imgDir) # list of images

        

        
    def __getitem__(self, idx):
        img_path = self.imgs[idx]
       
        # Transform images into tensors
        img = Image.open(img_path) # Open image
        w,h=img.size
        img = np.array(img) # Convert image into an array
        img = np.float32(np.divide(img, 2**16)) # Ensure all values are floats
        
        result=np.zeros((350,350), dtype=np.float32)
        x_center = (350 - w) // 2
        y_center = (350 - h) // 2 # copy img image into center of result image
        result[y_center:y_center+h, x_center:x_center+w] = img
        img = result
        
        targetlab=""
        if img_path.find('ok_membrane_') != -1:
            targetlab= 'Undamaged'
        if img_path.find('damage_membrane_') != -1:
            targetlab= 'Damaged'  # Find labels corresponding to image
        target = self.labels.index(targetlab) # Get the label and assign to a value
        
        # Convert label to tensor
        #torch.to
        
        if self.transforms is not None:
            img = self.transforms(img)
#             #print('In the transforms')
        imNo = idx
        return img, target, imNo
        
    def __len__(self):
        return len(self.imgs)

# %%
root="/workspace/myFile/Output/17052023/"
paths= glob.glob(root+"*/*.tiff")
DamagedCyto= [x for x in paths if "damage_membrane_" in x]
UndamagedCyto= [x for x in paths if "ok_membrane_" in x]
np.random.shuffle(UndamagedCyto)
UndamagedCyto=UndamagedCyto[:10000]
UndamagedCyto
# Out:
# ['/workspace/myFile/Output/17052023/A0422/ok_membrane_177.tiff',
#  '/workspace/myFile/Output/17052023/B1112/ok_membrane_254.tiff',
#  '/workspace/myFile/Output/17052023/B1103/ok_membrane_54.tiff',
#  '/workspace/myFile/Output/17052023/C0513/ok_membrane_185.tiff',
#  '/workspace/myFile/Output/17052023/C0408/ok_membrane_68.tiff',
#  '/workspace/myFile/Output/17052023/B1217/ok_membrane_81.tiff',
#  '/workspace/myFile/Output/17052023/B0405/ok_membrane_25.tiff',
#  '/workspace/myFile/Output/17052023/A0424/ok_membrane_137.tiff',
#  '/workspace/myFile/Output/17052023/D0503/ok_membrane_25.tiff',
#  '/workspace/myFile/Output/17052023/F1113/ok_membrane_260.tiff',
#  '/workspace/myFile/Output/17052023/E1107/ok_membrane_48.tiff',
#  '/workspace/myFile/Output/17052023/A0513/ok_membrane_878.tiff',
#  '/workspace/myFile/Output/17052023/D0508/ok_membrane_15.tiff',
#  '/workspace/myFile/Output/17052023/A1211/ok_membrane_124.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_440.tiff',
#  '/workspace/myFile/Output/17052023/A0624/ok_membrane_350.tiff',
#  '/workspace/myFile/Output/17052023/B1112/ok_membrane_1.tiff',
#  '/workspace/myFile/Output/17052023/A0415/ok_membrane_92.tiff',
#  '/workspace/myFile/Output/17052023/B1218/ok_membrane_35.tiff',
#  '/workspace/myFile/Output/17052023/A0405/ok_membrane_21.tiff',
#  '/workspace/myFile/Output/17052023/F0508/ok_membrane_361.tiff',
#  '/workspace/myFile/Output/17052023/E1013/ok_membrane_438.tiff',
#  '/workspace/myFile/Output/17052023/A1007/ok_membrane_303.tiff',
#  '/workspace/myFile/Output/17052023/A1022/ok_membrane_168.tiff',
#  '/workspace/myFile/Output/17052023/B0512/ok_membrane_122.tiff',
#  '/workspace/myFile/Output/17052023/E1216/ok_membrane_50.tiff',
#  '/workspace/myFile/Output/17052023/A1016/ok_membrane_103.tiff',
#  '/workspace/myFile/Output/17052023/A0413/ok_membrane_725.tiff',
#  '/workspace/myFile/Output/17052023/B1123/ok_membrane_63.tiff',
#  '/workspace/myFile/Output/17052023/D1114/ok_membrane_20.tiff',
#  '/workspace/myFile/Output/17052023/F0507/ok_membrane_236.tiff',
#  '/workspace/myFile/Output/17052023/E0422/ok_membrane_88.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_2053.tiff',
#  '/workspace/myFile/Output/17052023/C0408/ok_membrane_70.tiff',
#  '/workspace/myFile/Output/17052023/B1207/ok_membrane_45.tiff',
#  '/workspace/myFile/Output/17052023/C0514/ok_membrane_82.tiff',
#  '/workspace/myFile/Output/17052023/E0615/ok_membrane_77.tiff',
#  '/workspace/myFile/Output/17052023/A0613/ok_membrane_704.tiff',
#  '/workspace/myFile/Output/17052023/A1112/ok_membrane_597.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_2438.tiff',
#  '/workspace/myFile/Output/17052023/E1016/ok_membrane_44.tiff',
#  '/workspace/myFile/Output/17052023/A1115/ok_membrane_316.tiff',
#  '/workspace/myFile/Output/17052023/A1019/ok_membrane_111.tiff',
#  '/workspace/myFile/Output/17052023/A1012/ok_membrane_498.tiff',
#  '/workspace/myFile/Output/17052023/C1217/ok_membrane_109.tiff',
#  '/workspace/myFile/Output/17052023/A0518/ok_membrane_576.tiff',
#  '/workspace/myFile/Output/17052023/E0413/ok_membrane_437.tiff',
#  '/workspace/myFile/Output/17052023/C1208/ok_membrane_67.tiff',
#  '/workspace/myFile/Output/17052023/A0521/ok_membrane_302.tiff',
#  '/workspace/myFile/Output/17052023/A1118/ok_membrane_291.tiff',
#  '/workspace/myFile/Output/17052023/B0407/ok_membrane_49.tiff',
#  '/workspace/myFile/Output/17052023/A1008/ok_membrane_610.tiff',
#  '/workspace/myFile/Output/17052023/A1022/ok_membrane_427.tiff',
#  '/workspace/myFile/Output/17052023/A0407/ok_membrane_39.tiff',
#  '/workspace/myFile/Output/17052023/F0413/ok_membrane_45.tiff',
#  '/workspace/myFile/Output/17052023/D0503/ok_membrane_9.tiff',
#  '/workspace/myFile/Output/17052023/A1203/ok_membrane_27.tiff',
#  '/workspace/myFile/Output/17052023/A0401/ok_membrane_15.tiff',
#  '/workspace/myFile/Output/17052023/C0620/ok_membrane_120.tiff',
#  '/workspace/myFile/Output/17052023/A0520/ok_membrane_44.tiff',
#  '/workspace/myFile/Output/17052023/A0423/ok_membrane_521.tiff',
#  '/workspace/myFile/Output/17052023/A0408/ok_membrane_597.tiff',
#  '/workspace/myFile/Output/17052023/A0521/ok_membrane_72.tiff',
#  '/workspace/myFile/Output/17052023/A1203/ok_membrane_308.tiff',
#  '/workspace/myFile/Output/17052023/F1012/ok_membrane_31.tiff',
#  '/workspace/myFile/Output/17052023/E1111/ok_membrane_143.tiff',
#  '/workspace/myFile/Output/17052023/A0624/ok_membrane_306.tiff',
#  '/workspace/myFile/Output/17052023/F0413/ok_membrane_488.tiff',
#  '/workspace/myFile/Output/17052023/E1021/ok_membrane_110.tiff',
#  '/workspace/myFile/Output/17052023/A0617/ok_membrane_86.tiff',
#  '/workspace/myFile/Output/17052023/C1208/ok_membrane_126.tiff',
#  '/workspace/myFile/Output/17052023/F1017/ok_membrane_14.tiff',
#  '/workspace/myFile/Output/17052023/C1207/ok_membrane_48.tiff',
#  '/workspace/myFile/Output/17052023/A0408/ok_membrane_330.tiff',
#  '/workspace/myFile/Output/17052023/A0607/ok_membrane_691.tiff',
#  '/workspace/myFile/Output/17052023/E0417/ok_membrane_10.tiff',
#  '/workspace/myFile/Output/17052023/E1115/ok_membrane_92.tiff',
#  '/workspace/myFile/Output/17052023/E1023/ok_membrane_70.tiff',
#  '/workspace/myFile/Output/17052023/F1107/ok_membrane_56.tiff',
#  '/workspace/myFile/Output/17052023/B1119/ok_membrane_30.tiff',
#  '/workspace/myFile/Output/17052023/B1112/ok_membrane_270.tiff',
#  '/workspace/myFile/Output/17052023/A1125/ok_membrane_281.tiff',
#  '/workspace/myFile/Output/17052023/F1113/ok_membrane_278.tiff',
#  '/workspace/myFile/Output/17052023/A0409/ok_membrane_255.tiff',
#  '/workspace/myFile/Output/17052023/A1001/ok_membrane_4.tiff',
#  '/workspace/myFile/Output/17052023/F1112/ok_membrane_50.tiff',
#  '/workspace/myFile/Output/17052023/A1012/ok_membrane_68.tiff',
#  '/workspace/myFile/Output/17052023/A1007/ok_membrane_316.tiff',
#  '/workspace/myFile/Output/17052023/A0412/ok_membrane_393.tiff',
#  '/workspace/myFile/Output/17052023/F0401/ok_membrane_26.tiff',
#  '/workspace/myFile/Output/17052023/E0518/ok_membrane_45.tiff',
#  '/workspace/myFile/Output/17052023/C0608/ok_membrane_50.tiff',
#  '/workspace/myFile/Output/17052023/E1007/ok_membrane_149.tiff',
#  '/workspace/myFile/Output/17052023/A0613/ok_membrane_947.tiff',
#  '/workspace/myFile/Output/17052023/A0613/ok_membrane_538.tiff',
#  '/workspace/myFile/Output/17052023/A0418/ok_membrane_284.tiff',
#  '/workspace/myFile/Output/17052023/A1022/ok_membrane_172.tiff',
#  '/workspace/myFile/Output/17052023/A0612/ok_membrane_461.tiff',
#  '/workspace/myFile/Output/17052023/A0625/ok_membrane_206.tiff',
#  '/workspace/myFile/Output/17052023/A1020/ok_membrane_59.tiff',
#  '/workspace/myFile/Output/17052023/A0415/ok_membrane_225.tiff',
#  '/workspace/myFile/Output/17052023/A0617/ok_membrane_242.tiff',
#  '/workspace/myFile/Output/17052023/F1213/ok_membrane_185.tiff',
#  '/workspace/myFile/Output/17052023/F1221/ok_membrane_90.tiff',
#  '/workspace/myFile/Output/17052023/A0507/ok_membrane_212.tiff',
#  '/workspace/myFile/Output/17052023/C0418/ok_membrane_38.tiff',
#  '/workspace/myFile/Output/17052023/E0612/ok_membrane_52.tiff',
#  '/workspace/myFile/Output/17052023/F1213/ok_membrane_215.tiff',
#  '/workspace/myFile/Output/17052023/F0513/ok_membrane_231.tiff',
#  '/workspace/myFile/Output/17052023/A0408/ok_membrane_288.tiff',
#  '/workspace/myFile/Output/17052023/E1017/ok_membrane_177.tiff',
#  '/workspace/myFile/Output/17052023/A0509/ok_membrane_345.tiff',
#  '/workspace/myFile/Output/17052023/F0417/ok_membrane_105.tiff',
#  '/workspace/myFile/Output/17052023/F1106/ok_membrane_45.tiff',
#  '/workspace/myFile/Output/17052023/B1121/ok_membrane_2.tiff',
#  '/workspace/myFile/Output/17052023/A1112/ok_membrane_1.tiff',
#  '/workspace/myFile/Output/17052023/A1216/ok_membrane_254.tiff',
#  '/workspace/myFile/Output/17052023/A0418/ok_membrane_313.tiff',
#  '/workspace/myFile/Output/17052023/A0517/ok_membrane_157.tiff',
#  '/workspace/myFile/Output/17052023/F1109/ok_membrane_31.tiff',
#  '/workspace/myFile/Output/17052023/E0611/ok_membrane_34.tiff',
#  '/workspace/myFile/Output/17052023/E0601/ok_membrane_13.tiff',
#  '/workspace/myFile/Output/17052023/E1114/ok_membrane_23.tiff',
#  '/workspace/myFile/Output/17052023/E1105/ok_membrane_53.tiff',
#  '/workspace/myFile/Output/17052023/D0607/ok_membrane_46.tiff',
#  '/workspace/myFile/Output/17052023/D1113/ok_membrane_162.tiff',
#  '/workspace/myFile/Output/17052023/F0615/ok_membrane_10.tiff',
#  '/workspace/myFile/Output/17052023/A0402/ok_membrane_73.tiff',
#  '/workspace/myFile/Output/17052023/E0514/ok_membrane_64.tiff',
#  '/workspace/myFile/Output/17052023/E1222/ok_membrane_126.tiff',
#  '/workspace/myFile/Output/17052023/C1013/ok_membrane_236.tiff',
#  '/workspace/myFile/Output/17052023/C1111/ok_membrane_25.tiff',
#  '/workspace/myFile/Output/17052023/A0619/ok_membrane_315.tiff',
#  '/workspace/myFile/Output/17052023/A0408/ok_membrane_1045.tiff',
#  '/workspace/myFile/Output/17052023/C0511/ok_membrane_72.tiff',
#  '/workspace/myFile/Output/17052023/B1110/ok_membrane_27.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_1999.tiff',
#  '/workspace/myFile/Output/17052023/A1018/ok_membrane_220.tiff',
#  '/workspace/myFile/Output/17052023/B1013/ok_membrane_206.tiff',
#  '/workspace/myFile/Output/17052023/A1008/ok_membrane_566.tiff',
#  '/workspace/myFile/Output/17052023/D1122/ok_membrane_23.tiff',
#  '/workspace/myFile/Output/17052023/A0401/ok_membrane_94.tiff',
#  '/workspace/myFile/Output/17052023/A1019/ok_membrane_4.tiff',
#  '/workspace/myFile/Output/17052023/F0423/ok_membrane_195.tiff',
#  '/workspace/myFile/Output/17052023/A0519/ok_membrane_285.tiff',
#  '/workspace/myFile/Output/17052023/C1014/ok_membrane_4.tiff',
#  '/workspace/myFile/Output/17052023/B1013/ok_membrane_18.tiff',
#  '/workspace/myFile/Output/17052023/A1209/ok_membrane_78.tiff',
#  '/workspace/myFile/Output/17052023/B0507/ok_membrane_90.tiff',
#  '/workspace/myFile/Output/17052023/F1211/ok_membrane_3.tiff',
#  '/workspace/myFile/Output/17052023/A0408/ok_membrane_1039.tiff',
#  '/workspace/myFile/Output/17052023/D1002/ok_membrane_19.tiff',
#  '/workspace/myFile/Output/17052023/E1008/ok_membrane_150.tiff',
#  '/workspace/myFile/Output/17052023/F0408/ok_membrane_151.tiff',
#  '/workspace/myFile/Output/17052023/E1012/ok_membrane_234.tiff',
#  '/workspace/myFile/Output/17052023/A1208/ok_membrane_425.tiff',
#  '/workspace/myFile/Output/17052023/A0617/ok_membrane_279.tiff',
#  '/workspace/myFile/Output/17052023/C0519/ok_membrane_37.tiff',
#  '/workspace/myFile/Output/17052023/A0513/ok_membrane_817.tiff',
#  '/workspace/myFile/Output/17052023/E1108/ok_membrane_134.tiff',
#  '/workspace/myFile/Output/17052023/A1114/ok_membrane_156.tiff',
#  '/workspace/myFile/Output/17052023/E1207/ok_membrane_213.tiff',
#  '/workspace/myFile/Output/17052023/B0417/ok_membrane_175.tiff',
#  '/workspace/myFile/Output/17052023/E1212/ok_membrane_219.tiff',
#  '/workspace/myFile/Output/17052023/A1117/ok_membrane_302.tiff',
#  '/workspace/myFile/Output/17052023/B1014/ok_membrane_70.tiff',
#  '/workspace/myFile/Output/17052023/A0407/ok_membrane_499.tiff',
#  '/workspace/myFile/Output/17052023/D1211/ok_membrane_11.tiff',
#  '/workspace/myFile/Output/17052023/A1213/ok_membrane_475.tiff',
#  '/workspace/myFile/Output/17052023/B0417/ok_membrane_57.tiff',
#  '/workspace/myFile/Output/17052023/A1208/ok_membrane_437.tiff',
#  '/workspace/myFile/Output/17052023/A1120/ok_membrane_150.tiff',
#  '/workspace/myFile/Output/17052023/F1212/ok_membrane_146.tiff',
#  '/workspace/myFile/Output/17052023/A0422/ok_membrane_254.tiff',
#  '/workspace/myFile/Output/17052023/A0520/ok_membrane_254.tiff',
#  '/workspace/myFile/Output/17052023/F1113/ok_membrane_322.tiff',
#  '/workspace/myFile/Output/17052023/F1221/ok_membrane_24.tiff',
#  '/workspace/myFile/Output/17052023/A1018/ok_membrane_350.tiff',
#  '/workspace/myFile/Output/17052023/D1112/ok_membrane_64.tiff',
#  '/workspace/myFile/Output/17052023/E1007/ok_membrane_256.tiff',
#  '/workspace/myFile/Output/17052023/A0512/ok_membrane_147.tiff',
#  '/workspace/myFile/Output/17052023/A1107/ok_membrane_284.tiff',
#  '/workspace/myFile/Output/17052023/A1118/ok_membrane_333.tiff',
#  '/workspace/myFile/Output/17052023/F1204/ok_membrane_75.tiff',
#  '/workspace/myFile/Output/17052023/A0425/ok_membrane_96.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_960.tiff',
#  '/workspace/myFile/Output/17052023/D0403/ok_membrane_10.tiff',
#  '/workspace/myFile/Output/17052023/E1017/ok_membrane_171.tiff',
#  '/workspace/myFile/Output/17052023/A1211/ok_membrane_153.tiff',
#  '/workspace/myFile/Output/17052023/A0614/ok_membrane_313.tiff',
#  '/workspace/myFile/Output/17052023/C1013/ok_membrane_185.tiff',
#  '/workspace/myFile/Output/17052023/A0509/ok_membrane_107.tiff',
#  '/workspace/myFile/Output/17052023/D1025/ok_membrane_42.tiff',
#  '/workspace/myFile/Output/17052023/F0407/ok_membrane_21.tiff',
#  '/workspace/myFile/Output/17052023/A0509/ok_membrane_631.tiff',
#  '/workspace/myFile/Output/17052023/B0624/ok_membrane_68.tiff',
#  '/workspace/myFile/Output/17052023/C1203/ok_membrane_14.tiff',
#  '/workspace/myFile/Output/17052023/E1003/ok_membrane_162.tiff',
#  '/workspace/myFile/Output/17052023/A0606/ok_membrane_265.tiff',
#  '/workspace/myFile/Output/17052023/B1018/ok_membrane_59.tiff',
#  '/workspace/myFile/Output/17052023/A1114/ok_membrane_131.tiff',
#  '/workspace/myFile/Output/17052023/B0408/ok_membrane_71.tiff',
#  '/workspace/myFile/Output/17052023/F1001/ok_membrane_27.tiff',
#  '/workspace/myFile/Output/17052023/A1013/ok_membrane_507.tiff',
#  '/workspace/myFile/Output/17052023/A0423/ok_membrane_92.tiff',
#  '/workspace/myFile/Output/17052023/F1125/ok_membrane_28.tiff',
#  '/workspace/myFile/Output/17052023/F1213/ok_membrane_45.tiff',
#  '/workspace/myFile/Output/17052023/E1012/ok_membrane_19.tiff',
#  '/workspace/myFile/Output/17052023/A0423/ok_membrane_515.tiff',
#  '/workspace/myFile/Output/17052023/A1008/ok_membrane_149.tiff',
#  '/workspace/myFile/Output/17052023/B0405/ok_membrane_55.tiff',
#  '/workspace/myFile/Output/17052023/E1207/ok_membrane_76.tiff',
#  '/workspace/myFile/Output/17052023/A1017/ok_membrane_91.tiff',
#  '/workspace/myFile/Output/17052023/A0519/ok_membrane_186.tiff',
#  '/workspace/myFile/Output/17052023/A0505/ok_membrane_75.tiff',
#  '/workspace/myFile/Output/17052023/D0413/ok_membrane_98.tiff',
#  '/workspace/myFile/Output/17052023/E0509/ok_membrane_72.tiff',
#  '/workspace/myFile/Output/17052023/A1224/ok_membrane_79.tiff',
#  '/workspace/myFile/Output/17052023/E1220/ok_membrane_100.tiff',
#  '/workspace/myFile/Output/17052023/A0509/ok_membrane_695.tiff',
#  '/workspace/myFile/Output/17052023/C1013/ok_membrane_246.tiff',
#  '/workspace/myFile/Output/17052023/F0517/ok_membrane_612.tiff',
#  '/workspace/myFile/Output/17052023/A1021/ok_membrane_124.tiff',
#  '/workspace/myFile/Output/17052023/F1001/ok_membrane_65.tiff',
#  '/workspace/myFile/Output/17052023/B1020/ok_membrane_28.tiff',
#  '/workspace/myFile/Output/17052023/A0517/ok_membrane_25.tiff',
#  '/workspace/myFile/Output/17052023/E1108/ok_membrane_175.tiff',
#  '/workspace/myFile/Output/17052023/A1022/ok_membrane_195.tiff',
#  '/workspace/myFile/Output/17052023/A0617/ok_membrane_230.tiff',
#  '/workspace/myFile/Output/17052023/A1102/ok_membrane_13.tiff',
#  '/workspace/myFile/Output/17052023/E0607/ok_membrane_151.tiff',
#  '/workspace/myFile/Output/17052023/A1117/ok_membrane_52.tiff',
#  '/workspace/myFile/Output/17052023/A1018/ok_membrane_128.tiff',
#  '/workspace/myFile/Output/17052023/E0405/ok_membrane_12.tiff',
#  '/workspace/myFile/Output/17052023/A0422/ok_membrane_443.tiff',
#  '/workspace/myFile/Output/17052023/F1202/ok_membrane_59.tiff',
#  '/workspace/myFile/Output/17052023/F1017/ok_membrane_180.tiff',
#  '/workspace/myFile/Output/17052023/A0507/ok_membrane_355.tiff',
#  '/workspace/myFile/Output/17052023/A1113/ok_membrane_197.tiff',
#  '/workspace/myFile/Output/17052023/A1223/ok_membrane_259.tiff',
#  '/workspace/myFile/Output/17052023/F1204/ok_membrane_7.tiff',
#  '/workspace/myFile/Output/17052023/A0511/ok_membrane_31.tiff',
#  '/workspace/myFile/Output/17052023/B0417/ok_membrane_151.tiff',
#  '/workspace/myFile/Output/17052023/E1007/ok_membrane_183.tiff',
#  '/workspace/myFile/Output/17052023/F0623/ok_membrane_4.tiff',
#  '/workspace/myFile/Output/17052023/A0615/ok_membrane_215.tiff',
#  '/workspace/myFile/Output/17052023/C0613/ok_membrane_23.tiff',
#  '/workspace/myFile/Output/17052023/E1112/ok_membrane_316.tiff',
#  '/workspace/myFile/Output/17052023/C0522/ok_membrane_9.tiff',
#  '/workspace/myFile/Output/17052023/F0617/ok_membrane_34.tiff',
#  '/workspace/myFile/Output/17052023/E1013/ok_membrane_273.tiff',
#  '/workspace/myFile/Output/17052023/D1113/ok_membrane_190.tiff',
#  '/workspace/myFile/Output/17052023/F1008/ok_membrane_51.tiff',
#  '/workspace/myFile/Output/17052023/B0405/ok_membrane_20.tiff',
#  '/workspace/myFile/Output/17052023/F1125/ok_membrane_48.tiff',
#  '/workspace/myFile/Output/17052023/A0613/ok_membrane_329.tiff',
#  '/workspace/myFile/Output/17052023/A0512/ok_membrane_406.tiff',
#  '/workspace/myFile/Output/17052023/E0611/ok_membrane_136.tiff',
#  '/workspace/myFile/Output/17052023/C1022/ok_membrane_120.tiff',
#  '/workspace/myFile/Output/17052023/C1012/ok_membrane_173.tiff',
#  '/workspace/myFile/Output/17052023/F1215/ok_membrane_139.tiff',
#  '/workspace/myFile/Output/17052023/F1003/ok_membrane_68.tiff',
#  '/workspace/myFile/Output/17052023/F1122/ok_membrane_31.tiff',
#  '/workspace/myFile/Output/17052023/D1109/ok_membrane_12.tiff',
#  '/workspace/myFile/Output/17052023/B0423/ok_membrane_34.tiff',
#  '/workspace/myFile/Output/17052023/A0524/ok_membrane_584.tiff',
#  '/workspace/myFile/Output/17052023/E1017/ok_membrane_179.tiff',
#  '/workspace/myFile/Output/17052023/D1213/ok_membrane_99.tiff',
#  '/workspace/myFile/Output/17052023/F0512/ok_membrane_126.tiff',
#  '/workspace/myFile/Output/17052023/A0513/ok_membrane_26.tiff',
#  '/workspace/myFile/Output/17052023/A1225/ok_membrane_213.tiff',
#  '/workspace/myFile/Output/17052023/A0607/ok_membrane_202.tiff',
#  '/workspace/myFile/Output/17052023/E1013/ok_membrane_484.tiff',
#  '/workspace/myFile/Output/17052023/A0412/ok_membrane_248.tiff',
#  '/workspace/myFile/Output/17052023/C0614/ok_membrane_67.tiff',
#  '/workspace/myFile/Output/17052023/F1217/ok_membrane_29.tiff',
#  '/workspace/myFile/Output/17052023/A0625/ok_membrane_16.tiff',
#  '/workspace/myFile/Output/17052023/F0518/ok_membrane_164.tiff',
#  '/workspace/myFile/Output/17052023/E0624/ok_membrane_14.tiff',
#  '/workspace/myFile/Output/17052023/A0408/ok_membrane_365.tiff',
#  '/workspace/myFile/Output/17052023/A1115/ok_membrane_177.tiff',
#  '/workspace/myFile/Output/17052023/F1121/ok_membrane_93.tiff',
#  '/workspace/myFile/Output/17052023/B1109/ok_membrane_100.tiff',
#  '/workspace/myFile/Output/17052023/E1016/ok_membrane_35.tiff',
#  '/workspace/myFile/Output/17052023/A0615/ok_membrane_114.tiff',
#  '/workspace/myFile/Output/17052023/A0513/ok_membrane_1134.tiff',
#  '/workspace/myFile/Output/17052023/F1213/ok_membrane_202.tiff',
#  '/workspace/myFile/Output/17052023/A1022/ok_membrane_345.tiff',
#  '/workspace/myFile/Output/17052023/A1116/ok_membrane_62.tiff',
#  '/workspace/myFile/Output/17052023/A1116/ok_membrane_54.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_570.tiff',
#  '/workspace/myFile/Output/17052023/F1206/ok_membrane_28.tiff',
#  '/workspace/myFile/Output/17052023/C0523/ok_membrane_98.tiff',
#  '/workspace/myFile/Output/17052023/A0518/ok_membrane_64.tiff',
#  '/workspace/myFile/Output/17052023/A0412/ok_membrane_400.tiff',
#  '/workspace/myFile/Output/17052023/A0412/ok_membrane_182.tiff',
#  '/workspace/myFile/Output/17052023/A1217/ok_membrane_65.tiff',
#  '/workspace/myFile/Output/17052023/A0401/ok_membrane_41.tiff',
#  '/workspace/myFile/Output/17052023/F0513/ok_membrane_75.tiff',
#  '/workspace/myFile/Output/17052023/E1212/ok_membrane_21.tiff',
#  '/workspace/myFile/Output/17052023/C0413/ok_membrane_52.tiff',
#  '/workspace/myFile/Output/17052023/B0623/ok_membrane_35.tiff',
#  '/workspace/myFile/Output/17052023/A0425/ok_membrane_209.tiff',
#  '/workspace/myFile/Output/17052023/A1008/ok_membrane_647.tiff',
#  '/workspace/myFile/Output/17052023/A1012/ok_membrane_453.tiff',
#  '/workspace/myFile/Output/17052023/E1107/ok_membrane_123.tiff',
#  '/workspace/myFile/Output/17052023/F1017/ok_membrane_183.tiff',
#  '/workspace/myFile/Output/17052023/C1111/ok_membrane_126.tiff',
#  '/workspace/myFile/Output/17052023/D1119/ok_membrane_17.tiff',
#  '/workspace/myFile/Output/17052023/B0412/ok_membrane_108.tiff',
#  '/workspace/myFile/Output/17052023/B0407/ok_membrane_30.tiff',
#  '/workspace/myFile/Output/17052023/A1112/ok_membrane_553.tiff',
#  '/workspace/myFile/Output/17052023/A0512/ok_membrane_203.tiff',
#  '/workspace/myFile/Output/17052023/D0618/ok_membrane_39.tiff',
#  '/workspace/myFile/Output/17052023/F0504/ok_membrane_92.tiff',
#  '/workspace/myFile/Output/17052023/A1021/ok_membrane_76.tiff',
#  '/workspace/myFile/Output/17052023/C0512/ok_membrane_35.tiff',
#  '/workspace/myFile/Output/17052023/A0513/ok_membrane_537.tiff',
#  '/workspace/myFile/Output/17052023/B1206/ok_membrane_19.tiff',
#  '/workspace/myFile/Output/17052023/C0615/ok_membrane_81.tiff',
#  '/workspace/myFile/Output/17052023/A1009/ok_membrane_43.tiff',
#  '/workspace/myFile/Output/17052023/A1225/ok_membrane_202.tiff',
#  '/workspace/myFile/Output/17052023/E1224/ok_membrane_27.tiff',
#  '/workspace/myFile/Output/17052023/A0412/ok_membrane_292.tiff',
#  '/workspace/myFile/Output/17052023/B1118/ok_membrane_56.tiff',
#  '/workspace/myFile/Output/17052023/A0507/ok_membrane_59.tiff',
#  '/workspace/myFile/Output/17052023/F0413/ok_membrane_364.tiff',
#  '/workspace/myFile/Output/17052023/A0407/ok_membrane_144.tiff',
#  '/workspace/myFile/Output/17052023/F1002/ok_membrane_105.tiff',
#  '/workspace/myFile/Output/17052023/A1102/ok_membrane_87.tiff',
#  '/workspace/myFile/Output/17052023/A1017/ok_membrane_35.tiff',
#  '/workspace/myFile/Output/17052023/B0508/ok_membrane_145.tiff',
#  '/workspace/myFile/Output/17052023/B1001/ok_membrane_65.tiff',
#  '/workspace/myFile/Output/17052023/A1213/ok_membrane_554.tiff',
#  '/workspace/myFile/Output/17052023/C1111/ok_membrane_155.tiff',
#  '/workspace/myFile/Output/17052023/B1214/ok_membrane_53.tiff',
#  '/workspace/myFile/Output/17052023/A0423/ok_membrane_457.tiff',
#  '/workspace/myFile/Output/17052023/E0624/ok_membrane_77.tiff',
#  '/workspace/myFile/Output/17052023/A1207/ok_membrane_79.tiff',
#  '/workspace/myFile/Output/17052023/A1113/ok_membrane_340.tiff',
#  '/workspace/myFile/Output/17052023/F1117/ok_membrane_44.tiff',
#  '/workspace/myFile/Output/17052023/A1113/ok_membrane_313.tiff',
#  '/workspace/myFile/Output/17052023/D1213/ok_membrane_104.tiff',
#  '/workspace/myFile/Output/17052023/F1210/ok_membrane_29.tiff',
#  '/workspace/myFile/Output/17052023/E1224/ok_membrane_65.tiff',
#  '/workspace/myFile/Output/17052023/B1020/ok_membrane_57.tiff',
#  '/workspace/myFile/Output/17052023/E1019/ok_membrane_54.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_1747.tiff',
#  '/workspace/myFile/Output/17052023/A0607/ok_membrane_872.tiff',
#  '/workspace/myFile/Output/17052023/A1221/ok_membrane_44.tiff',
#  '/workspace/myFile/Output/17052023/A1007/ok_membrane_218.tiff',
#  '/workspace/myFile/Output/17052023/A1213/ok_membrane_704.tiff',
#  '/workspace/myFile/Output/17052023/A0613/ok_membrane_878.tiff',
#  '/workspace/myFile/Output/17052023/A1225/ok_membrane_41.tiff',
#  '/workspace/myFile/Output/17052023/E1004/ok_membrane_56.tiff',
#  '/workspace/myFile/Output/17052023/E0615/ok_membrane_9.tiff',
#  '/workspace/myFile/Output/17052023/D1211/ok_membrane_12.tiff',
#  '/workspace/myFile/Output/17052023/A1009/ok_membrane_49.tiff',
#  '/workspace/myFile/Output/17052023/C0418/ok_membrane_37.tiff',
#  '/workspace/myFile/Output/17052023/A1211/ok_membrane_193.tiff',
#  '/workspace/myFile/Output/17052023/C1011/ok_membrane_95.tiff',
#  '/workspace/myFile/Output/17052023/A0409/ok_membrane_290.tiff',
#  '/workspace/myFile/Output/17052023/B0402/ok_membrane_55.tiff',
#  '/workspace/myFile/Output/17052023/F1006/ok_membrane_76.tiff',
#  '/workspace/myFile/Output/17052023/F0614/ok_membrane_126.tiff',
#  '/workspace/myFile/Output/17052023/C1106/ok_membrane_58.tiff',
#  '/workspace/myFile/Output/17052023/F1103/ok_membrane_9.tiff',
#  '/workspace/myFile/Output/17052023/D1105/ok_membrane_22.tiff',
#  '/workspace/myFile/Output/17052023/F1012/ok_membrane_93.tiff',
#  '/workspace/myFile/Output/17052023/F1012/ok_membrane_105.tiff',
#  '/workspace/myFile/Output/17052023/B0425/ok_membrane_1.tiff',
#  '/workspace/myFile/Output/17052023/C1112/ok_membrane_18.tiff',
#  '/workspace/myFile/Output/17052023/A1203/ok_membrane_462.tiff',
#  '/workspace/myFile/Output/17052023/E0604/ok_membrane_3.tiff',
#  '/workspace/myFile/Output/17052023/A0423/ok_membrane_687.tiff',
#  '/workspace/myFile/Output/17052023/E1112/ok_membrane_219.tiff',
#  '/workspace/myFile/Output/17052023/D0607/ok_membrane_38.tiff',
#  '/workspace/myFile/Output/17052023/E0601/ok_membrane_4.tiff',
#  '/workspace/myFile/Output/17052023/A0507/ok_membrane_448.tiff',
#  '/workspace/myFile/Output/17052023/A0424/ok_membrane_303.tiff',
#  '/workspace/myFile/Output/17052023/D1006/ok_membrane_1.tiff',
#  '/workspace/myFile/Output/17052023/A1019/ok_membrane_57.tiff',
#  '/workspace/myFile/Output/17052023/A1104/ok_membrane_147.tiff',
#  '/workspace/myFile/Output/17052023/E1013/ok_membrane_330.tiff',
#  '/workspace/myFile/Output/17052023/A1113/ok_membrane_318.tiff',
#  '/workspace/myFile/Output/17052023/B0418/ok_membrane_56.tiff',
#  '/workspace/myFile/Output/17052023/F0509/ok_membrane_34.tiff',
#  '/workspace/myFile/Output/17052023/A0513/ok_membrane_1061.tiff',
#  '/workspace/myFile/Output/17052023/B1103/ok_membrane_30.tiff',
#  '/workspace/myFile/Output/17052023/C0624/ok_membrane_6.tiff',
#  '/workspace/myFile/Output/17052023/A1022/ok_membrane_476.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_925.tiff',
#  '/workspace/myFile/Output/17052023/A1013/ok_membrane_356.tiff',
#  '/workspace/myFile/Output/17052023/E1213/ok_membrane_80.tiff',
#  '/workspace/myFile/Output/17052023/A1218/ok_membrane_397.tiff',
#  '/workspace/myFile/Output/17052023/B0509/ok_membrane_7.tiff',
#  '/workspace/myFile/Output/17052023/A0403/ok_membrane_449.tiff',
#  '/workspace/myFile/Output/17052023/F0518/ok_membrane_16.tiff',
#  '/workspace/myFile/Output/17052023/E1223/ok_membrane_129.tiff',
#  '/workspace/myFile/Output/17052023/B0613/ok_membrane_29.tiff',
#  '/workspace/myFile/Output/17052023/B0423/ok_membrane_125.tiff',
#  '/workspace/myFile/Output/17052023/A0601/ok_membrane_340.tiff',
#  '/workspace/myFile/Output/17052023/F0623/ok_membrane_156.tiff',
#  '/workspace/myFile/Output/17052023/A0625/ok_membrane_3.tiff',
#  '/workspace/myFile/Output/17052023/F1205/ok_membrane_88.tiff',
#  '/workspace/myFile/Output/17052023/F1224/ok_membrane_18.tiff',
#  '/workspace/myFile/Output/17052023/A1109/ok_membrane_271.tiff',
#  '/workspace/myFile/Output/17052023/F0507/ok_membrane_186.tiff',
#  '/workspace/myFile/Output/17052023/F1109/ok_membrane_77.tiff',
#  '/workspace/myFile/Output/17052023/A1017/ok_membrane_234.tiff',
#  '/workspace/myFile/Output/17052023/C1111/ok_membrane_9.tiff',
#  '/workspace/myFile/Output/17052023/F1105/ok_membrane_41.tiff',
#  '/workspace/myFile/Output/17052023/C1205/ok_membrane_24.tiff',
#  '/workspace/myFile/Output/17052023/A1211/ok_membrane_315.tiff',
#  '/workspace/myFile/Output/17052023/A1214/ok_membrane_18.tiff',
#  '/workspace/myFile/Output/17052023/D0517/ok_membrane_48.tiff',
#  '/workspace/myFile/Output/17052023/C0405/ok_membrane_7.tiff',
#  '/workspace/myFile/Output/17052023/B0502/ok_membrane_82.tiff',
#  '/workspace/myFile/Output/17052023/D1111/ok_membrane_35.tiff',
#  '/workspace/myFile/Output/17052023/A1023/ok_membrane_73.tiff',
#  '/workspace/myFile/Output/17052023/B0510/ok_membrane_53.tiff',
#  '/workspace/myFile/Output/17052023/F1213/ok_membrane_169.tiff',
#  '/workspace/myFile/Output/17052023/F0417/ok_membrane_128.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_886.tiff',
#  '/workspace/myFile/Output/17052023/F1113/ok_membrane_90.tiff',
#  '/workspace/myFile/Output/17052023/C0404/ok_membrane_35.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_944.tiff',
#  '/workspace/myFile/Output/17052023/A1111/ok_membrane_170.tiff',
#  '/workspace/myFile/Output/17052023/F0424/ok_membrane_75.tiff',
#  '/workspace/myFile/Output/17052023/A0403/ok_membrane_538.tiff',
#  '/workspace/myFile/Output/17052023/D0512/ok_membrane_5.tiff',
#  '/workspace/myFile/Output/17052023/E1208/ok_membrane_95.tiff',
#  '/workspace/myFile/Output/17052023/A0409/ok_membrane_343.tiff',
#  '/workspace/myFile/Output/17052023/F0407/ok_membrane_11.tiff',
#  '/workspace/myFile/Output/17052023/A0524/ok_membrane_231.tiff',
#  '/workspace/myFile/Output/17052023/A0425/ok_membrane_204.tiff',
#  '/workspace/myFile/Output/17052023/A1109/ok_membrane_388.tiff',
#  '/workspace/myFile/Output/17052023/C0608/ok_membrane_51.tiff',
#  '/workspace/myFile/Output/17052023/A1003/ok_membrane_146.tiff',
#  '/workspace/myFile/Output/17052023/A1214/ok_membrane_270.tiff',
#  '/workspace/myFile/Output/17052023/E1220/ok_membrane_52.tiff',
#  '/workspace/myFile/Output/17052023/F1007/ok_membrane_126.tiff',
#  '/workspace/myFile/Output/17052023/B1109/ok_membrane_29.tiff',
#  '/workspace/myFile/Output/17052023/B1212/ok_membrane_164.tiff',
#  '/workspace/myFile/Output/17052023/A0407/ok_membrane_695.tiff',
#  '/workspace/myFile/Output/17052023/A1217/ok_membrane_191.tiff',
#  '/workspace/myFile/Output/17052023/A1013/ok_membrane_551.tiff',
#  '/workspace/myFile/Output/17052023/A0612/ok_membrane_120.tiff',
#  '/workspace/myFile/Output/17052023/A1008/ok_membrane_382.tiff',
#  '/workspace/myFile/Output/17052023/E1209/ok_membrane_111.tiff',
#  '/workspace/myFile/Output/17052023/E1008/ok_membrane_182.tiff',
#  '/workspace/myFile/Output/17052023/A1114/ok_membrane_395.tiff',
#  '/workspace/myFile/Output/17052023/A1020/ok_membrane_213.tiff',
#  '/workspace/myFile/Output/17052023/C0410/ok_membrane_31.tiff',
#  '/workspace/myFile/Output/17052023/A0510/ok_membrane_244.tiff',
#  '/workspace/myFile/Output/17052023/C0515/ok_membrane_97.tiff',
#  '/workspace/myFile/Output/17052023/A0407/ok_membrane_589.tiff',
#  '/workspace/myFile/Output/17052023/C0605/ok_membrane_1.tiff',
#  '/workspace/myFile/Output/17052023/A1003/ok_membrane_305.tiff',
#  '/workspace/myFile/Output/17052023/A0521/ok_membrane_18.tiff',
#  '/workspace/myFile/Output/17052023/E0409/ok_membrane_15.tiff',
#  '/workspace/myFile/Output/17052023/A1023/ok_membrane_264.tiff',
#  '/workspace/myFile/Output/17052023/E1208/ok_membrane_330.tiff',
#  '/workspace/myFile/Output/17052023/A0418/ok_membrane_111.tiff',
#  '/workspace/myFile/Output/17052023/F1004/ok_membrane_72.tiff',
#  '/workspace/myFile/Output/17052023/A1214/ok_membrane_165.tiff',
#  '/workspace/myFile/Output/17052023/F0524/ok_membrane_48.tiff',
#  '/workspace/myFile/Output/17052023/F1211/ok_membrane_120.tiff',
#  '/workspace/myFile/Output/17052023/A0408/ok_membrane_475.tiff',
#  '/workspace/myFile/Output/17052023/B1018/ok_membrane_58.tiff',
#  '/workspace/myFile/Output/17052023/D1213/ok_membrane_20.tiff',
#  '/workspace/myFile/Output/17052023/B0522/ok_membrane_23.tiff',
#  '/workspace/myFile/Output/17052023/A0517/ok_membrane_285.tiff',
#  '/workspace/myFile/Output/17052023/A0407/ok_membrane_114.tiff',
#  '/workspace/myFile/Output/17052023/A0413/ok_membrane_633.tiff',
#  '/workspace/myFile/Output/17052023/C1212/ok_membrane_8.tiff',
#  '/workspace/myFile/Output/17052023/E0611/ok_membrane_8.tiff',
#  '/workspace/myFile/Output/17052023/A1008/ok_membrane_328.tiff',
#  '/workspace/myFile/Output/17052023/E0514/ok_membrane_99.tiff',
#  '/workspace/myFile/Output/17052023/C1112/ok_membrane_127.tiff',
#  '/workspace/myFile/Output/17052023/C0409/ok_membrane_9.tiff',
#  '/workspace/myFile/Output/17052023/E0620/ok_membrane_22.tiff',
#  '/workspace/myFile/Output/17052023/A0507/ok_membrane_483.tiff',
#  '/workspace/myFile/Output/17052023/D1215/ok_membrane_28.tiff',
#  '/workspace/myFile/Output/17052023/A1118/ok_membrane_252.tiff',
#  '/workspace/myFile/Output/17052023/E0412/ok_membrane_26.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_732.tiff',
#  '/workspace/myFile/Output/17052023/C1203/ok_membrane_105.tiff',
#  '/workspace/myFile/Output/17052023/A0520/ok_membrane_13.tiff',
#  '/workspace/myFile/Output/17052023/A0612/ok_membrane_393.tiff',
#  '/workspace/myFile/Output/17052023/A1018/ok_membrane_149.tiff',
#  '/workspace/myFile/Output/17052023/A1007/ok_membrane_25.tiff',
#  '/workspace/myFile/Output/17052023/C1202/ok_membrane_43.tiff',
#  '/workspace/myFile/Output/17052023/C0513/ok_membrane_11.tiff',
#  '/workspace/myFile/Output/17052023/A1007/ok_membrane_269.tiff',
#  '/workspace/myFile/Output/17052023/A1118/ok_membrane_516.tiff',
#  '/workspace/myFile/Output/17052023/B1012/ok_membrane_174.tiff',
#  '/workspace/myFile/Output/17052023/D1009/ok_membrane_27.tiff',
#  '/workspace/myFile/Output/17052023/E0606/ok_membrane_8.tiff',
#  '/workspace/myFile/Output/17052023/C1212/ok_membrane_137.tiff',
#  '/workspace/myFile/Output/17052023/E1019/ok_membrane_80.tiff',
#  '/workspace/myFile/Output/17052023/B1002/ok_membrane_103.tiff',
#  '/workspace/myFile/Output/17052023/A0407/ok_membrane_116.tiff',
#  '/workspace/myFile/Output/17052023/F1108/ok_membrane_225.tiff',
#  '/workspace/myFile/Output/17052023/E1108/ok_membrane_282.tiff',
#  '/workspace/myFile/Output/17052023/A0614/ok_membrane_80.tiff',
#  '/workspace/myFile/Output/17052023/A0602/ok_membrane_59.tiff',
#  '/workspace/myFile/Output/17052023/E0605/ok_membrane_47.tiff',
#  '/workspace/myFile/Output/17052023/B0624/ok_membrane_89.tiff',
#  '/workspace/myFile/Output/17052023/A0403/ok_membrane_200.tiff',
#  '/workspace/myFile/Output/17052023/F0619/ok_membrane_46.tiff',
#  '/workspace/myFile/Output/17052023/B1119/ok_membrane_43.tiff',
#  '/workspace/myFile/Output/17052023/A0507/ok_membrane_295.tiff',
#  '/workspace/myFile/Output/17052023/B1121/ok_membrane_75.tiff',
#  '/workspace/myFile/Output/17052023/F0517/ok_membrane_118.tiff',
#  '/workspace/myFile/Output/17052023/B0613/ok_membrane_110.tiff',
#  '/workspace/myFile/Output/17052023/A1009/ok_membrane_73.tiff',
#  '/workspace/myFile/Output/17052023/B1209/ok_membrane_112.tiff',
#  '/workspace/myFile/Output/17052023/A1123/ok_membrane_36.tiff',
#  '/workspace/myFile/Output/17052023/A1209/ok_membrane_220.tiff',
#  '/workspace/myFile/Output/17052023/A0523/ok_membrane_326.tiff',
#  '/workspace/myFile/Output/17052023/A0418/ok_membrane_329.tiff',
#  '/workspace/myFile/Output/17052023/A0615/ok_membrane_199.tiff',
#  '/workspace/myFile/Output/17052023/E1016/ok_membrane_19.tiff',
#  '/workspace/myFile/Output/17052023/F1102/ok_membrane_10.tiff',
#  '/workspace/myFile/Output/17052023/A1109/ok_membrane_221.tiff',
#  '/workspace/myFile/Output/17052023/E1013/ok_membrane_345.tiff',
#  '/workspace/myFile/Output/17052023/A1002/ok_membrane_24.tiff',
#  '/workspace/myFile/Output/17052023/B0508/ok_membrane_22.tiff',
#  '/workspace/myFile/Output/17052023/F1103/ok_membrane_133.tiff',
#  '/workspace/myFile/Output/17052023/B1214/ok_membrane_27.tiff',
#  '/workspace/myFile/Output/17052023/F1010/ok_membrane_65.tiff',
#  '/workspace/myFile/Output/17052023/E0518/ok_membrane_159.tiff',
#  '/workspace/myFile/Output/17052023/A0408/ok_membrane_46.tiff',
#  '/workspace/myFile/Output/17052023/A0413/ok_membrane_785.tiff',
#  '/workspace/myFile/Output/17052023/F1006/ok_membrane_10.tiff',
#  '/workspace/myFile/Output/17052023/A0512/ok_membrane_501.tiff',
#  '/workspace/myFile/Output/17052023/A1117/ok_membrane_206.tiff',
#  '/workspace/myFile/Output/17052023/A1111/ok_membrane_446.tiff',
#  '/workspace/myFile/Output/17052023/A0517/ok_membrane_155.tiff',
#  '/workspace/myFile/Output/17052023/A1025/ok_membrane_119.tiff',
#  '/workspace/myFile/Output/17052023/E0411/ok_membrane_15.tiff',
#  '/workspace/myFile/Output/17052023/B0514/ok_membrane_85.tiff',
#  '/workspace/myFile/Output/17052023/A0512/ok_membrane_66.tiff',
#  '/workspace/myFile/Output/17052023/C1220/ok_membrane_14.tiff',
#  '/workspace/myFile/Output/17052023/B1224/ok_membrane_41.tiff',
#  '/workspace/myFile/Output/17052023/A1116/ok_membrane_5.tiff',
#  '/workspace/myFile/Output/17052023/A1104/ok_membrane_255.tiff',
#  '/workspace/myFile/Output/17052023/C1112/ok_membrane_189.tiff',
#  '/workspace/myFile/Output/17052023/F1112/ok_membrane_82.tiff',
#  '/workspace/myFile/Output/17052023/C0511/ok_membrane_80.tiff',
#  '/workspace/myFile/Output/17052023/A1208/ok_membrane_431.tiff',
#  '/workspace/myFile/Output/17052023/C1009/ok_membrane_60.tiff',
#  '/workspace/myFile/Output/17052023/A0607/ok_membrane_425.tiff',
#  '/workspace/myFile/Output/17052023/A1013/ok_membrane_633.tiff',
#  '/workspace/myFile/Output/17052023/A1013/ok_membrane_687.tiff',
#  '/workspace/myFile/Output/17052023/E0413/ok_membrane_388.tiff',
#  '/workspace/myFile/Output/17052023/F1101/ok_membrane_2.tiff',
#  '/workspace/myFile/Output/17052023/E1009/ok_membrane_22.tiff',
#  '/workspace/myFile/Output/17052023/A0404/ok_membrane_21.tiff',
#  '/workspace/myFile/Output/17052023/E1005/ok_membrane_24.tiff',
#  '/workspace/myFile/Output/17052023/E1012/ok_membrane_286.tiff',
#  '/workspace/myFile/Output/17052023/A0620/ok_membrane_213.tiff',
#  '/workspace/myFile/Output/17052023/A1111/ok_membrane_305.tiff',
#  '/workspace/myFile/Output/17052023/F1019/ok_membrane_26.tiff',
#  '/workspace/myFile/Output/17052023/F1118/ok_membrane_102.tiff',
#  '/workspace/myFile/Output/17052023/A0606/ok_membrane_207.tiff',
#  '/workspace/myFile/Output/17052023/F1025/ok_membrane_97.tiff',
#  '/workspace/myFile/Output/17052023/C1216/ok_membrane_45.tiff',
#  '/workspace/myFile/Output/17052023/A0513/ok_membrane_1110.tiff',
#  '/workspace/myFile/Output/17052023/F0413/ok_membrane_544.tiff',
#  '/workspace/myFile/Output/17052023/A1202/ok_membrane_207.tiff',
#  '/workspace/myFile/Output/17052023/F1102/ok_membrane_13.tiff',
#  '/workspace/myFile/Output/17052023/A0408/ok_membrane_563.tiff',
#  '/workspace/myFile/Output/17052023/B0514/ok_membrane_71.tiff',
#  '/workspace/myFile/Output/17052023/A1114/ok_membrane_179.tiff',
#  '/workspace/myFile/Output/17052023/A0401/ok_membrane_177.tiff',
#  '/workspace/myFile/Output/17052023/A1018/ok_membrane_561.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_1223.tiff',
#  '/workspace/myFile/Output/17052023/A1116/ok_membrane_107.tiff',
#  '/workspace/myFile/Output/17052023/A1013/ok_membrane_523.tiff',
#  '/workspace/myFile/Output/17052023/F0613/ok_membrane_128.tiff',
#  '/workspace/myFile/Output/17052023/A1021/ok_membrane_51.tiff',
#  '/workspace/myFile/Output/17052023/A0619/ok_membrane_214.tiff',
#  '/workspace/myFile/Output/17052023/F1020/ok_membrane_16.tiff',
#  '/workspace/myFile/Output/17052023/A1218/ok_membrane_297.tiff',
#  '/workspace/myFile/Output/17052023/A1111/ok_membrane_215.tiff',
#  '/workspace/myFile/Output/17052023/A0522/ok_membrane_40.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_1152.tiff',
#  '/workspace/myFile/Output/17052023/C0510/ok_membrane_4.tiff',
#  '/workspace/myFile/Output/17052023/C0414/ok_membrane_17.tiff',
#  '/workspace/myFile/Output/17052023/A1018/ok_membrane_449.tiff',
#  '/workspace/myFile/Output/17052023/A0624/ok_membrane_79.tiff',
#  '/workspace/myFile/Output/17052023/A0517/ok_membrane_414.tiff',
#  '/workspace/myFile/Output/17052023/A1102/ok_membrane_93.tiff',
#  '/workspace/myFile/Output/17052023/A1117/ok_membrane_260.tiff',
#  '/workspace/myFile/Output/17052023/A0403/ok_membrane_2.tiff',
#  '/workspace/myFile/Output/17052023/E1107/ok_membrane_134.tiff',
#  '/workspace/myFile/Output/17052023/E1215/ok_membrane_54.tiff',
#  '/workspace/myFile/Output/17052023/F1103/ok_membrane_111.tiff',
#  '/workspace/myFile/Output/17052023/F1007/ok_membrane_61.tiff',
#  '/workspace/myFile/Output/17052023/F1014/ok_membrane_51.tiff',
#  '/workspace/myFile/Output/17052023/A0409/ok_membrane_115.tiff',
#  '/workspace/myFile/Output/17052023/A0511/ok_membrane_39.tiff',
#  '/workspace/myFile/Output/17052023/A1109/ok_membrane_114.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_208.tiff',
#  '/workspace/myFile/Output/17052023/E0502/ok_membrane_90.tiff',
#  '/workspace/myFile/Output/17052023/A0423/ok_membrane_25.tiff',
#  '/workspace/myFile/Output/17052023/F1118/ok_membrane_62.tiff',
#  '/workspace/myFile/Output/17052023/A0612/ok_membrane_380.tiff',
#  '/workspace/myFile/Output/17052023/E1008/ok_membrane_137.tiff',
#  '/workspace/myFile/Output/17052023/A1106/ok_membrane_177.tiff',
#  '/workspace/myFile/Output/17052023/A1217/ok_membrane_458.tiff',
#  '/workspace/myFile/Output/17052023/B0624/ok_membrane_87.tiff',
#  '/workspace/myFile/Output/17052023/A1015/ok_membrane_63.tiff',
#  '/workspace/myFile/Output/17052023/A1212/ok_membrane_38.tiff',
#  '/workspace/myFile/Output/17052023/A0515/ok_membrane_12.tiff',
#  '/workspace/myFile/Output/17052023/D1220/ok_membrane_20.tiff',
#  '/workspace/myFile/Output/17052023/A1007/ok_membrane_405.tiff',
#  '/workspace/myFile/Output/17052023/E0424/ok_membrane_40.tiff',
#  '/workspace/myFile/Output/17052023/A0403/ok_membrane_518.tiff',
#  '/workspace/myFile/Output/17052023/A1202/ok_membrane_17.tiff',
#  '/workspace/myFile/Output/17052023/A1019/ok_membrane_52.tiff',
#  '/workspace/myFile/Output/17052023/F0517/ok_membrane_381.tiff',
#  '/workspace/myFile/Output/17052023/C1124/ok_membrane_87.tiff',
#  '/workspace/myFile/Output/17052023/A0607/ok_membrane_88.tiff',
#  '/workspace/myFile/Output/17052023/D1112/ok_membrane_157.tiff',
#  '/workspace/myFile/Output/17052023/A0407/ok_membrane_581.tiff',
#  '/workspace/myFile/Output/17052023/A0625/ok_membrane_28.tiff',
#  '/workspace/myFile/Output/17052023/E0518/ok_membrane_142.tiff',
#  '/workspace/myFile/Output/17052023/D1207/ok_membrane_12.tiff',
#  '/workspace/myFile/Output/17052023/E0607/ok_membrane_28.tiff',
#  '/workspace/myFile/Output/17052023/C0612/ok_membrane_96.tiff',
#  '/workspace/myFile/Output/17052023/D0604/ok_membrane_62.tiff',
#  '/workspace/myFile/Output/17052023/A0413/ok_membrane_387.tiff',
#  '/workspace/myFile/Output/17052023/E1007/ok_membrane_216.tiff',
#  '/workspace/myFile/Output/17052023/A1018/ok_membrane_306.tiff',
#  '/workspace/myFile/Output/17052023/F1004/ok_membrane_26.tiff',
#  '/workspace/myFile/Output/17052023/A1013/ok_membrane_543.tiff',
#  '/workspace/myFile/Output/17052023/A0413/ok_membrane_217.tiff',
#  '/workspace/myFile/Output/17052023/B1224/ok_membrane_49.tiff',
#  '/workspace/myFile/Output/17052023/F1008/ok_membrane_208.tiff',
#  '/workspace/myFile/Output/17052023/A1224/ok_membrane_121.tiff',
#  '/workspace/myFile/Output/17052023/A1215/ok_membrane_169.tiff',
#  '/workspace/myFile/Output/17052023/F0514/ok_membrane_21.tiff',
#  '/workspace/myFile/Output/17052023/A0512/ok_membrane_124.tiff',
#  '/workspace/myFile/Output/17052023/E1208/ok_membrane_271.tiff',
#  '/workspace/myFile/Output/17052023/A1109/ok_membrane_16.tiff',
#  '/workspace/myFile/Output/17052023/E0408/ok_membrane_140.tiff',
#  '/workspace/myFile/Output/17052023/A1205/ok_membrane_98.tiff',
#  '/workspace/myFile/Output/17052023/E1202/ok_membrane_32.tiff',
#  '/workspace/myFile/Output/17052023/E1013/ok_membrane_419.tiff',
#  '/workspace/myFile/Output/17052023/A0509/ok_membrane_329.tiff',
#  '/workspace/myFile/Output/17052023/E1219/ok_membrane_27.tiff',
#  '/workspace/myFile/Output/17052023/A1207/ok_membrane_165.tiff',
#  '/workspace/myFile/Output/17052023/A0517/ok_membrane_89.tiff',
#  '/workspace/myFile/Output/17052023/A1022/ok_membrane_376.tiff',
#  '/workspace/myFile/Output/17052023/B1103/ok_membrane_158.tiff',
#  '/workspace/myFile/Output/17052023/C0522/ok_membrane_30.tiff',
#  '/workspace/myFile/Output/17052023/D1002/ok_membrane_21.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_2226.tiff',
#  '/workspace/myFile/Output/17052023/E1208/ok_membrane_340.tiff',
#  '/workspace/myFile/Output/17052023/F1220/ok_membrane_78.tiff',
#  '/workspace/myFile/Output/17052023/A0404/ok_membrane_214.tiff',
#  '/workspace/myFile/Output/17052023/A1017/ok_membrane_362.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_2414.tiff',
#  '/workspace/myFile/Output/17052023/B1212/ok_membrane_48.tiff',
#  '/workspace/myFile/Output/17052023/E0602/ok_membrane_30.tiff',
#  '/workspace/myFile/Output/17052023/A1212/ok_membrane_439.tiff',
#  '/workspace/myFile/Output/17052023/C0603/ok_membrane_28.tiff',
#  '/workspace/myFile/Output/17052023/F1014/ok_membrane_4.tiff',
#  '/workspace/myFile/Output/17052023/A1109/ok_membrane_37.tiff',
#  '/workspace/myFile/Output/17052023/F0518/ok_membrane_120.tiff',
#  '/workspace/myFile/Output/17052023/A0408/ok_membrane_106.tiff',
#  '/workspace/myFile/Output/17052023/F1221/ok_membrane_82.tiff',
#  '/workspace/myFile/Output/17052023/A1115/ok_membrane_199.tiff',
#  '/workspace/myFile/Output/17052023/E0625/ok_membrane_18.tiff',
#  '/workspace/myFile/Output/17052023/A1123/ok_membrane_298.tiff',
#  '/workspace/myFile/Output/17052023/B1109/ok_membrane_76.tiff',
#  '/workspace/myFile/Output/17052023/E1011/ok_membrane_69.tiff',
#  '/workspace/myFile/Output/17052023/B0525/ok_membrane_10.tiff',
#  '/workspace/myFile/Output/17052023/F1009/ok_membrane_83.tiff',
#  '/workspace/myFile/Output/17052023/C0408/ok_membrane_29.tiff',
#  '/workspace/myFile/Output/17052023/A1005/ok_membrane_24.tiff',
#  '/workspace/myFile/Output/17052023/A0610/ok_membrane_51.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_293.tiff',
#  '/workspace/myFile/Output/17052023/A1008/ok_membrane_575.tiff',
#  '/workspace/myFile/Output/17052023/D1001/ok_membrane_5.tiff',
#  '/workspace/myFile/Output/17052023/C0423/ok_membrane_46.tiff',
#  '/workspace/myFile/Output/17052023/B1013/ok_membrane_173.tiff',
#  '/workspace/myFile/Output/17052023/F1117/ok_membrane_51.tiff',
#  '/workspace/myFile/Output/17052023/E0424/ok_membrane_64.tiff',
#  '/workspace/myFile/Output/17052023/A0402/ok_membrane_362.tiff',
#  '/workspace/myFile/Output/17052023/E0623/ok_membrane_85.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_1334.tiff',
#  '/workspace/myFile/Output/17052023/F1008/ok_membrane_206.tiff',
#  '/workspace/myFile/Output/17052023/D1024/ok_membrane_30.tiff',
#  '/workspace/myFile/Output/17052023/A0512/ok_membrane_120.tiff',
#  '/workspace/myFile/Output/17052023/A0518/ok_membrane_96.tiff',
#  '/workspace/myFile/Output/17052023/A0424/ok_membrane_354.tiff',
#  '/workspace/myFile/Output/17052023/E0422/ok_membrane_154.tiff',
#  '/workspace/myFile/Output/17052023/A0408/ok_membrane_415.tiff',
#  '/workspace/myFile/Output/17052023/C1113/ok_membrane_229.tiff',
#  '/workspace/myFile/Output/17052023/E1112/ok_membrane_223.tiff',
#  '/workspace/myFile/Output/17052023/E1108/ok_membrane_399.tiff',
#  '/workspace/myFile/Output/17052023/E1007/ok_membrane_14.tiff',
#  '/workspace/myFile/Output/17052023/A0413/ok_membrane_446.tiff',
#  '/workspace/myFile/Output/17052023/C0514/ok_membrane_80.tiff',
#  '/workspace/myFile/Output/17052023/E1222/ok_membrane_136.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_1618.tiff',
#  '/workspace/myFile/Output/17052023/A0403/ok_membrane_626.tiff',
#  '/workspace/myFile/Output/17052023/E1018/ok_membrane_165.tiff',
#  '/workspace/myFile/Output/17052023/A1208/ok_membrane_70.tiff',
#  '/workspace/myFile/Output/17052023/A1013/ok_membrane_73.tiff',
#  '/workspace/myFile/Output/17052023/D1111/ok_membrane_43.tiff',
#  '/workspace/myFile/Output/17052023/E1009/ok_membrane_66.tiff',
#  '/workspace/myFile/Output/17052023/E0509/ok_membrane_14.tiff',
#  '/workspace/myFile/Output/17052023/B1207/ok_membrane_58.tiff',
#  '/workspace/myFile/Output/17052023/B1103/ok_membrane_110.tiff',
#  '/workspace/myFile/Output/17052023/A1213/ok_membrane_387.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_1312.tiff',
#  '/workspace/myFile/Output/17052023/C1108/ok_membrane_148.tiff',
#  '/workspace/myFile/Output/17052023/B0413/ok_membrane_43.tiff',
#  '/workspace/myFile/Output/17052023/C0608/ok_membrane_38.tiff',
#  '/workspace/myFile/Output/17052023/C0502/ok_membrane_43.tiff',
#  '/workspace/myFile/Output/17052023/A1007/ok_membrane_283.tiff',
#  '/workspace/myFile/Output/17052023/F0511/ok_membrane_7.tiff',
#  '/workspace/myFile/Output/17052023/B1204/ok_membrane_46.tiff',
#  '/workspace/myFile/Output/17052023/A1216/ok_membrane_252.tiff',
#  '/workspace/myFile/Output/17052023/B0508/ok_membrane_76.tiff',
#  '/workspace/myFile/Output/17052023/B1010/ok_membrane_22.tiff',
#  '/workspace/myFile/Output/17052023/D0604/ok_membrane_9.tiff',
#  '/workspace/myFile/Output/17052023/F0517/ok_membrane_115.tiff',
#  '/workspace/myFile/Output/17052023/C1208/ok_membrane_22.tiff',
#  '/workspace/myFile/Output/17052023/A1120/ok_membrane_35.tiff',
#  '/workspace/myFile/Output/17052023/E1111/ok_membrane_185.tiff',
#  '/workspace/myFile/Output/17052023/F0509/ok_membrane_38.tiff',
#  '/workspace/myFile/Output/17052023/D1112/ok_membrane_164.tiff',
#  '/workspace/myFile/Output/17052023/A0518/ok_membrane_325.tiff',
#  '/workspace/myFile/Output/17052023/A1003/ok_membrane_266.tiff',
#  '/workspace/myFile/Output/17052023/A0423/ok_membrane_218.tiff',
#  '/workspace/myFile/Output/17052023/B1123/ok_membrane_85.tiff',
#  '/workspace/myFile/Output/17052023/E1116/ok_membrane_3.tiff',
#  '/workspace/myFile/Output/17052023/C0624/ok_membrane_18.tiff',
# ...
#  '/workspace/myFile/Output/17052023/E1112/ok_membrane_341.tiff',
#  '/workspace/myFile/Output/17052023/B0513/ok_membrane_88.tiff',
#  '/workspace/myFile/Output/17052023/A0610/ok_membrane_186.tiff',
#  '/workspace/myFile/Output/17052023/A1217/ok_membrane_181.tiff',
#  '/workspace/myFile/Output/17052023/C1114/ok_membrane_100.tiff',
#  '/workspace/myFile/Output/17052023/A0615/ok_membrane_212.tiff',
#  '/workspace/myFile/Output/17052023/D0415/ok_membrane_8.tiff',
#  '/workspace/myFile/Output/17052023/A0519/ok_membrane_588.tiff',
#  '/workspace/myFile/Output/17052023/E0408/ok_membrane_78.tiff',
#  '/workspace/myFile/Output/17052023/E1220/ok_membrane_76.tiff',
#  '/workspace/myFile/Output/17052023/C1003/ok_membrane_192.tiff',
#  '/workspace/myFile/Output/17052023/A1218/ok_membrane_71.tiff',
#  '/workspace/myFile/Output/17052023/A0612/ok_membrane_242.tiff',
#  '/workspace/myFile/Output/17052023/A0607/ok_membrane_631.tiff',
#  '/workspace/myFile/Output/17052023/A1120/ok_membrane_185.tiff',
#  '/workspace/myFile/Output/17052023/A0418/ok_membrane_276.tiff',
#  '/workspace/myFile/Output/17052023/A0625/ok_membrane_387.tiff',
#  '/workspace/myFile/Output/17052023/A0505/ok_membrane_52.tiff',
#  '/workspace/myFile/Output/17052023/E1011/ok_membrane_40.tiff',
#  '/workspace/myFile/Output/17052023/F0424/ok_membrane_67.tiff',
#  '/workspace/myFile/Output/17052023/C1012/ok_membrane_283.tiff',
#  '/workspace/myFile/Output/17052023/E0424/ok_membrane_88.tiff',
#  '/workspace/myFile/Output/17052023/E1217/ok_membrane_58.tiff',
#  '/workspace/myFile/Output/17052023/E1111/ok_membrane_8.tiff',
#  '/workspace/myFile/Output/17052023/A1216/ok_membrane_263.tiff',
#  '/workspace/myFile/Output/17052023/A1118/ok_membrane_37.tiff',
#  '/workspace/myFile/Output/17052023/A1208/ok_membrane_373.tiff',
#  '/workspace/myFile/Output/17052023/E1013/ok_membrane_375.tiff',
#  '/workspace/myFile/Output/17052023/B0418/ok_membrane_77.tiff',
#  '/workspace/myFile/Output/17052023/C1201/ok_membrane_26.tiff',
#  '/workspace/myFile/Output/17052023/E0616/ok_membrane_65.tiff',
#  '/workspace/myFile/Output/17052023/F0620/ok_membrane_45.tiff',
#  '/workspace/myFile/Output/17052023/F1103/ok_membrane_165.tiff',
#  '/workspace/myFile/Output/17052023/F1216/ok_membrane_95.tiff',
#  '/workspace/myFile/Output/17052023/A0507/ok_membrane_584.tiff',
#  '/workspace/myFile/Output/17052023/F1217/ok_membrane_108.tiff',
#  '/workspace/myFile/Output/17052023/A1017/ok_membrane_100.tiff',
#  '/workspace/myFile/Output/17052023/A1210/ok_membrane_122.tiff',
#  '/workspace/myFile/Output/17052023/F1014/ok_membrane_85.tiff',
#  '/workspace/myFile/Output/17052023/A1009/ok_membrane_17.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_1031.tiff',
#  '/workspace/myFile/Output/17052023/E1222/ok_membrane_39.tiff',
#  '/workspace/myFile/Output/17052023/A0601/ok_membrane_346.tiff',
#  '/workspace/myFile/Output/17052023/C1116/ok_membrane_65.tiff',
#  '/workspace/myFile/Output/17052023/E1215/ok_membrane_25.tiff',
#  '/workspace/myFile/Output/17052023/A1221/ok_membrane_91.tiff',
#  '/workspace/myFile/Output/17052023/A1112/ok_membrane_190.tiff',
#  '/workspace/myFile/Output/17052023/A0410/ok_membrane_129.tiff',
#  '/workspace/myFile/Output/17052023/A1003/ok_membrane_21.tiff',
#  '/workspace/myFile/Output/17052023/F1013/ok_membrane_127.tiff',
#  '/workspace/myFile/Output/17052023/A0606/ok_membrane_42.tiff',
#  '/workspace/myFile/Output/17052023/F1111/ok_membrane_115.tiff',
#  '/workspace/myFile/Output/17052023/D1103/ok_membrane_23.tiff',
#  '/workspace/myFile/Output/17052023/F0614/ok_membrane_83.tiff',
#  '/workspace/myFile/Output/17052023/F0513/ok_membrane_129.tiff',
#  '/workspace/myFile/Output/17052023/A1208/ok_membrane_97.tiff',
#  '/workspace/myFile/Output/17052023/A1109/ok_membrane_397.tiff',
#  '/workspace/myFile/Output/17052023/E1011/ok_membrane_59.tiff',
#  '/workspace/myFile/Output/17052023/A0517/ok_membrane_267.tiff',
#  '/workspace/myFile/Output/17052023/E1103/ok_membrane_78.tiff',
#  '/workspace/myFile/Output/17052023/D0413/ok_membrane_80.tiff',
#  '/workspace/myFile/Output/17052023/F0413/ok_membrane_194.tiff',
#  '/workspace/myFile/Output/17052023/A0615/ok_membrane_60.tiff',
#  '/workspace/myFile/Output/17052023/E1013/ok_membrane_97.tiff',
#  '/workspace/myFile/Output/17052023/D0408/ok_membrane_106.tiff',
#  '/workspace/myFile/Output/17052023/B1212/ok_membrane_63.tiff',
#  '/workspace/myFile/Output/17052023/B1109/ok_membrane_62.tiff',
#  '/workspace/myFile/Output/17052023/A1012/ok_membrane_459.tiff',
#  '/workspace/myFile/Output/17052023/F0625/ok_membrane_21.tiff',
#  '/workspace/myFile/Output/17052023/D1008/ok_membrane_51.tiff',
#  '/workspace/myFile/Output/17052023/C1204/ok_membrane_15.tiff',
#  '/workspace/myFile/Output/17052023/F1113/ok_membrane_62.tiff',
#  '/workspace/myFile/Output/17052023/C1019/ok_membrane_83.tiff',
#  '/workspace/myFile/Output/17052023/A1120/ok_membrane_234.tiff',
#  '/workspace/myFile/Output/17052023/A0509/ok_membrane_456.tiff',
#  '/workspace/myFile/Output/17052023/A0403/ok_membrane_606.tiff',
#  '/workspace/myFile/Output/17052023/A0517/ok_membrane_204.tiff',
#  '/workspace/myFile/Output/17052023/E1001/ok_membrane_84.tiff',
#  '/workspace/myFile/Output/17052023/B1112/ok_membrane_173.tiff',
#  '/workspace/myFile/Output/17052023/B1217/ok_membrane_5.tiff',
#  '/workspace/myFile/Output/17052023/C1124/ok_membrane_14.tiff',
#  '/workspace/myFile/Output/17052023/A0507/ok_membrane_39.tiff',
#  '/workspace/myFile/Output/17052023/C0502/ok_membrane_25.tiff',
#  '/workspace/myFile/Output/17052023/A0418/ok_membrane_125.tiff',
#  '/workspace/myFile/Output/17052023/C0502/ok_membrane_66.tiff',
#  '/workspace/myFile/Output/17052023/A1018/ok_membrane_99.tiff',
#  '/workspace/myFile/Output/17052023/F0424/ok_membrane_45.tiff',
#  '/workspace/myFile/Output/17052023/A1008/ok_membrane_577.tiff',
#  '/workspace/myFile/Output/17052023/D0517/ok_membrane_59.tiff',
#  '/workspace/myFile/Output/17052023/A0413/ok_membrane_134.tiff',
#  '/workspace/myFile/Output/17052023/F1012/ok_membrane_155.tiff',
#  '/workspace/myFile/Output/17052023/A1013/ok_membrane_177.tiff',
#  '/workspace/myFile/Output/17052023/A1211/ok_membrane_265.tiff',
#  '/workspace/myFile/Output/17052023/A1022/ok_membrane_27.tiff',
#  '/workspace/myFile/Output/17052023/B0413/ok_membrane_78.tiff',
#  '/workspace/myFile/Output/17052023/B1112/ok_membrane_295.tiff',
#  '/workspace/myFile/Output/17052023/F1125/ok_membrane_43.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_1480.tiff',
#  '/workspace/myFile/Output/17052023/A1114/ok_membrane_51.tiff',
#  '/workspace/myFile/Output/17052023/E1207/ok_membrane_183.tiff',
#  '/workspace/myFile/Output/17052023/F0517/ok_membrane_88.tiff',
#  '/workspace/myFile/Output/17052023/B1003/ok_membrane_128.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_1883.tiff',
#  '/workspace/myFile/Output/17052023/F1211/ok_membrane_114.tiff',
#  '/workspace/myFile/Output/17052023/A0611/ok_membrane_74.tiff',
#  '/workspace/myFile/Output/17052023/E0418/ok_membrane_195.tiff',
#  '/workspace/myFile/Output/17052023/A0512/ok_membrane_99.tiff',
#  '/workspace/myFile/Output/17052023/C0605/ok_membrane_70.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_1966.tiff',
#  '/workspace/myFile/Output/17052023/E1009/ok_membrane_28.tiff',
#  '/workspace/myFile/Output/17052023/C0520/ok_membrane_67.tiff',
#  '/workspace/myFile/Output/17052023/A0617/ok_membrane_350.tiff',
#  '/workspace/myFile/Output/17052023/A1213/ok_membrane_28.tiff',
#  '/workspace/myFile/Output/17052023/F0524/ok_membrane_38.tiff',
#  '/workspace/myFile/Output/17052023/D1101/ok_membrane_2.tiff',
#  '/workspace/myFile/Output/17052023/F0507/ok_membrane_176.tiff',
#  '/workspace/myFile/Output/17052023/B1002/ok_membrane_130.tiff',
#  '/workspace/myFile/Output/17052023/C0514/ok_membrane_11.tiff',
#  '/workspace/myFile/Output/17052023/A0512/ok_membrane_544.tiff',
#  '/workspace/myFile/Output/17052023/A0415/ok_membrane_20.tiff',
#  '/workspace/myFile/Output/17052023/C1021/ok_membrane_52.tiff',
#  '/workspace/myFile/Output/17052023/B0418/ok_membrane_40.tiff',
#  '/workspace/myFile/Output/17052023/E1205/ok_membrane_87.tiff',
#  '/workspace/myFile/Output/17052023/C0518/ok_membrane_97.tiff',
#  '/workspace/myFile/Output/17052023/C0418/ok_membrane_136.tiff',
#  '/workspace/myFile/Output/17052023/A1213/ok_membrane_52.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_2328.tiff',
#  '/workspace/myFile/Output/17052023/A1112/ok_membrane_123.tiff',
#  '/workspace/myFile/Output/17052023/B1002/ok_membrane_117.tiff',
#  '/workspace/myFile/Output/17052023/A0517/ok_membrane_319.tiff',
#  '/workspace/myFile/Output/17052023/A0507/ok_membrane_322.tiff',
#  '/workspace/myFile/Output/17052023/A1218/ok_membrane_332.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_2652.tiff',
#  '/workspace/myFile/Output/17052023/C1217/ok_membrane_85.tiff',
#  '/workspace/myFile/Output/17052023/F0625/ok_membrane_131.tiff',
#  '/workspace/myFile/Output/17052023/A1008/ok_membrane_185.tiff',
#  '/workspace/myFile/Output/17052023/C0515/ok_membrane_11.tiff',
#  '/workspace/myFile/Output/17052023/F1113/ok_membrane_228.tiff',
#  '/workspace/myFile/Output/17052023/F0616/ok_membrane_35.tiff',
#  '/workspace/myFile/Output/17052023/F1114/ok_membrane_88.tiff',
#  '/workspace/myFile/Output/17052023/B0412/ok_membrane_94.tiff',
#  '/workspace/myFile/Output/17052023/A0613/ok_membrane_588.tiff',
#  '/workspace/myFile/Output/17052023/E0413/ok_membrane_16.tiff',
#  '/workspace/myFile/Output/17052023/D0415/ok_membrane_3.tiff',
#  '/workspace/myFile/Output/17052023/C0403/ok_membrane_57.tiff',
#  '/workspace/myFile/Output/17052023/A0522/ok_membrane_84.tiff',
#  '/workspace/myFile/Output/17052023/C1112/ok_membrane_120.tiff',
#  '/workspace/myFile/Output/17052023/D0607/ok_membrane_29.tiff',
#  '/workspace/myFile/Output/17052023/E0607/ok_membrane_64.tiff',
#  '/workspace/myFile/Output/17052023/A1106/ok_membrane_151.tiff',
#  '/workspace/myFile/Output/17052023/A0408/ok_membrane_684.tiff',
#  '/workspace/myFile/Output/17052023/F0413/ok_membrane_537.tiff',
#  '/workspace/myFile/Output/17052023/E1013/ok_membrane_145.tiff',
#  '/workspace/myFile/Output/17052023/F0617/ok_membrane_61.tiff',
#  '/workspace/myFile/Output/17052023/A1218/ok_membrane_9.tiff',
#  '/workspace/myFile/Output/17052023/C1115/ok_membrane_60.tiff',
#  '/workspace/myFile/Output/17052023/C0524/ok_membrane_108.tiff',
#  '/workspace/myFile/Output/17052023/E0610/ok_membrane_10.tiff',
#  '/workspace/myFile/Output/17052023/A0519/ok_membrane_642.tiff',
#  '/workspace/myFile/Output/17052023/A0513/ok_membrane_259.tiff',
#  '/workspace/myFile/Output/17052023/A0518/ok_membrane_387.tiff',
#  '/workspace/myFile/Output/17052023/C0418/ok_membrane_201.tiff',
#  '/workspace/myFile/Output/17052023/E0413/ok_membrane_345.tiff',
#  '/workspace/myFile/Output/17052023/E1207/ok_membrane_118.tiff',
#  '/workspace/myFile/Output/17052023/E0606/ok_membrane_15.tiff',
#  '/workspace/myFile/Output/17052023/E1013/ok_membrane_368.tiff',
#  '/workspace/myFile/Output/17052023/E1008/ok_membrane_425.tiff',
#  '/workspace/myFile/Output/17052023/B0623/ok_membrane_66.tiff',
#  '/workspace/myFile/Output/17052023/A1203/ok_membrane_182.tiff',
#  '/workspace/myFile/Output/17052023/F0613/ok_membrane_319.tiff',
#  '/workspace/myFile/Output/17052023/B1013/ok_membrane_250.tiff',
#  '/workspace/myFile/Output/17052023/F0519/ok_membrane_43.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_2307.tiff',
#  '/workspace/myFile/Output/17052023/A1115/ok_membrane_166.tiff',
#  '/workspace/myFile/Output/17052023/E0618/ok_membrane_237.tiff',
#  '/workspace/myFile/Output/17052023/B1212/ok_membrane_25.tiff',
#  '/workspace/myFile/Output/17052023/F0416/ok_membrane_20.tiff',
#  '/workspace/myFile/Output/17052023/B1111/ok_membrane_130.tiff',
#  '/workspace/myFile/Output/17052023/A0513/ok_membrane_664.tiff',
#  '/workspace/myFile/Output/17052023/D1118/ok_membrane_5.tiff',
#  '/workspace/myFile/Output/17052023/A1217/ok_membrane_156.tiff',
#  '/workspace/myFile/Output/17052023/E1013/ok_membrane_267.tiff',
#  '/workspace/myFile/Output/17052023/F0604/ok_membrane_60.tiff',
#  '/workspace/myFile/Output/17052023/A0520/ok_membrane_54.tiff',
#  '/workspace/myFile/Output/17052023/E0611/ok_membrane_63.tiff',
#  '/workspace/myFile/Output/17052023/A0424/ok_membrane_328.tiff',
#  '/workspace/myFile/Output/17052023/A0513/ok_membrane_22.tiff',
#  '/workspace/myFile/Output/17052023/D0418/ok_membrane_19.tiff',
#  '/workspace/myFile/Output/17052023/B1111/ok_membrane_187.tiff',
#  '/workspace/myFile/Output/17052023/A1107/ok_membrane_221.tiff',
#  '/workspace/myFile/Output/17052023/A0610/ok_membrane_215.tiff',
#  '/workspace/myFile/Output/17052023/E0418/ok_membrane_65.tiff',
#  '/workspace/myFile/Output/17052023/B1002/ok_membrane_27.tiff',
#  '/workspace/myFile/Output/17052023/A1022/ok_membrane_385.tiff',
#  '/workspace/myFile/Output/17052023/A0408/ok_membrane_279.tiff',
#  '/workspace/myFile/Output/17052023/A1005/ok_membrane_92.tiff',
#  '/workspace/myFile/Output/17052023/B0414/ok_membrane_61.tiff',
#  '/workspace/myFile/Output/17052023/F0507/ok_membrane_55.tiff',
#  '/workspace/myFile/Output/17052023/B0423/ok_membrane_158.tiff',
#  '/workspace/myFile/Output/17052023/A0607/ok_membrane_241.tiff',
#  '/workspace/myFile/Output/17052023/F1114/ok_membrane_29.tiff',
#  '/workspace/myFile/Output/17052023/E0519/ok_membrane_33.tiff',
#  '/workspace/myFile/Output/17052023/A0607/ok_membrane_842.tiff',
#  '/workspace/myFile/Output/17052023/C0603/ok_membrane_15.tiff',
#  '/workspace/myFile/Output/17052023/A0505/ok_membrane_9.tiff',
#  '/workspace/myFile/Output/17052023/F1107/ok_membrane_140.tiff',
#  '/workspace/myFile/Output/17052023/A1016/ok_membrane_288.tiff',
#  '/workspace/myFile/Output/17052023/F0508/ok_membrane_213.tiff',
#  '/workspace/myFile/Output/17052023/A0424/ok_membrane_273.tiff',
#  '/workspace/myFile/Output/17052023/C1218/ok_membrane_36.tiff',
#  '/workspace/myFile/Output/17052023/C1012/ok_membrane_103.tiff',
#  '/workspace/myFile/Output/17052023/A0505/ok_membrane_21.tiff',
#  '/workspace/myFile/Output/17052023/F0408/ok_membrane_144.tiff',
#  '/workspace/myFile/Output/17052023/C1207/ok_membrane_142.tiff',
#  '/workspace/myFile/Output/17052023/A1021/ok_membrane_194.tiff',
#  '/workspace/myFile/Output/17052023/E0418/ok_membrane_92.tiff',
#  '/workspace/myFile/Output/17052023/A1022/ok_membrane_435.tiff',
#  '/workspace/myFile/Output/17052023/A0612/ok_membrane_102.tiff',
#  '/workspace/myFile/Output/17052023/E0523/ok_membrane_94.tiff',
#  '/workspace/myFile/Output/17052023/E1012/ok_membrane_381.tiff',
#  '/workspace/myFile/Output/17052023/A0613/ok_membrane_395.tiff',
#  '/workspace/myFile/Output/17052023/A1125/ok_membrane_262.tiff',
#  '/workspace/myFile/Output/17052023/A0522/ok_membrane_278.tiff',
#  '/workspace/myFile/Output/17052023/E1011/ok_membrane_3.tiff',
#  '/workspace/myFile/Output/17052023/E0522/ok_membrane_110.tiff',
#  '/workspace/myFile/Output/17052023/E1104/ok_membrane_67.tiff',
#  '/workspace/myFile/Output/17052023/E1212/ok_membrane_46.tiff',
#  '/workspace/myFile/Output/17052023/F0517/ok_membrane_412.tiff',
#  '/workspace/myFile/Output/17052023/B1002/ok_membrane_30.tiff',
#  '/workspace/myFile/Output/17052023/A0524/ok_membrane_306.tiff',
#  '/workspace/myFile/Output/17052023/A1113/ok_membrane_473.tiff',
#  '/workspace/myFile/Output/17052023/E1208/ok_membrane_18.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_715.tiff',
#  '/workspace/myFile/Output/17052023/B0413/ok_membrane_189.tiff',
#  '/workspace/myFile/Output/17052023/C1218/ok_membrane_65.tiff',
#  '/workspace/myFile/Output/17052023/E1112/ok_membrane_301.tiff',
#  '/workspace/myFile/Output/17052023/B0510/ok_membrane_31.tiff',
#  '/workspace/myFile/Output/17052023/C1003/ok_membrane_160.tiff',
#  '/workspace/myFile/Output/17052023/F1008/ok_membrane_200.tiff',
#  '/workspace/myFile/Output/17052023/C1001/ok_membrane_10.tiff',
#  '/workspace/myFile/Output/17052023/D1118/ok_membrane_13.tiff',
#  '/workspace/myFile/Output/17052023/A1217/ok_membrane_170.tiff',
#  '/workspace/myFile/Output/17052023/B1101/ok_membrane_473.tiff',
#  '/workspace/myFile/Output/17052023/C0522/ok_membrane_39.tiff',
#  '/workspace/myFile/Output/17052023/B1018/ok_membrane_66.tiff',
#  '/workspace/myFile/Output/17052023/F1013/ok_membrane_257.tiff',
#  '/workspace/myFile/Output/17052023/A0513/ok_membrane_1073.tiff',
#  ...]

# %%
imDr = "/workspace/myFile/Output/17052023/"  # Image patches directory

labels = ['Damaged', 'Undamaged']  # Your labels

# %%
# For data augmentation
def get_transform(train):
    transforms = []

    transforms.append(T.ToTensor())
    transforms.append(T.Normalize([0.0019368887995516483], [0.00672996630111016]))
    #transforms.append(T.RandomHorizontalFlip(0.5))
    
    if train:
        transforms.append(T.RandomHorizontalFlip())
        transforms.append(T.RandomVerticalFlip())
    
    return T.Compose(transforms)

# %%
def train_model(model, criterion, optimizer, scheduler, dataloaderTrain, dataloaderTest, num_epochs=25):
    since = time.time()
    # Create a temporary directory to save training checkpoints
    with TemporaryDirectory() as tempdir:
        best_model_params_path = os.path.join(tempdir, 'best_model_params.pt')

        torch.save(model.state_dict(), best_model_params_path)
        best_acc = 0.0

        for epoch in range(num_epochs):
            print(f'Epoch {epoch}/{num_epochs - 1}')
            print('-' * 10)

            # Each epoch has a training and validation phase
            for phase in ['train', 'val']:
                if phase == 'train':
                    model.train()  # Set model to training mode
                    dataloaders = dataloaderTrain
                else:
                    model.eval()   # Set model to evaluate mode
                    dataloaders = dataloaderTest

                running_loss = 0.0
                running_corrects = 0

                # Iterate over data.
                for inputs, labels, imNo in dataloaders:
                    inputs = inputs.to(device)
                    labels = labels.to(device)

                    # zero the parameter gradients
                    optimizer.zero_grad()

                    # forward
                    # track history if only in train
                    with torch.set_grad_enabled(phase == 'train'):
                        outputs = model(inputs)
                        _, preds = torch.max(outputs, 1)
                        loss = criterion(outputs, labels)
                        # backward + optimize only if in training phase
                        if phase == 'train':
                            loss.backward()
                            optimizer.step()

                    # statistics
                    running_loss += loss.item() * inputs.size(0)    # Loss
                    running_corrects += torch.sum(preds == labels.data) # Accuracy

                if phase == 'train':
                    scheduler.step()

                epoch_loss = running_loss / dataset_sizes[phase]    # Loss metric per epoch
                epoch_acc = running_corrects.double() / dataset_sizes[phase]    # Accuracy metric per epoch

                if phase == "train":    # This is the tensorboard code that writes accuracy and loss metrics
                    writer.add_scalar("Train/Accuracy", epoch_acc, epoch)
                    writer.add_scalar("Train/Loss", epoch_loss, epoch)
                else:
                    writer.add_scalar("Validation/Accuracy", epoch_acc, epoch)
                    writer.add_scalar("Validation/Loss", epoch_loss, epoch)

                print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

                # deep copy the model
                if phase == 'val' and epoch_acc > best_acc: 
                    # This compares validation accuracy to previous bests and adjusts model weights accordingly
                    best_acc = epoch_acc
                    torch.save(model.state_dict(), best_model_params_path)

            print()

        time_elapsed = time.time() - since  # Nice way to measure training time but info also stored (indirectly) by tensorboard
        print(
            f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
        print(f'Best val Acc: {best_acc:4f}')
        labels= labels.cpu().numpy()
        preds=preds.cpu().numpy()
        con_mat = confusion_matrix(labels, preds)   # Confusion matrix compares true class with predicted class
        # load best model weights
        model.load_state_dict(torch.load(best_model_params_path))
    writer.close()
    return model, con_mat   # We want to return the model because its the model, also confusion matrix for later analysis

# %%
# This is your RESNET
# Initialize CNN with kaiming
def init_cnn(m):
    # Set the weights of the RESNET
    if getattr(m, 'bias', None) is not None: nn.init.constant_(m.bias, 0)
    if isinstance(m, (nn.Conv2d,nn.Linear)): nn.init.kaiming_normal_(m.weight)
    for l in m.children(): init_cnn(l)


# noop function for returning nothing
def noop(x): return x
# activation function(RELU)
act_fn = nn.ReLU(inplace=True)

# Flatten
class Flatten(nn.Module):
    def forward(self, x): return x.view(x.size(0), -1)

# Make a convolution
def conv(ni, nf, ks=3, stride=1, bias=False):
    return nn.Conv2d(ni, nf, kernel_size=ks, stride=stride, padding=ks//2, bias=bias)

# Create a convuolutional layer with convolution and batch norm
def conv_layer(ni, nf, ks=3, stride=1, zero_bn=False, act=True):
    bn = nn.BatchNorm2d(nf) # get a 2d batch norm from Pytorhc
    nn.init.constant_(bn.weight, 0. if zero_bn else 1.)
    layers = [conv(ni, nf, ks, stride=stride), bn]
    if act: layers.append(act_fn) # add in the activation function if act is true
    return nn.Sequential(*layers)


# Resblock
class ResBlock(nn.Module):
    def __init__(self, expansion, ni, nh, stride = 1):
        super().__init__()
        # ni - number of inputs channels, nf - number of filters
        # nh - number of filters in first conv
        # expansion is 1 for resnet 18, 34 and 4 for larger networks
        nf, ni = nh*expansion, ni*expansion
        layers = [conv_layer(ni, nh, 3, stride = stride), # for resnet < 34 2 convs per resblock
                 conv_layer(nh, nf, 3, zero_bn = True, act = False)
                 ] if expansion == 1 else [ # for RESNET > 34 then 3 convs per block with bottleneck
                            conv_layer(ni, nh, 1),
                            conv_layer(nh, nh, 3, stride = stride),
                            conv_layer(nh, nf, 1, zero_bn = True, act = False)
        ]
        self.convs = nn.Sequential(*layers) # Creates the conv layers
        self.idconv = noop if ni==nf else conv_layer(ni, nf, 1, act = False) # id convolution ()
        self.pool = noop if stride== 1 else nn.AvgPool2d(2, ceil_mode = True) # average pool on 
        
    def forward(self, x): 
        # Forward function adds the convolution part to the id part 
        #return act_fn(self.convs(x)) + self.idconv(self.pool(x))
        return act_fn(self.convs(x) + self.idconv(self.pool(x)))

# XResnet
class XResNet(nn.Sequential):
    @classmethod
    def create(cls, expansion, layers, c_in=3, c_out=1000):
        nfs = [c_in, (c_in + 1)*8, 64, 64] # number of filters in stem layer (c_in is number of image channels)
        stem = [conv_layer(nfs[i], nfs[i+1], stride=2 if i==0 else 1)
            for i in range(3)]

        nfs = [64//expansion,64,128,256,512]
        res_layers = [cls._make_layer(expansion, nfs[i], nfs[i+1],
                                      n_blocks=l, stride=1 if i==0 else 2)
                  for i,l in enumerate(layers)]
        res = cls(
        *stem,
        nn.MaxPool2d(kernel_size=3, stride = 2, padding = 1), # then a max pooling layer
        *res_layers,
        nn.AdaptiveAvgPool2d(1), Flatten(), 
        nn.Linear(nfs[-1]*expansion, c_out)
        )
        init_cnn(res)
        return res
        
    @staticmethod
    def _make_layer(expansion, ni, nf, n_blocks, stride): # returns a resblock
        return nn.Sequential(
        *[ResBlock(expansion, ni if i==0 else nf, nf, stride if i==0 else 1)
         for i in range(n_blocks)])

# %%
def xresnet18 (**kwargs): return XResNet.create(1, [2, 2,  2, 2], **kwargs)
def xresnet34 (**kwargs): return XResNet.create(1, [3, 4,  6, 3], **kwargs)
def xresnet50 (**kwargs): return XResNet.create(4, [3, 4,  6, 3], **kwargs)
model = xresnet18(c_in = 1, c_out = 2)
#model = xresnet34(c_in = 1, c_out = 2)
#model = xresnet50(c_in = 1, c_out = 2)
model = model.to(device)

# Label smoothing cross entropy
import torch.nn.functional as F


def reduce_loss(loss, reduction='mean'):
    return loss.mean() if reduction=='mean' else loss.sum() if reduction=='sum' else loss

class LabelSmoothingCrossEntropy(nn.Module):
    def __init__(self, ε:float=0.1, reduction='mean'):
        super().__init__()
        self.ε,self.reduction = ε,reduction
    
    def forward(self, output, target):
        c = output.size()[-1]
        log_preds = F.log_softmax(output, dim=-1)
        loss = reduce_loss(-log_preds.sum(dim=-1), self.reduction)
        nll = F.nll_loss(log_preds, target, reduction=self.reduction)
        return lin_comb(loss/c, nll, self.ε)

# %%
# Helper functions that shows the image, true class, predicted class and degree of prediction

def images_to_probs(net, images):
    '''
    Generates predictions and corresponding probabilities from a trained
    network and a list of images
    '''
    output = net(images)
    # convert output probabilities to predicted class
    _, preds_tensor = torch.max(output, 1)
    preds = np.squeeze(preds_tensor.numpy())
    return preds, [F.softmax(el, dim=0)[i].item() for i, el in zip(preds, output)]


def plot_classes_preds(net, images, labels):
    '''
    Generates matplotlib Figure using a trained network, along with images
    and labels from a batch, that shows the network's top prediction along
    with its probability, alongside the actual label, coloring this
    information based on whether the prediction was correct or not.
    Uses the "images_to_probs" function.
    '''
    preds, probs = images_to_probs(net, images)
    # plot the images in the batch, along with predicted and true labels
    fig = plt.figure(figsize=(12, 48))
    for idx in np.arange(4):
        ax = fig.add_subplot(1, 4, idx+1, xticks=[], yticks=[])
        matplotlib_imshow(images[idx], one_channel=True)
        ax.set_title("{0}, {1:.1f}%\n(label: {2})".format(
            labels[preds[idx]],
            probs[idx] * 100.0,
            labels[labels[idx]]),
                    color=("green" if preds[idx]==labels[idx].item() else "red"))
    return fig

def matplotlib_imshow(img, one_channel=True):
    if one_channel:
        img = img.mean(dim=0)
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    if one_channel:
        plt.imshow(npimg, cmap="Greys")
    else:
        plt.imshow(np.transpose(npimg, (1, 2, 0)))

# %%
def confusion_matrix_calc(data_loader_test, classes, model_ft):       
        y_pred = []
        y_true = []
        for inputs, labels, imNo in data_loader_test:
                inputs = inputs.to(device)
                labels = labels.to(device)
                output = model_ft(inputs) # Feed Network

                output = (torch.max(torch.exp(output), 1)[1]).data.cpu().numpy()
                y_pred.extend(output) # Save Prediction
                
                labels = labels.data.cpu().numpy()
                y_true.extend(labels) # Save Truth

        # constant for classes
        # classes = ('Alive', 'Dead')

        # Build confusion matrix
        cf_matrix = confusion_matrix(y_true, y_pred)
        return cf_matrix

# %%
torch.manual_seed(10)
imIdx = torch.randperm(101106).tolist()

## Create dataset
dataSetTrain = DNADataset(imDr, get_transform(train = True), labels, imDx=imIdx)
dataSetTest = DNADataset(imDr, get_transform(train = False), labels, imDx=imIdx)

# ## Create dataloaders
# Get subset
torch.manual_seed(10)
indices = torch.randperm(len(dataSetTrain)).tolist()

noTrain = int(len(dataSetTrain)*0.7)

dataset_train = torch.utils.data.Subset(dataSetTrain, indices[-noTrain:])
dataset_test = torch.utils.data.Subset(dataSetTest, indices[:-noTrain])
#len(indices), len(indices[:-50]), len(indices[-50:]), 50/191, type(dataset_test)

dataset_sizes = {'train': len(dataset_train), 'val': len(dataset_test)}

# define training and validation data loaders
data_loader_train = torch.utils.data.DataLoader(
    dataset_train, batch_size=20, shuffle=True, num_workers=0)

data_loader_test = torch.utils.data.DataLoader(
    dataset_test, batch_size=1, shuffle=False, num_workers=0)


# Collate function (gathers together the outputs)
# def collate_fn(batch):
#     return tuple(zip(*batch))

len(indices[-noTrain:]), dataset_sizes
#dataset_test[0][1], dataset_test[3][1], dataset_test[-1][1], dataSetTrain.imgs
# Out:
# (12430, {'train': 12430, 'val': 5328})

# %%
criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.Adam(model.parameters(), weight_decay=1e-2) # standard ADAM optimiser

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %%
model_ft, con_mat = train_model(model, criterion, optimizer_ft, exp_lr_scheduler,
                       data_loader_train,data_loader_test,num_epochs=5)
# Out:
# Epoch 0/4
# ----------
# train Loss: 0.5952 Acc: 0.6962
# val Loss: 0.6716 Acc: 0.5456
#
# Epoch 1/4
# ----------
# train Loss: 0.5795 Acc: 0.7080
# val Loss: 0.5720 Acc: 0.7179
#
# Epoch 2/4
# ----------
# train Loss: 0.5732 Acc: 0.7142
# val Loss: 0.5748 Acc: 0.7006
#
# Epoch 3/4
# ----------
# train Loss: 0.5534 Acc: 0.7298
# val Loss: 0.7551 Acc: 0.4976
#
# Epoch 4/4
# ----------
# train Loss: 0.5391 Acc: 0.7388
# val Loss: 0.5356 Acc: 0.7361
#
# Training complete in 9m 52s
# Best val Acc: 0.736111

# %%
cf_matrix = confusion_matrix_calc(data_loader_test, labels, model_ft)

# %%
df_cm_ratio = pd.DataFrame(cf_matrix / np.sum(cf_matrix, axis=1)[:, None], index=[i for i in labels],
                     columns=[i for i in labels])
plt.figure(figsize=(12, 7))
sn.heatmap(df_cm_ratio, annot=True)
# plt.save("Confusion_matrix_ratio.png")
# Out:
# <AxesSubplot:>

# %%
df_cm_raw = pd.DataFrame(cf_matrix, index=[i for i in labels],
                     columns=[i for i in labels])
plt.figure(figsize=(12, 7))
sn.heatmap(df_cm_raw, annot=True)
# plt.save("Confusion_matrix_raw.png")
# Out:
# <AxesSubplot:>

# %%
cf_matrix
# Out:
# array([[1621, 1030],
#        [ 376, 2301]])
