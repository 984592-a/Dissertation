# %% [markdown]
# ### To note: Running this on different systems (i.e. local, SCW, server) will result in slight changes needing to the code

# %%
# Load libraries
import os
import numpy as np
import torch
import sys
import torchvision
import torchvision.transforms as T
import torchvision.models as models
from PIL import Image
from PIL import ImageEnhance
import matplotlib.pyplot as plt
import imagesize
import subprocess
sys.path
from IPython.core.debugger import set_trace
import scipy.ndimage
import matplotlib.patches as patches
# plt.rcParams['figure.figsize'] = [12,12]
# sys.path.append('/workspace/myFile/Mask_RCNN_Tutorial/')
from tqdm import tqdm
from torch import nn as nn
from torch import optim as optim
from torch.optim import lr_scheduler
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
import re
import time
import copy
import pylab
from torch.utils.tensorboard import SummaryWriter
from tempfile import TemporaryDirectory
import torch.backends.cudnn as cudnn
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import seaborn as sn
import pandas as pd
import glob
# Rather than have a messy notebook with a load of functions we can store them in separate .py files and import them

cudnn.benchmark = True
plt.ion()   # interactive mode
# Out:
# /opt/conda/lib/python3.8/site-packages/scipy/__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
# %load_ext tensorboard
writer = SummaryWriter("Experiments/09085epoch")    # This determines the tensorboard file name

# %%
class DNADataset(object):
    def __init__(self, root, transforms, labels, imDx = False):
        self.root, self.transforms, self.labels = root, transforms, labels
        self.imgDir=[]
        # load all image files, sorting them to ensure they are aligned
        for drug in ["A","B","C","D","E","F"]:
            subset=glob.glob(root+drug+"*/*.tiff")
            np.random.shuffle(subset)
            subset=subset[:12945]
            self.imgDir=self.imgDir+subset
        Damagednuclei= [x for x in self.imgDir if 'Damaged_nuclei_' in x]
        Undamagednuclei= [x for x in self.imgDir if "No_damage_nuclei" in x]
        #np.random.shuffle(Undamagednuclei)
        #Undamagednuclei=Undamagednuclei[:10000]
        self.imgDir= Damagednuclei+Undamagednuclei
        size80=[]
        for x in self.imgDir:
            img = Image.open(x) # Open image
            w,h=img.size
            if w<=80 and h<=80:
                size80.append(x)
        self.imgDir=size80              
        
        self.imgs = sorted(self.imgDir) # list of images

        

        
    def __getitem__(self, idx):
        img_path = self.imgs[idx]
       
        # Transform images into tensors
        img = Image.open(img_path) # Open image
        w,h=img.size
        img = np.array(img) # Convert image into an array
        img = np.float32(np.divide(img, 2**16)) # Ensure all values are floats
        
        result=np.zeros((80,80), dtype=np.float32)
        x_center = (80 - w) // 2
        y_center = (80 - h) // 2 # copy img image into center of result image
        result[y_center:y_center+h, x_center:x_center+w] = img
        img = result
        
        targetlab=""
        if img_path.find('No_damage_nuclei') != -1:
            targetlab= 'Undamaged'
        if img_path.find('Damaged_nuclei_') != -1:
            targetlab= 'Damaged'  # Find labels corresponding to image
        target = self.labels.index(targetlab) # Get the label and assign to a value
        
        # Convert label to tensor
        #torch.to
        
        if self.transforms is not None:
            img = self.transforms(img)
#             #print('In the transforms')
        imNo = idx
        return img, target, imNo
        
    def __len__(self):
        return len(self.imgs)

# %%
root="/workspace/myFile/Output/17052023/"
p= glob.glob(root+"*/*.tiff")
Damagednuclei= [x for x in p if 'Damaged_nuclei_' in x]
Undamagednuclei= [x for x in p if "No_damage_nuclei" in x]
#np.random.shuffle(Undamagednuclei)
#Undamagednuclei=Undamagednuclei[:10000]
#Undamagednuclei

# %%
imDr = "/workspace/myFile/Output/17052023/"  # Image patches directory

labels = ['Damaged', 'Undamaged']  # Your labels

# %%
# For data augmentation
def get_transform(train):
    transforms = []

    transforms.append(T.ToTensor())
    #transforms.append(T.Normalize([0.0019368887995516483], [0.00672996630111016]))
    #transforms.append(T.RandomHorizontalFlip(0.5))
    
    if train:
        transforms.append(T.RandomHorizontalFlip(p=0.5))
        transforms.append(T.RandomVerticalFlip(p=0.5))
    
    return T.Compose(transforms)

# %%
def train_model(model, criterion, optimizer, scheduler, train, test, num_epochs=25):
    since = time.time()
    # Create a temporary directory to save training checkpoints
    with TemporaryDirectory() as tempdir:
        best_model_params_path = os.path.join(tempdir, 'best_model_params.pt')

        torch.save(model.state_dict(), best_model_params_path)
        best_acc = 0.0
        
        for epoch in range(num_epochs):
            print(f'Epoch {epoch}/{num_epochs - 1}')
            print('-' * 10)
            dataset_train = torch.utils.data.Subset(dataSetTrain, train[epoch])
            dataset_test = torch.utils.data.Subset(dataSetTest, test[epoch])
            data_loader_train = torch.utils.data.DataLoader(
                dataset_train, batch_size=128, shuffle=True, num_workers=0)

            data_loader_test = torch.utils.data.DataLoader(
                dataset_test, batch_size=128, shuffle=False, num_workers=0)
            # Each epoch has a training and validation phase
            for phase in ['train', 'val']:
                if phase == 'train':
                    model.train()  # Set model to training mode
                    dataloaders = data_loader_train
                else:
                    model.eval()   # Set model to evaluate mode
                    dataloaders = data_loader_test

                running_loss = 0.0
                running_corrects = 0
                damaged_len=0
                damaged_corrects = 0
                undamaged_len=0
                undamaged_corrects = 0

                # Iterate over data.
                for inputs, labels, imNo in dataloaders:
                    inputs = inputs.to(device)
                    labels = labels.to(device)

                    # zero the parameter gradients
                    optimizer.zero_grad()

                    # forward
                    # track history if only in train
                    with torch.set_grad_enabled(phase == 'train'):
                        outputs = model(inputs)
                        _, preds = torch.max(outputs, 1)
                        loss = criterion(outputs, labels)
                        # backward + optimize only if in training phase
                        if phase == 'train':
                            loss.backward()
                            optimizer.step()

                    # statistics
                    running_loss += loss.item() * inputs.size(0)    # Loss
                    nada=torch.tensor(np.zeros(len(labels))).to(device)
                    uno=nada+1
                    falseneg=preds+1
                    falsepos=preds-1
                    FPplusTN=torch.sum(labels==nada)
                    TPplusFN=torch.sum(labels==uno)
                    FN=torch.sum(labels==falseneg)
                    FP=torch.sum(labels==falsepos)
                    TN=FPplusTN-FP
                    TP=TPplusFN-FN
                    running_corrects += torch.sum(preds == labels.data) # Accuracy
                    damaged_len+=TPplusFN
                    damaged_corrects += TP
                    undamaged_len+=FPplusTN
                    undamaged_corrects += TN
                damaged_acc = damaged_corrects / damaged_len
                undamaged_acc = undamaged_corrects/undamaged_len
                epoch_acc= (damaged_acc+undamaged_acc)/2
                
                if phase == 'train':
                    scheduler.step()

                epoch_loss = running_loss / dataset_sizes[phase]    # Loss metric per epoch
                #epoch_acc = running_corrects.double() / dataset_sizes[phase]    # Accuracy metric per epoch

                if phase == "train":    # This is the tensorboard code that writes accuracy and loss metrics
                    writer.add_scalar("Train/Accuracy", epoch_acc, epoch)
                    writer.add_scalar("Train/Loss", epoch_loss, epoch)
                else:
                    writer.add_scalar("Validation/Accuracy", epoch_acc, epoch)
                    writer.add_scalar("Validation/Loss", epoch_loss, epoch)

                print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

                # deep copy the model
                if phase == 'val' and epoch_acc >= best_acc: 
                    # This compares validation accuracy to previous bests and adjusts model weights accordingly
                    best_acc = epoch_acc
                    torch.save(model.state_dict(), best_model_params_path)
                    con_mat= torch.tensor([[damaged_corrects, damaged_len-damaged_corrects],[undamaged_len-undamaged_corrects,undamaged_corrects]])

            print()

        time_elapsed = time.time() - since  # Nice way to measure training time but info also stored (indirectly) by tensorboard
        print(
            f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
        print(f'Best val Acc: {best_acc:4f}')
        #labels= labels.cpu().numpy()
        #preds=preds.cpu().numpy()
        model.load_state_dict(torch.load(best_model_params_path))
    writer.close()
    return model, con_mat, best_acc   # We want to return the model because its the model, also confusion matrix for later analysis

# %%
# This is your RESNET
# Initialize CNN with kaiming
def init_cnn(m):
    # Set the weights of the RESNET
    if getattr(m, 'bias', None) is not None: nn.init.constant_(m.bias, 0)
    if isinstance(m, (nn.Conv2d,nn.Linear)): nn.init.kaiming_normal_(m.weight)
    for l in m.children(): init_cnn(l)


# noop function for returning nothing
def noop(x): return x
# activation function(RELU)
act_fn = nn.ReLU(inplace=True)

# Flatten
class Flatten(nn.Module):
    def forward(self, x): return x.view(x.size(0), -1)

# Make a convolution
def conv(ni, nf, ks=3, stride=1, bias=False):
    return nn.Conv2d(ni, nf, kernel_size=ks, stride=stride, padding=ks//2, bias=bias)

# Create a convuolutional layer with convolution and batch norm
def conv_layer(ni, nf, ks=3, stride=1, zero_bn=False, act=True):
    bn = nn.BatchNorm2d(nf) # get a 2d batch norm from Pytorhc
    nn.init.constant_(bn.weight, 0. if zero_bn else 1.)
    layers = [conv(ni, nf, ks, stride=stride), bn]
    if act: layers.append(act_fn) # add in the activation function if act is true
    return nn.Sequential(*layers)


# Resblock
class ResBlock(nn.Module):
    def __init__(self, expansion, ni, nh, stride = 1):
        super().__init__()
        # ni - number of inputs channels, nf - number of filters
        # nh - number of filters in first conv
        # expansion is 1 for resnet 18, 34 and 4 for larger networks
        nf, ni = nh*expansion, ni*expansion
        layers = [conv_layer(ni, nh, 3, stride = stride), # for resnet < 34 2 convs per resblock
                 conv_layer(nh, nf, 3, zero_bn = True, act = False)
                 ] if expansion == 1 else [ # for RESNET > 34 then 3 convs per block with bottleneck
                            conv_layer(ni, nh, 1),
                            conv_layer(nh, nh, 3, stride = stride),
                            conv_layer(nh, nf, 1, zero_bn = True, act = False)
        ]
        self.convs = nn.Sequential(*layers) # Creates the conv layers
        self.idconv = noop if ni==nf else conv_layer(ni, nf, 1, act = False) # id convolution ()
        self.pool = noop if stride== 1 else nn.AvgPool2d(2, ceil_mode = True) # average pool on 
        
    def forward(self, x): 
        # Forward function adds the convolution part to the id part 
        #return act_fn(self.convs(x)) + self.idconv(self.pool(x))
        return act_fn(self.convs(x) + self.idconv(self.pool(x)))

# XResnet
class XResNet(nn.Sequential):
    @classmethod
    def create(cls, expansion, layers, c_in=3, c_out=1000):
        nfs = [c_in, (c_in + 1)*8, 64, 64] # number of filters in stem layer (c_in is number of image channels)
        stem = [conv_layer(nfs[i], nfs[i+1], stride=2 if i==0 else 1)
            for i in range(3)]

        nfs = [64//expansion,64,128,256,512]
        res_layers = [cls._make_layer(expansion, nfs[i], nfs[i+1],
                                      n_blocks=l, stride=1 if i==0 else 2)
                  for i,l in enumerate(layers)]
        res = cls(
        *stem,
        nn.MaxPool2d(kernel_size=3, stride = 2, padding = 1), # then a max pooling layer
        *res_layers,
        nn.AdaptiveAvgPool2d(1), Flatten(), 
        nn.Linear(nfs[-1]*expansion, c_out)
        )
        init_cnn(res)
        return res
        
    @staticmethod
    def _make_layer(expansion, ni, nf, n_blocks, stride): # returns a resblock
        return nn.Sequential(
        *[ResBlock(expansion, ni if i==0 else nf, nf, stride if i==0 else 1)
         for i in range(n_blocks)])

# %%
def xresnet18 (**kwargs): return XResNet.create(1, [2, 2,  2, 2], **kwargs)
def xresnet34 (**kwargs): return XResNet.create(1, [3, 4,  6, 3], **kwargs)
def xresnet50 (**kwargs): return XResNet.create(4, [3, 4,  6, 3], **kwargs)
model18 = xresnet18(c_in = 1, c_out = 2)
model34 = xresnet34(c_in = 1, c_out = 2)
model50 = xresnet50(c_in = 1, c_out = 2)

# Label smoothing cross entropy
import torch.nn.functional as F


def reduce_loss(loss, reduction='mean'):
    return loss.mean() if reduction=='mean' else loss.sum() if reduction=='sum' else loss

class LabelSmoothingCrossEntropy(nn.Module):
    def __init__(self, ε:float=0.1, reduction='mean'):
        super().__init__()
        self.ε,self.reduction = ε,reduction
    
    def forward(self, output, target):
        c = output.size()[-1]
        log_preds = F.log_softmax(output, dim=-1)
        loss = reduce_loss(-log_preds.sum(dim=-1), self.reduction)
        nll = F.nll_loss(log_preds, target, reduction=self.reduction)
        return lin_comb(loss/c, nll, self.ε)

# %%
# Helper functions that shows the image, true class, predicted class and degree of prediction

def images_to_probs(net, images):
    '''
    Generates predictions and corresponding probabilities from a trained
    network and a list of images
    '''
    output = net(images)
    # convert output probabilities to predicted class
    _, preds_tensor = torch.max(output, 1)
    preds = np.squeeze(preds_tensor.numpy())
    return preds, [F.softmax(el, dim=0)[i].item() for i, el in zip(preds, output)]


def plot_classes_preds(net, images, labels):
    '''
    Generates matplotlib Figure using a trained network, along with images
    and labels from a batch, that shows the network's top prediction along
    with its probability, alongside the actual label, coloring this
    information based on whether the prediction was correct or not.
    Uses the "images_to_probs" function.
    '''
    preds, probs = images_to_probs(net, images)
    # plot the images in the batch, along with predicted and true labels
    fig = plt.figure(figsize=(12, 48))
    for idx in np.arange(4):
        ax = fig.add_subplot(1, 4, idx+1, xticks=[], yticks=[])
        matplotlib_imshow(images[idx], one_channel=True)
        ax.set_title("{0}, {1:.1f}%\n(label: {2})".format(
            labels[preds[idx]],
            probs[idx] * 100.0,
            labels[labels[idx]]),
                    color=("green" if preds[idx]==labels[idx].item() else "red"))
    return fig

def matplotlib_imshow(img, one_channel=True):
    if one_channel:
        img = img.mean(dim=0)
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    if one_channel:
        plt.imshow(npimg, cmap="Greys")
    else:
        plt.imshow(np.transpose(npimg, (1, 2, 0)))

# %%
def confusion_matrix_calc(data_loader_test, classes, model_ft):       
        y_pred = []
        y_true = []
        for inputs, labels, imNo in data_loader_test:
                inputs = inputs.to(device)
                labels = labels.to(device)
                output = model_ft(inputs) # Feed Network

                output = (torch.max(torch.exp(output), 1)[1]).data.cpu().numpy()
                y_pred.extend(output) # Save Prediction
                
                labels = labels.data.cpu().numpy()
                y_true.extend(labels) # Save Truth

        # constant for classes
        # classes = ('Alive', 'Dead')

        # Build confusion matrix
        cf_matrix = confusion_matrix(y_true, y_pred)
        return cf_matrix

# %%
k=5 #NUMBER OF K FOLDS
epoch=range(30) #NUMBER OF EPOCHS

torch.manual_seed(10)
imIdx = torch.randperm(1).tolist()

## Create dataset
dataSetTrain = DNADataset(imDr, get_transform(train = True), labels, imDx=imIdx)
dataSetTest = DNADataset(imDr, get_transform(train = False), labels, imDx=imIdx)

data_loader_train=[]
data_loader_test=[]

# ## Create dataloaders
# Get subset
torch.manual_seed(10)
TotalSetTrain=list(range(len(dataSetTrain)))
np.random.shuffle(TotalSetTrain)
TotalSetTest=list(range(len(dataSetTest)))
np.random.shuffle(TotalSetTest)

train=[]
test=[]
for epoch in epoch:
    
    Kfifth = len(dataSetTrain)//k
    split= epoch%k
    train.append(TotalSetTrain[(split+1)*Kfifth:]+TotalSetTrain[:Kfifth*split])
    test.append(TotalSetTest[split*Kfifth:(split+1)*Kfifth])

#dataset_train = torch.utils.data.Subset(dataSetTrain, indices[-noTrain:])

#dataset_test = torch.utils.data.Subset(dataSetTest, indices[:-noTrain])
#len(indices), len(indices[:-50]), len(indices[-50:]), 50/191, type(dataset_test)

dataset_sizes = {'train': len(train[0]), 'val': len(test[0])}

#dataset_train = torch.utils.data.Subset(dataSetTrain, train)
#data_loader_train.append(dataset_train)
#dataset_testo = torch.utils.data.Subset(dataSetTest, test)
#data_loader_test.append(dataset_testo)
# define training and validation data loaders


# Collate function (gathers together the outputs)
# def collate_fn(batch):
#     return tuple(zip(*batch))

#len(indices[-noTrain:]), dataset_sizes
#dataset_test[0][1], dataset_test[3][1], dataset_test[-1][1], dataSetTrain.imgs

# %%
class_weights= [0.924865,0.075135] #1-(#inclass/ #intotal )
class_weights = torch.Tensor(class_weights)
class_weights=class_weights.to(device)
criterion = nn.CrossEntropyLoss(weight = class_weights) 

# Observe that all parameters are being optimized
learning_rate=[0.05, 0.1,0.2]
Momentum=[0.5,0.9,0.99]
GAMMA=[0.05, 0.1, 0.5]
#Batch_size= [16,32]#,64,128]
models=[model18, model34, model50]
modelnames=["model18","model34","model50"]
#ADD IN A THING SO IT SAVES THE TENSORBOARD TO DIFFERENT BITS
best_params = None
best_score=0.00
Current_params=None
for lrnum in range(3):
    for gamnum in range(3):
        for Momnum in range(3):
            for modnum in range(3):
                model=models[modnum]
                model = model.to(device)
                optimizer_ft = optim.SGD(model.parameters(), lr=learning_rate[lrnum], momentum=Momentum[Momnum])
                exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=GAMMA[gamnum])
                writer = SummaryWriter("Experiments/undersampledrug2/lr"+str(learning_rate[lrnum])+"momentum"+
                        str(Momentum[Momnum])+"gamma"+str(GAMMA[gamnum])+"model"+modelnames[modnum])  
                model_ft, con_mat, current_score = train_model(model, criterion, optimizer_ft, exp_lr_scheduler,
                   train,test,num_epochs=5)
                con_mat=con_mat.cpu().numpy()
                current_score=current_score.cpu().numpy()
                Current_params= {'learning rate': learning_rate[lrnum], 'gamma': GAMMA[gamnum], 
                                   'Momentum': Momentum[Momnum], 'Model': modelnames[modnum]}
                print(con_mat)
                print("Current hyperparameters:", Current_params)
                df_cm_ratio = pd.DataFrame(con_mat / np.sum(con_mat, axis=1)[:, None], index=[i for i in labels],
                                     columns=[i for i in labels])
                plt.figure(figsize=(12, 7))
                sn.heatmap(df_cm_ratio, annot=True)
                if current_score > best_score:
                    best_score = current_score
                    best_params = {'learning rate': learning_rate[lrnum], 'gamma': GAMMA[gamnum], 
                                   'Momentum': Momentum[Momnum], 'Model': modelnames[modnum]}
                            
print("Best hyperparameters:", best_params)
print("Best score:", best_score)
# Out:
# Epoch 0/4
# ----------
# train Loss: 0.5633 Acc: 0.6940
# val Loss: 0.7977 Acc: 0.6182
#
# Epoch 1/4
# ----------
# train Loss: 0.4998 Acc: 0.7595
# val Loss: 0.4728 Acc: 0.7819
#
# Epoch 2/4
# ----------
# train Loss: 0.4650 Acc: 0.7815
# val Loss: 0.4524 Acc: 0.7825
#
# Epoch 3/4
# ----------
# train Loss: 0.4539 Acc: 0.7878
# val Loss: 0.4281 Acc: 0.8005
#
# Epoch 4/4
# ----------
# train Loss: 0.4386 Acc: 0.7968
# val Loss: 0.4204 Acc: 0.8105
#
# Training complete in 4m 32s
# Best val Acc: 0.810483
# [[5679 1468]
#  [ 162  771]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.5666 Acc: 0.6945
# val Loss: 0.6776 Acc: 0.6176
#
# Epoch 1/4
# ----------
# train Loss: 0.4953 Acc: 0.7623
# val Loss: 0.6036 Acc: 0.7235
#
# Epoch 2/4
# ----------
# train Loss: 0.4660 Acc: 0.7771
# val Loss: 0.4983 Acc: 0.7803
#
# Epoch 3/4
# ----------
# train Loss: 0.4479 Acc: 0.7854
# val Loss: 0.4701 Acc: 0.7748
#
# Epoch 4/4
# ----------
# train Loss: 0.4317 Acc: 0.8000
# val Loss: 0.4340 Acc: 0.7908
#
# Training complete in 4m 59s
# Best val Acc: 0.790808
# [[5122 2025]
#  [ 126  807]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.7416 Acc: 0.6608
# val Loss: 1.3866 Acc: 0.5337
#
# Epoch 1/4
# ----------
# train Loss: 0.5566 Acc: 0.7473
# val Loss: 0.5461 Acc: 0.7392
#
# Epoch 2/4
# ----------
# train Loss: 0.5129 Acc: 0.7651
# val Loss: 0.4431 Acc: 0.8057
#
# Epoch 3/4
# ----------
# train Loss: 0.5045 Acc: 0.7714
# val Loss: 0.4931 Acc: 0.7516
#
# Epoch 4/4
# ----------
# train Loss: 0.4775 Acc: 0.7819
# val Loss: 0.5261 Acc: 0.6762
#
# Training complete in 5m 32s
# Best val Acc: 0.805692
# [[5698 1447]
#  [ 174  761]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.5394 Acc: 0.7383
# val Loss: 0.6152 Acc: 0.7396
#
# Epoch 1/4
# ----------
# train Loss: 0.4815 Acc: 0.7710
# val Loss: 0.7391 Acc: 0.6761
#
# Epoch 2/4
# ----------
# train Loss: 0.4590 Acc: 0.7795
# val Loss: 0.5739 Acc: 0.7406
#
# Epoch 3/4
# ----------
# train Loss: 0.4357 Acc: 0.7920
# val Loss: 0.4812 Acc: 0.7216
#
# Epoch 4/4
# ----------
# train Loss: 0.4209 Acc: 0.7986
# val Loss: 0.4071 Acc: 0.8159
#
# Training complete in 4m 28s
# Best val Acc: 0.815940
# [[5374 1773]
#  [ 112  821]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.5395 Acc: 0.7318
# val Loss: 0.7671 Acc: 0.6775
#
# Epoch 1/4
# ----------
# train Loss: 0.4794 Acc: 0.7690
# val Loss: 0.4550 Acc: 0.7592
#
# Epoch 2/4
# ----------
# train Loss: 0.4458 Acc: 0.7829
# val Loss: 0.5208 Acc: 0.7091
#
# Epoch 3/4
# ----------
# train Loss: 0.4268 Acc: 0.7928
# val Loss: 0.4489 Acc: 0.7365
#
# Epoch 4/4
# ----------
# train Loss: 0.4158 Acc: 0.8048
# val Loss: 0.4798 Acc: 0.7881
#
# Training complete in 5m 1s
# Best val Acc: 0.788104
# [[6286  861]
#  [ 283  650]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.7472 Acc: 0.7023
# val Loss: 0.5930 Acc: 0.6226
#
# Epoch 1/4
# ----------
# train Loss: 0.5456 Acc: 0.7513
# val Loss: 2.5977 Acc: 0.4998
#
# Epoch 2/4
# ----------
# train Loss: 0.4543 Acc: 0.7814
# val Loss: 0.4686 Acc: 0.7823
#
# Epoch 3/4
# ----------
# train Loss: 0.4450 Acc: 0.7889
# val Loss: 0.5171 Acc: 0.7470
#
# Epoch 4/4
# ----------
# train Loss: 0.4547 Acc: 0.7892
# val Loss: 0.5016 Acc: 0.7883
#
# Training complete in 5m 32s
# Best val Acc: 0.788308
# [[6197  950]
#  [ 271  662]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.5200 Acc: 0.7440
# val Loss: 0.5813 Acc: 0.7574
#
# Epoch 1/4
# ----------
# train Loss: 0.5112 Acc: 0.7398
# val Loss: 0.6575 Acc: 0.6203
#
# Epoch 2/4
# ----------
# train Loss: 0.4774 Acc: 0.7701
# val Loss: 0.7108 Acc: 0.5657
#
# Epoch 3/4
# ----------
# train Loss: 0.4533 Acc: 0.7789
# val Loss: 0.4380 Acc: 0.7875
#
# Epoch 4/4
# ----------
# train Loss: 0.4429 Acc: 0.7903
# val Loss: 0.4741 Acc: 0.7560
#
# Training complete in 4m 26s
# Best val Acc: 0.787503
# [[5198 1898]
#  [ 155  829]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.5044 Acc: 0.7489
# val Loss: 0.4915 Acc: 0.7548
#
# Epoch 1/4
# ----------
# train Loss: 0.5022 Acc: 0.7569
# val Loss: 0.4591 Acc: 0.7821
#
# Epoch 2/4
# ----------
# train Loss: 0.4579 Acc: 0.7759
# val Loss: 0.4695 Acc: 0.7600
#
# Epoch 3/4
# ----------
# train Loss: 0.4575 Acc: 0.7740
# val Loss: 0.5230 Acc: 0.6906
#
# Epoch 4/4
# ----------
# train Loss: 0.4424 Acc: 0.7883
# val Loss: 0.4509 Acc: 0.7728
#
# Training complete in 4m 58s
# Best val Acc: 0.782108
# [[5164 1974]
#  [ 150  792]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.5483 Acc: 0.7308
# val Loss: 1.5532 Acc: 0.5291
#
# Epoch 1/4
# ----------
# train Loss: 0.5047 Acc: 0.7485
# val Loss: 0.4778 Acc: 0.7582
#
# Epoch 2/4
# ----------
# train Loss: 0.4712 Acc: 0.7700
# val Loss: 0.5974 Acc: 0.7159
#
# Epoch 3/4
# ----------
# train Loss: 0.4643 Acc: 0.7759
# val Loss: 0.4411 Acc: 0.7799
#
# Epoch 4/4
# ----------
# train Loss: 0.4520 Acc: 0.7814
# val Loss: 0.4702 Acc: 0.7936
#
# Training complete in 5m 31s
# Best val Acc: 0.793573
# [[5782 1365]
#  [ 207  726]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4234 Acc: 0.7989
# val Loss: 0.4235 Acc: 0.8033
#
# Epoch 1/4
# ----------
# train Loss: 0.4157 Acc: 0.8056
# val Loss: 0.4129 Acc: 0.7994
#
# Epoch 2/4
# ----------
# train Loss: 0.4112 Acc: 0.8079
# val Loss: 0.4311 Acc: 0.7845
#
# Epoch 3/4
# ----------
# train Loss: 0.4044 Acc: 0.8090
# val Loss: 0.4107 Acc: 0.8018
#
# Epoch 4/4
# ----------
# train Loss: 0.4036 Acc: 0.8094
# val Loss: 0.4109 Acc: 0.8161
#
# Training complete in 4m 26s
# Best val Acc: 0.816110
# [[5476 1671]
#  [ 125  808]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4464 Acc: 0.7876
# val Loss: 0.4426 Acc: 0.8011
#
# Epoch 1/4
# ----------
# train Loss: 0.4374 Acc: 0.7905
# val Loss: 0.4368 Acc: 0.7882
#
# Epoch 2/4
# ----------
# train Loss: 0.4326 Acc: 0.7938
# val Loss: 0.4340 Acc: 0.7971
#
# Epoch 3/4
# ----------
# train Loss: 0.4290 Acc: 0.7943
# val Loss: 0.4267 Acc: 0.7923
#
# Epoch 4/4
# ----------
# train Loss: 0.4246 Acc: 0.7975
# val Loss: 0.4335 Acc: 0.8078
#
# Training complete in 4m 59s
# Best val Acc: 0.807818
# [[5526 1621]
#  [ 147  786]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4334 Acc: 0.7923
# val Loss: 0.4368 Acc: 0.7901
#
# Epoch 1/4
# ----------
# train Loss: 0.4274 Acc: 0.7946
# val Loss: 0.4261 Acc: 0.7889
#
# Epoch 2/4
# ----------
# train Loss: 0.4224 Acc: 0.7982
# val Loss: 0.4261 Acc: 0.7927
#
# Epoch 3/4
# ----------
# train Loss: 0.4194 Acc: 0.7995
# val Loss: 0.5156 Acc: 0.6814
#
# Epoch 4/4
# ----------
# train Loss: 0.4159 Acc: 0.8046
# val Loss: 0.4217 Acc: 0.8044
#
# Training complete in 5m 33s
# Best val Acc: 0.804375
# [[5224 1923]
#  [ 114  819]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4117 Acc: 0.8099
# val Loss: 0.8952 Acc: 0.5902
#
# Epoch 1/4
# ----------
# train Loss: 0.4092 Acc: 0.8069
# val Loss: 0.4073 Acc: 0.8055
#
# Epoch 2/4
# ----------
# train Loss: 0.4008 Acc: 0.8141
# val Loss: 0.4212 Acc: 0.7929
#
# Epoch 3/4
# ----------
# train Loss: 0.3975 Acc: 0.8145
# val Loss: 0.4113 Acc: 0.8145
#
# Epoch 4/4
# ----------
# train Loss: 0.3940 Acc: 0.8156
# val Loss: 0.4161 Acc: 0.8209
#
# Training complete in 4m 28s
# Best val Acc: 0.820922
# [[5698 1449]
#  [ 145  788]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4361 Acc: 0.7957
# val Loss: 0.4490 Acc: 0.8014
#
# Epoch 1/4
# ----------
# train Loss: 0.4277 Acc: 0.7958
# val Loss: 0.6749 Acc: 0.6562
#
# Epoch 2/4
# ----------
# train Loss: 0.4236 Acc: 0.8006
# val Loss: 0.8034 Acc: 0.6037
#
# Epoch 3/4
# ----------
# train Loss: 0.4139 Acc: 0.8044
# val Loss: 1.2230 Acc: 0.5168
#
# Epoch 4/4
# ----------
# train Loss: 0.4082 Acc: 0.8083
# val Loss: 0.4159 Acc: 0.8153
#
# Training complete in 4m 59s
# Best val Acc: 0.815330
# [[5687 1460]
#  [ 154  779]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4257 Acc: 0.7993
# val Loss: 0.4312 Acc: 0.7810
#
# Epoch 1/4
# ----------
# train Loss: 0.4174 Acc: 0.8042
# val Loss: 0.4404 Acc: 0.7749
#
# Epoch 2/4
# ----------
# train Loss: 0.4137 Acc: 0.8073
# val Loss: 0.4141 Acc: 0.8020
#
# Epoch 3/4
# ----------
# train Loss: 0.4061 Acc: 0.8082
# val Loss: 0.8902 Acc: 0.5777
#
# Epoch 4/4
# ----------
# train Loss: 0.4062 Acc: 0.8122
# val Loss: 0.4445 Acc: 0.7718
#
# Training complete in 5m 31s
# Best val Acc: 0.802038
# [[5172 1973]
#  [ 112  823]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4289 Acc: 0.7988
# val Loss: 0.8684 Acc: 0.5041
#
# Epoch 1/4
# ----------
# train Loss: 0.4432 Acc: 0.7902
# val Loss: 0.7808 Acc: 0.5185
#
# Epoch 2/4
# ----------
# train Loss: 0.4337 Acc: 0.7943
# val Loss: 0.4963 Acc: 0.7946
#
# Epoch 3/4
# ----------
# train Loss: 0.4418 Acc: 0.7882
# val Loss: 0.9388 Acc: 0.5988
#
# Epoch 4/4
# ----------
# train Loss: 0.4195 Acc: 0.8043
# val Loss: 0.6830 Acc: 0.6553
#
# Training complete in 4m 27s
# Best val Acc: 0.794575
# [[5990 1155]
#  [ 233  702]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4508 Acc: 0.7913
# val Loss: 0.6093 Acc: 0.7068
#
# Epoch 1/4
# ----------
# train Loss: 0.4556 Acc: 0.7761
# val Loss: 0.9186 Acc: 0.5602
#
# Epoch 2/4
# ----------
# train Loss: 0.4470 Acc: 0.7822
# val Loss: 1.1410 Acc: 0.5486
#
# Epoch 3/4
# ----------
# train Loss: 0.4390 Acc: 0.7908
# val Loss: 0.6993 Acc: 0.7047
#
# Epoch 4/4
# ----------
# train Loss: 0.4407 Acc: 0.7906
# val Loss: 0.6912 Acc: 0.5742
#
# Training complete in 4m 59s
# Best val Acc: 0.706827
# [[5885 1230]
#  [ 399  566]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4638 Acc: 0.7722
# val Loss: 0.4891 Acc: 0.7318
#
# Epoch 1/4
# ----------
# train Loss: 0.4591 Acc: 0.7847
# val Loss: 0.6555 Acc: 0.6944
#
# Epoch 2/4
# ----------
# train Loss: 0.4371 Acc: 0.7912
# val Loss: 0.4536 Acc: 0.7564
#
# Epoch 3/4
# ----------
# train Loss: 0.4262 Acc: 0.7923
# val Loss: 0.6924 Acc: 0.7772
#
# Epoch 4/4
# ----------
# train Loss: 0.4465 Acc: 0.7835
# val Loss: 0.4489 Acc: 0.7971
#
# Training complete in 5m 33s
# Best val Acc: 0.797145
# [[5113 2034]
#  [ 113  820]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4242 Acc: 0.7984
# val Loss: 0.4222 Acc: 0.7933
#
# Epoch 1/4
# ----------
# train Loss: 0.4081 Acc: 0.8087
# val Loss: 0.4077 Acc: 0.8005
#
# Epoch 2/4
# ----------
# train Loss: 0.4008 Acc: 0.8105
# val Loss: 0.4207 Acc: 0.7927
#
# Epoch 3/4
# ----------
# train Loss: 0.3970 Acc: 0.8126
# val Loss: 0.4014 Acc: 0.8108
#
# Epoch 4/4
# ----------
# train Loss: 0.3958 Acc: 0.8159
# val Loss: 0.4116 Acc: 0.8155
#
# Training complete in 4m 27s
# Best val Acc: 0.815504
# [[5475 1672]
#  [ 126  807]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4390 Acc: 0.7896
# val Loss: 0.4333 Acc: 0.7918
#
# Epoch 1/4
# ----------
# train Loss: 0.4301 Acc: 0.7951
# val Loss: 0.4238 Acc: 0.7984
#
# Epoch 2/4
# ----------
# train Loss: 0.4193 Acc: 0.8015
# val Loss: 0.4247 Acc: 0.8017
#
# Epoch 3/4
# ----------
# train Loss: 0.4171 Acc: 0.8046
# val Loss: 0.4160 Acc: 0.8062
#
# Epoch 4/4
# ----------
# train Loss: 0.4137 Acc: 0.8074
# val Loss: 0.4213 Acc: 0.8078
#
# Training complete in 4m 58s
# Best val Acc: 0.807763
# [[5395 1752]
#  [ 130  803]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4174 Acc: 0.8075
# val Loss: 0.6868 Acc: 0.6178
#
# Epoch 1/4
# ----------
# train Loss: 0.4079 Acc: 0.8115
# val Loss: 0.4035 Acc: 0.8069
#
# Epoch 2/4
# ----------
# train Loss: 0.3989 Acc: 0.8138
# val Loss: 0.4100 Acc: 0.8030
#
# Epoch 3/4
# ----------
# train Loss: 0.3973 Acc: 0.8144
# val Loss: 0.8855 Acc: 0.5175
#
# Epoch 4/4
# ----------
# train Loss: 0.3970 Acc: 0.8173
# val Loss: 0.4149 Acc: 0.8039
#
# Training complete in 5m 32s
# Best val Acc: 0.806881
# [[5404 1734]
#  [ 135  807]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model50'}
# /tmp/ipykernel_8813/1219295120.py:37: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(12, 7))
# Epoch 0/4
# ----------
# train Loss: 0.4025 Acc: 0.8111
# val Loss: 0.4186 Acc: 0.7869
#
# Epoch 1/4
# ----------
# train Loss: 0.3983 Acc: 0.8124
# val Loss: 0.3980 Acc: 0.8090
#
# Epoch 2/4
# ----------
# train Loss: 0.3928 Acc: 0.8164
# val Loss: 0.4056 Acc: 0.8070
#
# Epoch 3/4
# ----------
# train Loss: 0.3898 Acc: 0.8162
# val Loss: 0.4052 Acc: 0.8201
#
# Epoch 4/4
# ----------
# train Loss: 0.3835 Acc: 0.8219
# val Loss: 0.4303 Acc: 0.7906
#
# Training complete in 4m 26s
# Best val Acc: 0.820056
# [[5660 1436]
#  [ 155  829]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4232 Acc: 0.8026
# val Loss: 0.4290 Acc: 0.8065
#
# Epoch 1/4
# ----------
# train Loss: 0.4210 Acc: 0.7975
# val Loss: 0.4160 Acc: 0.7873
#
# Epoch 2/4
# ----------
# train Loss: 0.4098 Acc: 0.8075
# val Loss: 0.4186 Acc: 0.8150
#
# Epoch 3/4
# ----------
# train Loss: 0.4024 Acc: 0.8103
# val Loss: 0.4281 Acc: 0.8133
#
# Epoch 4/4
# ----------
# train Loss: 0.4026 Acc: 0.8123
# val Loss: 0.4092 Acc: 0.8213
#
# Training complete in 5m 0s
# Best val Acc: 0.821316
# [[5650 1497]
#  [ 138  795]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4037 Acc: 0.8140
# val Loss: 0.4091 Acc: 0.8088
#
# Epoch 1/4
# ----------
# train Loss: 0.3991 Acc: 0.8137
# val Loss: 0.4204 Acc: 0.7897
#
# Epoch 2/4
# ----------
# train Loss: 0.3916 Acc: 0.8180
# val Loss: 0.4197 Acc: 0.7904
#
# Epoch 3/4
# ----------
# train Loss: 0.3850 Acc: 0.8192
# val Loss: 0.3942 Acc: 0.8110
#
# Epoch 4/4
# ----------
# train Loss: 0.3852 Acc: 0.8226
# val Loss: 0.4029 Acc: 0.8066
#
# Training complete in 5m 30s
# Best val Acc: 0.811047
# [[5186 1910]
#  [ 107  877]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4203 Acc: 0.8056
# val Loss: 0.4596 Acc: 0.7494
#
# Epoch 1/4
# ----------
# train Loss: 0.4185 Acc: 0.8021
# val Loss: 0.4949 Acc: 0.7799
#
# Epoch 2/4
# ----------
# train Loss: 0.4219 Acc: 0.8006
# val Loss: 0.5829 Acc: 0.6260
#
# Epoch 3/4
# ----------
# train Loss: 0.4077 Acc: 0.8090
# val Loss: 0.4243 Acc: 0.8049
#
# Epoch 4/4
# ----------
# train Loss: 0.4179 Acc: 0.8078
# val Loss: 0.4414 Acc: 0.7805
#
# Training complete in 4m 26s
# Best val Acc: 0.804881
# [[5423 1673]
#  [ 152  832]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4458 Acc: 0.7875
# val Loss: 0.9072 Acc: 0.5069
#
# Epoch 1/4
# ----------
# train Loss: 0.4676 Acc: 0.7685
# val Loss: 1.3991 Acc: 0.5206
#
# Epoch 2/4
# ----------
# train Loss: 0.4620 Acc: 0.7744
# val Loss: 0.8980 Acc: 0.5845
#
# Epoch 3/4
# ----------
# train Loss: 0.4384 Acc: 0.7868
# val Loss: 0.6926 Acc: 0.7022
#
# Epoch 4/4
# ----------
# train Loss: 0.4463 Acc: 0.7889
# val Loss: 0.4855 Acc: 0.7588
#
# Training complete in 4m 57s
# Best val Acc: 0.758773
# [[4373 2774]
#  [  88  845]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4243 Acc: 0.7993
# val Loss: 0.6806 Acc: 0.5048
#
# Epoch 1/4
# ----------
# train Loss: 0.4533 Acc: 0.7826
# val Loss: 0.4313 Acc: 0.8051
#
# Epoch 2/4
# ----------
# train Loss: 0.4412 Acc: 0.7848
# val Loss: 0.4895 Acc: 0.7340
#
# Epoch 3/4
# ----------
# train Loss: 0.4161 Acc: 0.8017
# val Loss: 0.4502 Acc: 0.7877
#
# Epoch 4/4
# ----------
# train Loss: 0.4212 Acc: 0.7979
# val Loss: 0.5068 Acc: 0.8013
#
# Training complete in 5m 32s
# Best val Acc: 0.805132
# [[5523 1615]
#  [ 154  788]]
# Current hyperparameters: {'learning rate': 0.05, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3972 Acc: 0.8145
# val Loss: 0.3934 Acc: 0.8193
#
# Epoch 1/4
# ----------
# train Loss: 0.3898 Acc: 0.8181
# val Loss: 0.3858 Acc: 0.8209
#
# Epoch 2/4
# ----------
# train Loss: 0.3886 Acc: 0.8169
# val Loss: 0.3960 Acc: 0.8170
#
# Epoch 3/4
# ----------
# train Loss: 0.3811 Acc: 0.8242
# val Loss: 0.3905 Acc: 0.8222
#
# Epoch 4/4
# ----------
# train Loss: 0.3789 Acc: 0.8253
# val Loss: 0.3903 Acc: 0.8311
#
# Training complete in 4m 26s
# Best val Acc: 0.831140
# [[5507 1640]
#  [ 101  832]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4179 Acc: 0.8059
# val Loss: 0.4578 Acc: 0.7604
#
# Epoch 1/4
# ----------
# train Loss: 0.4122 Acc: 0.8067
# val Loss: 0.4268 Acc: 0.7856
#
# Epoch 2/4
# ----------
# train Loss: 0.4050 Acc: 0.8101
# val Loss: 0.4242 Acc: 0.7914
#
# Epoch 3/4
# ----------
# train Loss: 0.4014 Acc: 0.8120
# val Loss: 0.4135 Acc: 0.8180
#
# Epoch 4/4
# ----------
# train Loss: 0.3997 Acc: 0.8146
# val Loss: 0.4632 Acc: 0.7658
#
# Training complete in 4m 58s
# Best val Acc: 0.818005
# [[5703 1393]
#  [ 165  819]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4075 Acc: 0.8090
# val Loss: 0.4090 Acc: 0.8071
#
# Epoch 1/4
# ----------
# train Loss: 0.4033 Acc: 0.8110
# val Loss: 0.3983 Acc: 0.8164
#
# Epoch 2/4
# ----------
# train Loss: 0.3952 Acc: 0.8119
# val Loss: 0.4081 Acc: 0.8124
#
# Epoch 3/4
# ----------
# train Loss: 0.3917 Acc: 0.8173
# val Loss: 0.4123 Acc: 0.7905
#
# Epoch 4/4
# ----------
# train Loss: 0.3906 Acc: 0.8188
# val Loss: 0.4056 Acc: 0.8080
#
# Training complete in 5m 30s
# Best val Acc: 0.816436
# [[5404 1734]
#  [ 117  825]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3912 Acc: 0.8179
# val Loss: 0.3918 Acc: 0.8218
#
# Epoch 1/4
# ----------
# train Loss: 0.3860 Acc: 0.8191
# val Loss: 0.4526 Acc: 0.7584
#
# Epoch 2/4
# ----------
# train Loss: 0.3815 Acc: 0.8224
# val Loss: 0.4019 Acc: 0.8140
#
# Epoch 3/4
# ----------
# train Loss: 0.3785 Acc: 0.8241
# val Loss: 0.3827 Acc: 0.8163
#
# Epoch 4/4
# ----------
# train Loss: 0.3743 Acc: 0.8252
# val Loss: 0.3990 Acc: 0.8142
#
# Training complete in 4m 25s
# Best val Acc: 0.821849
# [[5649 1466]
#  [ 145  820]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4122 Acc: 0.8053
# val Loss: 0.4252 Acc: 0.7892
#
# Epoch 1/4
# ----------
# train Loss: 0.4083 Acc: 0.8084
# val Loss: 0.4289 Acc: 0.8107
#
# Epoch 2/4
# ----------
# train Loss: 0.4028 Acc: 0.8109
# val Loss: 0.4159 Acc: 0.8150
#
# Epoch 3/4
# ----------
# train Loss: 0.3990 Acc: 0.8117
# val Loss: 0.4131 Acc: 0.8141
#
# Epoch 4/4
# ----------
# train Loss: 0.3984 Acc: 0.8159
# val Loss: 0.8092 Acc: 0.5923
#
# Training complete in 4m 58s
# Best val Acc: 0.814965
# [[5884 1261]
#  [ 181  754]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4063 Acc: 0.8123
# val Loss: 0.4142 Acc: 0.7978
#
# Epoch 1/4
# ----------
# train Loss: 0.4005 Acc: 0.8146
# val Loss: 0.4642 Acc: 0.7384
#
# Epoch 2/4
# ----------
# train Loss: 0.3954 Acc: 0.8139
# val Loss: 0.4236 Acc: 0.8116
#
# Epoch 3/4
# ----------
# train Loss: 0.3851 Acc: 0.8171
# val Loss: 0.3958 Acc: 0.8169
#
# Epoch 4/4
# ----------
# train Loss: 0.3873 Acc: 0.8172
# val Loss: 0.4068 Acc: 0.8160
#
# Training complete in 5m 31s
# Best val Acc: 0.816880
# [[5413 1683]
#  [ 127  857]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4251 Acc: 0.8031
# val Loss: 0.6806 Acc: 0.5760
#
# Epoch 1/4
# ----------
# train Loss: 0.4573 Acc: 0.7839
# val Loss: 0.4817 Acc: 0.7121
#
# Epoch 2/4
# ----------
# train Loss: 0.4334 Acc: 0.7974
# val Loss: 0.4944 Acc: 0.7586
#
# Epoch 3/4
# ----------
# train Loss: 0.4739 Acc: 0.7785
# val Loss: 0.4946 Acc: 0.7955
#
# Epoch 4/4
# ----------
# train Loss: 0.4347 Acc: 0.7930
# val Loss: 0.4889 Acc: 0.7777
#
# Training complete in 4m 29s
# Best val Acc: 0.795491
# [[6220  876]
#  [ 281  703]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4553 Acc: 0.7794
# val Loss: 1.0254 Acc: 0.5189
#
# Epoch 1/4
# ----------
# train Loss: 0.4560 Acc: 0.7814
# val Loss: 0.9575 Acc: 0.5368
#
# Epoch 2/4
# ----------
# train Loss: 0.4449 Acc: 0.7857
# val Loss: 1.4346 Acc: 0.5167
#
# Epoch 3/4
# ----------
# train Loss: 0.4316 Acc: 0.7966
# val Loss: 0.5781 Acc: 0.7354
#
# Epoch 4/4
# ----------
# train Loss: 0.4192 Acc: 0.8045
# val Loss: 0.4830 Acc: 0.7908
#
# Training complete in 5m 1s
# Best val Acc: 0.790758
# [[5060 2087]
#  [ 118  815]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4365 Acc: 0.7897
# val Loss: 0.5796 Acc: 0.7437
#
# Epoch 1/4
# ----------
# train Loss: 0.4671 Acc: 0.7697
# val Loss: 1.5314 Acc: 0.5141
#
# Epoch 2/4
# ----------
# train Loss: 0.4686 Acc: 0.7732
# val Loss: 0.4290 Acc: 0.7908
#
# Epoch 3/4
# ----------
# train Loss: 0.4386 Acc: 0.7888
# val Loss: 0.6400 Acc: 0.6653
#
# Epoch 4/4
# ----------
# train Loss: 0.4363 Acc: 0.7969
# val Loss: 0.4392 Acc: 0.8069
#
# Training complete in 5m 32s
# Best val Acc: 0.806927
# [[5429 1718]
#  [ 136  797]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4181 Acc: 0.8041
# val Loss: 0.4088 Acc: 0.8078
#
# Epoch 1/4
# ----------
# train Loss: 0.4057 Acc: 0.8097
# val Loss: 0.4018 Acc: 0.8074
#
# Epoch 2/4
# ----------
# train Loss: 0.3989 Acc: 0.8117
# val Loss: 0.4071 Acc: 0.8119
#
# Epoch 3/4
# ----------
# train Loss: 0.3982 Acc: 0.8145
# val Loss: 0.4032 Acc: 0.8080
#
# Epoch 4/4
# ----------
# train Loss: 0.3931 Acc: 0.8172
# val Loss: 0.4044 Acc: 0.8147
#
# Training complete in 4m 27s
# Best val Acc: 0.814696
# [[5203 1944]
#  [  92  841]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4116 Acc: 0.8063
# val Loss: 0.4074 Acc: 0.8043
#
# Epoch 1/4
# ----------
# train Loss: 0.4009 Acc: 0.8109
# val Loss: 0.4086 Acc: 0.7979
#
# Epoch 2/4
# ----------
# train Loss: 0.3959 Acc: 0.8133
# val Loss: 0.4065 Acc: 0.8046
#
# Epoch 3/4
# ----------
# train Loss: 0.3879 Acc: 0.8188
# val Loss: 0.3994 Acc: 0.8137
#
# Epoch 4/4
# ----------
# train Loss: 0.3869 Acc: 0.8191
# val Loss: 0.4034 Acc: 0.8183
#
# Training complete in 4m 58s
# Best val Acc: 0.818298
# [[5446 1701]
#  [ 117  816]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4131 Acc: 0.8000
# val Loss: 0.4084 Acc: 0.8062
#
# Epoch 1/4
# ----------
# train Loss: 0.4060 Acc: 0.8087
# val Loss: 0.3989 Acc: 0.8063
#
# Epoch 2/4
# ----------
# train Loss: 0.3975 Acc: 0.8113
# val Loss: 0.4115 Acc: 0.8002
#
# Epoch 3/4
# ----------
# train Loss: 0.3973 Acc: 0.8136
# val Loss: 0.4054 Acc: 0.7956
#
# Epoch 4/4
# ----------
# train Loss: 0.3917 Acc: 0.8155
# val Loss: 0.4014 Acc: 0.8162
#
# Training complete in 5m 31s
# Best val Acc: 0.816187
# [[5209 1938]
#  [  90  843]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3997 Acc: 0.8145
# val Loss: 0.4085 Acc: 0.8242
#
# Epoch 1/4
# ----------
# train Loss: 0.3942 Acc: 0.8143
# val Loss: 0.3971 Acc: 0.8060
#
# Epoch 2/4
# ----------
# train Loss: 0.3912 Acc: 0.8175
# val Loss: 0.4085 Acc: 0.8197
#
# Epoch 3/4
# ----------
# train Loss: 0.3862 Acc: 0.8192
# val Loss: 0.3990 Acc: 0.8179
#
# Epoch 4/4
# ----------
# train Loss: 0.3831 Acc: 0.8260
# val Loss: 0.4825 Acc: 0.8103
#
# Training complete in 4m 28s
# Best val Acc: 0.824186
# [[5697 1418]
#  [ 147  818]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3950 Acc: 0.8179
# val Loss: 0.4039 Acc: 0.8023
#
# Epoch 1/4
# ----------
# train Loss: 0.3955 Acc: 0.8166
# val Loss: 0.4049 Acc: 0.7960
#
# Epoch 2/4
# ----------
# train Loss: 0.3885 Acc: 0.8180
# val Loss: 0.4153 Acc: 0.8198
#
# Epoch 3/4
# ----------
# train Loss: 0.3883 Acc: 0.8203
# val Loss: 0.3922 Acc: 0.8144
#
# Epoch 4/4
# ----------
# train Loss: 0.3854 Acc: 0.8217
# val Loss: 0.4070 Acc: 0.8233
#
# Training complete in 4m 58s
# Best val Acc: 0.823279
# [[5747 1400]
#  [ 147  786]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.3990 Acc: 0.8139
# val Loss: 0.4065 Acc: 0.8200
#
# Epoch 1/4
# ----------
# train Loss: 0.3987 Acc: 0.8128
# val Loss: 0.4096 Acc: 0.7950
#
# Epoch 2/4
# ----------
# train Loss: 0.3952 Acc: 0.8144
# val Loss: 0.4272 Acc: 0.7833
#
# Epoch 3/4
# ----------
# train Loss: 0.3866 Acc: 0.8180
# val Loss: 0.3921 Acc: 0.8150
#
# Epoch 4/4
# ----------
# train Loss: 0.3862 Acc: 0.8227
# val Loss: 0.4202 Acc: 0.7914
#
# Training complete in 5m 30s
# Best val Acc: 0.819967
# [[5519 1596]
#  [ 131  834]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4494 Acc: 0.7845
# val Loss: 0.4714 Acc: 0.8050
#
# Epoch 1/4
# ----------
# train Loss: 0.4582 Acc: 0.7749
# val Loss: 0.4475 Acc: 0.8131
#
# Epoch 2/4
# ----------
# train Loss: 0.4219 Acc: 0.7949
# val Loss: 0.4499 Acc: 0.7903
#
# Epoch 3/4
# ----------
# train Loss: 0.4258 Acc: 0.7977
# val Loss: 0.4336 Acc: 0.7800
#
# Epoch 4/4
# ----------
# train Loss: 0.4305 Acc: 0.7962
# val Loss: 0.4502 Acc: 0.7477
#
# Training complete in 4m 27s
# Best val Acc: 0.813064
# [[6053 1085]
#  [ 209  733]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4276 Acc: 0.7987
# val Loss: 0.6817 Acc: 0.6529
#
# Epoch 1/4
# ----------
# train Loss: 0.4306 Acc: 0.7968
# val Loss: 0.7554 Acc: 0.6265
#
# Epoch 2/4
# ----------
# train Loss: 0.4441 Acc: 0.7853
# val Loss: 0.5831 Acc: 0.7745
#
# Epoch 3/4
# ----------
# train Loss: 0.4436 Acc: 0.7864
# val Loss: 0.4216 Acc: 0.7944
#
# Epoch 4/4
# ----------
# train Loss: 0.4157 Acc: 0.8069
# val Loss: 0.4287 Acc: 0.7956
#
# Training complete in 4m 58s
# Best val Acc: 0.795598
# [[4953 2194]
#  [  95  838]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4136 Acc: 0.8056
# val Loss: 0.9069 Acc: 0.5174
#
# Epoch 1/4
# ----------
# train Loss: 0.4326 Acc: 0.7920
# val Loss: 0.5630 Acc: 0.7457
#
# Epoch 2/4
# ----------
# train Loss: 0.4237 Acc: 0.7944
# val Loss: 0.7819 Acc: 0.5169
#
# Epoch 3/4
# ----------
# train Loss: 0.4094 Acc: 0.8043
# val Loss: 0.4043 Acc: 0.8139
#
# Epoch 4/4
# ----------
# train Loss: 0.4129 Acc: 0.8120
# val Loss: 0.4316 Acc: 0.7941
#
# Training complete in 5m 29s
# Best val Acc: 0.813905
# [[5378 1718]
#  [ 128  856]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4023 Acc: 0.8146
# val Loss: 0.4104 Acc: 0.7917
#
# Epoch 1/4
# ----------
# train Loss: 0.3962 Acc: 0.8153
# val Loss: 0.3914 Acc: 0.8094
#
# Epoch 2/4
# ----------
# train Loss: 0.3905 Acc: 0.8168
# val Loss: 0.4022 Acc: 0.8133
#
# Epoch 3/4
# ----------
# train Loss: 0.3850 Acc: 0.8182
# val Loss: 0.3918 Acc: 0.8129
#
# Epoch 4/4
# ----------
# train Loss: 0.3872 Acc: 0.8199
# val Loss: 0.4011 Acc: 0.8082
#
# Training complete in 4m 24s
# Best val Acc: 0.813261
# [[5447 1698]
#  [ 127  808]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3938 Acc: 0.8141
# val Loss: 0.3882 Acc: 0.8146
#
# Epoch 1/4
# ----------
# train Loss: 0.3883 Acc: 0.8208
# val Loss: 0.3861 Acc: 0.8234
#
# Epoch 2/4
# ----------
# train Loss: 0.3840 Acc: 0.8217
# val Loss: 0.4018 Acc: 0.8071
#
# Epoch 3/4
# ----------
# train Loss: 0.3768 Acc: 0.8227
# val Loss: 0.3927 Acc: 0.8097
#
# Epoch 4/4
# ----------
# train Loss: 0.3761 Acc: 0.8244
# val Loss: 0.3996 Acc: 0.8120
#
# Training complete in 4m 58s
# Best val Acc: 0.823423
# [[5625 1513]
#  [ 133  809]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.3898 Acc: 0.8195
# val Loss: 0.3918 Acc: 0.8087
#
# Epoch 1/4
# ----------
# train Loss: 0.3839 Acc: 0.8208
# val Loss: 0.3898 Acc: 0.8164
#
# Epoch 2/4
# ----------
# train Loss: 0.3816 Acc: 0.8203
# val Loss: 0.4993 Acc: 0.7137
#
# Epoch 3/4
# ----------
# train Loss: 0.3782 Acc: 0.8237
# val Loss: 0.3862 Acc: 0.8121
#
# Epoch 4/4
# ----------
# train Loss: 0.3753 Acc: 0.8272
# val Loss: 0.3871 Acc: 0.8250
#
# Training complete in 5m 31s
# Best val Acc: 0.824980
# [[5350 1797]
#  [  92  841]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3937 Acc: 0.8144
# val Loss: 0.3903 Acc: 0.8225
#
# Epoch 1/4
# ----------
# train Loss: 0.3907 Acc: 0.8158
# val Loss: 0.3914 Acc: 0.8133
#
# Epoch 2/4
# ----------
# train Loss: 0.3825 Acc: 0.8232
# val Loss: 0.3982 Acc: 0.8121
#
# Epoch 3/4
# ----------
# train Loss: 0.3801 Acc: 0.8219
# val Loss: 0.3868 Acc: 0.8211
#
# Epoch 4/4
# ----------
# train Loss: 0.3792 Acc: 0.8239
# val Loss: 0.3951 Acc: 0.8189
#
# Training complete in 4m 25s
# Best val Acc: 0.822522
# [[5489 1626]
#  [ 122  843]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3878 Acc: 0.8205
# val Loss: 0.4471 Acc: 0.7712
#
# Epoch 1/4
# ----------
# train Loss: 0.3832 Acc: 0.8224
# val Loss: 0.4035 Acc: 0.7973
#
# Epoch 2/4
# ----------
# train Loss: 0.3804 Acc: 0.8198
# val Loss: 0.3998 Acc: 0.8150
#
# Epoch 3/4
# ----------
# train Loss: 0.3751 Acc: 0.8262
# val Loss: 0.4106 Acc: 0.7976
#
# Epoch 4/4
# ----------
# train Loss: 0.3740 Acc: 0.8269
# val Loss: 0.4024 Acc: 0.8215
#
# Training complete in 4m 57s
# Best val Acc: 0.821457
# [[5675 1472]
#  [ 141  792]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.3847 Acc: 0.8232
# val Loss: 0.4075 Acc: 0.7888
#
# Epoch 1/4
# ----------
# train Loss: 0.3844 Acc: 0.8221
# val Loss: 0.3847 Acc: 0.8172
#
# Epoch 2/4
# ----------
# train Loss: 0.3792 Acc: 0.8243
# val Loss: 0.3978 Acc: 0.8133
#
# Epoch 3/4
# ----------
# train Loss: 0.3736 Acc: 0.8264
# val Loss: 0.3915 Acc: 0.8160
#
# Epoch 4/4
# ----------
# train Loss: 0.3767 Acc: 0.8261
# val Loss: 0.3931 Acc: 0.8094
#
# Training complete in 5m 30s
# Best val Acc: 0.817164
# [[5278 1860]
#  [  99  843]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4084 Acc: 0.8087
# val Loss: 0.4880 Acc: 0.8060
#
# Epoch 1/4
# ----------
# train Loss: 0.4198 Acc: 0.8040
# val Loss: 0.4278 Acc: 0.8177
#
# Epoch 2/4
# ----------
# train Loss: 0.4133 Acc: 0.8085
# val Loss: 0.4176 Acc: 0.8044
#
# Epoch 3/4
# ----------
# train Loss: 0.4289 Acc: 0.7952
# val Loss: 0.4767 Acc: 0.8127
#
# Epoch 4/4
# ----------
# train Loss: 0.4184 Acc: 0.8106
# val Loss: 0.4271 Acc: 0.7959
#
# Training complete in 4m 26s
# Best val Acc: 0.817713
# [[5839 1299]
#  [ 172  770]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4100 Acc: 0.8119
# val Loss: 0.5029 Acc: 0.7707
#
# Epoch 1/4
# ----------
# train Loss: 0.4521 Acc: 0.7791
# val Loss: 0.4165 Acc: 0.8166
#
# Epoch 2/4
# ----------
# train Loss: 0.4575 Acc: 0.7819
# val Loss: 0.6243 Acc: 0.7401
#
# Epoch 3/4
# ----------
# train Loss: 0.4109 Acc: 0.7989
# val Loss: 0.4857 Acc: 0.7202
#
# Epoch 4/4
# ----------
# train Loss: 0.4011 Acc: 0.8114
# val Loss: 0.4930 Acc: 0.7380
#
# Training complete in 4m 58s
# Best val Acc: 0.816605
# [[5952 1186]
#  [ 189  753]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4254 Acc: 0.7979
# val Loss: 0.4467 Acc: 0.8164
#
# Epoch 1/4
# ----------
# train Loss: 0.4265 Acc: 0.7992
# val Loss: 0.4030 Acc: 0.8098
#
# Epoch 2/4
# ----------
# train Loss: 0.4195 Acc: 0.7988
# val Loss: 0.7984 Acc: 0.5170
#
# Epoch 3/4
# ----------
# train Loss: 0.4293 Acc: 0.7941
# val Loss: 0.5106 Acc: 0.7948
#
# Epoch 4/4
# ----------
# train Loss: 0.4212 Acc: 0.8016
# val Loss: 0.5604 Acc: 0.6626
#
# Training complete in 5m 30s
# Best val Acc: 0.816417
# [[5874 1241]
#  [ 186  779]]
# Current hyperparameters: {'learning rate': 0.1, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3967 Acc: 0.8177
# val Loss: 0.3912 Acc: 0.8128
#
# Epoch 1/4
# ----------
# train Loss: 0.3839 Acc: 0.8215
# val Loss: 0.3887 Acc: 0.8174
#
# Epoch 2/4
# ----------
# train Loss: 0.3837 Acc: 0.8213
# val Loss: 0.3934 Acc: 0.8172
#
# Epoch 3/4
# ----------
# train Loss: 0.3756 Acc: 0.8267
# val Loss: 0.3890 Acc: 0.8135
#
# Epoch 4/4
# ----------
# train Loss: 0.3736 Acc: 0.8271
# val Loss: 0.3940 Acc: 0.8251
#
# Training complete in 4m 26s
# Best val Acc: 0.825109
# [[5574 1573]
#  [ 121  812]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3993 Acc: 0.8092
# val Loss: 0.3986 Acc: 0.8198
#
# Epoch 1/4
# ----------
# train Loss: 0.3937 Acc: 0.8170
# val Loss: 0.3909 Acc: 0.8251
#
# Epoch 2/4
# ----------
# train Loss: 0.3868 Acc: 0.8195
# val Loss: 0.3944 Acc: 0.8229
#
# Epoch 3/4
# ----------
# train Loss: 0.3782 Acc: 0.8248
# val Loss: 0.3867 Acc: 0.8192
#
# Epoch 4/4
# ----------
# train Loss: 0.3801 Acc: 0.8244
# val Loss: 0.3974 Acc: 0.8213
#
# Training complete in 4m 57s
# Best val Acc: 0.825142
# [[5695 1443]
#  [ 139  803]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.3970 Acc: 0.8110
# val Loss: 0.3910 Acc: 0.8114
#
# Epoch 1/4
# ----------
# train Loss: 0.3833 Acc: 0.8173
# val Loss: 0.3855 Acc: 0.8214
#
# Epoch 2/4
# ----------
# train Loss: 0.3811 Acc: 0.8239
# val Loss: 0.3952 Acc: 0.8062
#
# Epoch 3/4
# ----------
# train Loss: 0.3747 Acc: 0.8219
# val Loss: 0.3992 Acc: 0.7973
#
# Epoch 4/4
# ----------
# train Loss: 0.3707 Acc: 0.8277
# val Loss: 0.6817 Acc: 0.5867
#
# Training complete in 5m 30s
# Best val Acc: 0.821401
# [[5437 1701]
#  [ 112  830]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3892 Acc: 0.8192
# val Loss: 0.4082 Acc: 0.7980
#
# Epoch 1/4
# ----------
# train Loss: 0.3833 Acc: 0.8242
# val Loss: 0.4053 Acc: 0.7864
#
# Epoch 2/4
# ----------
# train Loss: 0.3794 Acc: 0.8247
# val Loss: 0.4033 Acc: 0.8141
#
# Epoch 3/4
# ----------
# train Loss: 0.3745 Acc: 0.8274
# val Loss: 0.3886 Acc: 0.8216
#
# Epoch 4/4
# ----------
# train Loss: 0.3764 Acc: 0.8257
# val Loss: 0.3937 Acc: 0.8329
#
# Training complete in 4m 26s
# Best val Acc: 0.832938
# [[5571 1576]
#  [ 106  827]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3928 Acc: 0.8168
# val Loss: 0.6012 Acc: 0.6673
#
# Epoch 1/4
# ----------
# train Loss: 0.3856 Acc: 0.8207
# val Loss: 0.4028 Acc: 0.8067
#
# Epoch 2/4
# ----------
# train Loss: 0.3866 Acc: 0.8210
# val Loss: 0.3888 Acc: 0.8201
#
# Epoch 3/4
# ----------
# train Loss: 0.3771 Acc: 0.8243
# val Loss: 0.5100 Acc: 0.7229
#
# Epoch 4/4
# ----------
# train Loss: 0.3744 Acc: 0.8277
# val Loss: 0.3923 Acc: 0.8282
#
# Training complete in 4m 53s
# Best val Acc: 0.828205
# [[5511 1636]
#  [ 107  826]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.3884 Acc: 0.8189
# val Loss: 0.4047 Acc: 0.8271
#
# Epoch 1/4
# ----------
# train Loss: 0.3898 Acc: 0.8205
# val Loss: 0.3876 Acc: 0.8244
#
# Epoch 2/4
# ----------
# train Loss: 0.3800 Acc: 0.8249
# val Loss: 0.3985 Acc: 0.8268
#
# Epoch 3/4
# ----------
# train Loss: 0.3788 Acc: 0.8208
# val Loss: 0.3955 Acc: 0.7924
#
# Epoch 4/4
# ----------
# train Loss: 0.3773 Acc: 0.8207
# val Loss: 0.4521 Acc: 0.8173
#
# Training complete in 5m 30s
# Best val Acc: 0.827068
# [[5797 1318]
#  [ 155  810]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4388 Acc: 0.8000
# val Loss: 0.4408 Acc: 0.7836
#
# Epoch 1/4
# ----------
# train Loss: 0.4883 Acc: 0.7600
# val Loss: 0.4363 Acc: 0.7474
#
# Epoch 2/4
# ----------
# train Loss: 0.4979 Acc: 0.7614
# val Loss: 0.5541 Acc: 0.6599
#
# Epoch 3/4
# ----------
# train Loss: 0.5169 Acc: 0.7413
# val Loss: 0.4464 Acc: 0.7607
#
# Epoch 4/4
# ----------
# train Loss: 0.5741 Acc: 0.7184
# val Loss: 1.2238 Acc: 0.5606
#
# Training complete in 4m 27s
# Best val Acc: 0.783598
# [[4913 2202]
#  [ 119  846]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4263 Acc: 0.7970
# val Loss: 0.7549 Acc: 0.7330
#
# Epoch 1/4
# ----------
# train Loss: 0.4716 Acc: 0.7773
# val Loss: 1.7610 Acc: 0.5156
#
# Epoch 2/4
# ----------
# train Loss: 0.4494 Acc: 0.7877
# val Loss: 0.6487 Acc: 0.7421
#
# Epoch 3/4
# ----------
# train Loss: 0.4376 Acc: 0.7939
# val Loss: 0.4396 Acc: 0.7884
#
# Epoch 4/4
# ----------
# train Loss: 0.5291 Acc: 0.7537
# val Loss: 1.3014 Acc: 0.4036
#
# Training complete in 4m 56s
# Best val Acc: 0.788373
# [[4857 2239]
#  [ 106  878]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4993 Acc: 0.7594
# val Loss: 3.4948 Acc: 0.5138
#
# Epoch 1/4
# ----------
# train Loss: 0.5804 Acc: 0.7104
# val Loss: 0.8680 Acc: 0.5479
#
# Epoch 2/4
# ----------
# train Loss: 0.5324 Acc: 0.7409
# val Loss: 0.7200 Acc: 0.6451
#
# Epoch 3/4
# ----------
# train Loss: 0.5223 Acc: 0.7484
# val Loss: 0.4542 Acc: 0.7703
#
# Epoch 4/4
# ----------
# train Loss: 0.4808 Acc: 0.7606
# val Loss: 0.5549 Acc: 0.7759
#
# Training complete in 5m 30s
# Best val Acc: 0.775894
# [[6280  867]
#  [ 305  628]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.99, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4079 Acc: 0.8055
# val Loss: 0.4112 Acc: 0.7942
#
# Epoch 1/4
# ----------
# train Loss: 0.3963 Acc: 0.8120
# val Loss: 0.3978 Acc: 0.8062
#
# Epoch 2/4
# ----------
# train Loss: 0.3892 Acc: 0.8164
# val Loss: 0.4036 Acc: 0.8154
#
# Epoch 3/4
# ----------
# train Loss: 0.3897 Acc: 0.8161
# val Loss: 0.3894 Acc: 0.8148
#
# Epoch 4/4
# ----------
# train Loss: 0.3808 Acc: 0.8232
# val Loss: 0.4004 Acc: 0.8267
#
# Training complete in 4m 26s
# Best val Acc: 0.826724
# [[5689 1458]
#  [ 133  800]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4062 Acc: 0.8105
# val Loss: 0.4016 Acc: 0.8145
#
# Epoch 1/4
# ----------
# train Loss: 0.4004 Acc: 0.8129
# val Loss: 0.3949 Acc: 0.8090
#
# Epoch 2/4
# ----------
# train Loss: 0.3916 Acc: 0.8146
# val Loss: 0.4045 Acc: 0.8095
#
# Epoch 3/4
# ----------
# train Loss: 0.3875 Acc: 0.8179
# val Loss: 0.3964 Acc: 0.8133
#
# Epoch 4/4
# ----------
# train Loss: 0.3910 Acc: 0.8161
# val Loss: 0.4040 Acc: 0.8225
#
# Training complete in 4m 58s
# Best val Acc: 0.822477
# [[5590 1557]
#  [ 128  805]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4345 Acc: 0.7963
# val Loss: 0.4398 Acc: 0.8026
#
# Epoch 1/4
# ----------
# train Loss: 0.4259 Acc: 0.7976
# val Loss: 0.4216 Acc: 0.7991
#
# Epoch 2/4
# ----------
# train Loss: 0.4243 Acc: 0.7991
# val Loss: 0.4370 Acc: 0.7866
#
# Epoch 3/4
# ----------
# train Loss: 0.4228 Acc: 0.8018
# val Loss: 0.4325 Acc: 0.7783
#
# Epoch 4/4
# ----------
# train Loss: 0.4144 Acc: 0.8093
# val Loss: 0.4215 Acc: 0.8096
#
# Training complete in 5m 32s
# Best val Acc: 0.809631
# [[5460 1687]
#  [ 135  798]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3934 Acc: 0.8195
# val Loss: 0.4120 Acc: 0.7896
#
# Epoch 1/4
# ----------
# train Loss: 0.3855 Acc: 0.8211
# val Loss: 0.3778 Acc: 0.8197
#
# Epoch 2/4
# ----------
# train Loss: 0.3863 Acc: 0.8231
# val Loss: 0.3954 Acc: 0.8235
#
# Epoch 3/4
# ----------
# train Loss: 0.3784 Acc: 0.8268
# val Loss: 0.4757 Acc: 0.8009
#
# Epoch 4/4
# ----------
# train Loss: 0.3766 Acc: 0.8282
# val Loss: 0.3989 Acc: 0.8051
#
# Training complete in 4m 26s
# Best val Acc: 0.823454
# [[5692 1453]
#  [ 140  795]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3977 Acc: 0.8158
# val Loss: 0.3903 Acc: 0.8095
#
# Epoch 1/4
# ----------
# train Loss: 0.3903 Acc: 0.8158
# val Loss: 0.3961 Acc: 0.8112
#
# Epoch 2/4
# ----------
# train Loss: 0.3878 Acc: 0.8184
# val Loss: 0.4013 Acc: 0.8154
#
# Epoch 3/4
# ----------
# train Loss: 0.3872 Acc: 0.8211
# val Loss: 0.3886 Acc: 0.8148
#
# Epoch 4/4
# ----------
# train Loss: 0.3806 Acc: 0.8222
# val Loss: 0.4005 Acc: 0.8195
#
# Training complete in 4m 55s
# Best val Acc: 0.819534
# [[5456 1691]
#  [ 116  817]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4231 Acc: 0.8035
# val Loss: 0.4429 Acc: 0.8058
#
# Epoch 1/4
# ----------
# train Loss: 0.4196 Acc: 0.8012
# val Loss: 1.0235 Acc: 0.5580
#
# Epoch 2/4
# ----------
# train Loss: 0.4141 Acc: 0.8059
# val Loss: 0.4763 Acc: 0.7485
#
# Epoch 3/4
# ----------
# train Loss: 0.4111 Acc: 0.8068
# val Loss: 0.6064 Acc: 0.7621
#
# Epoch 4/4
# ----------
# train Loss: 0.4061 Acc: 0.8122
# val Loss: 0.4447 Acc: 0.7885
#
# Training complete in 5m 30s
# Best val Acc: 0.805774
# [[5435 1680]
#  [ 147  818]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4537 Acc: 0.7840
# val Loss: 1.1534 Acc: 0.5903
#
# Epoch 1/4
# ----------
# train Loss: 0.4873 Acc: 0.7617
# val Loss: 0.4557 Acc: 0.8092
#
# Epoch 2/4
# ----------
# train Loss: 0.4370 Acc: 0.7976
# val Loss: 1.8563 Acc: 0.5407
#
# Epoch 3/4
# ----------
# train Loss: 0.4455 Acc: 0.7900
# val Loss: 0.4287 Acc: 0.7852
#
# Epoch 4/4
# ----------
# train Loss: 0.4496 Acc: 0.7929
# val Loss: 0.5112 Acc: 0.7806
#
# Training complete in 4m 27s
# Best val Acc: 0.809164
# [[5770 1368]
#  [ 179  763]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.4223 Acc: 0.8016
# val Loss: 0.4606 Acc: 0.7792
#
# Epoch 1/4
# ----------
# train Loss: 0.4480 Acc: 0.7889
# val Loss: 0.4378 Acc: 0.7973
#
# Epoch 2/4
# ----------
# train Loss: 0.4229 Acc: 0.7969
# val Loss: 0.4343 Acc: 0.8121
#
# Epoch 3/4
# ----------
# train Loss: 0.4382 Acc: 0.7972
# val Loss: 0.5696 Acc: 0.7169
#
# Epoch 4/4
# ----------
# train Loss: 0.4976 Acc: 0.7716
# val Loss: 1.2609 Acc: 0.5176
#
# Training complete in 5m 0s
# Best val Acc: 0.812139
# [[6134 1011]
#  [ 219  716]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4821 Acc: 0.7665
# val Loss: 0.4983 Acc: 0.7824
#
# Epoch 1/4
# ----------
# train Loss: 0.4432 Acc: 0.7880
# val Loss: 0.8386 Acc: 0.7347
#
# Epoch 2/4
# ----------
# train Loss: 0.4872 Acc: 0.7658
# val Loss: 0.6345 Acc: 0.7184
#
# Epoch 3/4
# ----------
# train Loss: 0.4548 Acc: 0.7808
# val Loss: 2.6967 Acc: 0.4715
#
# Epoch 4/4
# ----------
# train Loss: 0.5011 Acc: 0.7644
# val Loss: 0.5933 Acc: 0.7384
#
# Training complete in 5m 30s
# Best val Acc: 0.782441
# [[5973 1142]
#  [ 265  700]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.1, 'Momentum': 0.99, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4084 Acc: 0.8032
# val Loss: 0.3960 Acc: 0.8117
#
# Epoch 1/4
# ----------
# train Loss: 0.3969 Acc: 0.8084
# val Loss: 0.4125 Acc: 0.7992
#
# Epoch 2/4
# ----------
# train Loss: 0.3921 Acc: 0.8165
# val Loss: 0.4057 Acc: 0.8116
#
# Epoch 3/4
# ----------
# train Loss: 0.3878 Acc: 0.8142
# val Loss: 0.4081 Acc: 0.7936
#
# Epoch 4/4
# ----------
# train Loss: 0.3842 Acc: 0.8203
# val Loss: 0.4070 Acc: 0.8185
#
# Training complete in 4m 27s
# Best val Acc: 0.818503
# [[5357 1790]
#  [ 105  828]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3967 Acc: 0.8172
# val Loss: 0.3899 Acc: 0.8185
#
# Epoch 1/4
# ----------
# train Loss: 0.3867 Acc: 0.8207
# val Loss: 0.3974 Acc: 0.8087
#
# Epoch 2/4
# ----------
# train Loss: 0.3847 Acc: 0.8198
# val Loss: 0.3933 Acc: 0.8158
#
# Epoch 3/4
# ----------
# train Loss: 0.3797 Acc: 0.8229
# val Loss: 0.3871 Acc: 0.8152
#
# Epoch 4/4
# ----------
# train Loss: 0.3770 Acc: 0.8249
# val Loss: 0.3987 Acc: 0.8236
#
# Training complete in 4m 58s
# Best val Acc: 0.823639
# [[5530 1617]
#  [ 118  815]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4309 Acc: 0.7965
# val Loss: 0.4306 Acc: 0.7967
#
# Epoch 1/4
# ----------
# train Loss: 0.4264 Acc: 0.7971
# val Loss: 0.4222 Acc: 0.8095
#
# Epoch 2/4
# ----------
# train Loss: 0.4162 Acc: 0.8014
# val Loss: 0.4275 Acc: 0.7885
#
# Epoch 3/4
# ----------
# train Loss: 0.4118 Acc: 0.8018
# val Loss: 0.4485 Acc: 0.7547
#
# Epoch 4/4
# ----------
# train Loss: 0.4070 Acc: 0.8092
# val Loss: 0.4332 Acc: 0.8161
#
# Training complete in 5m 31s
# Best val Acc: 0.816127
# [[5775 1372]
#  [ 164  769]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.5, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.3960 Acc: 0.8166
# val Loss: 0.3840 Acc: 0.8221
#
# Epoch 1/4
# ----------
# train Loss: 0.3943 Acc: 0.8181
# val Loss: 0.3943 Acc: 0.8157
#
# Epoch 2/4
# ----------
# train Loss: 0.3889 Acc: 0.8202
# val Loss: 0.4016 Acc: 0.8118
#
# Epoch 3/4
# ----------
# train Loss: 0.3787 Acc: 0.8240
# val Loss: 0.3936 Acc: 0.8122
#
# Epoch 4/4
# ----------
# train Loss: 0.3787 Acc: 0.8226
# val Loss: 0.3938 Acc: 0.8233
#
# Training complete in 4m 27s
# Best val Acc: 0.823271
# [[5226 1921]
#  [  79  854]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.3864 Acc: 0.8197
# val Loss: 0.3827 Acc: 0.8184
#
# Epoch 1/4
# ----------
# train Loss: 0.3816 Acc: 0.8246
# val Loss: 0.3896 Acc: 0.8236
#
# Epoch 2/4
# ----------
# train Loss: 0.3809 Acc: 0.8192
# val Loss: 0.3998 Acc: 0.8110
#
# Epoch 3/4
# ----------
# train Loss: 0.3741 Acc: 0.8268
# val Loss: 0.4373 Acc: 0.8161
#
# Epoch 4/4
# ----------
# train Loss: 0.3714 Acc: 0.8259
# val Loss: 0.4177 Acc: 0.7899
#
# Training complete in 4m 57s
# Best val Acc: 0.823649
# [[5704 1434]
#  [ 143  799]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4163 Acc: 0.8026
# val Loss: 0.4211 Acc: 0.8140
#
# Epoch 1/4
# ----------
# train Loss: 0.4128 Acc: 0.8043
# val Loss: 0.4181 Acc: 0.7859
#
# Epoch 2/4
# ----------
# train Loss: 0.4076 Acc: 0.8084
# val Loss: 0.4389 Acc: 0.7681
#
# Epoch 3/4
# ----------
# train Loss: 0.4021 Acc: 0.8095
# val Loss: 0.4170 Acc: 0.8226
#
# Epoch 4/4
# ----------
# train Loss: 0.4003 Acc: 0.8102
# val Loss: 0.4054 Acc: 0.8121
#
# Training complete in 5m 29s
# Best val Acc: 0.822589
# [[5732 1364]
#  [ 160  824]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.9, 'Model': 'model50'}
# Epoch 0/4
# ----------
# train Loss: 0.4338 Acc: 0.7977
# val Loss: 0.5348 Acc: 0.7958
#
# Epoch 1/4
# ----------
# train Loss: 0.4830 Acc: 0.7714
# val Loss: 0.7894 Acc: 0.6927
#
# Epoch 2/4
# ----------
# train Loss: 0.5130 Acc: 0.7507
# val Loss: 1.2813 Acc: 0.5170
#
# Epoch 3/4
# ----------
# train Loss: 0.5050 Acc: 0.7565
# val Loss: 0.6251 Acc: 0.7708
#
# Epoch 4/4
# ----------
# train Loss: 0.4963 Acc: 0.7549
# val Loss: 0.6506 Acc: 0.7625
#
# Training complete in 4m 28s
# Best val Acc: 0.795806
# [[4954 2161]
#  [ 101  864]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model18'}
# Epoch 0/4
# ----------
# train Loss: 0.5343 Acc: 0.7659
# val Loss: 0.7497 Acc: 0.5148
#
# Epoch 1/4
# ----------
# train Loss: 0.5074 Acc: 0.7555
# val Loss: 0.5394 Acc: 0.7306
#
# Epoch 2/4
# ----------
# train Loss: 1.5536 Acc: 0.7413
# val Loss: 4166.0415 Acc: 0.5000
#
# Epoch 3/4
# ----------
# train Loss: 3.0224 Acc: 0.5043
# val Loss: 4.8880 Acc: 0.4899
#
# Epoch 4/4
# ----------
# train Loss: 8.5263 Acc: 0.4946
# val Loss: 284.8869 Acc: 0.4813
#
# Training complete in 5m 2s
# Best val Acc: 0.730571
# [[3572 3566]
#  [  37  905]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model34'}
# Epoch 0/4
# ----------
# train Loss: 0.4557 Acc: 0.7872
# val Loss: 0.9874 Acc: 0.5148
#
# Epoch 1/4
# ----------
# train Loss: 0.4593 Acc: 0.7745
# val Loss: 0.4454 Acc: 0.7890
#
# Epoch 2/4
# ----------
# train Loss: 0.4417 Acc: 0.7898
# val Loss: 0.6490 Acc: 0.6477
#
# Epoch 3/4
# ----------
# train Loss: 0.4296 Acc: 0.7946
# val Loss: 0.6386 Acc: 0.7840
#
# Epoch 4/4
# ----------
# train Loss: 0.4649 Acc: 0.7776
# val Loss: 0.4639 Acc: 0.7375
#
# Training complete in 5m 34s
# Best val Acc: 0.788961
# [[5474 1664]
#  [ 178  764]]
# Current hyperparameters: {'learning rate': 0.2, 'gamma': 0.5, 'Momentum': 0.99, 'Model': 'model50'}
# Best hyperparameters: {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model18'}
# Best score: 0.83293796

# %%
#cf_matrix = confusion_matrix_calc(data_loader_test, labels, model_ft)

# %%
# !kill 8488
# Out:
# /bin/dash: 1: kill: No such process

# %%
# %tensorboard --logdir Experiments/undersampledrug2
# Out:
#       <iframe id="tensorboard-frame-c14896db05ac79bf" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-c14896db05ac79bf");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
print(best_params)
best_score
# Out:
# {'learning rate': 0.2, 'gamma': 0.05, 'Momentum': 0.9, 'Model': 'model18'}
# array(0.83293796, dtype=float32)
